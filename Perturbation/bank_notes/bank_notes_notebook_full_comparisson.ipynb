# %% [markdown]
# ## Loading data

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/bank_notes/plsda/bank_notes.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '1':'26.07']

# %%
# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1':'26.07'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1':'26.07'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# 2026-01-24 10:32:39,126 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
#
# 2026-01-24 10:32:39,130 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
# 2026-01-24 10:32:39,183 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
#
# 2026-01-24 10:32:39,187 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.

# %%
# PLS-DA with optimized latent variables
from modeling import pls_optimized

plsda_results = pls_optimized(
    Xcalclass_prep, 
    ycalclass,
    LVmax=4,
    Xpred=Xpredclass_prep,
    ypred=ypredclass,
    aim='classification',
    cv=10
)

# Convenience references used later
pls_model = plsda_results[3]               # fitted PLS model
vip_scores_mat = plsda_results[4]          # VIP scores matrix (features × LV)
y_pred_cont = plsda_results[5].iloc[:, -1] # continuous predictions for Xcalclass (used for MI/Cov)

# plotando o vip scores rapidamente
vip_scores_mat.T.plot()

# %%
# calculando a covariancia entre cada variável espectral e a predição do modelo PLS-DA
cov_scores = []
y_pred = plsda_results[5].iloc[:,-1].values # using the continuous predictions from LV=3
for col in Xcalclass_prep.columns:
    x_values = Xcalclass_prep[col].values
    covariance = np.cov(x_values, y_pred)[0, 1] # covariance between x and y
    cov_scores.append(covariance)
cov_scores_df = pd.DataFrame(cov_scores, index=Xcalclass_prep.columns, columns=['Covariance'])
cov_scores_df = np.abs(cov_scores_df)
cov_scores_df.plot()

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('background1', 1.0, 2.74),
('Ar ka + Ag L', 2.76, 3.47),
('Ca ka', 3.5, 3.91),
('Ca kb', 3.93, 4.24),
('Ti ka', 4.26, 4.72),
('Ti kb', 4.75, 5.13),
('background2', 5.16, 6.12),
('Fe ka', 6.15, 6.76),
('Fe kb', 6.79, 7.32),
('background3', 7.35, 7.78),
('Cu ka', 7.81, 8.29),
('Zn ka', 8.29, 8.80),
('Cu kb', 8.80, 9.26),
('Zn kb', 9.26, 10.00),
('background4', 10.00, 21.46),
('Ag ka scattering', 21.49, 22.71),
('background5', 22.74, 24.52),
('background6', 24.55, 26.07),
]

import explaining as exp
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_sums_df = exp.aggregate_spectral_zones(spectral_zones_class, aggregator='extreme')
predicates_quantiles = exp.predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8])
co_occurrence_matrix_df = predicates_quantiles[2]
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=y_pred_cont
)

# %% [markdown]
# ## VIP, Regression Coefficients e SHAP (como no original)

# %%
# VIP scores por energia
vip_scores_df = pd.DataFrame({
    'energy': vip_scores_mat.T.index,
    'VIP_Score': vip_scores_mat.T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in vip_scores_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip)
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# Coeficientes de regressão do PLS
reg_vet = pd.DataFrame(pls_model.coef_, columns=pls_model.feature_names_in_).T
reg_vet.insert(0, 'energy', reg_vet.index)
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy','Reg_coef']
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs()
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
energy_to_zone_reg = {}
for zone_name, start, end in spectral_cuts:
    for e in reg_vet['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_reg[e] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg)
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
shap_unique_df = pd.read_csv('shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df

# %% [markdown]
# # **bagging - covariance**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graph(
        bags_result=all_results_cov[seed]['bags_result'],
        mi_results_dict=all_results_cov[seed]['cov_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 91
# Removida aresta Ca ka > -9.12 -> Ca ka > -11.34 (peso 680.0)
# Mantida aresta Ca ka > -11.34 -> Ca ka > -9.12 (peso 1020.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -3.71 -> Fe kb > -3.35 (peso 53.0)
# Mantida aresta Fe kb > -3.35 -> Ca ka > -3.71 (peso 477.0)
#
# ======================================================================
#
# Removida aresta Ti ka > -11.81 -> Ti ka <= 9.71 (peso 504.0)
# Mantida aresta Ti ka <= 9.71 -> Ti ka > -11.81 (peso 840.0)
#
# ======================================================================
#
# Removida aresta Fe kb > -3.54 -> Ti ka > -11.81 (peso 260.0)
# Mantida aresta Ti ka > -11.81 -> Fe kb > -3.54 (peso 650.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 5.26 -> Fe kb > -3.78 (peso 143.0)
# Mantida aresta Fe kb > -3.78 -> Ti ka <= 5.26 (peso 1287.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -4.15 -> Ca kb > -3.42 (peso 680.0)
# Mantida aresta Ca kb > -3.42 -> Ca kb > -4.15 (peso 1020.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka > -4.62 -> Ti kb > -4.43 (peso 378.0)
# Mantida aresta Ti kb > -4.43 -> Cu ka > -4.62 (peso 378.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > -2.18 -> Ti kb > -4.43 (peso 128.0)
# Mantida aresta Ti kb > -4.43 -> Ca kb > -2.18 (peso 128.0)
#
# ======================================================================
#
# Removida aresta Ti kb > -4.43 -> Cu ka > -4.31 (peso 149.0)
# Mantida aresta Cu ka > -4.31 -> Ti kb > -4.43 (peso 298.0)
#
# ======================================================================
#
# Removida aresta Cu ka > -4.62 -> Cu ka > -3.81 (peso 114.0)
# Mantida aresta Cu ka > -3.81 -> Cu ka > -4.62 (peso 570.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > -2.18 -> Ca ka <= 15.99 (peso 56.0)
# Mantida aresta Ca ka <= 15.99 -> Ca kb > -2.18 (peso 56.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -2.18 -> Cu ka > -4.31 (peso 58.0)
# Mantida aresta Cu ka > -4.31 -> Ca kb > -2.18 (peso 116.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > -2.18 -> Ti kb <= 5.00 (peso 436.0)
# Mantida aresta Ti kb <= 5.00 -> Ca kb > -2.18 (peso 436.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 2.64 -> Ti ka > -3.08 (peso 60.0)
# Mantida aresta Ti ka > -3.08 -> Ti kb <= 2.64 (peso 540.0)
#
# ======================================================================
#
# Removida aresta Cu kb > -1.94 -> Ti ka > 5.26 (peso 146.0)
# Mantida aresta Ti ka > 5.26 -> Cu kb > -1.94 (peso 365.0)
#
# ======================================================================
#
# Removida aresta Cu kb > -1.94 -> Ca kb <= 6.30 (peso 270.0)
# Mantida aresta Ca kb <= 6.30 -> Cu kb > -1.94 (peso 540.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 6.30 -> Cu kb > 1.49 (peso 96.0)
# Mantida aresta Cu kb > 1.49 -> Ca kb <= 6.30 (peso 96.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 6.30 -> Ti kb > -2.36 (peso 170.0)
# Mantida aresta Ti kb > -2.36 -> Ca kb <= 6.30 (peso 510.0)
#
# ======================================================================
#
# Removida aresta Cu kb > -2.22 -> Ti kb > -2.36 (peso 292.0)
# Mantida aresta Ti kb > -2.36 -> Cu kb > -2.22 (peso 438.0)
#
# ======================================================================
#
# Removida aresta Ti kb > -2.36 -> Cu kb > 1.49 (peso 82.0)
# Mantida aresta Cu kb > 1.49 -> Ti kb > -2.36 (peso 164.0)
#
# ======================================================================
#
# Removida aresta Cu kb > 1.49 -> Ti ka <= -3.08 (peso 60.0)
# Mantida aresta Ti ka <= -3.08 -> Cu kb > 1.49 (peso 150.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -1.99 -> Zn ka <= 2.74 (peso 340.0)
# Mantida aresta Zn ka <= 2.74 -> Zn ka > -1.99 (peso 850.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 2.64 -> Zn ka <= 2.74 (peso 81.0)
# Mantida aresta Zn ka <= 2.74 -> Ti kb > 2.64 (peso 162.0)
#
# ======================================================================
#
# Removida aresta background5 <= 2.48 -> Ti kb > 2.64 (peso 59.0)
# Mantida aresta Ti kb > 2.64 -> background5 <= 2.48 (peso 118.0)
#
# ======================================================================
#
# Removida aresta background2 <= 2.59 -> Ti kb > 2.64 (peso 53.0)
# Mantida aresta Ti kb > 2.64 -> background2 <= 2.59 (peso 106.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 2.89 -> Ti kb > 2.64 (peso 44.0)
# Mantida aresta Ti kb > 2.64 -> background4 <= 2.89 (peso 44.0)
#
# ======================================================================
#
# Removida aresta background5 <= 2.88 -> background5 <= 2.48 (peso 344.0)
# Mantida aresta background5 <= 2.48 -> background5 <= 2.88 (peso 860.0)
#
# ======================================================================
#
# Removida aresta background5 <= 2.48 -> background2 <= 2.59 (peso 102.0)
# Mantida aresta background2 <= 2.59 -> background5 <= 2.48 (peso 204.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 2.48 -> background4 <= 2.89 (peso 80.0)
# Mantida aresta background4 <= 2.89 -> background5 <= 2.48 (peso 80.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 3.28 -> background5 <= 2.88 (peso 360.0)
# Mantida aresta background5 <= 2.88 -> background2 <= 3.28 (peso 360.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.24 -> background5 <= 2.88 (peso 138.0)
# Mantida aresta background5 <= 2.88 -> background4 <= 3.24 (peso 138.0)
#
# ======================================================================
#
# Removida aresta Zn ka <= 2.18 -> background2 <= 3.28 (peso 141.0)
# Mantida aresta background2 <= 3.28 -> Zn ka <= 2.18 (peso 282.0)
#
# ======================================================================
#
# Removida aresta background2 > -2.08 -> Zn ka <= 2.18 (peso 129.0)
# Mantida aresta Zn ka <= 2.18 -> background2 > -2.08 (peso 258.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka <= 2.18 -> background2 <= 2.59 (peso 111.0)
# Mantida aresta background2 <= 2.59 -> Zn ka <= 2.18 (peso 111.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > -2.43 -> Ag ka scattering <= 2.57 (peso 127.0)
# Mantida aresta Ag ka scattering <= 2.57 -> background6 > -2.43 (peso 127.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.59 -> Ag ka scattering <= 3.08 (peso 133.0)
# Mantida aresta Ag ka scattering <= 3.08 -> background2 <= 2.59 (peso 133.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3.08 -> background2 > -2.08 (peso 181.0)
# Mantida aresta background2 > -2.08 -> Ag ka scattering <= 3.08 (peso 362.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.53 -> Ag ka scattering <= 3.08 (peso 139.0)
# Mantida aresta Ag ka scattering <= 3.08 -> background1 <= 2.53 (peso 139.0)
#
# ======================================================================
#
# Removida aresta background6 <= 2.28 -> background2 > -2.08 (peso 91.0)
# Mantida aresta background2 > -2.08 -> background6 <= 2.28 (peso 182.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= -3.71 -> background2 > -2.08 (peso 141.0)
# Mantida aresta background2 > -2.08 -> Ca ka <= -3.71 (peso 141.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.28 -> background4 <= 3.24 (peso 73.0)
# Mantida aresta background4 <= 3.24 -> background6 <= 2.28 (peso 73.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.28 -> Ag ka scattering <= -1.94 (peso 68.0)
# Mantida aresta Ag ka scattering <= -1.94 -> background6 <= 2.28 (peso 68.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> Ca ka <= -3.71 (peso 137.0)
# Mantida aresta Ca ka <= -3.71 -> background5 > -2.53 (peso 137.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.46 -> background5 > -2.53 (peso 141.0)
# Mantida aresta background5 > -2.53 -> Zn ka > -1.46 (peso 141.0)
#
# ======================================================================
#
# Removida aresta background4 <= 2.89 -> Ca ka <= -3.71 (peso 79.0)
# Mantida aresta Ca ka <= -3.71 -> background4 <= 2.89 (peso 158.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.54 -> background4 <= 2.89 (peso 115.0)
# Mantida aresta background4 <= 2.89 -> background4 <= 3.54 (peso 115.0)
#
# ======================================================================
#
# Removida aresta background4 <= 3.54 -> background4 <= 3.24 (peso 171.0)
# Mantida aresta background4 <= 3.24 -> background4 <= 3.54 (peso 342.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -1.46 -> Ag ka scattering <= -1.94 (peso 68.0)
# Mantida aresta Ag ka scattering <= -1.94 -> Zn ka > -1.46 (peso 136.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > -2.43 -> Zn ka > -1.46 (peso 138.0)
# Mantida aresta Zn ka > -1.46 -> background6 > -2.43 (peso 138.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.16 -> Zn ka > -1.46 (peso 59.0)
# Mantida aresta Zn ka > -1.46 -> background2 <= 2.16 (peso 59.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 1.70 -> Ag ka scattering <= -1.94 (peso 42.0)
# Mantida aresta Ag ka scattering <= -1.94 -> background3 <= 1.70 (peso 42.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 1.70 -> Ti kb <= -2.36 (peso 49.0)
# Mantida aresta Ti kb <= -2.36 -> background3 <= 1.70 (peso 49.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.22 -> Ti kb <= -2.36 (peso 44.0)
# Mantida aresta Ti kb <= -2.36 -> background1 <= 2.22 (peso 44.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > -2.84 -> Ti kb <= -2.36 (peso 82.0)
# Mantida aresta Ti kb <= -2.36 -> Ag ka scattering > -2.84 (peso 164.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= -2.36 -> background1 > -2.42 (peso 92.0)
# Mantida aresta background1 > -2.42 -> Ti kb <= -2.36 (peso 92.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 3.00 -> background6 > -2.43 (peso 174.0)
# Mantida aresta background6 > -2.43 -> background1 <= 3.00 (peso 174.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= -9.12 -> background6 <= 2.71 (peso 70.0)
# Mantida aresta background6 <= 2.71 -> Ca ka <= -9.12 (peso 70.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -2.19 -> Ca ka <= -9.12 (peso 113.0)
# Mantida aresta Ca ka <= -9.12 -> Cu ka <= -2.19 (peso 113.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.16 -> background6 <= 2.71 (peso 64.0)
# Mantida aresta background6 <= 2.71 -> background2 <= 2.16 (peso 64.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.16 -> background6 <= 3.20 (peso 86.0)
# Mantida aresta background6 <= 3.20 -> background2 <= 2.16 (peso 86.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 3.20 -> background3 <= 2.47 (peso 184.0)
# Mantida aresta background3 <= 2.47 -> background6 <= 3.20 (peso 184.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > -2.42 -> background4 > -3.06 (peso 186.0)
# Mantida aresta background4 > -3.06 -> background1 > -2.42 (peso 186.0)
#
# ======================================================================
#
# Removida aresta background1 > -2.42 -> Cu kb <= 2.72 (peso 187.0)
# Mantida aresta Cu kb <= 2.72 -> background1 > -2.42 (peso 374.0)
#
# ======================================================================
#
# Removida aresta background1 <= 3.00 -> background1 <= 2.53 (peso 171.0)
# Mantida aresta background1 <= 2.53 -> background1 <= 3.00 (peso 342.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -2.19 -> Zn kb <= 1.87 (peso 93.0)
# Mantida aresta Zn kb <= 1.87 -> Cu ka <= -2.19 (peso 93.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 2.47 -> Cu ka <= -2.19 (peso 185.0)
# Mantida aresta Cu ka <= -2.19 -> background3 <= 2.47 (peso 185.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 1.87 -> Cu kb <= 2.72 (peso 94.0)
# Mantida aresta Cu kb <= 2.72 -> Zn kb <= 1.87 (peso 94.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= 2.72 -> Ar ka + Ag L <= 2.08 (peso 131.0)
# Mantida aresta Ar ka + Ag L <= 2.08 -> Cu kb <= 2.72 (peso 131.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= -2.18 -> Cu kb <= 2.72 (peso 138.0)
# Mantida aresta Cu kb <= 2.72 -> Ca kb <= -2.18 (peso 138.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.80 -> Ar ka + Ag L <= 2.47 (peso 86.0)
# Mantida aresta Ar ka + Ag L <= 2.47 -> Fe ka <= -9.80 (peso 86.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 2.57 -> background5 <= 2.03 (peso 38.0)
# Mantida aresta background5 <= 2.03 -> Ag ka scattering > 2.57 (peso 38.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 3.24 -> Ar ka + Ag L > -1.64 (peso 77.0)
# Mantida aresta Ar ka + Ag L > -1.64 -> background4 > 3.24 (peso 77.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 2.09 -> Zn ka > 2.18 (peso 52.0)
# Mantida aresta Zn ka > 2.18 -> background3 > 2.09 (peso 52.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 2.09 -> background3 <= 2.47 (peso 59.0)
# Mantida aresta background3 <= 2.47 -> background3 > 2.09 (peso 59.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -3.81 -> Zn ka > 2.18 (peso 45.0)
# Mantida aresta Zn ka > 2.18 -> Cu ka <= -3.81 (peso 45.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 2.47 -> Ca kb <= -3.42 (peso 96.0)
# Mantida aresta Ca kb <= -3.42 -> background3 <= 2.47 (peso 96.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 2.57 -> Ca kb <= -3.42 (peso 42.0)
# Mantida aresta Ca kb <= -3.42 -> Ag ka scattering > 2.57 (peso 42.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 3.24 -> Ca kb <= -3.42 (peso 37.0)
# Mantida aresta Ca kb <= -3.42 -> background4 > 3.24 (peso 37.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= -3.42 -> background4 > 2.89 (peso 57.0)
# Mantida aresta background4 > 2.89 -> Ca kb <= -3.42 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -3.81 -> background4 > 3.24 (peso 69.0)
# Mantida aresta background4 > 3.24 -> Cu ka <= -3.81 (peso 69.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -3.81 -> background6 > 2.28 (peso 96.0)
# Mantida aresta background6 > 2.28 -> Cu ka <= -3.81 (peso 96.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 2.89 -> background6 > 2.28 (peso 108.0)
# Mantida aresta background6 > 2.28 -> background4 > 2.89 (peso 108.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > -2.22 -> background6 > 2.71 (peso 87.0)
# Mantida aresta background6 > 2.71 -> Ar ka + Ag L > -2.22 (peso 87.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > -1.63 -> Ag ka scattering > -1.94 (peso 135.0)
# Mantida aresta Ag ka scattering > -1.94 -> background3 > -1.63 (peso 135.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > -1.63 -> background3 <= 2.09 (peso 113.0)
# Mantida aresta background3 <= 2.09 -> background3 > -1.63 (peso 113.0)
#
# ======================================================================
#
# Removida aresta Zn kb > 2.27 -> background2 > 2.16 (peso 60.0)
# Mantida aresta background2 > 2.16 -> Zn kb > 2.27 (peso 120.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.28 -> background2 > 2.16 (peso 100.0)
# Mantida aresta background2 > 2.16 -> background6 > 2.28 (peso 100.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 2.09 -> Zn kb <= 2.73 (peso 134.0)
# Mantida aresta Zn kb <= 2.73 -> background3 <= 2.09 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > 2.53 -> background5 > 2.03 (peso 65.0)
# Mantida aresta background5 > 2.03 -> background1 > 2.53 (peso 65.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= -9.53 -> background2 > 2.59 (peso 61.0)
# Mantida aresta background2 > 2.59 -> Fe ka <= -9.53 (peso 122.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.53 -> background6 > 2.28 (peso 100.0)
# Mantida aresta background6 > 2.28 -> Fe ka <= -9.53 (peso 100.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 660
# Total de arestas removidas por bidirecionalidade: 91
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 107
# Total de nós terminais: 2
#
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 97
# Removida aresta Ca ka > -11.34 -> Fe ka > -10.00 (peso 184.0)
# Mantida aresta Fe ka > -10.00 -> Ca ka > -11.34 (peso 1104.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -9.12 -> Ca ka > -11.34 (peso 680.0)
# Mantida aresta Ca ka > -11.34 -> Ca ka > -9.12 (peso 850.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -3.71 -> Fe kb > -3.35 (peso 53.0)
# Mantida aresta Fe kb > -3.35 -> Ca ka > -3.71 (peso 477.0)
#
# ======================================================================
#
# Removida aresta Ti ka > -11.81 -> Ti ka <= 9.71 (peso 672.0)
# Mantida aresta Ti ka <= 9.71 -> Ti ka > -11.81 (peso 1008.0)
#
# ======================================================================
#
# Removida aresta Fe kb > -3.54 -> Ti ka <= 9.71 (peso 282.0)
# Mantida aresta Ti ka <= 9.71 -> Fe kb > -3.54 (peso 564.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 5.26 -> Fe kb > -3.78 (peso 143.0)
# Mantida aresta Fe kb > -3.78 -> Ti ka <= 5.26 (peso 858.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb > -3.78 -> Ca kb > -4.15 (peso 192.0)
# Mantida aresta Ca kb > -4.15 -> Fe kb > -3.78 (peso 192.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -3.42 -> Ti ka <= 5.26 (peso 226.0)
# Mantida aresta Ti ka <= 5.26 -> Ca kb > -3.42 (peso 452.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -4.15 -> Ti ka <= 5.26 (peso 136.0)
# Mantida aresta Ti ka <= 5.26 -> Ca kb > -4.15 (peso 408.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -4.15 -> Ca kb > -3.42 (peso 510.0)
# Mantida aresta Ca kb > -3.42 -> Ca kb > -4.15 (peso 1020.0)
#
# ======================================================================
#
# Removida aresta Cu ka > -4.62 -> Ti kb > -4.43 (peso 189.0)
# Mantida aresta Ti kb > -4.43 -> Cu ka > -4.62 (peso 567.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -2.18 -> Cu ka > -4.62 (peso 85.0)
# Mantida aresta Cu ka > -4.62 -> Ca kb > -2.18 (peso 170.0)
#
# ======================================================================
#
# Removida aresta Cu ka > -4.31 -> Ti kb <= 5.00 (peso 264.0)
# Mantida aresta Ti kb <= 5.00 -> Cu ka > -4.31 (peso 396.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 15.99 -> Ti kb > -4.43 (peso 204.0)
# Mantida aresta Ti kb > -4.43 -> Ca ka <= 15.99 (peso 408.0)
#
# ======================================================================
#
# Removida aresta Ti ka > -3.08 -> Ca ka <= 15.99 (peso 170.0)
# Mantida aresta Ca ka <= 15.99 -> Ti ka > -3.08 (peso 680.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 15.99 -> Ti kb <= 5.00 (peso 340.0)
# Mantida aresta Ti kb <= 5.00 -> Ca ka <= 15.99 (peso 680.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > -2.18 -> Ti kb <= 5.00 (peso 327.0)
# Mantida aresta Ti kb <= 5.00 -> Ca kb > -2.18 (peso 327.0)
#
# ======================================================================
#
# Removida aresta Cu kb > -1.94 -> Ti ka > 5.26 (peso 73.0)
# Mantida aresta Ti ka > 5.26 -> Cu kb > -1.94 (peso 365.0)
#
# ======================================================================
#
# Removida aresta Cu kb > -1.94 -> Ca kb <= 6.30 (peso 135.0)
# Mantida aresta Ca kb <= 6.30 -> Cu kb > -1.94 (peso 540.0)
#
# ======================================================================
#
# Removida aresta Ti kb > -2.36 -> Ca kb <= 6.30 (peso 170.0)
# Mantida aresta Ca kb <= 6.30 -> Ti kb > -2.36 (peso 340.0)
#
# ======================================================================
#
# Removida aresta Cu kb > -2.22 -> Ti kb > -2.36 (peso 292.0)
# Mantida aresta Ti kb > -2.36 -> Cu kb > -2.22 (peso 584.0)
#
# ======================================================================
#
# Removida aresta Cu kb > 1.49 -> Cu kb > -2.22 (peso 114.0)
# Mantida aresta Cu kb > -2.22 -> Cu kb > 1.49 (peso 228.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= -3.08 -> Cu kb > -2.22 (peso 92.0)
# Mantida aresta Cu kb > -2.22 -> Ti ka <= -3.08 (peso 184.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > -2.36 -> Cu kb > 1.49 (peso 164.0)
# Mantida aresta Cu kb > 1.49 -> Ti kb > -2.36 (peso 164.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > -2.36 -> Ti ka <= -3.08 (peso 14.0)
# Mantida aresta Ti ka <= -3.08 -> Ti kb > -2.36 (peso 14.0)
#
# ======================================================================
#
# Removida aresta Cu kb > 1.49 -> Ti ka <= -3.08 (peso 60.0)
# Mantida aresta Ti ka <= -3.08 -> Cu kb > 1.49 (peso 90.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.99 -> background2 <= 3.28 (peso 358.0)
# Mantida aresta background2 <= 3.28 -> Zn ka > -1.99 (peso 358.0)
#
# ======================================================================
#
# Removida aresta Zn ka <= 2.74 -> Zn ka > -1.99 (peso 340.0)
# Mantida aresta Zn ka > -1.99 -> Zn ka <= 2.74 (peso 680.0)
#
# ======================================================================
#
# Removida aresta background2 <= 3.28 -> Zn ka <= 2.74 (peso 186.0)
# Mantida aresta Zn ka <= 2.74 -> background2 <= 3.28 (peso 558.0)
#
# ======================================================================
#
# Removida aresta background5 <= 2.88 -> Ti kb > 2.64 (peso 166.0)
# Mantida aresta Ti kb > 2.64 -> background5 <= 2.88 (peso 249.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 2.64 -> Zn ka <= 2.74 (peso 81.0)
# Mantida aresta Zn ka <= 2.74 -> Ti kb > 2.64 (peso 81.0)
#
# ======================================================================
#
# Removida aresta background5 <= 2.88 -> background5 <= 2.48 (peso 344.0)
# Mantida aresta background5 <= 2.48 -> background5 <= 2.88 (peso 516.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 2.88 -> background2 <= 2.59 (peso 137.0)
# Mantida aresta background2 <= 2.59 -> background5 <= 2.88 (peso 137.0)
#
# ======================================================================
#
# Removida aresta Zn ka <= 2.74 -> background5 <= 2.48 (peso 142.0)
# Mantida aresta background5 <= 2.48 -> Zn ka <= 2.74 (peso 284.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 2.48 -> background2 <= 2.59 (peso 102.0)
# Mantida aresta background2 <= 2.59 -> background5 <= 2.48 (peso 102.0)
#
# ======================================================================
#
# Removida aresta background4 <= 2.89 -> Ca ka <= -3.71 (peso 79.0)
# Mantida aresta Ca ka <= -3.71 -> background4 <= 2.89 (peso 237.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 2.89 -> background2 <= 2.59 (peso 71.0)
# Mantida aresta background2 <= 2.59 -> background4 <= 2.89 (peso 71.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > -2.08 -> Ag ka scattering <= 3.08 (peso 181.0)
# Mantida aresta Ag ka scattering <= 3.08 -> background2 > -2.08 (peso 181.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3.08 -> background1 > -2.42 (peso 182.0)
# Mantida aresta background1 > -2.42 -> Ag ka scattering <= 3.08 (peso 182.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.59 -> background2 > -2.08 (peso 111.0)
# Mantida aresta background2 > -2.08 -> background2 <= 2.59 (peso 111.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= -3.71 -> background2 > -2.08 (peso 282.0)
# Mantida aresta background2 > -2.08 -> Ca ka <= -3.71 (peso 423.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > -2.08 -> background6 > -2.43 (peso 182.0)
# Mantida aresta background6 > -2.43 -> background2 > -2.08 (peso 182.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.24 -> background2 > -2.08 (peso 142.0)
# Mantida aresta background2 > -2.08 -> background4 <= 3.24 (peso 142.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 2.57 -> background1 > -2.42 (peso 136.0)
# Mantida aresta background1 > -2.42 -> Ag ka scattering <= 2.57 (peso 136.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> Ag ka scattering <= 2.57 (peso 132.0)
# Mantida aresta Ag ka scattering <= 2.57 -> background5 > -2.53 (peso 132.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 2.57 -> Zn ka > -1.46 (peso 104.0)
# Mantida aresta Zn ka > -1.46 -> Ag ka scattering <= 2.57 (peso 104.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.22 -> Ag ka scattering <= 2.57 (peso 68.0)
# Mantida aresta Ag ka scattering <= 2.57 -> background1 <= 2.22 (peso 68.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.54 -> background6 > -2.43 (peso 178.0)
# Mantida aresta background6 > -2.43 -> background4 <= 3.54 (peso 178.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.54 -> background4 <= 3.24 (peso 342.0)
# Mantida aresta background4 <= 3.24 -> background4 <= 3.54 (peso 342.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> background4 <= 3.54 (peso 178.0)
# Mantida aresta background4 <= 3.54 -> background5 > -2.53 (peso 178.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> background6 > -2.43 (peso 183.0)
# Mantida aresta background6 > -2.43 -> background5 > -2.53 (peso 183.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.46 -> Ag ka scattering > -2.84 (peso 274.0)
# Mantida aresta Ag ka scattering > -2.84 -> Zn ka > -1.46 (peso 274.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -1.46 -> Ag ka scattering <= -1.94 (peso 68.0)
# Mantida aresta Ag ka scattering <= -1.94 -> Zn ka > -1.46 (peso 136.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.28 -> background4 <= 3.24 (peso 73.0)
# Mantida aresta background4 <= 3.24 -> background6 <= 2.28 (peso 73.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.16 -> Zn ka <= 2.18 (peso 78.0)
# Mantida aresta Zn ka <= 2.18 -> background2 <= 2.16 (peso 78.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 2.27 -> Cu kb <= 2.72 (peso 140.0)
# Mantida aresta Cu kb <= 2.72 -> Zn kb <= 2.27 (peso 140.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= -1.94 -> background5 > -2.53 (peso 86.0)
# Mantida aresta background5 > -2.53 -> Ag ka scattering <= -1.94 (peso 172.0)
#
# ======================================================================
#
# Removida aresta background6 <= 2.28 -> background5 > -2.53 (peso 87.0)
# Mantida aresta background5 > -2.53 -> background6 <= 2.28 (peso 174.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.53 -> Cu ka <= -2.19 (peso 134.0)
# Mantida aresta Cu ka <= -2.19 -> background1 <= 2.53 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.53 -> background1 <= 2.22 (peso 113.0)
# Mantida aresta background1 <= 2.22 -> background1 <= 2.53 (peso 113.0)
#
# ======================================================================
#
# Removida aresta background1 <= 2.53 -> background1 <= 3.00 (peso 171.0)
# Mantida aresta background1 <= 3.00 -> background1 <= 2.53 (peso 342.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 1.70 -> background6 <= 2.28 (peso 49.0)
# Mantida aresta background6 <= 2.28 -> background3 <= 1.70 (peso 49.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -2.19 -> background6 <= 2.28 (peso 92.0)
# Mantida aresta background6 <= 2.28 -> Cu ka <= -2.19 (peso 92.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 3.00 -> Ca ka <= -9.12 (peso 88.0)
# Mantida aresta Ca ka <= -9.12 -> background1 <= 3.00 (peso 88.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 3.00 -> Cu ka <= -2.19 (peso 177.0)
# Mantida aresta Cu ka <= -2.19 -> background1 <= 3.00 (peso 177.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > -2.42 -> Ti kb <= -2.36 (peso 92.0)
# Mantida aresta Ti kb <= -2.36 -> background1 > -2.42 (peso 92.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= -9.12 -> Ti kb <= -2.36 (peso 28.0)
# Mantida aresta Ti kb <= -2.36 -> Ca ka <= -9.12 (peso 28.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 2.08 -> Ca ka <= -9.12 (peso 75.0)
# Mantida aresta Ca ka <= -9.12 -> Ar ka + Ag L <= 2.08 (peso 75.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= -9.12 -> background1 > -2.42 (peso 94.0)
# Mantida aresta background1 > -2.42 -> Ca ka <= -9.12 (peso 188.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 2.03 -> background3 > 1.70 (peso 71.0)
# Mantida aresta background3 > 1.70 -> background5 <= 2.03 (peso 71.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 2.09 -> Zn ka > 2.18 (peso 52.0)
# Mantida aresta Zn ka > 2.18 -> background3 > 2.09 (peso 52.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= -3.42 -> Zn ka > 2.18 (peso 39.0)
# Mantida aresta Zn ka > 2.18 -> Ca kb <= -3.42 (peso 39.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > 2.18 -> Zn kb > -2.02 (peso 92.0)
# Mantida aresta Zn kb > -2.02 -> Zn ka > 2.18 (peso 92.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > -2.02 -> Ar ka + Ag L <= 2.08 (peso 135.0)
# Mantida aresta Ar ka + Ag L <= 2.08 -> Zn kb > -2.02 (peso 135.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 1.70 -> Ca kb <= -2.18 (peso 94.0)
# Mantida aresta Ca kb <= -2.18 -> background3 > 1.70 (peso 94.0)
#
# ======================================================================
#
# Removida aresta background6 <= 3.20 -> Cu ka <= -2.19 (peso 179.0)
# Mantida aresta Cu ka <= -2.19 -> background6 <= 3.20 (peso 358.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > -1.63 -> Zn kb <= 1.87 (peso 93.0)
# Mantida aresta Zn kb <= 1.87 -> background3 > -1.63 (peso 93.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > -1.63 -> background6 > 2.71 (peso 91.0)
# Mantida aresta background6 > 2.71 -> background3 > -1.63 (peso 91.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > -1.64 -> background6 > 2.71 (peso 67.0)
# Mantida aresta background6 > 2.71 -> Ar ka + Ag L > -1.64 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 2.47 -> Ca kb <= -3.42 (peso 96.0)
# Mantida aresta Ca kb <= -3.42 -> background3 <= 2.47 (peso 96.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 2.09 -> background4 > 2.89 (peso 70.0)
# Mantida aresta background4 > 2.89 -> background3 > 2.09 (peso 70.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.16 -> Ag ka scattering > -1.94 (peso 98.0)
# Mantida aresta Ag ka scattering > -1.94 -> background2 > 2.16 (peso 98.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.25 -> background2 > 2.16 (peso 129.0)
# Mantida aresta background2 > 2.16 -> Fe ka <= -9.25 (peso 129.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.16 -> Zn kb <= 2.73 (peso 138.0)
# Mantida aresta Zn kb <= 2.73 -> background2 > 2.16 (peso 138.0)
#
# ======================================================================
#
# Removida aresta background4 > 3.24 -> Ag ka scattering > -1.94 (peso 71.0)
# Mantida aresta Ag ka scattering > -1.94 -> background4 > 3.24 (peso 142.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > -1.94 -> Ar ka + Ag L > -1.64 (peso 103.0)
# Mantida aresta Ar ka + Ag L > -1.64 -> Ag ka scattering > -1.94 (peso 206.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.71 -> Cu ka <= -3.81 (peso 109.0)
# Mantida aresta Cu ka <= -3.81 -> background6 <= 2.71 (peso 109.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.28 -> background4 > 3.24 (peso 73.0)
# Mantida aresta background4 > 3.24 -> background6 > 2.28 (peso 73.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.28 -> Ar ka + Ag L <= 2.47 (peso 136.0)
# Mantida aresta Ar ka + Ag L <= 2.47 -> background6 > 2.28 (peso 136.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 2.27 -> background4 > 3.24 (peso 72.0)
# Mantida aresta background4 > 3.24 -> Zn kb <= 2.27 (peso 72.0)
#
# ======================================================================
#
# Removida aresta background4 > 2.89 -> background4 > 3.24 (peso 113.0)
# Mantida aresta background4 > 3.24 -> background4 > 2.89 (peso 226.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.53 -> Zn kb > 1.87 (peso 103.0)
# Mantida aresta Zn kb > 1.87 -> Fe ka <= -9.53 (peso 103.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > 2.08 -> Zn kb > 2.27 (peso 51.0)
# Mantida aresta Zn kb > 2.27 -> Ar ka + Ag L > 2.08 (peso 51.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > 2.53 -> Fe ka <= -9.80 (peso 43.0)
# Mantida aresta Fe ka <= -9.80 -> background1 > 2.53 (peso 43.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.80 -> Ar ka + Ag L <= 2.47 (peso 86.0)
# Mantida aresta Ar ka + Ag L <= 2.47 -> Fe ka <= -9.80 (peso 86.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > 1.87 -> Zn ka <= -1.46 (peso 71.0)
# Mantida aresta Zn ka <= -1.46 -> Zn kb > 1.87 (peso 71.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka <= -1.46 -> Cu kb <= -1.94 (peso 50.0)
# Mantida aresta Cu kb <= -1.94 -> Zn ka <= -1.46 (peso 50.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 660
# Total de arestas removidas por bidirecionalidade: 97
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 109
# Total de nós terminais: 2
#
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 102
# Removida aresta Ca ka > -11.34 -> Fe ka > -10.00 (peso 184.0)
# Mantida aresta Fe ka > -10.00 -> Ca ka > -11.34 (peso 1104.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -9.12 -> Ca ka > -11.34 (peso 680.0)
# Mantida aresta Ca ka > -11.34 -> Ca ka > -9.12 (peso 1020.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -3.71 -> Fe kb > -3.35 (peso 53.0)
# Mantida aresta Fe kb > -3.35 -> Ca ka > -3.71 (peso 477.0)
#
# ======================================================================
#
# Removida aresta Fe kb > -3.54 -> Ti ka > -11.81 (peso 390.0)
# Mantida aresta Ti ka > -11.81 -> Fe kb > -3.54 (peso 650.0)
#
# ======================================================================
#
# Removida aresta Ti ka > -11.81 -> Ti ka <= 9.71 (peso 336.0)
# Mantida aresta Ti ka <= 9.71 -> Ti ka > -11.81 (peso 672.0)
#
# ======================================================================
#
# Removida aresta Fe kb > -3.54 -> Ti ka <= 9.71 (peso 282.0)
# Mantida aresta Ti ka <= 9.71 -> Fe kb > -3.54 (peso 423.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -3.42 -> Ti ka <= 5.26 (peso 113.0)
# Mantida aresta Ti ka <= 5.26 -> Ca kb > -3.42 (peso 565.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -4.15 -> Ti ka <= 5.26 (peso 272.0)
# Mantida aresta Ti ka <= 5.26 -> Ca kb > -4.15 (peso 408.0)
#
# ======================================================================
#
# Removida aresta Cu ka > -3.81 -> Ti ka <= 5.26 (peso 52.0)
# Mantida aresta Ti ka <= 5.26 -> Cu ka > -3.81 (peso 104.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -4.15 -> Ca kb > -3.42 (peso 340.0)
# Mantida aresta Ca kb > -3.42 -> Ca kb > -4.15 (peso 1020.0)
#
# ======================================================================
#
# Removida aresta Ti kb > -4.43 -> Cu ka > -3.81 (peso 101.0)
# Mantida aresta Cu ka > -3.81 -> Ti kb > -4.43 (peso 202.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -2.18 -> Ti kb > -4.43 (peso 128.0)
# Mantida aresta Ti kb > -4.43 -> Ca kb > -2.18 (peso 192.0)
#
# ======================================================================
#
# Removida aresta Cu ka > -4.62 -> Cu ka > -3.81 (peso 114.0)
# Mantida aresta Cu ka > -3.81 -> Cu ka > -4.62 (peso 342.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka > -3.81 -> Cu ka > -4.31 (peso 114.0)
# Mantida aresta Cu ka > -4.31 -> Cu ka > -3.81 (peso 114.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 15.99 -> Ti kb <= 5.00 (peso 170.0)
# Mantida aresta Ti kb <= 5.00 -> Ca ka <= 15.99 (peso 850.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 5.00 -> Ca kb > -2.18 (peso 109.0)
# Mantida aresta Ca kb > -2.18 -> Ti kb <= 5.00 (peso 327.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= 5.00 -> Cu ka > -4.62 (peso 179.0)
# Mantida aresta Cu ka > -4.62 -> Ti kb <= 5.00 (peso 179.0)
#
# ======================================================================
#
# Removida aresta Cu ka > -4.31 -> Cu ka > -4.62 (peso 173.0)
# ...
#
# ======================================================================
#
# Removida aresta background2 <= 3.28 -> Ti kb > 2.64 (peso 166.0)
# Mantida aresta Ti kb > 2.64 -> background2 <= 3.28 (peso 249.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 2.64 -> background5 <= 2.48 (peso 59.0)
# Mantida aresta background5 <= 2.48 -> Ti kb > 2.64 (peso 59.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 2.64 -> background2 <= 2.59 (peso 53.0)
# Mantida aresta background2 <= 2.59 -> Ti kb > 2.64 (peso 53.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka <= 2.18 -> background2 > -2.08 (peso 129.0)
# Mantida aresta background2 > -2.08 -> Zn ka <= 2.18 (peso 129.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.59 -> background2 > -2.08 (peso 111.0)
# Mantida aresta background2 > -2.08 -> background2 <= 2.59 (peso 111.0)
#
# ======================================================================
#
# Removida aresta background4 <= 3.24 -> background2 <= 2.59 (peso 99.0)
# Mantida aresta background2 <= 2.59 -> background4 <= 3.24 (peso 198.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 2.89 -> background2 <= 2.59 (peso 142.0)
# Mantida aresta background2 <= 2.59 -> background4 <= 2.89 (peso 142.0)
#
# ======================================================================
#
# Removida aresta background5 > -2.53 -> background2 > -2.08 (peso 180.0)
# Mantida aresta background2 > -2.08 -> background5 > -2.53 (peso 360.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > -2.08 -> Ca ka <= -3.71 (peso 141.0)
# Mantida aresta Ca ka <= -3.71 -> background2 > -2.08 (peso 141.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.54 -> background2 > -2.08 (peso 184.0)
# Mantida aresta background2 > -2.08 -> background4 <= 3.54 (peso 184.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3.08 -> background2 > -2.08 (peso 181.0)
# Mantida aresta background2 > -2.08 -> Ag ka scattering <= 3.08 (peso 181.0)
#
# ======================================================================
#
# Removida aresta background5 <= 2.88 -> background5 <= 2.48 (peso 172.0)
# Mantida aresta background5 <= 2.48 -> background5 <= 2.88 (peso 344.0)
#
# ======================================================================
#
# Removida aresta background6 > -2.43 -> background4 <= 2.89 (peso 86.0)
# Mantida aresta background4 <= 2.89 -> background6 > -2.43 (peso 172.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 2.57 -> background6 > -2.43 (peso 127.0)
# Mantida aresta background6 > -2.43 -> Ag ka scattering <= 2.57 (peso 254.0)
#
# ======================================================================
#
# Removida aresta background6 > -2.43 -> Ca ka <= -3.71 (peso 137.0)
# Mantida aresta Ca ka <= -3.71 -> background6 > -2.43 (peso 411.0)
#
# ======================================================================
#
# Removida aresta background4 <= 3.24 -> background4 <= 3.54 (peso 342.0)
# Mantida aresta background4 <= 3.54 -> background4 <= 3.24 (peso 513.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 3.54 -> Ca ka <= -3.71 (peso 143.0)
# Mantida aresta Ca ka <= -3.71 -> background4 <= 3.54 (peso 143.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.46 -> background4 <= 3.54 (peso 136.0)
# Mantida aresta background4 <= 3.54 -> Zn ka > -1.46 (peso 136.0)
#
# ======================================================================
#
# Removida aresta background1 <= 3.00 -> Ag ka scattering > -2.84 (peso 181.0)
# Mantida aresta Ag ka scattering > -2.84 -> background1 <= 3.00 (peso 362.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > -2.84 -> Zn ka > -1.46 (peso 137.0)
# Mantida aresta Zn ka > -1.46 -> Ag ka scattering > -2.84 (peso 137.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > -2.84 -> background1 <= 2.22 (peso 87.0)
# Mantida aresta background1 <= 2.22 -> Ag ka scattering > -2.84 (peso 87.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 3.00 -> background6 <= 3.20 (peso 181.0)
# Mantida aresta background6 <= 3.20 -> background1 <= 3.00 (peso 181.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> background1 <= 3.00 (peso 181.0)
# Mantida aresta background1 <= 3.00 -> background5 > -2.53 (peso 181.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.22 -> background1 <= 2.53 (peso 113.0)
# Mantida aresta background1 <= 2.53 -> background1 <= 2.22 (peso 113.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.22 -> Ca ka <= -9.12 (peso 47.0)
# Mantida aresta Ca ka <= -9.12 -> background1 <= 2.22 (peso 47.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= -1.94 -> Ti kb <= -2.36 (peso 49.0)
# Mantida aresta Ti kb <= -2.36 -> Ag ka scattering <= -1.94 (peso 98.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.28 -> Ti kb <= -2.36 (peso 90.0)
# Mantida aresta Ti kb <= -2.36 -> background6 <= 2.28 (peso 90.0)
#
# ======================================================================
#
# Removida aresta background6 <= 2.71 -> Ti kb <= -2.36 (peso 67.0)
# Mantida aresta Ti kb <= -2.36 -> background6 <= 2.71 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 2.08 -> Ti kb <= -2.36 (peso 61.0)
# Mantida aresta Ti kb <= -2.36 -> Ar ka + Ag L <= 2.08 (peso 61.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= -2.36 -> Ca ka <= -9.12 (peso 28.0)
# Mantida aresta Ca ka <= -9.12 -> Ti kb <= -2.36 (peso 28.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 2.57 -> Ag ka scattering <= 3.08 (peso 170.0)
# Mantida aresta Ag ka scattering <= 3.08 -> Ag ka scattering <= 2.57 (peso 340.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 2.57 -> Ca ka <= -9.12 (peso 71.0)
# Mantida aresta Ca ka <= -9.12 -> Ag ka scattering <= 2.57 (peso 71.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> Ag ka scattering <= 3.08 (peso 179.0)
# Mantida aresta Ag ka scattering <= 3.08 -> background5 > -2.53 (peso 179.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= 2.72 -> background1 > -2.42 (peso 187.0)
# Mantida aresta background1 > -2.42 -> Cu kb <= 2.72 (peso 187.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.46 -> background2 <= 2.16 (peso 59.0)
# Mantida aresta background2 <= 2.16 -> Zn ka > -1.46 (peso 59.0)
#
# ======================================================================
#
# Removida aresta background2 <= 2.16 -> background3 <= 1.70 (peso 44.0)
# Mantida aresta background3 <= 1.70 -> background2 <= 2.16 (peso 88.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.28 -> background2 <= 2.16 (peso 43.0)
# Mantida aresta background2 <= 2.16 -> background6 <= 2.28 (peso 43.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.28 -> background3 <= 1.70 (peso 49.0)
# Mantida aresta background3 <= 1.70 -> background6 <= 2.28 (peso 49.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= -2.18 -> Cu ka <= -2.19 (peso 135.0)
# Mantida aresta Cu ka <= -2.19 -> Ca kb <= -2.18 (peso 270.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 2.71 -> Cu ka <= -2.19 (peso 140.0)
# Mantida aresta Cu ka <= -2.19 -> background6 <= 2.71 (peso 140.0)
#
# ======================================================================
#
# Removida aresta background4 > -3.06 -> Ca ka <= -9.12 (peso 82.0)
# Mantida aresta Ca ka <= -9.12 -> background4 > -3.06 (peso 328.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 2.08 -> Cu kb <= 2.72 (peso 131.0)
# Mantida aresta Cu kb <= 2.72 -> Ar ka + Ag L <= 2.08 (peso 131.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 2.08 -> Ca kb <= -2.18 (peso 113.0)
# Mantida aresta Ca kb <= -2.18 -> Ar ka + Ag L <= 2.08 (peso 113.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.16 -> background6 <= 2.71 (peso 106.0)
# Mantida aresta background6 <= 2.71 -> background2 > 2.16 (peso 106.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 1.87 -> Ar ka + Ag L > -1.64 (peso 65.0)
# Mantida aresta Ar ka + Ag L > -1.64 -> Zn kb <= 1.87 (peso 65.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > -1.64 -> Zn kb <= 2.73 (peso 133.0)
# Mantida aresta Zn kb <= 2.73 -> Ar ka + Ag L > -1.64 (peso 133.0)
#
# ======================================================================
#
# Removida aresta Zn kb > -2.02 -> background6 <= 3.20 (peso 188.0)
# Mantida aresta background6 <= 3.20 -> Zn kb > -2.02 (peso 376.0)
#
# ======================================================================
#
# Removida aresta background4 > 3.24 -> background4 > 2.89 (peso 113.0)
# Mantida aresta background4 > 2.89 -> background4 > 3.24 (peso 226.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= -9.53 -> background4 > 2.89 (peso 100.0)
# Mantida aresta background4 > 2.89 -> Fe ka <= -9.53 (peso 200.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu ka <= -3.81 -> background6 > 2.28 (peso 96.0)
# Mantida aresta background6 > 2.28 -> Cu ka <= -3.81 (peso 96.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3.08 -> background3 > 1.70 (peso 130.0)
# Mantida aresta background3 > 1.70 -> Ag ka scattering <= 3.08 (peso 130.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 1.70 -> background6 > 2.71 (peso 140.0)
# Mantida aresta background6 > 2.71 -> background3 > 1.70 (peso 140.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 2.47 -> Zn ka > 2.18 (peso 90.0)
# Mantida aresta Zn ka > 2.18 -> Ar ka + Ag L <= 2.47 (peso 90.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.16 -> Ag ka scattering > -1.94 (peso 98.0)
# Mantida aresta Ag ka scattering > -1.94 -> background2 > 2.16 (peso 98.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.16 -> Zn kb <= 2.27 (peso 110.0)
# Mantida aresta Zn kb <= 2.27 -> background2 > 2.16 (peso 110.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > -1.63 -> Ag ka scattering > -1.94 (peso 135.0)
# Mantida aresta Ag ka scattering > -1.94 -> background3 > -1.63 (peso 135.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.28 -> Ca kb <= -3.42 (peso 63.0)
# Mantida aresta Ca kb <= -3.42 -> background6 > 2.28 (peso 63.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= -3.42 -> Ag ka scattering > 2.57 (peso 42.0)
# Mantida aresta Ag ka scattering > 2.57 -> Ca kb <= -3.42 (peso 42.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.53 -> Zn kb > 1.87 (peso 103.0)
# Mantida aresta Zn kb > 1.87 -> Fe ka <= -9.53 (peso 103.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= 1.49 -> Fe ka <= -9.25 (peso 134.0)
# Mantida aresta Fe ka <= -9.25 -> Cu kb <= 1.49 (peso 134.0)
#
# ======================================================================
#
# Removida aresta Cu kb <= -1.94 -> Fe ka <= -9.80 (peso 51.0)
# Mantida aresta Fe ka <= -9.80 -> Cu kb <= -1.94 (peso 102.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.80 -> Zn ka <= -1.46 (peso 46.0)
# Mantida aresta Zn ka <= -1.46 -> Fe ka <= -9.80 (peso 46.0)
#
# ======================================================================
#
# Removida aresta background1 > 2.53 -> Ag ka scattering > 2.57 (peso 47.0)
# Mantida aresta Ag ka scattering > 2.57 -> background1 > 2.53 (peso 94.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 2.27 -> Zn kb > 2.27 (peso 0.0)
# Mantida aresta Zn kb > 2.27 -> Zn kb <= 2.27 (peso 0.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 682
# Total de arestas removidas por bidirecionalidade: 99
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 107
# Total de nós terminais: 2
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
# Processando LRC do grafo...
#
# Processando LRC do grafo...
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#     Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0          Fe ka > -9.53        Fe ka > -9.53        Fe ka > -9.53
# 1          Fe ka > -9.80        Fe ka > -9.80        Fe ka > -9.80
# 2         Ca ka > -11.34       Fe ka > -10.00       Fe ka > -10.00
# 3         Fe ka > -10.00       Ca ka > -11.34       Ca ka > -11.34
# 4          Ca ka > -3.71        Ti ka <= 9.71        Ca kb > -3.42
# ..                   ...                  ...                  ...
# 106       Cu ka <= -4.31         Zn ka > 2.18       Fe ka <= -9.80
# 107              Class_A       Cu ka <= -4.31              Class_A
# 108              Class_B      Fe ka <= -10.00              Class_B
# 109                  NaN              Class_A                  NaN
# 110                  NaN              Class_B                  NaN
#
#     Predicate_Cov_Seed_3
# 0          Fe ka > -9.53
# 1          Fe ka > -9.80
# 2          Ti ka <= 5.26
# 3         Fe ka > -10.00
# 4          Ti ka <= 9.71
# ..                   ...
# 106      Fe ka <= -10.00
# 107              Class_A
# 108              Class_B
# 109                  NaN
# 110                  NaN
#
# [111 rows x 4 columns]

# %%
from collections import defaultdict

# Coletar posições de cada predicado em cada seed do lrc_pert_all_seeds_df
positions_dict_lrc = defaultdict(list)

# Iterar sobre cada coluna do dataframe lrc_pert_all_seeds_df
for col in lrc_cov_all_seeds_df.columns:
    # Pegar os predicados da coluna (não-nulos)
    predicates_in_seed = lrc_cov_all_seeds_df[col].dropna().tolist()
    
    # Para cada predicado, guardar sua posição (1-based)
    for position, predicate in enumerate(predicates_in_seed, start=1):
        positions_dict_lrc[predicate].append(position)

# Calcular média e número de aparições
results_lrc = []
for predicate, positions in positions_dict_lrc.items():
    zone_row = predicates_quantiles[0].loc[predicates_quantiles[0]['rule'] == predicate, 'zone']
    zone_value = zone_row.values[0] if not zone_row.empty else None
    results_lrc.append({
        'Predicate': predicate,
        'Mean_Position': np.mean(positions),
        'Appearances': len(positions),
        'Zone': zone_value
    })

# Ordenar: menor posição média primeiro, mais aparições em caso de empate
ranking_lrc_cov_df = pd.DataFrame(results_lrc).sort_values(
    by=['Mean_Position', 'Appearances'], 
    ascending=[True, False]
).reset_index(drop=True)

# Lista final ordenada
lista_ordenada_lrc = ranking_lrc_cov_df['Predicate'].tolist()
ranking_lrc_cov_df
# Out:
#            Predicate  Mean_Position  Appearances   Zone
# 0      Fe ka > -9.53           1.00            4  Fe ka
# 1      Fe ka > -9.80           2.00            4  Fe ka
# 2     Fe ka > -10.00           3.50            4  Fe ka
# 3     Ca ka > -11.34           4.75            4  Ca ka
# 4      Ca ka > -3.71           7.00            4  Ca ka
# ..               ...            ...          ...    ...
# 107   Fe kb <= -3.35         104.00            2  Fe kb
# 108   Cu ka <= -4.31         107.00            3  Cu ka
# 109  Fe ka <= -10.00         108.00            2  Fe ka
# 110          Class_A         108.50            4   None
# 111          Class_B         109.50            4   None
#
# [112 rows x 4 columns]

# %%
ranking_cov_lrc_unique_df = ranking_lrc_cov_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
ranking_cov_lrc_unique_df['Zone']
# Out:
# 0                Fe ka
# 1                Ca ka
# 2                Ti ka
# 3                Fe kb
# 4                Ca kb
# 5                Cu ka
# 6                Ti kb
# 7                Cu kb
# 8                Zn ka
# 9          background5
# 10         background4
# 11         background2
# 12         background1
# 13    Ag ka scattering
# 14         background6
# 15               Zn kb
# 16         background3
# 17        Ar ka + Ag L
# 18                None
# Name: Zone, dtype: object

# %% [markdown]
# # **Perturbation**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        perturbation_value=0,
        metric='mean_relative_dev',   # Média com sinal (pode ser negativo)
        verbose=True
    )

    # Remove todos os valores iguais a zero de todos os bags em perm_results[bag]["Permutation"] e salva como perm_results_thresholded
    # pert_results_seed_thresholded = {}
    # for bag, df in perm_results_seed.items():
    #     # Verifica se é um DataFrame e se a coluna 'Permutation' existe
    #     if isinstance(df, pd.DataFrame) and 'Permutation' in df.columns:
    #         filtered_df = df[df['Permutation'] > 0].copy()
    #         pert_results_seed_thresholded[bag] = filtered_df
    #     else:
    #         # Se não for DataFrame esperado, apenas copia
    #         pert_results_seed_thresholded[bag] = df

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graph(
        bags_result=all_results_pert[seed]['bags_result'],
        mi_results_dict=all_results_pert[seed]['pert_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 109 | Descartados: 35
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 36
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Valor de perturbação: 0
# Métrica: mean_relative_dev
# Total de folds: 10
#
#
# [Bag_1] Processando 109 predicados...
#   Predicado: background1 > -2.42 (n=186)
#     Zona: 69 colunas
#     Importance: 0.004310
#   Predicado: background1 <= 2.22 (n=86)
#     Zona: 69 colunas
#     Importance: 0.009231
#   Predicado: background1 > 2.22 (n=141)
#     Zona: 69 colunas
#     Importance: 0.005112
#   Predicado: background1 <= 2.53 (n=137)
#     Zona: 69 colunas
#     Importance: 0.008393
#   Predicado: background1 > 2.53 (n=90)
#     Zona: 69 colunas
#     Importance: 0.004054
#   Predicado: background1 <= 3.00 (n=180)
#     Zona: 69 colunas
#     Importance: 0.008809
#   Predicado: Ar ka + Ag L > -2.22 (n=184)
#     Zona: 29 colunas
#     Importance: 0.002898
#   Predicado: Ar ka + Ag L <= -1.64 (n=93)
#     Zona: 29 colunas
#     Importance: -0.001041
#   Predicado: Ar ka + Ag L > -1.64 (n=134)
#     Zona: 29 colunas
#     Importance: 0.003769
#   Predicado: Ar ka + Ag L <= 2.08 (n=136)
#     Zona: 29 colunas
#     Importance: -0.000278
#   Predicado: Ar ka + Ag L > 2.08 (n=91)
#     Zona: 29 colunas
#     Importance: 0.004902
#   Predicado: Ar ka + Ag L <= 2.47 (n=181)
#     Zona: 29 colunas
#     Importance: 0.001788
#   Predicado: Ca ka > -11.34 (n=185)
#     Zona: 17 colunas
#     Importance: 0.054060
#   Predicado: Ca ka <= -9.12 (n=89)
#     Zona: 17 colunas
#     Importance: 0.203732
#   Predicado: Ca ka > -9.12 (n=138)
#     Zona: 17 colunas
#     Importance: -0.084278
#   Predicado: Ca ka <= -3.71 (n=132)
#     Zona: 17 colunas
#     Importance: 0.130759
#   Predicado: Ca ka > -3.71 (n=95)
#     Zona: 17 colunas
#     Importance: -0.113246
#   Predicado: Ca ka <= 15.99 (n=181)
#     Zona: 17 colunas
#     Importance: 0.078578
#   Predicado: Ca kb > -4.15 (n=185)
#     Zona: 13 colunas
#     Importance: -0.021276
#   Predicado: Ca kb <= -3.42 (n=89)
#     Zona: 13 colunas
#     Importance: 0.024243
#   Predicado: Ca kb > -3.42 (n=138)
#     Zona: 13 colunas
#     Importance: -0.014963
#   Predicado: Ca kb <= -2.18 (n=134)
#     Zona: 13 colunas
#     Importance: 0.023975
#   Predicado: Ca kb > -2.18 (n=93)
#     Zona: 13 colunas
#     Importance: -0.033547
#   Predicado: Ca kb <= 6.30 (n=181)
#     Zona: 13 colunas
#     Importance: 0.005640
#   Predicado: Ti ka > -11.81 (n=180)
#     Zona: 19 colunas
#     Importance: -0.660514
#   Predicado: Ti ka <= -3.08 (n=93)
#     Zona: 19 colunas
#     Importance: -0.333393
#   Predicado: Ti ka > -3.08 (n=134)
#     Zona: 19 colunas
#     Importance: -0.780562
#   Predicado: Ti ka <= 5.26 (n=137)
#     Zona: 19 colunas
#     Importance: 0.013277
#   Predicado: Ti ka > 5.26 (n=90)
#     Zona: 19 colunas
#     Importance: -1.526886
#   Predicado: Ti ka <= 9.71 (n=182)
#     Zona: 19 colunas
#     Importance: 0.364703
#   Predicado: Ti kb > -4.43 (n=186)
#     Zona: 16 colunas
#     Importance: -0.082440
#   Predicado: Ti kb <= -2.36 (n=91)
#     Zona: 16 colunas
#     Importance: -0.048394
#   Predicado: Ti kb > -2.36 (n=136)
#     Zona: 16 colunas
#     Importance: -0.095552
#   Predicado: Ti kb <= 2.64 (n=137)
#     Zona: 16 colunas
#     Importance: -0.023158
#   Predicado: Ti kb > 2.64 (n=90)
#     Zona: 16 colunas
#     Importance: -0.158069
#   Predicado: Ti kb <= 5.00 (n=179)
#     Zona: 16 colunas
#     Importance: -0.075521
#   Predicado: background2 > -2.08 (n=185)
#     Zona: 39 colunas
#     Importance: 0.004072
#   Predicado: background2 <= 2.16 (n=89)
#     Zona: 39 colunas
#     Importance: -0.007019
#   Predicado: background2 > 2.16 (n=138)
#     Zona: 39 colunas
#     Importance: 0.007568
#   Predicado: background2 <= 2.59 (n=133)
#     Zona: 39 colunas
#     Importance: -0.004519
#   Predicado: background2 > 2.59 (n=94)
#     Zona: 39 colunas
#     Importance: 0.010860
#   Predicado: background2 <= 3.28 (n=182)
#     Zona: 39 colunas
#     Importance: 0.001812
#   Predicado: Fe ka <= -10.00 (n=58)
#     Zona: 25 colunas
#     Importance: 0.000862
#   Predicado: Fe ka > -10.00 (n=169)
#     Zona: 25 colunas
#     Importance: 0.003447
#   Predicado: Fe ka <= -9.80 (n=90)
#     Zona: 25 colunas
#     Importance: 0.017437
#   Predicado: Fe ka > -9.80 (n=137)
#     Zona: 25 colunas
#     Importance: -0.006838
#   Predicado: Fe ka <= -9.53 (n=138)
#     Zona: 25 colunas
#     Importance: 0.022987
#   Predicado: Fe ka > -9.53 (n=89)
#     Zona: 25 colunas
#     Importance: -0.028536
#   Predicado: Fe ka <= -9.25 (n=182)
#     Zona: 25 colunas
#     Importance: 0.001784
#   Predicado: Fe kb > -3.78 (n=195)
#     Zona: 22 colunas
#     Importance: 0.001016
#   Predicado: Fe kb <= -3.54 (n=84)
#     Zona: 22 colunas
#     Importance: 0.002486
#   Predicado: Fe kb > -3.54 (n=143)
#     Zona: 22 colunas
#     Importance: -0.002246
#   Predicado: Fe kb <= -3.35 (n=134)
#     Zona: 22 colunas
#     Importance: 0.004099
#   Predicado: Fe kb > -3.35 (n=93)
#     Zona: 22 colunas
#     Importance: -0.007115
#   Predicado: Fe kb <= -3.14 (n=174)
#     Zona: 22 colunas
#     Importance: -0.000354
#   Predicado: background3 > -1.63 (n=179)
#     Zona: 18 colunas
#     Importance: -0.000209
#   Predicado: background3 <= 1.70 (n=90)
#     Zona: 18 colunas
#     Importance: -0.000906
#   Predicado: background3 > 1.70 (n=137)
#     Zona: 18 colunas
#     Importance: -0.000066
#   Predicado: background3 <= 2.09 (n=129)
#     Zona: 18 colunas
#     Importance: -0.001526
#   Predicado: background3 > 2.09 (n=98)
#     Zona: 18 colunas
#     Importance: 0.001085
#   Predicado: background3 <= 2.47 (n=178)
#     Zona: 18 colunas
#     Importance: -0.000313
#   Predicado: Cu ka > -4.62 (n=182)
#     Zona: 20 colunas
#     Importance: 0.153924
#   Predicado: Cu ka <= -4.31 (n=84)
#     Zona: 20 colunas
#     Importance: -0.006335
#   Predicado: Cu ka > -4.31 (n=143)
#     Zona: 20 colunas
#     Importance: 0.183745
#   Predicado: Cu ka <= -3.81 (n=133)
#     Zona: 20 colunas
#     Importance: -0.001904
#   Predicado: Cu ka > -3.81 (n=94)
#     Zona: 20 colunas
#     Importance: 0.276561
#   Predicado: Cu ka <= -2.19 (n=179)
#     Zona: 20 colunas
#     Importance: -0.019546
#   Predicado: Zn ka > -1.99 (n=186)
#     Zona: 21 colunas
#     Importance: 0.002340
#   Predicado: Zn ka <= -1.46 (n=86)
#     Zona: 21 colunas
#     Importance: -0.000658
#   Predicado: Zn ka > -1.46 (n=141)
#     Zona: 21 colunas
#     Importance: 0.003263
#   Predicado: Zn ka <= 2.18 (n=133)
#     Zona: 21 colunas
#     Importance: -0.000421
#   Predicado: Zn ka > 2.18 (n=94)
#     Zona: 21 colunas
#     Importance: 0.004887
#   Predicado: Zn ka <= 2.74 (n=183)
#     Zona: 21 colunas
#     Importance: -0.000520
#   Predicado: Cu kb > -2.22 (n=188)
#     Zona: 19 colunas
#     Importance: 0.006433
#   Predicado: Cu kb <= -1.94 (n=94)
#     Zona: 19 colunas
#     Importance: -0.000492
#   Predicado: Cu kb > -1.94 (n=133)
#     Zona: 19 colunas
#     Importance: 0.011416
#   Predicado: Cu kb <= 1.49 (n=135)
#     Zona: 19 colunas
#     Importance: -0.000194
#   Predicado: Cu kb > 1.49 (n=92)
#     Zona: 19 colunas
#     Importance: 0.016285
#   Predicado: Cu kb <= 2.72 (n=180)
#     Zona: 19 colunas
#     Importance: 0.000730
#   Predicado: Zn kb > -2.02 (n=183)
#     Zona: 30 colunas
#     Importance: 0.000658
#   Predicado: Zn kb <= 1.87 (n=92)
#     Zona: 30 colunas
#     Importance: 0.000045
#   Predicado: Zn kb > 1.87 (n=135)
#     Zona: 30 colunas
#     Importance: 0.001234
#   Predicado: Zn kb <= 2.27 (n=136)
#     Zona: 30 colunas
#     Importance: 0.000184
#   Predicado: Zn kb > 2.27 (n=91)
#     Zona: 30 colunas
#     Importance: 0.001601
#   Predicado: Zn kb <= 2.73 (n=180)
#     Zona: 30 colunas
#     Importance: -0.000453
#   Predicado: background4 > -3.06 (n=185)
#     Zona: 451 colunas
#     Importance: 0.005561
#   Predicado: background4 <= 2.89 (n=93)
#     Zona: 451 colunas
#     Importance: -0.003072
#   Predicado: background4 > 2.89 (n=134)
#     Zona: 451 colunas
#     Importance: 0.019450
#   Predicado: background4 <= 3.24 (n=138)
#     Zona: 451 colunas
#     Importance: 0.017910
#   Predicado: background4 > 3.24 (n=89)
#     Zona: 451 colunas
#     Importance: -0.001695
#   Predicado: background4 <= 3.54 (n=181)
#     Zona: 451 colunas
#     Importance: 0.022302
#   Predicado: Ag ka scattering > -2.84 (n=185)
#     Zona: 49 colunas
#     Importance: -0.011683
#   Predicado: Ag ka scattering <= -1.94 (n=87)
#     Zona: 49 colunas
#     Importance: -0.012067
#   Predicado: Ag ka scattering > -1.94 (n=140)
#     Zona: 49 colunas
#     Importance: -0.012280
#   Predicado: Ag ka scattering <= 2.57 (n=131)
#     Zona: 49 colunas
#     Importance: -0.044377
#   Predicado: Ag ka scattering > 2.57 (n=96)
#     Zona: 49 colunas
#     Importance: 0.031712
#   Predicado: Ag ka scattering <= 3.08 (n=178)
#     Zona: 49 colunas
#     Importance: -0.042511
#   Predicado: background5 > -2.53 (n=183)
#     Zona: 71 colunas
#     Importance: 0.002558
#   Predicado: background5 <= 2.03 (n=84)
#     Zona: 71 colunas
#     Importance: 0.002727
#   Predicado: background5 > 2.03 (n=143)
#     Zona: 71 colunas
#     Importance: 0.002688
#   Predicado: background5 <= 2.48 (n=131)
#     Zona: 71 colunas
#     Importance: 0.001219
#   Predicado: background5 > 2.48 (n=96)
#     Zona: 71 colunas
#     Importance: 0.004727
#   Predicado: background5 <= 2.88 (n=179)
#     Zona: 71 colunas
#     Importance: -0.000572
#   Predicado: background6 > -2.43 (n=181)
#     Zona: 61 colunas
#     Importance: 0.000332
#   Predicado: background6 <= 2.28 (n=89)
#     Zona: 61 colunas
#     Importance: -0.007520
#   Predicado: background6 > 2.28 (n=138)
#     Zona: 61 colunas
#     Importance: 0.000704
#   Predicado: background6 <= 2.71 (n=137)
#     Zona: 61 colunas
#     Importance: -0.019351
#   Predicado: background6 > 2.71 (n=90)
#     Zona: 61 colunas
#     Importance: 0.023099
#   Predicado: background6 <= 3.20 (n=182)
#     Zona: 61 colunas
#     Importance: -0.015787
#
# [Bag_2] Processando 109 predicados...
#   Predicado: background1 > -2.42 (n=184)
#     Zona: 69 colunas
#     Importance: 0.002184
#   Predicado: background1 <= 2.22 (n=88)
#     Zona: 69 colunas
#     Importance: 0.008278
#   Predicado: background1 > 2.22 (n=139)
#     Zona: 69 colunas
#     Importance: 0.002947
#   Predicado: background1 <= 2.53 (n=136)
#     Zona: 69 colunas
#     Importance: 0.007820
#   Predicado: background1 > 2.53 (n=91)
#     Zona: 69 colunas
#     Importance: 0.000820
#   Predicado: background1 <= 3.00 (n=178)
#     Zona: 69 colunas
#     Importance: 0.006920
#   Predicado: Ar ka + Ag L > -2.22 (n=182)
#     Zona: 29 colunas
#     Importance: 0.000760
#   Predicado: Ar ka + Ag L <= -1.64 (n=95)
#     Zona: 29 colunas
#     Importance: -0.001817
#   Predicado: Ar ka + Ag L > -1.64 (n=132)
#     Zona: 29 colunas
#     Importance: 0.001357
#   Predicado: Ar ka + Ag L <= 2.08 (n=143)
#     Zona: 29 colunas
#     Importance: -0.001122
#   Predicado: Ar ka + Ag L > 2.08 (n=84)
#     Zona: 29 colunas
#     Importance: 0.001989
#   Predicado: Ar ka + Ag L <= 2.47 (n=184)
#     Zona: 29 colunas
#     Importance: 0.000579
#   Predicado: Ca ka > -11.34 (n=185)
#     Zona: 17 colunas
#     Importance: -0.061680
#   Predicado: Ca ka <= -9.12 (n=85)
#     Zona: 17 colunas
#     Importance: 0.221629
#   Predicado: Ca ka > -9.12 (n=142)
#     Zona: 17 colunas
#     Importance: -0.113787
#   Predicado: Ca ka <= -3.71 (n=130)
#     Zona: 17 colunas
#     Importance: 0.106331
#   Predicado: Ca ka > -3.71 (n=97)
#     Zona: 17 colunas
#     Importance: -0.114869
#   Predicado: Ca ka <= 15.99 (n=179)
#     Zona: 17 colunas
#     Importance: 0.060454
#   Predicado: Ca kb > -4.15 (n=184)
#     Zona: 13 colunas
#     Importance: -0.023892
#   Predicado: Ca kb <= -3.42 (n=87)
#     Zona: 13 colunas
#     Importance: 0.023917
#   Predicado: Ca kb > -3.42 (n=140)
#     Zona: 13 colunas
#     Importance: -0.019188
#   Predicado: Ca kb <= -2.18 (n=133)
#     Zona: 13 colunas
#     Importance: 0.019112
#   Predicado: Ca kb > -2.18 (n=94)
#     Zona: 13 colunas
#     Importance: -0.033484
#   Predicado: Ca kb <= 6.30 (n=179)
#     Zona: 13 colunas
#     Importance: 0.002086
#   Predicado: Ti ka > -11.81 (n=177)
#     Zona: 19 colunas
#     Importance: -0.850535
#   Predicado: Ti ka <= -3.08 (n=94)
#     Zona: 19 colunas
#     Importance: -0.334435
#   Predicado: Ti ka > -3.08 (n=133)
#     Zona: 19 colunas
#     Importance: -1.029228
#   Predicado: Ti ka <= 5.26 (n=140)
#     Zona: 19 colunas
#     Importance: 0.030349
#   Predicado: Ti ka > 5.26 (n=87)
#     Zona: 19 colunas
#     Importance: -1.983600
#   Predicado: Ti ka <= 9.71 (n=183)
#     Zona: 19 colunas
#     Importance: 0.100641
#   Predicado: Ti kb > -4.43 (n=182)
#     Zona: 16 colunas
#     Importance: -0.130942
#   Predicado: Ti kb <= -2.36 (n=94)
#     Zona: 16 colunas
#     Importance: -0.047881
#   Predicado: Ti kb > -2.36 (n=133)
#     Zona: 16 colunas
#     Importance: -0.162577
#   Predicado: Ti kb <= 2.64 (n=138)
#     Zona: 16 colunas
#     Importance: -0.020582
#   Predicado: Ti kb > 2.64 (n=89)
#     Zona: 16 colunas
#     Importance: -0.261609
#   Predicado: Ti kb <= 5.00 (n=183)
#     Zona: 16 colunas
#     Importance: -0.081000
#   Predicado: background2 > -2.08 (n=184)
#     Zona: 39 colunas
#     Importance: -0.000950
#   Predicado: background2 <= 2.16 (n=92)
#     Zona: 39 colunas
#     Importance: -0.007095
#   Predicado: background2 > 2.16 (n=135)
#     Zona: 39 colunas
#     Importance: 0.001016
#   Predicado: background2 <= 2.59 (n=135)
#     Zona: 39 colunas
#     Importance: -0.002690
#   Predicado: background2 > 2.59 (n=92)
#     Zona: 39 colunas
#     Importance: -0.001658
#   Predicado: background2 <= 3.28 (n=182)
#     Zona: 39 colunas
#     Importance: -0.003218
#   Predicado: Fe ka <= -10.00 (n=56)
#     Zona: 25 colunas
#     Importance: 0.006638
#   Predicado: Fe ka > -10.00 (n=171)
#     Zona: 25 colunas
#     Importance: -0.004805
#   Predicado: Fe ka <= -9.80 (n=83)
#     Zona: 25 colunas
#     Importance: 0.021161
#   Predicado: Fe ka > -9.80 (n=144)
#     Zona: 25 colunas
#     Importance: -0.015321
#   Predicado: Fe ka <= -9.53 (n=134)
#     Zona: 25 colunas
#     Importance: 0.020044
#   Predicado: Fe ka > -9.53 (n=93)
#     Zona: 25 colunas
#     Importance: -0.033718
#   Predicado: Fe ka <= -9.25 (n=185)
#     Zona: 25 colunas
#     Importance: 0.001532
#   Predicado: Fe kb > -3.78 (n=191)
#     Zona: 22 colunas
#     Importance: 0.000713
#   Predicado: Fe kb <= -3.54 (n=85)
#     Zona: 22 colunas
#     Importance: -0.003225
#   Predicado: Fe kb > -3.54 (n=142)
#     Zona: 22 colunas
#     Importance: -0.001500
#   Predicado: Fe kb <= -3.35 (n=139)
#     Zona: 22 colunas
#     Importance: 0.000293
#   Predicado: Fe kb > -3.35 (n=88)
#     Zona: 22 colunas
#     Importance: -0.005999
#   Predicado: Fe kb <= -3.14 (n=177)
#     Zona: 22 colunas
#     Importance: -0.002112
#   Predicado: background3 > -1.63 (n=180)
#     Zona: 18 colunas
#     Importance: 0.000624
#   Predicado: background3 <= 1.70 (n=92)
#     Zona: 18 colunas
#     Importance: -0.000475
#   Predicado: background3 > 1.70 (n=135)
#     Zona: 18 colunas
#     Importance: 0.000849
#   Predicado: background3 <= 2.09 (n=133)
#     Zona: 18 colunas
#     Importance: 0.000000
#   Predicado: background3 > 2.09 (n=94)
#     Zona: 18 colunas
#     Importance: 0.000754
#   Predicado: background3 <= 2.47 (n=179)
#     Zona: 18 colunas
#     Importance: 0.000688
#   Predicado: Cu ka > -4.62 (n=183)
#     Zona: 20 colunas
#     Importance: 0.139580
#   Predicado: Cu ka <= -4.31 (n=93)
#     Zona: 20 colunas
#     Importance: -0.052971
#   Predicado: Cu ka > -4.31 (n=134)
#     Zona: 20 colunas
#     Importance: 0.210166
#   Predicado: Cu ka <= -3.81 (n=136)
#     Zona: 20 colunas
#     Importance: -0.033757
#   Predicado: Cu ka > -3.81 (n=91)
#     Zona: 20 colunas
#     Importance: 0.305790
#   Predicado: Cu ka <= -2.19 (n=181)
#     Zona: 20 colunas
#     Importance: -0.024459
#   Predicado: Zn ka > -1.99 (n=181)
#     Zona: 21 colunas
#     Importance: -0.000388
#   Predicado: Zn ka <= -1.46 (n=90)
#     Zona: 21 colunas
#     Importance: -0.002287
#   Predicado: Zn ka > -1.46 (n=137)
#     Zona: 21 colunas
#     Importance: 0.000719
#   Predicado: Zn ka <= 2.18 (n=134)
#     Zona: 21 colunas
#     Importance: -0.001441
#   Predicado: Zn ka > 2.18 (n=93)
#     Zona: 21 colunas
#     Importance: 0.000923
#   Predicado: Zn ka <= 2.74 (n=181)
#     Zona: 21 colunas
#     Importance: -0.000980
#   Predicado: Cu kb > -2.22 (n=191)
#     Zona: 19 colunas
#     Importance: 0.005525
#   Predicado: Cu kb <= -1.94 (n=88)
#     Zona: 19 colunas
#     Importance: -0.000465
#   Predicado: Cu kb > -1.94 (n=139)
#     Zona: 19 colunas
#     Importance: 0.009463
#   Predicado: Cu kb <= 1.49 (n=135)
#     Zona: 19 colunas
#     Importance: 0.001435
#   Predicado: Cu kb > 1.49 (n=92)
#     Zona: 19 colunas
#     Importance: 0.011747
#   Predicado: Cu kb <= 2.72 (n=182)
#     Zona: 19 colunas
#     Importance: 0.001909
#   Predicado: Zn kb > -2.02 (n=180)
#     Zona: 30 colunas
#     Importance: 0.000623
#   Predicado: Zn kb <= 1.87 (n=92)
#     Zona: 30 colunas
#     Importance: -0.000089
#   Predicado: Zn kb > 1.87 (n=135)
#     Zona: 30 colunas
#     Importance: 0.001238
#   Predicado: Zn kb <= 2.27 (n=133)
#     Zona: 30 colunas
#     Importance: -0.000048
#   Predicado: Zn kb > 2.27 (n=94)
#     Zona: 30 colunas
#     Importance: 0.001759
#   Predicado: Zn kb <= 2.73 (n=181)
#     Zona: 30 colunas
#     Importance: -0.000592
#   Predicado: background4 > -3.06 (n=181)
#     Zona: 451 colunas
#     Importance: -0.021936
#   Predicado: background4 <= 2.89 (n=91)
#     Zona: 451 colunas
#     Importance: -0.000132
#   Predicado: background4 > 2.89 (n=136)
#     Zona: 451 colunas
#     Importance: -0.020990
#   Predicado: background4 <= 3.24 (n=138)
#     Zona: 451 colunas
#     Importance: 0.015406
#   Predicado: background4 > 3.24 (n=89)
#     Zona: 451 colunas
#     Importance: -0.056098
#   Predicado: background4 <= 3.54 (n=182)
#     Zona: 451 colunas
#     Importance: 0.018334
#   Predicado: Ag ka scattering > -2.84 (n=183)
#     Zona: 49 colunas
#     Importance: -0.013563
#   Predicado: Ag ka scattering <= -1.94 (n=96)
#     Zona: 49 colunas
#     Importance: 0.003187
#   Predicado: Ag ka scattering > -1.94 (n=131)
#     Zona: 49 colunas
#     Importance: -0.024237
#   Predicado: Ag ka scattering <= 2.57 (n=138)
#     Zona: 49 colunas
#     Importance: -0.033641
#   Predicado: Ag ka scattering > 2.57 (n=89)
#     Zona: 49 colunas
#     Importance: 0.019925
#   Predicado: Ag ka scattering <= 3.08 (n=178)
#     Zona: 49 colunas
#     Importance: -0.042366
#   Predicado: background5 > -2.53 (n=182)
#     Zona: 71 colunas
#     Importance: -0.000722
#   Predicado: background5 <= 2.03 (n=93)
#     Zona: 71 colunas
#     Importance: 0.001648
#   Predicado: background5 > 2.03 (n=134)
#     Zona: 71 colunas
#     Importance: -0.001371
#   Predicado: background5 <= 2.48 (n=138)
#     Zona: 71 colunas
#     Importance: -0.000107
#   Predicado: background5 > 2.48 (n=89)
#     Zona: 71 colunas
#     Importance: -0.000176
#   Predicado: background5 <= 2.88 (n=183)
#     Zona: 71 colunas
#     Importance: -0.001683
#   Predicado: background6 > -2.43 (n=183)
#     Zona: 61 colunas
#     Importance: -0.002543
#   Predicado: background6 <= 2.28 (n=84)
#     Zona: 61 colunas
#     Importance: -0.009464
#   Predicado: background6 > 2.28 (n=143)
#     Zona: 61 colunas
#     Importance: -0.001351
#   Predicado: background6 <= 2.71 (n=134)
#     Zona: 61 colunas
#     Importance: -0.021665
#   Predicado: background6 > 2.71 (n=93)
#     Zona: 61 colunas
#     Importance: 0.020592
#   Predicado: background6 <= 3.20 (n=181)
#     Zona: 61 colunas
#     Importance: -0.012717
#
# [Bag_3] Processando 108 predicados...
#   Predicado: background1 > -2.42 (n=186)
#     Zona: 69 colunas
#     Importance: 0.004386
#   Predicado: background1 <= 2.22 (n=89)
#     Zona: 69 colunas
#     Importance: 0.005952
#   Predicado: background1 > 2.22 (n=138)
#     Zona: 69 colunas
#     Importance: 0.005201
#   Predicado: background1 <= 2.53 (n=138)
#     Zona: 69 colunas
#     Importance: 0.006144
#   Predicado: background1 > 2.53 (n=89)
#     Zona: 69 colunas
#     Importance: 0.004490
#   Predicado: background1 <= 3.00 (n=178)
#     Zona: 69 colunas
#     Importance: 0.007201
#   Predicado: Ar ka + Ag L > -2.22 (n=182)
#     Zona: 29 colunas
#     Importance: 0.002718
#   Predicado: Ar ka + Ag L <= -1.64 (n=92)
#     Zona: 29 colunas
#     Importance: 0.001792
#   Predicado: Ar ka + Ag L > -1.64 (n=135)
#     Zona: 29 colunas
#     Importance: 0.003495
#   Predicado: Ar ka + Ag L <= 2.08 (n=137)
#     Zona: 29 colunas
#     Importance: 0.001779
#   Predicado: Ar ka + Ag L > 2.08 (n=90)
#     Zona: 29 colunas
#     Importance: 0.004365
#   Predicado: Ar ka + Ag L <= 2.47 (n=184)
#     Zona: 29 colunas
#     Importance: 0.003186
#   Predicado: Ca ka > -11.34 (n=186)
#     Zona: 17 colunas
#     Importance: 0.068550
#   Predicado: Ca ka <= -9.12 (n=84)
#     Zona: 17 colunas
#     Importance: 0.301199
#   Predicado: Ca ka > -9.12 (n=143)
#     Zona: 17 colunas
#     Importance: -0.066272
#   Predicado: Ca ka <= -3.71 (n=131)
#     Zona: 17 colunas
#     Importance: 0.209099
#   Predicado: Ca ka > -3.71 (n=96)
#     Zona: 17 colunas
#     Importance: -0.120501
#   Predicado: Ca ka <= 15.99 (n=176)
#     Zona: 17 colunas
#     Importance: 0.138184
#   Predicado: Ca kb > -4.15 (n=185)
#     Zona: 13 colunas
#     Importance: -0.012404
#   Predicado: Ca kb <= -3.42 (n=84)
#     Zona: 13 colunas
#     Importance: 0.035044
#   Predicado: Ca kb > -3.42 (n=143)
#     Zona: 13 colunas
#     Importance: -0.011435
#   Predicado: Ca kb <= -2.18 (n=131)
#     Zona: 13 colunas
#     Importance: 0.029379
#   Predicado: Ca kb > -2.18 (n=96)
#     Zona: 13 colunas
#     Importance: -0.026459
#   Predicado: Ca kb <= 6.30 (n=176)
#     Zona: 13 colunas
#     Importance: 0.013284
#   Predicado: Ti ka > -11.81 (n=177)
#     Zona: 19 colunas
#     Importance: -0.326021
#   Predicado: Ti ka <= -3.08 (n=91)
#     Zona: 19 colunas
#     Importance: -0.342939
#   Predicado: Ti ka > -3.08 (n=136)
#     Zona: 19 colunas
#     Importance: -0.325886
#   Predicado: Ti ka <= 5.26 (n=139)
#     Zona: 19 colunas
#     Importance: -0.003994
#   Predicado: Ti ka > 5.26 (n=88)
#     Zona: 19 colunas
#     Importance: -0.851964
#   Predicado: Ti ka <= 9.71 (n=187)
#     Zona: 19 colunas
#     Importance: 0.239499
#   Predicado: Ti kb > -4.43 (n=180)
#     Zona: 16 colunas
#     Importance: -0.029702
#   Predicado: Ti kb <= -2.36 (n=90)
#     Zona: 16 colunas
#     Importance: -0.047756
#   Predicado: Ti kb > -2.36 (n=137)
#     Zona: 16 colunas
#     Importance: -0.025091
#   Predicado: Ti kb <= 2.64 (n=140)
#     Zona: 16 colunas
#     Importance: -0.025110
#   Predicado: Ti kb > 2.64 (n=87)
#     Zona: 16 colunas
#     Importance: -0.048507
#   Predicado: Ti kb <= 5.00 (n=187)
#     Zona: 16 colunas
#     Importance: -0.057827
#   Predicado: background2 > -2.08 (n=180)
#     Zona: 39 colunas
#     Importance: 0.005421
#   Predicado: background2 <= 2.16 (n=93)
#     Zona: 39 colunas
#     Importance: -0.004579
#   Predicado: background2 > 2.16 (n=134)
#     Zona: 39 colunas
#     Importance: 0.007985
#   Predicado: background2 <= 2.59 (n=136)
#     Zona: 39 colunas
#     Importance: -0.002246
#   Predicado: background2 > 2.59 (n=91)
#     Zona: 39 colunas
#     Importance: 0.010435
#   Predicado: background2 <= 3.28 (n=188)
#     Zona: 39 colunas
#     Importance: 0.003089
#   Predicado: Fe ka > -10.00 (n=174)
#     Zona: 25 colunas
#     Importance: 0.000397
#   Predicado: Fe ka <= -9.80 (n=81)
#     Zona: 25 colunas
#     Importance: 0.034740
#   Predicado: Fe ka > -9.80 (n=146)
#     Zona: 25 colunas
#     Importance: -0.004836
#   Predicado: Fe ka <= -9.53 (n=126)
#     Zona: 25 colunas
#     Importance: 0.035362
#   Predicado: Fe ka > -9.53 (n=101)
#     Zona: 25 colunas
#     Importance: -0.023246
#   Predicado: Fe ka <= -9.25 (n=178)
#     Zona: 25 colunas
#     Importance: 0.010083
#   Predicado: Fe kb > -3.78 (n=192)
#     Zona: 22 colunas
#     Importance: 0.002068
#   Predicado: Fe kb <= -3.54 (n=83)
#     Zona: 22 colunas
#     Importance: 0.004508
#   Predicado: Fe kb > -3.54 (n=144)
#     Zona: 22 colunas
#     Importance: -0.001658
#   Predicado: Fe kb <= -3.35 (n=133)
#     Zona: 22 colunas
#     Importance: 0.003767
#   Predicado: Fe kb > -3.35 (n=94)
#     Zona: 22 colunas
#     Importance: -0.003889
#   Predicado: Fe kb <= -3.14 (n=174)
#     Zona: 22 colunas
#     Importance: 0.001138
#   Predicado: background3 > -1.63 (n=185)
#     Zona: 18 colunas
#     Importance: -0.000182
#   Predicado: background3 <= 1.70 (n=88)
#     Zona: 18 colunas
#     Importance: -0.000337
#   Predicado: background3 > 1.70 (n=139)
#     Zona: 18 colunas
#     Importance: -0.000193
#   Predicado: background3 <= 2.09 (n=133)
#     Zona: 18 colunas
#     Importance: -0.001294
#   Predicado: background3 > 2.09 (n=94)
#     Zona: 18 colunas
#     Importance: 0.001230
#   Predicado: background3 <= 2.47 (n=178)
#     Zona: 18 colunas
#     Importance: -0.000086
#   Predicado: Cu ka > -4.62 (n=183)
#     Zona: 20 colunas
#     Importance: 0.087182
#   Predicado: Cu ka <= -4.31 (n=86)
#     Zona: 20 colunas
#     Importance: -0.041086
#   Predicado: Cu ka > -4.31 (n=141)
#     Zona: 20 colunas
#     Importance: 0.114761
#   Predicado: Cu ka <= -3.81 (n=134)
#     Zona: 20 colunas
#     Importance: -0.032057
#   Predicado: Cu ka > -3.81 (n=93)
#     Zona: 20 colunas
#     Importance: 0.182188
#   Predicado: Cu ka <= -2.19 (n=180)
#     Zona: 20 colunas
#     Importance: -0.051603
#   Predicado: Zn ka > -1.99 (n=177)
#     Zona: 21 colunas
#     Importance: 0.002058
#   Predicado: Zn ka <= -1.46 (n=93)
#     Zona: 21 colunas
#     Importance: -0.000480
#   Predicado: Zn ka > -1.46 (n=134)
#     Zona: 21 colunas
#     Importance: 0.002818
#   Predicado: Zn ka <= 2.18 (n=134)
#     Zona: 21 colunas
#     Importance: 0.000076
#   Predicado: Zn ka > 2.18 (n=93)
#     Zona: 21 colunas
#     Importance: 0.003471
#   Predicado: Zn ka <= 2.74 (n=183)
#     Zona: 21 colunas
#     Importance: 0.000133
#   Predicado: Cu kb > -2.22 (n=189)
#     Zona: 19 colunas
#     Importance: 0.003045
#   Predicado: Cu kb <= -1.94 (n=92)
#     Zona: 19 colunas
#     Importance: -0.001053
#   Predicado: Cu kb > -1.94 (n=135)
#     Zona: 19 colunas
#     Importance: 0.006439
#   Predicado: Cu kb <= 1.49 (n=133)
#     Zona: 19 colunas
#     Importance: -0.002174
#   Predicado: Cu kb > 1.49 (n=94)
#     Zona: 19 colunas
#     Importance: 0.011293
#   Predicado: Cu kb <= 2.72 (n=181)
#     Zona: 19 colunas
#     Importance: -0.000864
#   Predicado: Zn kb > -2.02 (n=183)
#     Zona: 30 colunas
#     Importance: 0.001102
#   Predicado: Zn kb <= 1.87 (n=95)
#     Zona: 30 colunas
#     Importance: -0.000341
#   Predicado: Zn kb > 1.87 (n=132)
#     Zona: 30 colunas
#     Importance: 0.001678
#   Predicado: Zn kb <= 2.27 (n=136)
#     Zona: 30 colunas
#     Importance: 0.000023
#   Predicado: Zn kb > 2.27 (n=91)
#     Zona: 30 colunas
#     Importance: 0.002044
#   Predicado: Zn kb <= 2.73 (n=180)
#     Zona: 30 colunas
#     Importance: -0.000572
#   Predicado: background4 > -3.06 (n=183)
#     Zona: 451 colunas
#     Importance: 0.006795
#   Predicado: background4 <= 2.89 (n=94)
#     Zona: 451 colunas
#     Importance: -0.002568
#   Predicado: background4 > 2.89 (n=133)
#     Zona: 451 colunas
#     Importance: 0.020548
#   Predicado: background4 <= 3.24 (n=138)
#     Zona: 451 colunas
#     Importance: 0.005468
#   Predicado: background4 > 3.24 (n=89)
#     Zona: 451 colunas
#     Importance: 0.019516
#   Predicado: background4 <= 3.54 (n=184)
#     Zona: 451 colunas
#     Importance: 0.012873
#   Predicado: Ag ka scattering > -2.84 (n=181)
#     Zona: 49 colunas
#     Importance: 0.002085
#   Predicado: Ag ka scattering <= -1.94 (n=95)
#     Zona: 49 colunas
#     Importance: -0.008425
#   Predicado: Ag ka scattering > -1.94 (n=132)
#     Zona: 49 colunas
#     Importance: 0.000060
#   Predicado: Ag ka scattering <= 2.57 (n=140)
#     Zona: 49 colunas
#     Importance: -0.041490
#   Predicado: Ag ka scattering > 2.57 (n=87)
#     Zona: 49 colunas
#     Importance: 0.057658
#   Predicado: Ag ka scattering <= 3.08 (n=185)
#     Zona: 49 colunas
#     Importance: -0.045869
#   Predicado: background5 > -2.53 (n=176)
#     Zona: 71 colunas
#     Importance: 0.002030
#   Predicado: background5 <= 2.03 (n=96)
#     Zona: 71 colunas
#     Importance: 0.002411
#   Predicado: background5 > 2.03 (n=131)
#     Zona: 71 colunas
#     Importance: 0.002060
#   Predicado: background5 <= 2.48 (n=141)
#     Zona: 71 colunas
#     Importance: 0.000512
#   Predicado: background5 > 2.48 (n=86)
#     Zona: 71 colunas
#     Importance: 0.004989
#   Predicado: background5 <= 2.88 (n=182)
#     Zona: 71 colunas
#     Importance: 0.000095
#   Predicado: background6 > -2.43 (n=182)
#     Zona: 61 colunas
#     Importance: 0.006287
#   Predicado: background6 <= 2.28 (n=91)
#     Zona: 61 colunas
#     Importance: -0.009231
#   Predicado: background6 > 2.28 (n=136)
#     Zona: 61 colunas
#     Importance: 0.008635
#   Predicado: background6 <= 2.71 (n=133)
#     Zona: 61 colunas
#     Importance: -0.005970
#   Predicado: background6 > 2.71 (n=94)
#     Zona: 61 colunas
#     Importance: 0.012003
#   Predicado: background6 <= 3.20 (n=181)
#     Zona: 61 colunas
#     Importance: -0.005409
#
# [Bag_4] Processando 108 predicados...
#   Predicado: background1 > -2.42 (n=183)
#     Zona: 69 colunas
#     Importance: 0.002575
#   Predicado: background1 <= 2.22 (n=92)
#     Zona: 69 colunas
#     Importance: 0.009175
#   Predicado: background1 > 2.22 (n=135)
#     Zona: 69 colunas
#     Importance: 0.002773
#   Predicado: background1 <= 2.53 (n=143)
#     Zona: 69 colunas
#     Importance: 0.008221
#   Predicado: background1 > 2.53 (n=84)
#     Zona: 69 colunas
#     Importance: 0.000510
#   Predicado: background1 <= 3.00 (n=181)
#     Zona: 69 colunas
#     Importance: 0.007190
#   Predicado: Ar ka + Ag L > -2.22 (n=182)
#     Zona: 29 colunas
#     Importance: 0.002299
#   Predicado: Ar ka + Ag L <= -1.64 (n=88)
#     Zona: 29 colunas
#     Importance: -0.000580
#   Predicado: Ar ka + Ag L > -1.64 (n=139)
#     Zona: 29 colunas
#     Importance: 0.002682
#   Predicado: Ar ka + Ag L <= 2.08 (n=134)
#     Zona: 29 colunas
#     Importance: 0.000157
#   Predicado: Ar ka + Ag L > 2.08 (n=93)
#     Zona: 29 colunas
#     Importance: 0.003233
#   Predicado: Ar ka + Ag L <= 2.47 (n=179)
#     Zona: 29 colunas
#     Importance: 0.001563
#   Predicado: Ca ka > -11.34 (n=183)
#     Zona: 17 colunas
#     Importance: -0.042366
#   Predicado: Ca ka <= -9.12 (n=88)
#     Zona: 17 colunas
#     Importance: 0.072645
#   Predicado: Ca ka > -9.12 (n=139)
#     Zona: 17 colunas
#     Importance: -0.128544
#   Predicado: Ca ka <= -3.71 (n=135)
#     Zona: 17 colunas
#     Importance: -0.004487
#   Predicado: Ca ka > -3.71 (n=92)
#     Zona: 17 colunas
#     Importance: -0.118143
#   Predicado: Ca ka <= 15.99 (n=183)
#     Zona: 17 colunas
#     Importance: -0.021642
#   Predicado: Ca kb > -4.15 (n=185)
#     Zona: 13 colunas
#     Importance: -0.023699
#   Predicado: Ca kb <= -3.42 (n=89)
#     Zona: 13 colunas
#     Importance: 0.006576
#   Predicado: Ca kb > -3.42 (n=138)
#     Zona: 13 colunas
#     Importance: -0.020557
#   Predicado: Ca kb <= -2.18 (n=133)
#     Zona: 13 colunas
#     Importance: 0.007150
#   Predicado: Ca kb > -2.18 (n=94)
#     Zona: 13 colunas
#     Importance: -0.034070
#   Predicado: Ca kb <= 6.30 (n=181)
#     Zona: 13 colunas
#     Importance: -0.007246
#   Predicado: Ti ka > -11.81 (n=179)
#     Zona: 19 colunas
#     Importance: -1.179245
#   Predicado: Ti ka <= -3.08 (n=91)
#     Zona: 19 colunas
#     Importance: -0.337351
#   Predicado: Ti ka > -3.08 (n=136)
#     Zona: 19 colunas
#     Importance: -1.452224
#   Predicado: Ti ka <= 5.26 (n=136)
#     Zona: 19 colunas
#     Importance: -0.004911
#   Predicado: Ti ka > 5.26 (n=91)
#     Zona: 19 colunas
#     Importance: -2.500368
#   Predicado: Ti ka <= 9.71 (n=182)
#     Zona: 19 colunas
#     Importance: 0.023604
#   Predicado: Ti kb > -4.43 (n=180)
#     Zona: 16 colunas
#     Importance: -0.167781
#   Predicado: Ti kb <= -2.36 (n=89)
#     Zona: 16 colunas
#     Importance: -0.048858
#   Predicado: Ti kb > -2.36 (n=138)
#     Zona: 16 colunas
#     Importance: -0.204488
#   Predicado: Ti kb <= 2.64 (n=135)
#     Zona: 16 colunas
#     Importance: -0.024884
#   Predicado: Ti kb > 2.64 (n=92)
#     Zona: 16 colunas
#     Importance: -0.317482
#   Predicado: Ti kb <= 5.00 (n=184)
#     Zona: 16 colunas
#     Importance: -0.093952
#   Predicado: background2 > -2.08 (n=177)
#     Zona: 39 colunas
#     Importance: -0.000035
#   Predicado: background2 <= 2.16 (n=97)
#     Zona: 39 colunas
#     Importance: -0.006289
#   Predicado: background2 > 2.16 (n=130)
#     Zona: 39 colunas
#     Importance: 0.002199
#   Predicado: background2 <= 2.59 (n=143)
#     Zona: 39 colunas
#     Importance: -0.001683
#   Predicado: background2 > 2.59 (n=84)
#     Zona: 39 colunas
#     Importance: -0.000994
#   Predicado: background2 <= 3.28 (n=192)
#     Zona: 39 colunas
#     Importance: -0.002306
#   Predicado: Fe ka > -10.00 (n=173)
#     Zona: 25 colunas
#     Importance: -0.012312
#   Predicado: Fe ka <= -9.80 (n=86)
#     Zona: 25 colunas
#     Importance: 0.018791
#   Predicado: Fe ka > -9.80 (n=141)
#     Zona: 25 colunas
#     Importance: -0.024860
#   Predicado: Fe ka <= -9.53 (n=140)
#     Zona: 25 colunas
#     Importance: 0.019347
#   Predicado: Fe ka > -9.53 (n=87)
#     Zona: 25 colunas
#     Importance: -0.052849
#   Predicado: Fe ka <= -9.25 (n=183)
#     Zona: 25 colunas
#     Importance: -0.004321
#   Predicado: Fe kb > -3.78 (n=188)
#     Zona: 22 colunas
#     Importance: -0.001569
#   Predicado: Fe kb <= -3.54 (n=84)
#     Zona: 22 colunas
#     Importance: -0.005876
#   Predicado: Fe kb > -3.54 (n=143)
#     Zona: 22 colunas
#     Importance: -0.002426
#   Predicado: Fe kb <= -3.35 (n=140)
#     Zona: 22 colunas
#     Importance: -0.001291
#   Predicado: Fe kb > -3.35 (n=87)
#     Zona: 22 colunas
#     Importance: -0.007584
#   Predicado: Fe kb <= -3.14 (n=178)
#     Zona: 22 colunas
#     Importance: -0.004609
#   Predicado: background3 > -1.63 (n=180)
#     Zona: 18 colunas
#     Importance: 0.000360
#   Predicado: background3 <= 1.70 (n=89)
#     Zona: 18 colunas
#     Importance: -0.001027
#   Predicado: background3 > 1.70 (n=138)
#     Zona: 18 colunas
#     Importance: 0.000709
#   Predicado: background3 <= 2.09 (n=133)
#     Zona: 18 colunas
#     Importance: -0.000569
#   Predicado: background3 > 2.09 (n=94)
#     Zona: 18 colunas
#     Importance: 0.000874
#   Predicado: background3 <= 2.47 (n=178)
#     Zona: 18 colunas
#     Importance: 0.000319
#   Predicado: Cu ka > -4.62 (n=188)
#     Zona: 20 colunas
#     Importance: 0.076152
#   Predicado: Cu ka <= -4.31 (n=85)
#     Zona: 20 colunas
#     Importance: -0.003578
#   Predicado: Cu ka > -4.31 (n=142)
#     Zona: 20 colunas
#     Importance: 0.091592
#   Predicado: Cu ka <= -3.81 (n=131)
#     Zona: 20 colunas
#     Importance: -0.003701
#   Predicado: Cu ka > -3.81 (n=96)
#     Zona: 20 colunas
#     Importance: 0.137361
#   Predicado: Cu ka <= -2.19 (n=179)
#     Zona: 20 colunas
#     Importance: -0.000586
#   Predicado: Zn ka > -1.99 (n=180)
#     Zona: 21 colunas
#     Importance: 0.000164
#   Predicado: Zn ka <= -1.46 (n=88)
#     Zona: 21 colunas
#     Importance: -0.000642
#   Predicado: Zn ka > -1.46 (n=139)
#     Zona: 21 colunas
#     Importance: 0.000372
#   Predicado: Zn ka <= 2.18 (n=134)
#     Zona: 21 colunas
#     Importance: -0.000380
#   Predicado: Zn ka > 2.18 (n=93)
#     Zona: 21 colunas
#     Importance: 0.000495
#   Predicado: Zn ka <= 2.74 (n=183)
#     Zona: 21 colunas
#     Importance: -0.000289
#   Predicado: Cu kb > -2.22 (n=185)
#     Zona: 19 colunas
#     Importance: 0.002434
#   Predicado: Cu kb <= -1.94 (n=95)
#     Zona: 19 colunas
#     Importance: -0.000831
#   Predicado: Cu kb > -1.94 (n=132)
#     Zona: 19 colunas
#     Importance: 0.005815
#   Predicado: Cu kb <= 1.49 (n=138)
#     Zona: 19 colunas
#     Importance: 0.001182
#   Predicado: Cu kb > 1.49 (n=89)
#     Zona: 19 colunas
#     Importance: 0.005904
#   Predicado: Cu kb <= 2.72 (n=181)
#     Zona: 19 colunas
#     Importance: 0.001667
#   Predicado: Zn kb > -2.02 (n=181)
#     Zona: 30 colunas
#     Importance: 0.000645
#   Predicado: Zn kb <= 1.87 (n=89)
#     Zona: 30 colunas
#     Importance: -0.000546
#   Predicado: Zn kb > 1.87 (n=138)
#     Zona: 30 colunas
#     Importance: 0.001265
#   Predicado: Zn kb <= 2.27 (n=137)
#     Zona: 30 colunas
#     Importance: 0.000013
#   Predicado: Zn kb > 2.27 (n=90)
#     Zona: 30 colunas
#     Importance: 0.001380
#   Predicado: Zn kb <= 2.73 (n=179)
#     Zona: 30 colunas
#     Importance: -0.000689
#   Predicado: background4 > -3.06 (n=180)
#     Zona: 451 colunas
#     Importance: -0.020846
#   Predicado: background4 <= 2.89 (n=93)
#     Zona: 451 colunas
#     Importance: -0.005002
#   Predicado: background4 > 2.89 (n=134)
#     Zona: 451 colunas
#     Importance: -0.015873
#   Predicado: background4 <= 3.24 (n=140)
#     Zona: 451 colunas
#     Importance: 0.011536
#   Predicado: background4 > 3.24 (n=87)
#     Zona: 451 colunas
#     Importance: -0.048360
#   Predicado: background4 <= 3.54 (n=187)
#     Zona: 451 colunas
#     Importance: 0.015512
#   Predicado: Ag ka scattering > -2.84 (n=183)
#     Zona: 49 colunas
#     Importance: -0.017190
#   Predicado: Ag ka scattering <= -1.94 (n=87)
#     Zona: 49 colunas
#     Importance: -0.006582
#   Predicado: Ag ka scattering > -1.94 (n=140)
#     Zona: 49 colunas
#     Importance: -0.027531
#   Predicado: Ag ka scattering <= 2.57 (n=131)
#     Zona: 49 colunas
#     Importance: -0.048289
#   Predicado: Ag ka scattering > 2.57 (n=96)
#     Zona: 49 colunas
#     Importance: 0.019781
#   Predicado: Ag ka scattering <= 3.08 (n=179)
#     Zona: 49 colunas
#     Importance: -0.052093
#   Predicado: background5 > -2.53 (n=178)
#     Zona: 71 colunas
#     Importance: -0.000663
#   Predicado: background5 <= 2.03 (n=94)
#     Zona: 71 colunas
#     Importance: 0.002919
#   Predicado: background5 > 2.03 (n=133)
#     Zona: 71 colunas
#     Importance: -0.001839
#   Predicado: background5 <= 2.48 (n=140)
#     Zona: 71 colunas
#     Importance: 0.001143
#   Predicado: background5 > 2.48 (n=87)
#     Zona: 71 colunas
#     Importance: -0.001496
#   Predicado: background5 <= 2.88 (n=183)
#     Zona: 71 colunas
#     Importance: -0.000856
#   Predicado: background6 > -2.43 (n=182)
#     Zona: 61 colunas
#     Importance: -0.000864
#   Predicado: background6 <= 2.28 (n=88)
#     Zona: 61 colunas
#     Importance: -0.008131
#   Predicado: background6 > 2.28 (n=139)
#     Zona: 61 colunas
#     Importance: -0.001306
#   Predicado: background6 <= 2.71 (n=131)
#     Zona: 61 colunas
#     Importance: -0.020482
#   Predicado: background6 > 2.71 (n=96)
#     Zona: 61 colunas
#     Importance: 0.018605
#   Predicado: background6 <= 3.20 (n=178)
#     Zona: 61 colunas
#     Importance: -0.014092
#
# [Bag_5] Processando 108 predicados...
#   Predicado: background1 > -2.42 (n=183)
#     Zona: 69 colunas
#     Importance: 0.001783
#   Predicado: background1 <= 2.22 (n=90)
#     Zona: 69 colunas
#     Importance: 0.007769
#   Predicado: background1 > 2.22 (n=137)
#     Zona: 69 colunas
#     Importance: 0.002234
#   Predicado: background1 <= 2.53 (n=137)
#     Zona: 69 colunas
#     Importance: 0.006588
#   Predicado: background1 > 2.53 (n=90)
#     Zona: 69 colunas
#     Importance: 0.001141
#   Predicado: background1 <= 3.00 (n=181)
#     Zona: 69 colunas
#     Importance: 0.005945
#   Predicado: Ar ka + Ag L > -2.22 (n=181)
#     Zona: 29 colunas
#     Importance: 0.001387
#   Predicado: Ar ka + Ag L <= -1.64 (n=89)
#     Zona: 29 colunas
#     Importance: -0.000910
#   Predicado: Ar ka + Ag L > -1.64 (n=138)
#     Zona: 29 colunas
#     Importance: 0.001579
#   Predicado: Ar ka + Ag L <= 2.08 (n=134)
#     Zona: 29 colunas
#     Importance: -0.000256
#   Predicado: Ar ka + Ag L > 2.08 (n=93)
#     Zona: 29 colunas
#     Importance: 0.001841
#   Predicado: Ar ka + Ag L <= 2.47 (n=181)
#     Zona: 29 colunas
#     Importance: 0.001290
#   Predicado: Ca ka > -11.34 (n=181)
#     Zona: 17 colunas
#     Importance: -0.111950
#   Predicado: Ca ka <= -9.12 (n=91)
#     Zona: 17 colunas
#     Importance: 0.091981
#   Predicado: Ca ka > -9.12 (n=136)
#     Zona: 17 colunas
#     Importance: -0.129280
#   Predicado: Ca ka <= -3.71 (n=136)
#     Zona: 17 colunas
#     Importance: 0.004257
#   Predicado: Ca ka > -3.71 (n=91)
#     Zona: 17 colunas
#     Importance: -0.107592
#   Predicado: Ca ka <= 15.99 (n=184)
#     Zona: 17 colunas
#     Importance: -0.010396
#   Predicado: Ca kb > -4.15 (n=187)
#     Zona: 13 colunas
#     Importance: -0.023718
#   Predicado: Ca kb <= -3.42 (n=92)
#     Zona: 13 colunas
#     Importance: 0.010936
#   Predicado: Ca kb > -3.42 (n=135)
#     Zona: 13 colunas
#     Importance: -0.020866
#   Predicado: Ca kb <= -2.18 (n=137)
#     Zona: 13 colunas
#     Importance: 0.009473
#   Predicado: Ca kb > -2.18 (n=90)
#     Zona: 13 colunas
#     Importance: -0.034540
#   Predicado: Ca kb <= 6.30 (n=183)
#     Zona: 13 colunas
#     Importance: -0.005026
#   Predicado: Ti ka > -11.81 (n=183)
#     Zona: 19 colunas
#     Importance: -1.163580
#   Predicado: Ti ka <= -3.08 (n=88)
#     Zona: 19 colunas
#     Importance: -0.332177
#   Predicado: Ti ka > -3.08 (n=139)
#     Zona: 19 colunas
#     Importance: -1.434067
#   Predicado: Ti ka <= 5.26 (n=133)
#     Zona: 19 colunas
#     Importance: 0.025759
#   Predicado: Ti ka > 5.26 (n=94)
#     Zona: 19 colunas
#     Importance: -2.468009
#   Predicado: Ti ka <= 9.71 (n=181)
#     Zona: 19 colunas
#     Importance: -0.086592
#   Predicado: Ti kb > -4.43 (n=184)
#     Zona: 16 colunas
#     Importance: -0.173513
#   Predicado: Ti kb <= -2.36 (n=86)
#     Zona: 16 colunas
#     Importance: -0.048762
#   Predicado: Ti kb > -2.36 (n=141)
#     Zona: 16 colunas
#     Importance: -0.212046
#   Predicado: Ti kb <= 2.64 (n=133)
#     Zona: 16 colunas
#     Importance: -0.022160
#   Predicado: Ti kb > 2.64 (n=94)
#     Zona: 16 colunas
#     Importance: -0.331327
#   Predicado: Ti kb <= 5.00 (n=180)
#     Zona: 16 colunas
#     Importance: -0.107531
#   Predicado: background2 > -2.08 (n=183)
#     Zona: 39 colunas
#     Importance: -0.000122
#   Predicado: background2 <= 2.16 (n=86)
#     Zona: 39 colunas
#     Importance: -0.004197
#   Predicado: background2 > 2.16 (n=141)
#     Zona: 39 colunas
#     Importance: 0.000029
#   Predicado: background2 <= 2.59 (n=128)
#     Zona: 39 colunas
#     Importance: -0.000223
#   Predicado: background2 > 2.59 (n=99)
#     Zona: 39 colunas
#     Importance: -0.003317
#   Predicado: background2 <= 3.28 (n=177)
#     Zona: 39 colunas
#     Importance: -0.001296
#   Predicado: Fe ka > -10.00 (n=173)
#     Zona: 25 colunas
#     Importance: -0.012691
#   Predicado: Fe ka <= -9.80 (n=88)
#     Zona: 25 colunas
#     Importance: 0.012073
#   Predicado: Fe ka > -9.80 (n=139)
#     Zona: 25 colunas
#     Importance: -0.021891
#   Predicado: Fe ka <= -9.53 (n=139)
#     Zona: 25 colunas
#     Importance: 0.014081
#   Predicado: Fe ka > -9.53 (n=88)
#     Zona: 25 colunas
#     Importance: -0.044746
#   Predicado: Fe ka <= -9.25 (n=186)
#     Zona: 25 colunas
#     Importance: -0.003105
#   Predicado: Fe kb > -3.78 (n=191)
#     Zona: 22 colunas
#     Importance: -0.001904
#   Predicado: Fe kb <= -3.54 (n=88)
#     Zona: 22 colunas
#     Importance: -0.004758
#   Predicado: Fe kb > -3.54 (n=139)
#     Zona: 22 colunas
#     Importance: -0.003599
#   Predicado: Fe kb <= -3.35 (n=140)
#     Zona: 22 colunas
#     Importance: -0.002844
#   Predicado: Fe kb > -3.35 (n=87)
#     Zona: 22 colunas
#     Importance: -0.005985
#   Predicado: Fe kb <= -3.14 (n=177)
#     Zona: 22 colunas
#     Importance: -0.004485
#   Predicado: background3 > -1.63 (n=182)
#     Zona: 18 colunas
#     Importance: 0.000551
#   Predicado: background3 <= 1.70 (n=91)
#     Zona: 18 colunas
#     Importance: -0.000539
#   Predicado: background3 > 1.70 (n=136)
#     Zona: 18 colunas
#     Importance: 0.000719
#   Predicado: background3 <= 2.09 (n=131)
#     Zona: 18 colunas
#     Importance: -0.000112
#   Predicado: background3 > 2.09 (n=96)
#     Zona: 18 colunas
#     Importance: 0.000660
#   Predicado: background3 <= 2.47 (n=181)
#     Zona: 18 colunas
#     Importance: 0.000585
#   Predicado: Cu ka > -4.62 (n=182)
#     Zona: 20 colunas
#     Importance: 0.103514
#   Predicado: Cu ka <= -4.31 (n=88)
#     Zona: 20 colunas
#     Importance: -0.050999
#   Predicado: Cu ka > -4.31 (n=139)
#     Zona: 20 colunas
#     Importance: 0.147770
#   Predicado: Cu ka <= -3.81 (n=137)
#     Zona: 20 colunas
#     Importance: -0.031167
#   Predicado: Cu ka > -3.81 (n=90)
#     Zona: 20 colunas
#     Importance: 0.225801
#   Predicado: Cu ka <= -2.19 (n=180)
#     Zona: 20 colunas
#     Importance: -0.004526
#   Predicado: Zn ka > -1.99 (n=181)
#     Zona: 21 colunas
#     Importance: -0.001121
#   Predicado: Zn ka <= -1.46 (n=92)
#     Zona: 21 colunas
#     Importance: -0.001831
#   Predicado: Zn ka > -1.46 (n=135)
#     Zona: 21 colunas
#     Importance: -0.000410
#   Predicado: Zn ka <= 2.18 (n=138)
#     Zona: 21 colunas
#     Importance: -0.001126
#   Predicado: Zn ka > 2.18 (n=89)
#     Zona: 21 colunas
#     Importance: -0.000769
#   Predicado: Zn ka <= 2.74 (n=184)
#     Zona: 21 colunas
#     Importance: -0.001199
#   Predicado: Cu kb > -2.22 (n=191)
#     Zona: 19 colunas
#     Importance: 0.003182
#   Predicado: Cu kb <= -1.94 (n=90)
#     Zona: 19 colunas
#     Importance: -0.000244
#   Predicado: Cu kb > -1.94 (n=137)
#     Zona: 19 colunas
#     Importance: 0.005982
#   Predicado: Cu kb <= 1.49 (n=132)
#     Zona: 19 colunas
#     Importance: 0.002121
#   Predicado: Cu kb > 1.49 (n=95)
#     Zona: 19 colunas
#     Importance: 0.005449
#   Predicado: Cu kb <= 2.72 (n=179)
#     Zona: 19 colunas
#     Importance: 0.002422
#   Predicado: Zn kb > -2.02 (n=183)
#     Zona: 30 colunas
#     Importance: 0.000629
#   Predicado: Zn kb <= 1.87 (n=90)
#     Zona: 30 colunas
#     Importance: -0.000488
#   Predicado: Zn kb > 1.87 (n=137)
#     Zona: 30 colunas
#     Importance: 0.001288
#   Predicado: Zn kb <= 2.27 (n=134)
#     Zona: 30 colunas
#     Importance: -0.000198
#   Predicado: Zn kb > 2.27 (n=93)
#     Zona: 30 colunas
#     Importance: 0.001711
#   Predicado: Zn kb <= 2.73 (n=179)
#     Zona: 30 colunas
#     Importance: -0.000715
#   Predicado: background4 > -3.06 (n=178)
#     Zona: 451 colunas
#     Importance: -0.025848
#   Predicado: background4 <= 2.89 (n=90)
#     Zona: 451 colunas
#     Importance: -0.003510
#   Predicado: background4 > 2.89 (n=137)
#     Zona: 451 colunas
#     Importance: -0.023136
#   Predicado: background4 <= 3.24 (n=134)
#     Zona: 451 colunas
#     Importance: 0.006608
#   Predicado: background4 > 3.24 (n=93)
#     Zona: 451 colunas
#     Importance: -0.047000
#   Predicado: background4 <= 3.54 (n=183)
#     Zona: 451 colunas
#     Importance: 0.014055
#   Predicado: Ag ka scattering > -2.84 (n=182)
#     Zona: 49 colunas
#     Importance: -0.018410
#   Predicado: Ag ka scattering <= -1.94 (n=93)
#     Zona: 49 colunas
#     Importance: -0.000639
#   Predicado: Ag ka scattering > -1.94 (n=134)
#     Zona: 49 colunas
#     Importance: -0.029852
#   Predicado: Ag ka scattering <= 2.57 (n=138)
#     Zona: 49 colunas
#     Importance: -0.037076
#   Predicado: Ag ka scattering > 2.57 (n=89)
#     Zona: 49 colunas
#     Importance: 0.011875
#   Predicado: Ag ka scattering <= 3.08 (n=177)
#     Zona: 49 colunas
#     Importance: -0.050058
#   Predicado: background5 > -2.53 (n=180)
#     Zona: 71 colunas
#     Importance: -0.002091
#   Predicado: background5 <= 2.03 (n=90)
#     Zona: 71 colunas
#     Importance: 0.002058
#   Predicado: background5 > 2.03 (n=137)
#     Zona: 71 colunas
#     Importance: -0.003201
#   Predicado: background5 <= 2.48 (n=141)
#     Zona: 71 colunas
#     Importance: -0.000445
#   Predicado: background5 > 2.48 (n=86)
#     Zona: 71 colunas
#     Importance: -0.002216
#   Predicado: background5 <= 2.88 (n=183)
#     Zona: 71 colunas
#     Importance: -0.001534
#   Predicado: background6 > -2.43 (n=177)
#     Zona: 61 colunas
#     Importance: -0.007223
#   Predicado: background6 <= 2.28 (n=93)
#     Zona: 61 colunas
#     Importance: -0.007431
#   Predicado: background6 > 2.28 (n=134)
#     Zona: 61 colunas
#     Importance: -0.007552
#   Predicado: background6 <= 2.71 (n=136)
#     Zona: 61 colunas
#     Importance: -0.019389
#   Predicado: background6 > 2.71 (n=91)
#     Zona: 61 colunas
#     Importance: 0.010262
#   Predicado: background6 <= 3.20 (n=182)
#     Zona: 61 colunas
#     Importance: -0.013063
#
# [Bag_6] Processando 109 predicados...
#   Predicado: background1 > -2.42 (n=185)
#     Zona: 69 colunas
#     Importance: 0.004557
#   Predicado: background1 <= 2.22 (n=92)
#     Zona: 69 colunas
#     Importance: 0.004436
#   Predicado: background1 > 2.22 (n=135)
#     Zona: 69 colunas
#     Importance: 0.005588
#   Predicado: background1 <= 2.53 (n=142)
#     Zona: 69 colunas
#     Importance: 0.005386
#   Predicado: background1 > 2.53 (n=85)
#     Zona: 69 colunas
#     Importance: 0.004679
#   Predicado: background1 <= 3.00 (n=187)
#     Zona: 69 colunas
#     Importance: 0.006612
#   Predicado: Ar ka + Ag L > -2.22 (n=180)
#     Zona: 29 colunas
#     Importance: 0.000232
#   Predicado: Ar ka + Ag L <= -1.64 (n=93)
#     Zona: 29 colunas
#     Importance: -0.002492
#   Predicado: Ar ka + Ag L > -1.64 (n=134)
#     Zona: 29 colunas
#     Importance: 0.000741
#   Predicado: Ar ka + Ag L <= 2.08 (n=138)
#     Zona: 29 colunas
# ...
# Mantida aresta background6 <= 2.71 -> Ca kb > -3.42 (peso 98.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > -3.42 -> Fe ka > -9.53 (peso 80.0)
# Mantida aresta Fe ka > -9.53 -> Ca kb > -3.42 (peso 80.0)
#
# ======================================================================
#
# Removida aresta background4 > 3.24 -> background6 <= 2.71 (peso 67.0)
# Mantida aresta background6 <= 2.71 -> background4 > 3.24 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.71 -> background4 > 3.24 (peso 46.0)
# Mantida aresta background4 > 3.24 -> background6 > 2.71 (peso 46.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.80 -> background6 <= 2.71 (peso 69.0)
# Mantida aresta background6 <= 2.71 -> Fe ka <= -9.80 (peso 69.0)
#
# ======================================================================
#
# Removida aresta background6 <= 2.71 -> Fe ka <= -9.53 (peso 104.0)
# Mantida aresta Fe ka <= -9.53 -> background6 <= 2.71 (peso 208.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 3.20 -> background4 <= 3.54 (peso 354.0)
# Mantida aresta background4 <= 3.54 -> background6 <= 3.20 (peso 354.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 3.20 -> background6 > 2.71 (peso 56.0)
# Mantida aresta background6 > 2.71 -> background6 <= 3.20 (peso 56.0)
#
# ======================================================================
#
# Removida aresta background6 > 2.28 -> background5 > 2.48 (peso 75.0)
# Mantida aresta background5 > 2.48 -> background6 > 2.28 (peso 150.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.28 -> background1 > -2.42 (peso 146.0)
# Mantida aresta background1 > -2.42 -> background6 > 2.28 (peso 146.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.59 -> background6 <= 2.28 (peso 106.0)
# Mantida aresta background6 <= 2.28 -> background2 > 2.59 (peso 106.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -9.25 -> background4 > 2.89 (peso 137.0)
# Mantida aresta background4 > 2.89 -> Fe ka <= -9.25 (peso 137.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > 1.87 -> Fe ka <= -9.25 (peso 138.0)
# Mantida aresta Fe ka <= -9.25 -> Zn kb > 1.87 (peso 138.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.59 -> background1 <= 2.22 (peso 42.0)
# Mantida aresta background1 <= 2.22 -> background2 > 2.59 (peso 42.0)
#
# ======================================================================
#
# Removida aresta background1 <= 3.00 -> background1 <= 2.22 (peso 113.0)
# Mantida aresta background1 <= 2.22 -> background1 <= 3.00 (peso 339.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 2.53 -> background1 <= 2.22 (peso 113.0)
# Mantida aresta background1 <= 2.22 -> background1 <= 2.53 (peso 113.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.59 -> background2 > 2.16 (peso 116.0)
# Mantida aresta background2 > 2.16 -> background2 > 2.59 (peso 116.0)
#
# ======================================================================
#
# Removida aresta background1 <= 3.00 -> background2 > 2.16 (peso 137.0)
# Mantida aresta background2 > 2.16 -> background1 <= 3.00 (peso 274.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 2.16 -> background1 <= 2.53 (peso 194.0)
# Mantida aresta background1 <= 2.53 -> background2 > 2.16 (peso 194.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.16 -> background2 > 2.16 (peso 0.0)
# Mantida aresta background2 > 2.16 -> background2 <= 2.16 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 6.30 -> Fe ka <= -9.80 (peso 96.0)
# Mantida aresta Fe ka <= -9.80 -> Ca kb <= 6.30 (peso 192.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.16 -> Fe kb > -3.35 (peso 38.0)
# Mantida aresta Fe kb > -3.35 -> background2 <= 2.16 (peso 38.0)
#
# ======================================================================
#
# Removida aresta background2 > -2.08 -> background1 > 2.53 (peso 90.0)
# Mantida aresta background1 > 2.53 -> background2 > -2.08 (peso 180.0)
#
# ======================================================================
#
# Removida aresta background6 > 2.71 -> background4 <= 3.54 (peso 91.0)
# Mantida aresta background4 <= 3.54 -> background6 > 2.71 (peso 182.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 2.71 -> background4 <= 3.24 (peso 68.0)
# Mantida aresta background4 <= 3.24 -> background6 > 2.71 (peso 68.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= -1.64 -> background3 > 2.09 (peso 45.0)
# Mantida aresta background3 > 2.09 -> Ar ka + Ag L <= -1.64 (peso 45.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= -1.64 -> background5 > 2.03 (peso 68.0)
# Mantida aresta background5 > 2.03 -> Ar ka + Ag L <= -1.64 (peso 68.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= -1.64 -> Zn kb > 1.87 (peso 64.0)
# Mantida aresta Zn kb > 1.87 -> Ar ka + Ag L <= -1.64 (peso 64.0)
#
# ======================================================================
#
# Removida aresta Fe kb > -3.54 -> Ar ka + Ag L > -1.64 (peso 103.0)
# Mantida aresta Ar ka + Ag L > -1.64 -> Fe kb > -3.54 (peso 206.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > 2.22 -> background5 > 2.48 (peso 134.0)
# Mantida aresta background5 > 2.48 -> background1 > 2.22 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 3.28 -> Zn kb > 2.27 (peso 90.0)
# Mantida aresta Zn kb > 2.27 -> background2 <= 3.28 (peso 90.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > 2.18 -> Zn ka <= 2.18 (peso 0.0)
# Mantida aresta Zn ka <= 2.18 -> Zn ka > 2.18 (peso 0.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > -1.64 -> Zn ka <= -1.46 (peso 146.0)
# Mantida aresta Zn ka <= -1.46 -> Ar ka + Ag L > -1.64 (peso 146.0)
#
# ======================================================================
#
# Removida aresta Zn kb > 2.27 -> Ag ka scattering <= -1.94 (peso 49.0)
# Mantida aresta Ag ka scattering <= -1.94 -> Zn kb > 2.27 (peso 98.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.46 -> Zn kb > 2.27 (peso 62.0)
# Mantida aresta Zn kb > 2.27 -> Zn ka > -1.46 (peso 62.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= -3.14 -> background3 > -1.63 (peso 177.0)
# Mantida aresta background3 > -1.63 -> Fe kb <= -3.14 (peso 177.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= -1.94 -> Ar ka + Ag L <= 2.08 (peso 67.0)
# Mantida aresta Ar ka + Ag L <= 2.08 -> Cu kb <= -1.94 (peso 67.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= -1.94 -> background5 <= 2.48 (peso 72.0)
# Mantida aresta background5 <= 2.48 -> Cu kb <= -1.94 (peso 72.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -1.99 -> Ar ka + Ag L <= 2.08 (peso 138.0)
# Mantida aresta Ar ka + Ag L <= 2.08 -> Zn ka > -1.99 (peso 276.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 2.08 -> Zn kb > -2.02 (peso 135.0)
# Mantida aresta Zn kb > -2.02 -> Ar ka + Ag L <= 2.08 (peso 270.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 2.88 -> background3 > 2.09 (peso 92.0)
# Mantida aresta background3 > 2.09 -> background5 <= 2.88 (peso 92.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 2.59 -> Cu kb <= 2.72 (peso 139.0)
# Mantida aresta Cu kb <= 2.72 -> background2 <= 2.59 (peso 139.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka <= 2.74 -> Zn ka > -1.46 (peso 114.0)
# Mantida aresta Zn ka > -1.46 -> Zn ka <= 2.74 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 2.48 -> Zn kb <= 2.73 (peso 140.0)
# Mantida aresta Zn kb <= 2.73 -> background5 <= 2.48 (peso 140.0)
#
# ======================================================================
#
# Removida aresta background5 > -2.53 -> Zn ka <= 2.74 (peso 175.0)
# Mantida aresta Zn ka <= 2.74 -> background5 > -2.53 (peso 350.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > -2.22 -> background5 <= 2.03 (peso 92.0)
# Mantida aresta background5 <= 2.03 -> Ar ka + Ag L > -2.22 (peso 92.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 2.47 -> Ar ka + Ag L > -2.22 (peso 171.0)
# Mantida aresta Ar ka + Ag L > -2.22 -> Ar ka + Ag L <= 2.47 (peso 342.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= 2.72 -> Zn kb <= 1.87 (peso 94.0)
# Mantida aresta Zn kb <= 1.87 -> Cu kb <= 2.72 (peso 94.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= -3.54 -> Fe kb <= -3.35 (peso 111.0)
# Mantida aresta Fe kb <= -3.35 -> Fe kb <= -3.54 (peso 111.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb > -3.78 -> background3 > 2.09 (peso 97.0)
# Mantida aresta background3 > 2.09 -> Fe kb > -3.78 (peso 97.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 2.09 -> background3 > 2.09 (peso 0.0)
# Mantida aresta background3 > 2.09 -> background3 <= 2.09 (peso 0.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > -2.53 -> background3 <= 2.09 (peso 134.0)
# Mantida aresta background3 <= 2.09 -> background5 > -2.53 (peso 134.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 2.09 -> Fe kb > -3.78 (peso 140.0)
# Mantida aresta Fe kb > -3.78 -> background3 <= 2.09 (peso 140.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > -2.02 -> background5 > -2.53 (peso 183.0)
# Mantida aresta background5 > -2.53 -> Zn kb > -2.02 (peso 183.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb <= 1.49 -> Zn kb <= 2.73 (peso 139.0)
# Mantida aresta Zn kb <= 2.73 -> Cu kb <= 1.49 (peso 139.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu kb > -2.22 -> background3 > 1.70 (peso 140.0)
# Mantida aresta background3 > 1.70 -> Cu kb > -2.22 (peso 140.0)
#
# ======================================================================
#
# Removida aresta background3 > 1.70 -> background3 > -1.63 (peso 169.0)
# Mantida aresta background3 > -1.63 -> background3 > 1.70 (peso 507.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 1.70 -> background3 <= 2.47 (peso 113.0)
# Mantida aresta background3 <= 2.47 -> background3 > 1.70 (peso 113.0)
#
# ======================================================================
#
# Removida aresta background3 > 1.70 -> Zn kb <= 1.87 (peso 73.0)
# Mantida aresta Zn kb <= 1.87 -> background3 > 1.70 (peso 146.0)
#
# ======================================================================
#
# Removida aresta background3 <= 2.47 -> background3 > -1.63 (peso 172.0)
# Mantida aresta background3 > -1.63 -> background3 <= 2.47 (peso 344.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > -1.63 -> Zn kb <= 2.27 (peso 137.0)
# Mantida aresta Zn kb <= 2.27 -> background3 > -1.63 (peso 137.0)
#
# ======================================================================
#
# Removida aresta background3 <= 2.47 -> Zn kb <= 1.87 (peso 89.0)
# Mantida aresta Zn kb <= 1.87 -> background3 <= 2.47 (peso 178.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 1.87 -> Zn kb <= 2.73 (peso 115.0)
# Mantida aresta Zn kb <= 2.73 -> Zn kb <= 1.87 (peso 115.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb <= 1.87 -> background3 <= 1.70 (peso 42.0)
# Mantida aresta background3 <= 1.70 -> Zn kb <= 1.87 (peso 42.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 1.70 -> background3 <= 2.47 (peso 115.0)
# Mantida aresta background3 <= 2.47 -> background3 <= 1.70 (peso 115.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 896
# Total de arestas removidas por bidirecionalidade: 101
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 109
# Total de nós terminais: 2
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
# Processando LRC do grafo...
#
# Processando LRC do grafo...
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#     Predicate_pert_Seed_0 Predicate_pert_Seed_1      Predicate_pert_Seed_2  \
# 0            Ti ka > 5.26          Ti ka > 5.26              Ti ka > -3.08
# 1           Ti ka > -3.08         Ti ka > -3.08               Ti ka > 5.26
# 2     background4 <= 3.54        Ca ka <= -3.71             Ti ka > -11.81
# 3     background2 <= 3.28        Ca ka <= 15.99             Ca ka <= -3.71
# 4      background3 > 1.70        Ti ka <= -3.08        background1 <= 3.00
# ..                    ...                   ...                        ...
# 107   background4 <= 2.89          Cu kb > 1.49  Ag ka scattering <= -1.94
# 108   background2 <= 2.16        Zn ka <= -1.46              Zn ka > -1.46
# 109               Class_A         Fe kb > -3.14                    Class_A
# 110               Class_B               Class_A                    Class_B
# 111                   NaN               Class_B                        NaN
#
#     Predicate_pert_Seed_3
# 0            Ti ka > 5.26
# 1           Ti ka > -3.08
# 2          Ti ka > -11.81
# 3           Ti kb > -2.36
# 4          Ca ka <= -3.71
# ..                    ...
# 107   background6 <= 2.28
# 108       Fe ka <= -10.00
# 109               Class_A
# 110               Class_B
# 111                   NaN
#
# [112 rows x 4 columns]

# %%
from collections import defaultdict

# Coletar posições de cada predicado em cada seed do lrc_pert_all_seeds_df
positions_dict_lrc = defaultdict(list) # o defaultdict cria listas vazias automaticamente

# Iterar sobre cada coluna do dataframe lrc_pert_all_seeds_df
for col in lrc_pert_all_seeds_df.columns:
    # Pegar os predicados da coluna (não-nulos)
    predicates_in_seed = lrc_pert_all_seeds_df[col].dropna().tolist()
    
    # Para cada predicado, guardar sua posição (1-based)
    for position, predicate in enumerate(predicates_in_seed, start=1):
        positions_dict_lrc[predicate].append(position)

# Calcular média e número de aparições
results_lrc = []
for predicate, positions in positions_dict_lrc.items():
    zone_row = predicates_quantiles[0].loc[predicates_quantiles[0]['rule'] == predicate, 'zone']
    zone_value = zone_row.values[0] if not zone_row.empty else None
    results_lrc.append({
        'Predicate': predicate,
        'Mean_Position': np.mean(positions),
        'Appearances': len(positions),
        'Zone': zone_value
    })

# Ordenar: menor posição média primeiro, mais aparições em caso de empate
ranking_lrc_pert_df = pd.DataFrame(results_lrc).sort_values(
    by=['Mean_Position', 'Appearances'], 
    ascending=[True, False]
).reset_index(drop=True)

# Lista final ordenada
lista_ordenada_lrc = ranking_lrc_pert_df['Predicate'].tolist()
ranking_lrc_pert_df
# Out:
#                      Predicate  Mean_Position  Appearances              Zone
# 0                 Ti ka > 5.26           1.25            4             Ti ka
# 1                Ti ka > -3.08           1.75            4             Ti ka
# 2          background1 <= 2.22           8.75            4       background1
# 3          background1 <= 3.00          10.00            4       background1
# 4                Ti kb > -2.36          10.75            4             Ti kb
# ..                         ...            ...          ...               ...
# 107             Cu kb <= -1.94         101.25            4             Cu kb
# 108  Ag ka scattering <= -1.94         102.75            4  Ag ka scattering
# 109              Fe kb > -3.14         110.00            1             Fe kb
# 110                    Class_A         110.25            4              None
# 111                    Class_B         111.25            4              None
#
# [112 rows x 4 columns]

# %%
ranking_pert_lrc_unique_df = ranking_lrc_pert_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
ranking_pert_lrc_unique_df['Zone']
# Out:
# 0                Ti ka
# 1          background1
# 2                Ti kb
# 3                Cu ka
# 4          background4
# 5                Ca ka
# 6     Ag ka scattering
# 7          background2
# 8          background3
# 9                Ca kb
# 10               Cu kb
# 11               Fe kb
# 12               Zn kb
# 13               Fe ka
# 14         background6
# 15        Ar ka + Ag L
# 16         background5
# 17               Zn ka
# 18                None
# Name: Zone, dtype: object

# %%
with pd.ExcelWriter('Perturbation_method.xlsx') as writer:
    # Primeiro: salvar os rankings médios
    ranking_lrc_pert_df.to_excel(writer, sheet_name='Mean_LRC', index=False)
    ranking_pert_lrc_unique_df.to_excel(writer, sheet_name='Mean_LRC_Unique', index=False)
    
    # Segundo: salvar os LRCs por seed
    for seed in random_seeds:
        lrc_pert_by_seed[seed].to_excel(writer, sheet_name=f'LRC_seed_{seed}', index=False)
    
    # Terceiro: salvar os resultados de perturbação por bag e seed
    for seed in random_seeds:
        for bag_name, df in all_results_pert[seed]['pert_results_dict'].items():
            # Criar nome único: seed_0_Bag_1, seed_1_Bag_1, etc.
            sheet_name = f'seed_{seed}_{bag_name}'[:31]  # Excel limita a 31 caracteres
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# %% [markdown]
# # **Permutation**

# %%
ranking_perm_lrc_unique_df = pd.read_excel('Permutation_method.xlsx', sheet_name='Mean_LRC_Unique')
ranking_perm_lrc_unique_df['Zone']
# Out:
# 0                Ti ka
# 1                Cu ka
# 2                Ca ka
# 3     Ag ka scattering
# 4                Ti kb
# 5                Fe ka
# 6                Ca kb
# 7          background4
# 8          background6
# 9                Fe kb
# 10               Cu kb
# 11               Zn ka
# 12         background2
# 13         background1
# 14         background5
# 15        Ar ka + Ag L
# 16               Zn kb
# 17         background3
# 18                 NaN
# Name: Zone, dtype: object

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(ranking_pert_lrc_unique_df['Zone']),
    len(ranking_perm_lrc_unique_df['Zone']),
    len(ranking_cov_lrc_unique_df['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Vip': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_coef': pad_list(reg_vet_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'].astype(str), max_len),
    'LRC_cov' : pad_list(ranking_cov_lrc_unique_df['Zone'], max_len),
    'LRC_pert' : pad_list(ranking_pert_lrc_unique_df['Zone'], max_len),
    'LRC_perm' : pad_list(ranking_perm_lrc_unique_df['Zone'], max_len)
})

#features_importance.to_csv('feature_importance.csv', index=False. sep=';')
features_importance
# Out:
#                  Vip          Reg_coef              Shap           LRC_cov  \
# 0              Fe ka             Ti ka             Ti ka             Fe ka
# 1              Ca ka             Ti kb             Ca ka             Ca ka
# 2              Ti ka  Ag ka scattering             Cu ka             Ti ka
# 3              Cu ka             Ca ka             Fe ka             Fe kb
# 4              Fe kb             Cu ka             Ti kb             Ca kb
# 5              Ca kb       background6  Ag ka scattering             Cu ka
# 6              Ti kb             Ca kb       background6             Ti kb
# 7   Ag ka scattering             Cu kb      Ar ka + Ag L             Cu kb
# 8        background6       background4       background4             Zn ka
# 9              Cu kb       background2       background5       background5
# 10       background4      Ar ka + Ag L       background1       background4
# 11             Zn ka             Zn kb       background2       background2
# 12       background2       background5             Ca kb       background1
# 13      Ar ka + Ag L             Fe ka             Fe kb  Ag ka scattering
# 14       background5       background1       background3       background6
# 15             Zn kb             Zn ka             Zn ka             Zn kb
# 16       background1       background3             Cu kb       background3
# 17       background3             Fe kb             Zn kb      Ar ka + Ag L
# 18              None              None              None              None
#
#             LRC_pert          LRC_perm
# 0              Ti ka             Ti ka
# 1        background1             Cu ka
# 2              Ti kb             Ca ka
# 3              Cu ka  Ag ka scattering
# 4        background4             Ti kb
# 5              Ca ka             Fe ka
# 6   Ag ka scattering             Ca kb
# 7        background2       background4
# 8        background3       background6
# 9              Ca kb             Fe kb
# 10             Cu kb             Cu kb
# 11             Fe kb             Zn ka
# 12             Zn kb       background2
# 13             Fe ka       background1
# 14       background6       background5
# 15      Ar ka + Ag L      Ar ka + Ag L
# 16       background5             Zn kb
# 17             Zn ka       background3
# 18              None               NaN

# %%
# RBO (Rank-Biased Overlap) para comparar rankings
import rbo
rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if x is not None]
methods = ['Reg_coef', 'Shap', 'LRC_cov', 'LRC_pert', 'LRC_perm']
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if x is not None]
    # Truncate both lists to the same length (minimum of both)
    min_len = min(len(reference_list), len(compare_list))
    ref_trunc = reference_list[:min_len]
    cmp_trunc = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trunc, cmp_trunc).rbo(p=0.7, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method','RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
#rbo_results.to_csv('rbo_rank.csv', index=False. sep=';')
rbo_results
# Out:
#   Reference    Method  RBO_Score
# 2       Vip   LRC_cov   0.922269
# 1       Vip      Shap   0.462804
# 4       Vip  LRC_perm   0.330146
# 0       Vip  Reg_coef   0.235755
# 3       Vip  LRC_pert   0.206954
