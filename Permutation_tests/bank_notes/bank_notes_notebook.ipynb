# %% [markdown]
# ## Loading data

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/bank_notes/plsda/bank_notes.csv', sep=';') # local copy of Toledo 2022 dataset (os ... indica para omitir o caminho longo)
data = data_complete.loc[:, '1':'26.07']

# %%
# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1':'26.07'], test_size=0.30)  # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1':'26.07'], test_size=0.30)  # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True)  # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0])  # target for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0])  # target for prediction set

# preprocessings
import preprocessings as prepr  # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-01-20 13:16:13,799 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-01-20 13:16:13,878 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-01-20 13:16:13,930 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 2026-01-20 13:16:13,965 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
# PLS-DA with optimized latent variables
from modeling import pls_optimized

plsda_results = pls_optimized(
    Xcalclass_prep, 
    ycalclass,
    LVmax=4,
    Xpred=Xpredclass_prep,
    ypred=ypredclass,
    aim='classification',
    cv=10
)

# Convenience references used later
pls_model = plsda_results[3]               # fitted PLS model
vip_scores_mat = plsda_results[4]          # VIP scores matrix (features × LV)
y_pred_cont = plsda_results[5].iloc[:, -1] # continuous predictions for Xcalclass (used for MI/Cov)

# plotando o vip scores rapidamente
vip_scores_mat.T.plot()

# %% [markdown]
# ## Spectral cuts (domain knowledge)

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('background1', 1.0, 2.74),
('Ar ka + Ag L', 2.76, 3.47),
('Ca ka', 3.5, 3.91),
('Ca kb', 3.93, 4.24),
('Ti ka', 4.26, 4.72),
('Ti kb', 4.75, 5.13),
('background2', 5.16, 6.12),
('Fe ka', 6.15, 6.76),
('Fe kb', 6.79, 7.32),
('background3', 7.35, 7.78),
('Cu', 7.81, 8.29),
('background4', 8.32, 21.46),
('Ag ka scattering', 21.49, 22.71),
('background5', 22.74, 24.52),
('background6', 24.55, 26.07),
]

import explaining as exp
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_sums_df = exp.aggregate_spectral_zones(spectral_zones_class, aggregator='sum')
predicates_quantiles = exp.predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8])
co_occurrence_matrix_df = predicates_quantiles[2]
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=y_pred_cont
)

# %% [markdown]
# ## Permutation Importance para Predicados
#
# Esta seção implementa uma alternativa robusta à função `calculate_predicate_metrics` utilizando **Permutation Importance** aplicada a zonas espectrais inteiras.
#
# ### Motivação
#
# A abordagem original (`calculate_predicate_metrics`) calcula a importância dos predicados usando métricas como Mutual Information ou Covariância entre os valores agregados da zona e as predições do modelo. Embora útil, essa abordagem não captura diretamente o **impacto causal** da zona espectral no modelo.
#
# A **Permutation Importance** é mais robusta porque:
# 1. **Mede o impacto real**: Permuta a zona espectral completa e mede a queda de performance do modelo
# 2. **Independente de escala**: Não depende da escala das variáveis
# 3. **Considera interações**: Captura o efeito conjunto de todas as variáveis na zona espectral
# 4. **Compatível com sklearn**: Usa a infraestrutura padrão do scikit-learn
#
# ### Estratégia Técnica
#
# Para permutar um **bloco de colunas** (zona espectral) como uma unidade usando `sklearn.inspection.permutation_importance`:
#
# 1. **Random Projection**: Criamos uma projeção aleatória determinística do bloco em um único escalar por amostra
# 2. O escalar serve como "chave" que representa o bloco inteiro
# 3. Quando o sklearn permuta esta coluna, está efetivamente permutando linhas inteiras do bloco original
# 4. Se essa estratégia falhar, usamos um **fallback manual** que permuta diretamente o bloco

# %%
from permutation import calculate_predicate_metrics_permutation

# LISTA DE SEMENTES A TESTAR
random_seeds = [0]

all_results = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=5,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.5), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.1), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    # Calcular MI

        perm_results = calculate_predicate_metrics_permutation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        y_calclass=y_pred_cont,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        scoring='neg_root_mean_squared_error',
        task_type='regression',
        n_repeats=5,  # Usar 10-20 em produção para resultados mais estáveis
        random_state=0,
        n_jobs=-1,
        verbose=True,
        save_detailed_results=True
    )

    # Remove todos os valores iguais a zero de todos os bags em perm_results[bag]["Permutation"] e salva como perm_results_thresholded
    perm_results_thresholded = {}
    for bag, df in perm_results.items():
        # Verifica se é um DataFrame e se a coluna 'Permutation' existe
        if isinstance(df, pd.DataFrame) and 'Permutation' in df.columns:
            filtered_df = df[df['Permutation'] > 0].copy()
            perm_results_thresholded[bag] = filtered_df
        else:
            # Se não for DataFrame esperado, apenas copia
            perm_results_thresholded[bag] = df


    # Salvar no dicionário principal
    all_results[seed] = {
        'bags_result': bags_result_seed,
        'mi_results_dict': perm_results_thresholded
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")

# Construir grafo para esta semente
    DG = exp.build_predicate_graph(
        bags_result=all_results[seed]['bags_result'],
        mi_results_dict=all_results[seed]['mi_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )

    # Armazenar grafo
    graphs_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_by_seed[seed] = lrc_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_df_seed = lrc_by_seed[seed].rename(columns={'Node': f'Predicate_Seed_{seed}'})
    lrc_all_seeds_df = pd.concat([lrc_all_seeds_df, lrc_df_seed[[f'Predicate_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_unique_by_seed = {}
for seed, lrc_df in lrc_by_seed.items():
    lrc_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_unique_df = lrc_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_unique_by_seed[seed] = lrc_unique_df

lrc_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 110 | Descartados: 10
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 111 | Descartados: 9
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 104 | Descartados: 16
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 108 | Descartados: 12
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 110 | Descartados: 10
# ======================================================================
# PERMUTATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa: regression
# Métrica de scoring: neg_root_mean_squared_error
# Número de repetições: 5
# Random state: 0
# Total de folds: 5
#
#
# [Bag_1] Processando 110 predicados...
#   Predicado: background1 > -7.55 (n=119)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3894
#     y_true: min=-0.4913, max=1.0640, mean=0.3894
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0015, importance=0.0015
#     Rep 2: permuted_score=-0.0014, importance=0.0014
#     Rep 3: permuted_score=-0.0014, importance=0.0014
#     Importance: 0.001397 ± 0.000070
#   Predicado: background1 <= -2.14 (n=54)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3133, max=0.9907, mean=0.2954
#     y_true: min=-0.3133, max=0.9907, mean=0.2954
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0011, importance=0.0011
#     Rep 2: permuted_score=-0.0012, importance=0.0012
#     Rep 3: permuted_score=-0.0011, importance=0.0011
#     Importance: 0.001152 ± 0.000055
#   Predicado: background1 > -2.14 (n=88)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4450
#     y_true: min=-0.4913, max=1.0640, mean=0.4450
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0016, importance=0.0016
#     Rep 2: permuted_score=-0.0015, importance=0.0015
#     Rep 3: permuted_score=-0.0014, importance=0.0014
#     Importance: 0.001439 ± 0.000098
#   Predicado: background1 <= 2.61 (n=82)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3133, max=1.0368, mean=0.3306
#     y_true: min=-0.3133, max=1.0368, mean=0.3306
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0013, importance=0.0013
#     Rep 2: permuted_score=-0.0014, importance=0.0014
#     Rep 3: permuted_score=-0.0013, importance=0.0013
#     Importance: 0.001319 ± 0.000029
#   Predicado: background1 > 2.61 (n=60)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4668
#     y_true: min=-0.4913, max=1.0640, mean=0.4668
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0015, importance=0.0015
#     Rep 2: permuted_score=-0.0016, importance=0.0016
#     Rep 3: permuted_score=-0.0014, importance=0.0014
#     Importance: 0.001444 ± 0.000109
#   Predicado: background1 <= 7.73 (n=112)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0556, mean=0.3554
#     y_true: min=-0.3915, max=1.0556, mean=0.3554
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0012, importance=0.0012
#     Rep 2: permuted_score=-0.0013, importance=0.0013
#     Rep 3: permuted_score=-0.0014, importance=0.0014
#     Importance: 0.001306 ± 0.000064
#   Predicado: background1 > 7.73 (n=30)
#     Zona: 69 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.5104
#     y_true: min=-0.4913, max=1.0640, mean=0.5104
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0016, importance=0.0016
#     Rep 2: permuted_score=-0.0014, importance=0.0014
#     Rep 3: permuted_score=-0.0017, importance=0.0017
#     Importance: 0.001524 ± 0.000168
#   Predicado: Ar ka + Ag L <= -5.42 (n=29)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.1838, max=0.9611, mean=0.4057
#     y_true: min=-0.1838, max=0.9611, mean=0.4057
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0012, importance=0.0012
#     Rep 2: permuted_score=-0.0010, importance=0.0010
#     Rep 3: permuted_score=-0.0013, importance=0.0013
#     Importance: 0.001112 ± 0.000130
#   Predicado: Ar ka + Ag L > -5.42 (n=113)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3836
#     y_true: min=-0.4913, max=1.0640, mean=0.3836
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0010, importance=0.0010
#     Rep 2: permuted_score=-0.0011, importance=0.0011
#     Rep 3: permuted_score=-0.0012, importance=0.0012
#     Importance: 0.001130 ± 0.000058
#   Predicado: Ar ka + Ag L <= -2.13 (n=61)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.3688
#     y_true: min=-0.4913, max=1.0587, mean=0.3688
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0011, importance=0.0011
#     Rep 2: permuted_score=-0.0011, importance=0.0011
#     Rep 3: permuted_score=-0.0012, importance=0.0012
#     Importance: 0.001165 ± 0.000073
#   Predicado: Ar ka + Ag L > -2.13 (n=81)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.4027
#     y_true: min=-0.3915, max=1.0640, mean=0.4027
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0010, importance=0.0010
#     Rep 2: permuted_score=-0.0009, importance=0.0009
#     Rep 3: permuted_score=-0.0010, importance=0.0010
#     Importance: 0.000965 ± 0.000046
#   Predicado: Ar ka + Ag L <= 1.73 (n=90)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.4130
#     y_true: min=-0.4913, max=1.0587, mean=0.4130
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0012, importance=0.0012
#     Rep 2: permuted_score=-0.0011, importance=0.0011
#     Rep 3: permuted_score=-0.0011, importance=0.0011
#     Importance: 0.001157 ± 0.000063
#   Predicado: Ar ka + Ag L > 1.73 (n=52)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.3451
#     y_true: min=-0.3915, max=1.0640, mean=0.3451
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0011, importance=0.0011
#     Rep 2: permuted_score=-0.0010, importance=0.0010
#     Rep 3: permuted_score=-0.0010, importance=0.0010
#     Importance: 0.000980 ± 0.000093
#   Predicado: Ar ka + Ag L <= 5.57 (n=116)
#     Zona: 29 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3805
#     y_true: min=-0.4913, max=1.0640, mean=0.3805
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0012, importance=0.0012
#     Rep 2: permuted_score=-0.0013, importance=0.0013
#     Rep 3: permuted_score=-0.0012, importance=0.0012
#     Importance: 0.001221 ± 0.000064
#   Predicado: Ca ka > -84.19 (n=122)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3879
#     y_true: min=-0.4913, max=1.0640, mean=0.3879
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1296, importance=0.1296
#     Rep 2: permuted_score=-0.1371, importance=0.1371
#     Rep 3: permuted_score=-0.1386, importance=0.1386
#     Importance: 0.132952 ± 0.007308
#   Predicado: Ca ka <= -67.03 (n=51)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.8419, mean=0.1832
#     y_true: min=-0.4913, max=0.8419, mean=0.1832
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0073, importance=0.0073
#     Rep 2: permuted_score=-0.0088, importance=0.0088
#     Rep 3: permuted_score=-0.0074, importance=0.0074
#     Importance: 0.007818 ± 0.000535
#   Predicado: Ca ka > -67.03 (n=91)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3581, max=1.0640, mean=0.5030
#     y_true: min=-0.3581, max=1.0640, mean=0.5030
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1299, importance=0.1299
#     Rep 2: permuted_score=-0.1187, importance=0.1187
#     Rep 3: permuted_score=-0.1305, importance=0.1305
#     Importance: 0.126274 ± 0.004298
#   Predicado: Ca ka <= -23.18 (n=82)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.8419, mean=0.1456
#     y_true: min=-0.4913, max=0.8419, mean=0.1456
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0285, importance=0.0285
#     Rep 2: permuted_score=-0.0318, importance=0.0318
#     Rep 3: permuted_score=-0.0293, importance=0.0293
#     Importance: 0.030060 ± 0.001099
#   Predicado: Ca ka > -23.18 (n=60)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2462, max=1.0640, mean=0.7197
#     y_true: min=-0.2462, max=1.0640, mean=0.7197
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1065, importance=0.1065
#     Rep 2: permuted_score=-0.1081, importance=0.1081
#     Rep 3: permuted_score=-0.1133, importance=0.1133
#     Importance: 0.106980 ± 0.003638
#   Predicado: Ca ka <= 113.48 (n=115)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0556, mean=0.2472
#     y_true: min=-0.4913, max=1.0556, mean=0.2472
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0701, importance=0.0701
#     Rep 2: permuted_score=-0.0777, importance=0.0777
#     Rep 3: permuted_score=-0.0706, importance=0.0706
#     Importance: 0.072201 ± 0.003091
#   Predicado: Ca kb <= -25.56 (n=28)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=0.8419, mean=0.3312
#     y_true: min=-0.3915, max=0.8419, mean=0.3312
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0010, importance=0.0010
#     Rep 2: permuted_score=-0.0010, importance=0.0010
#     Rep 3: permuted_score=-0.0010, importance=0.0010
#     Importance: 0.001037 ± 0.000069
#   Predicado: Ca kb > -25.56 (n=114)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4021
#     y_true: min=-0.4913, max=1.0640, mean=0.4021
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0161, importance=0.0161
#     Rep 2: permuted_score=-0.0163, importance=0.0163
#     Rep 3: permuted_score=-0.0157, importance=0.0157
#     Importance: 0.015892 ± 0.000227
#   Predicado: Ca kb <= -16.92 (n=54)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.8419, mean=0.1756
#     y_true: min=-0.4913, max=0.8419, mean=0.1756
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0020, importance=0.0020
#     Rep 2: permuted_score=-0.0020, importance=0.0020
#     Rep 3: permuted_score=-0.0020, importance=0.0020
#     Importance: 0.001970 ± 0.000084
#   Predicado: Ca kb > -16.92 (n=88)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2496, max=1.0640, mean=0.5186
#     y_true: min=-0.2496, max=1.0640, mean=0.5186
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0149, importance=0.0149
#     Rep 2: permuted_score=-0.0156, importance=0.0156
#     Rep 3: permuted_score=-0.0168, importance=0.0168
#     Importance: 0.015805 ± 0.000676
#   Predicado: Ca kb <= -6.98 (n=82)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.8419, mean=0.1467
#     y_true: min=-0.4913, max=0.8419, mean=0.1467
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0035, importance=0.0035
#     Rep 2: permuted_score=-0.0034, importance=0.0034
#     Rep 3: permuted_score=-0.0039, importance=0.0039
#     Importance: 0.003578 ± 0.000154
#   Predicado: Ca kb > -6.98 (n=60)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2462, max=1.0640, mean=0.7181
#     y_true: min=-0.2462, max=1.0640, mean=0.7181
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0135, importance=0.0135
#     Rep 2: permuted_score=-0.0113, importance=0.0113
#     Rep 3: permuted_score=-0.0153, importance=0.0153
#     Importance: 0.013825 ± 0.001400
#   Predicado: Ca kb <= 37.90 (n=115)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0556, mean=0.2465
#     y_true: min=-0.4913, max=1.0556, mean=0.2465
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0090, importance=0.0090
#     Rep 2: permuted_score=-0.0085, importance=0.0085
#     Rep 3: permuted_score=-0.0092, importance=0.0092
#     Importance: 0.008774 ± 0.000356
#   Predicado: Ti ka > -93.99 (n=116)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.2617
#     y_true: min=-0.4913, max=1.0640, mean=0.2617
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.3593, importance=0.3593
#     Rep 2: permuted_score=-0.3657, importance=0.3657
#     Rep 3: permuted_score=-0.3959, importance=0.3959
#     Importance: 0.377063 ± 0.014104
#   Predicado: Ti ka <= -15.10 (n=59)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=0.3585, max=1.0640, mean=0.8873
#     y_true: min=0.3585, max=1.0640, mean=0.8873
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1101, importance=0.1101
#     Rep 2: permuted_score=-0.1206, importance=0.1206
#     Rep 3: permuted_score=-0.1189, importance=0.1189
#     Importance: 0.116394 ± 0.006460
#   Predicado: Ti ka > -15.10 (n=83)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.3451, mean=0.0333
#     y_true: min=-0.4913, max=0.3451, mean=0.0333
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.2301, importance=0.2301
#     Rep 2: permuted_score=-0.2281, importance=0.2281
#     Rep 3: permuted_score=-0.2315, importance=0.2315
#     Importance: 0.231619 ± 0.003148
#   Predicado: Ti ka <= 31.35 (n=84)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.0672, max=1.0640, mean=0.6777
#     y_true: min=-0.0672, max=1.0640, mean=0.6777
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.2455, importance=0.2455
#     Rep 2: permuted_score=-0.2415, importance=0.2415
#     Rep 3: permuted_score=-0.2358, importance=0.2358
#     Importance: 0.244483 ± 0.007524
#   Predicado: Ti ka > 31.35 (n=58)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.1873, mean=-0.0313
#     y_true: min=-0.4913, max=0.1873, mean=-0.0313
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1894, importance=0.1894
#     Rep 2: permuted_score=-0.1959, importance=0.1959
#     Rep 3: permuted_score=-0.1909, importance=0.1909
#     Importance: 0.189388 ± 0.003920
#   Predicado: Ti ka <= 69.02 (n=116)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.1838, max=1.0640, mean=0.5107
#     y_true: min=-0.1838, max=1.0640, mean=0.5107
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.3382, importance=0.3382
#     Rep 2: permuted_score=-0.3684, importance=0.3684
#     Rep 3: permuted_score=-0.3280, importance=0.3280
#     Importance: 0.338391 ± 0.015497
#   Predicado: Ti kb <= -35.94 (n=28)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=0.7552, max=1.0571, mean=0.9590
#     y_true: min=0.7552, max=1.0571, mean=0.9590
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0028, importance=0.0028
#     Rep 2: permuted_score=-0.0034, importance=0.0034
#     Rep 3: permuted_score=-0.0032, importance=0.0032
#     Importance: 0.003198 ± 0.000348
#   Predicado: Ti kb > -35.94 (n=114)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.2479
#     y_true: min=-0.4913, max=1.0640, mean=0.2479
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0561, importance=0.0561
#     Rep 2: permuted_score=-0.0534, importance=0.0534
#     Rep 3: permuted_score=-0.0599, importance=0.0599
#     Importance: 0.057742 ± 0.002703
#   Predicado: Ti kb <= -12.29 (n=60)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=0.1113, max=1.0640, mean=0.8665
#     y_true: min=0.1113, max=1.0640, mean=0.8665
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0138, importance=0.0138
#     Rep 2: permuted_score=-0.0151, importance=0.0151
#     Rep 3: permuted_score=-0.0132, importance=0.0132
#     Importance: 0.014063 ± 0.000696
#   Predicado: Ti kb > -12.29 (n=82)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.7803, mean=0.0382
#     y_true: min=-0.4913, max=0.7803, mean=0.0382
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0429, importance=0.0429
#     Rep 2: permuted_score=-0.0454, importance=0.0454
#     Rep 3: permuted_score=-0.0439, importance=0.0439
#     Importance: 0.046586 ± 0.003192
#   Predicado: Ti kb <= 7.64 (n=88)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.1696, max=1.0640, mean=0.6437
#     y_true: min=-0.1696, max=1.0640, mean=0.6437
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0337, importance=0.0337
#     Rep 2: permuted_score=-0.0365, importance=0.0365
#     Rep 3: permuted_score=-0.0343, importance=0.0343
#     Importance: 0.033891 ± 0.001494
#   Predicado: Ti kb > 7.64 (n=54)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.3451, mean=-0.0283
#     y_true: min=-0.4913, max=0.3451, mean=-0.0283
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0454, importance=0.0454
#     Rep 2: permuted_score=-0.0444, importance=0.0444
#     Rep 3: permuted_score=-0.0392, importance=0.0392
#     Importance: 0.042752 ± 0.002156
#   Predicado: Ti kb <= 25.84 (n=114)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.1838, max=1.0640, mean=0.5105
#     y_true: min=-0.1838, max=1.0640, mean=0.5105
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0392, importance=0.0392
#     Rep 2: permuted_score=-0.0424, importance=0.0424
#     Rep 3: permuted_score=-0.0380, importance=0.0380
#     Importance: 0.039780 ± 0.001839
#   Predicado: Ti kb > 25.84 (n=28)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=0.2328, mean=-0.1100
#     y_true: min=-0.4913, max=0.2328, mean=-0.1100
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0407, importance=0.0407
#     Rep 2: permuted_score=-0.0327, importance=0.0327
#     Rep 3: permuted_score=-0.0367, importance=0.0367
#     Importance: 0.036795 ± 0.002537
#   Predicado: background2 <= -11.03 (n=29)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.0394, max=1.0640, mean=0.7004
#     y_true: min=-0.0394, max=1.0640, mean=0.7004
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0012, importance=0.0012
#     Rep 2: permuted_score=-0.0011, importance=0.0011
#     Rep 3: permuted_score=-0.0013, importance=0.0013
#     Importance: 0.001191 ± 0.000088
#   Predicado: background2 > -11.03 (n=113)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.3080
#     y_true: min=-0.4913, max=1.0587, mean=0.3080
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0024, importance=0.0024
#     Rep 2: permuted_score=-0.0026, importance=0.0026
#     Rep 3: permuted_score=-0.0026, importance=0.0026
#     Importance: 0.002514 ± 0.000067
#   Predicado: background2 <= -6.67 (n=57)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3133, max=1.0640, mean=0.5326
#     y_true: min=-0.3133, max=1.0640, mean=0.5326
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0013, importance=0.0013
#     Rep 2: permuted_score=-0.0013, importance=0.0013
#     Rep 3: permuted_score=-0.0012, importance=0.0012
#     Importance: 0.001255 ± 0.000027
#   Predicado: background2 > -6.67 (n=85)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.2913
#     y_true: min=-0.4913, max=1.0587, mean=0.2913
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0025, importance=0.0025
#     Rep 2: permuted_score=-0.0021, importance=0.0021
#     Rep 3: permuted_score=-0.0022, importance=0.0022
#     Importance: 0.002246 ± 0.000117
#   Predicado: background2 <= 0.19 (n=87)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.4655
#     y_true: min=-0.3915, max=1.0640, mean=0.4655
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0016, importance=0.0016
#     Rep 2: permuted_score=-0.0016, importance=0.0016
#     Rep 3: permuted_score=-0.0016, importance=0.0016
#     Importance: 0.001562 ± 0.000079
#   Predicado: background2 > 0.19 (n=55)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.2658
#     y_true: min=-0.4913, max=1.0587, mean=0.2658
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0020, importance=0.0020
#     Rep 2: permuted_score=-0.0017, importance=0.0017
#     Rep 3: permuted_score=-0.0022, importance=0.0022
#     Importance: 0.001899 ± 0.000160
#   Predicado: background2 <= 11.97 (n=110)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.4060
#     y_true: min=-0.3915, max=1.0640, mean=0.4060
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0019, importance=0.0019
#     Rep 2: permuted_score=-0.0019, importance=0.0019
#     Rep 3: permuted_score=-0.0019, importance=0.0019
#     Importance: 0.001907 ± 0.000031
#   Predicado: background2 > 11.97 (n=32)
#     Zona: 39 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.3267
#     y_true: min=-0.4913, max=1.0587, mean=0.3267
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0014, importance=0.0014
#     Rep 2: permuted_score=-0.0017, importance=0.0017
#     Rep 3: permuted_score=-0.0015, importance=0.0015
#     Importance: 0.001435 ± 0.000159
#   Predicado: Fe ka <= -87.71 (n=28)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2496, max=1.0571, mean=0.3371
#     y_true: min=-0.2496, max=1.0571, mean=0.3371
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000540 ± 0.000034
#   Predicado: Fe ka > -87.71 (n=114)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4007
#     y_true: min=-0.4913, max=1.0640, mean=0.4007
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0369, importance=0.0369
#     Rep 2: permuted_score=-0.0368, importance=0.0368
#     Rep 3: permuted_score=-0.0377, importance=0.0377
#     Importance: 0.035904 ± 0.001962
#   Predicado: Fe ka <= -85.11 (n=59)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0571, mean=0.3291
#     y_true: min=-0.4913, max=1.0571, mean=0.3291
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0006, importance=0.0006
#     Rep 2: permuted_score=-0.0006, importance=0.0006
#     Rep 3: permuted_score=-0.0007, importance=0.0007
#     Importance: 0.000580 ± 0.000049
#   Predicado: Fe ka > -85.11 (n=83)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4597, max=1.0640, mean=0.4301
#     y_true: min=-0.4597, max=1.0640, mean=0.4301
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0431, importance=0.0431
#     Rep 2: permuted_score=-0.0425, importance=0.0425
#     Rep 3: permuted_score=-0.0393, importance=0.0393
#     Importance: 0.041793 ± 0.001451
#   Predicado: Fe ka <= -82.70 (n=89)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0571, mean=0.3313
#     y_true: min=-0.4913, max=1.0571, mean=0.3313
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0007, importance=0.0007
#     Rep 2: permuted_score=-0.0006, importance=0.0006
#     Rep 3: permuted_score=-0.0006, importance=0.0006
#     Importance: 0.000632 ± 0.000044
#   Predicado: Fe ka > -82.70 (n=53)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.4837
#     y_true: min=-0.3915, max=1.0640, mean=0.4837
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0479, importance=0.0479
#     Rep 2: permuted_score=-0.0522, importance=0.0522
#     Rep 3: permuted_score=-0.0509, importance=0.0509
#     Importance: 0.049727 ± 0.001689
#   Predicado: Fe ka <= -78.61 (n=112)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0571, mean=0.3396
#     y_true: min=-0.4913, max=1.0571, mean=0.3396
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0007, importance=0.0007
#     Rep 2: permuted_score=-0.0006, importance=0.0006
#     Rep 3: permuted_score=-0.0007, importance=0.0007
#     Importance: 0.000678 ± 0.000039
#   Predicado: Fe ka > -78.61 (n=30)
#     Zona: 25 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.5695
#     y_true: min=-0.3915, max=1.0640, mean=0.5695
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0564, importance=0.0564
#     Rep 2: permuted_score=-0.0474, importance=0.0474
#     Rep 3: permuted_score=-0.0576, importance=0.0576
#     Importance: 0.052681 ± 0.003937
#   Predicado: Fe kb > -28.54 (n=121)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3888
#     y_true: min=-0.4913, max=1.0640, mean=0.3888
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0077, importance=0.0077
#     Rep 2: permuted_score=-0.0080, importance=0.0080
#     Rep 3: permuted_score=-0.0070, importance=0.0070
#     Importance: 0.007548 ± 0.000365
#   Predicado: Fe kb <= -26.06 (n=49)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0571, mean=0.4508
#     y_true: min=-0.3915, max=1.0571, mean=0.4508
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000477 ± 0.000035
#   Predicado: Fe kb > -26.06 (n=93)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3551
#     y_true: min=-0.4913, max=1.0640, mean=0.3551
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0085, importance=0.0085
#     Rep 2: permuted_score=-0.0078, importance=0.0078
#     Rep 3: permuted_score=-0.0079, importance=0.0079
#     Importance: 0.008118 ± 0.000395
#   Predicado: Fe kb <= -23.43 (n=79)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0571, mean=0.4216
#     y_true: min=-0.3915, max=1.0571, mean=0.4216
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000483 ± 0.000033
#   Predicado: Fe kb > -23.43 (n=63)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3462
#     y_true: min=-0.4913, max=1.0640, mean=0.3462
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0111, importance=0.0111
#     Rep 2: permuted_score=-0.0086, importance=0.0086
#     Rep 3: permuted_score=-0.0097, importance=0.0097
#     Importance: 0.010069 ± 0.000881
#   Predicado: Fe kb <= -20.48 (n=112)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0640, mean=0.3694
#     y_true: min=-0.3915, max=1.0640, mean=0.3694
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0006, importance=0.0006
#     Rep 2: permuted_score=-0.0006, importance=0.0006
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000549 ± 0.000010
#   Predicado: Fe kb > -20.48 (n=30)
#     Zona: 22 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.4581
#     y_true: min=-0.4913, max=1.0587, mean=0.4581
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0120, importance=0.0120
#     Rep 2: permuted_score=-0.0117, importance=0.0117
#     Rep 3: permuted_score=-0.0135, importance=0.0135
#     Importance: 0.012435 ± 0.000632
#   Predicado: background3 <= -3.66 (n=30)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.1468, max=1.0640, mean=0.5916
#     y_true: min=-0.1468, max=1.0640, mean=0.5916
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0004, importance=0.0004
#     Rep 2: permuted_score=-0.0004, importance=0.0004
#     Rep 3: permuted_score=-0.0004, importance=0.0004
#     Importance: 0.000412 ± 0.000024
#   Predicado: background3 > -3.66 (n=112)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.3336
#     y_true: min=-0.4913, max=1.0587, mean=0.3336
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000514 ± 0.000007
#   Predicado: background3 <= -1.76 (n=56)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2496, max=1.0640, mean=0.4914
#     y_true: min=-0.2496, max=1.0640, mean=0.4914
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0004, importance=0.0004
#     Rep 2: permuted_score=-0.0004, importance=0.0004
#     Rep 3: permuted_score=-0.0004, importance=0.0004
#     Importance: 0.000434 ± 0.000033
#   Predicado: background3 > -1.76 (n=86)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.3209
#     y_true: min=-0.4913, max=1.0587, mean=0.3209
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000525 ± 0.000042
#   Predicado: background3 <= 1.02 (n=84)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4597, max=1.0640, mean=0.4109
#     y_true: min=-0.4597, max=1.0640, mean=0.4109
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0004, importance=0.0004
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0004, importance=0.0004
#     Importance: 0.000419 ± 0.000039
#   Predicado: background3 > 1.02 (n=58)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.3551
#     y_true: min=-0.4913, max=1.0587, mean=0.3551
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000500 ± 0.000027
#   Predicado: background3 <= 4.10 (n=109)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3873
#     y_true: min=-0.4913, max=1.0640, mean=0.3873
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0004, importance=0.0004
#     Rep 2: permuted_score=-0.0005, importance=0.0005
#     Rep 3: permuted_score=-0.0004, importance=0.0004
#     Importance: 0.000446 ± 0.000020
#   Predicado: background3 > 4.10 (n=33)
#     Zona: 18 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3133, max=1.0587, mean=0.3909
#     y_true: min=-0.3133, max=1.0587, mean=0.3909
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0005, importance=0.0005
#     Rep 2: permuted_score=-0.0006, importance=0.0006
#     Rep 3: permuted_score=-0.0005, importance=0.0005
#     Importance: 0.000489 ± 0.000041
#   Predicado: Cu <= -37.01 (n=30)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.1657, max=1.0587, mean=0.6787
#     y_true: min=-0.1657, max=1.0587, mean=0.6787
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0026, importance=0.0026
#     Rep 2: permuted_score=-0.0026, importance=0.0026
#     Rep 3: permuted_score=-0.0024, importance=0.0024
#     Importance: 0.002630 ± 0.000184
#   Predicado: Cu > -37.01 (n=112)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3103
#     y_true: min=-0.4913, max=1.0640, mean=0.3103
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1084, importance=0.1084
#     Rep 2: permuted_score=-0.1200, importance=0.1200
#     Rep 3: permuted_score=-0.1100, importance=0.1100
#     Importance: 0.111977 ± 0.004916
#   Predicado: Cu <= -33.81 (n=55)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4597, max=1.0640, mean=0.5781
#     y_true: min=-0.4597, max=1.0640, mean=0.5781
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0032, importance=0.0032
#     Rep 2: permuted_score=-0.0033, importance=0.0033
#     Rep 3: permuted_score=-0.0033, importance=0.0033
#     Importance: 0.003291 ± 0.000096
#   Predicado: Cu > -33.81 (n=87)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0249, mean=0.2681
#     y_true: min=-0.4913, max=1.0249, mean=0.2681
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1204, importance=0.1204
#     Rep 2: permuted_score=-0.1100, importance=0.1100
#     Rep 3: permuted_score=-0.1152, importance=0.1152
#     Importance: 0.119229 ± 0.007219
#   Predicado: Cu <= -28.05 (n=83)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.5221
#     y_true: min=-0.4913, max=1.0640, mean=0.5221
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0037, importance=0.0037
#     Rep 2: permuted_score=-0.0041, importance=0.0041
#     Rep 3: permuted_score=-0.0040, importance=0.0040
#     Importance: 0.003923 ± 0.000183
#   Predicado: Cu > -28.05 (n=59)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0249, mean=0.1997
#     y_true: min=-0.3915, max=1.0249, mean=0.1997
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1359, importance=0.1359
#     Rep 2: permuted_score=-0.1404, importance=0.1404
#     Rep 3: permuted_score=-0.1346, importance=0.1346
#     Importance: 0.137085 ± 0.009003
#   Predicado: Cu <= -8.52 (n=107)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4746
#     y_true: min=-0.4913, max=1.0640, mean=0.4746
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0071, importance=0.0071
#     Rep 2: permuted_score=-0.0066, importance=0.0066
#     Rep 3: permuted_score=-0.0070, importance=0.0070
#     Importance: 0.007009 ± 0.000275
#   Predicado: Cu > -8.52 (n=35)
#     Zona: 20 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2462, max=0.9912, mean=0.1239
#     y_true: min=-0.2462, max=0.9912, mean=0.1239
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.1522, importance=0.1522
#     Rep 2: permuted_score=-0.1451, importance=0.1451
#     Rep 3: permuted_score=-0.1384, importance=0.1384
#     Importance: 0.141964 ± 0.007905
#   Predicado: background4 <= -59.98 (n=30)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=0.0551, max=1.0556, mean=0.7211
#     y_true: min=0.0551, max=1.0556, mean=0.7211
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0109, importance=0.0109
#     Rep 2: permuted_score=-0.0094, importance=0.0094
#     Rep 3: permuted_score=-0.0073, importance=0.0073
#     Importance: 0.009393 ± 0.001314
#   Predicado: background4 > -59.98 (n=112)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.2989
#     y_true: min=-0.4913, max=1.0640, mean=0.2989
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0097, importance=0.0097
#     Rep 2: permuted_score=-0.0107, importance=0.0107
#     Rep 3: permuted_score=-0.0096, importance=0.0096
#     Importance: 0.010074 ± 0.000496
#   Predicado: background4 <= -10.57 (n=54)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2496, max=1.0587, mean=0.6384
#     y_true: min=-0.2496, max=1.0587, mean=0.6384
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0098, importance=0.0098
#     Rep 2: permuted_score=-0.0100, importance=0.0100
#     Rep 3: permuted_score=-0.0104, importance=0.0104
#     Importance: 0.010382 ± 0.000646
#   Predicado: background4 > -10.57 (n=88)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.2346
#     y_true: min=-0.4913, max=1.0640, mean=0.2346
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0078, importance=0.0078
#     Rep 2: permuted_score=-0.0070, importance=0.0070
#     Rep 3: permuted_score=-0.0072, importance=0.0072
#     Importance: 0.007467 ± 0.000350
#   Predicado: background4 <= 30.03 (n=80)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3581, max=1.0640, mean=0.5829
#     y_true: min=-0.3581, max=1.0640, mean=0.5829
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0131, importance=0.0131
#     Rep 2: permuted_score=-0.0120, importance=0.0120
#     Rep 3: permuted_score=-0.0129, importance=0.0129
#     Importance: 0.012264 ± 0.000682
#   Predicado: background4 > 30.03 (n=62)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0571, mean=0.1368
#     y_true: min=-0.4913, max=1.0571, mean=0.1368
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0070, importance=0.0070
#     Rep 2: permuted_score=-0.0073, importance=0.0073
#     Rep 3: permuted_score=-0.0072, importance=0.0072
#     Importance: 0.007550 ± 0.000478
#   Predicado: background4 <= 59.25 (n=112)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4725
#     y_true: min=-0.4913, max=1.0640, mean=0.4725
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0122, importance=0.0122
#     Rep 2: permuted_score=-0.0129, importance=0.0129
#     Rep 3: permuted_score=-0.0138, importance=0.0138
#     Importance: 0.012784 ± 0.000813
#   Predicado: background4 > 59.25 (n=30)
#     Zona: 517 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4597, max=0.9935, mean=0.0731
#     y_true: min=-0.4597, max=0.9935, mean=0.0731
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0064, importance=0.0064
#     Rep 2: permuted_score=-0.0069, importance=0.0069
#     Rep 3: permuted_score=-0.0059, importance=0.0059
#     Importance: 0.006279 ± 0.000361
#   Predicado: Ag ka scattering <= -17.00 (n=28)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2496, max=1.0587, mean=0.4251
#     y_true: min=-0.2496, max=1.0587, mean=0.4251
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0390, importance=0.0390
#     Rep 2: permuted_score=-0.0396, importance=0.0396
#     Rep 3: permuted_score=-0.0349, importance=0.0349
#     Importance: 0.039793 ± 0.003382
#   Predicado: Ag ka scattering > -17.00 (n=114)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3791
#     y_true: min=-0.4913, max=1.0640, mean=0.3791
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0186, importance=0.0186
#     Rep 2: permuted_score=-0.0187, importance=0.0187
#     Rep 3: permuted_score=-0.0206, importance=0.0206
#     Importance: 0.019025 ± 0.000845
#   Predicado: Ag ka scattering <= -1.33 (n=56)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.3915, max=1.0587, mean=0.4371
#     y_true: min=-0.3915, max=1.0587, mean=0.4371
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0324, importance=0.0324
#     Rep 2: permuted_score=-0.0301, importance=0.0301
#     Rep 3: permuted_score=-0.0329, importance=0.0329
#     Importance: 0.033003 ± 0.001863
#   Predicado: Ag ka scattering > -1.33 (n=86)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3563
#     y_true: min=-0.4913, max=1.0640, mean=0.3563
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0153, importance=0.0153
#     Rep 2: permuted_score=-0.0164, importance=0.0164
#     Rep 3: permuted_score=-0.0172, importance=0.0172
#     Importance: 0.016253 ± 0.000919
#   Predicado: Ag ka scattering <= 7.59 (n=88)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0587, mean=0.4468
#     y_true: min=-0.4913, max=1.0587, mean=0.4468
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0302, importance=0.0302
#     Rep 2: permuted_score=-0.0314, importance=0.0314
#     Rep 3: permuted_score=-0.0308, importance=0.0308
#     Importance: 0.030857 ± 0.000396
#   Predicado: Ag ka scattering > 7.59 (n=54)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4597, max=1.0640, mean=0.2926
#     y_true: min=-0.4597, max=1.0640, mean=0.2926
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0185, importance=0.0185
#     Rep 2: permuted_score=-0.0177, importance=0.0177
#     Rep 3: permuted_score=-0.0158, importance=0.0158
#     Importance: 0.017444 ± 0.000930
#   Predicado: Ag ka scattering <= 16.12 (n=119)
#     Zona: 49 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4306
#     y_true: min=-0.4913, max=1.0640, mean=0.4306
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0298, importance=0.0298
#     Rep 2: permuted_score=-0.0279, importance=0.0279
#     Rep 3: permuted_score=-0.0289, importance=0.0289
#     Importance: 0.028481 ± 0.001140
#   Predicado: background5 <= -10.87 (n=30)
#     Zona: 71 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.2462, max=1.0025, mean=0.5872
#     y_true: min=-0.2462, max=1.0025, mean=0.5872
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0013, importance=0.0013
#     Rep 2: permuted_score=-0.0014, importance=0.0014
#     Rep 3: permuted_score=-0.0015, importance=0.0015
#     Importance: 0.001407 ± 0.000066
#   Predicado: background5 > -10.87 (n=112)
#     Zona: 71 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.3348
#     y_true: min=-0.4913, max=1.0640, mean=0.3348
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0020, importance=0.0020
#     Rep 2: permuted_score=-0.0018, importance=0.0018
#     Rep 3: permuted_score=-0.0018, importance=0.0018
#     Importance: 0.001889 ± 0.000087
#   Predicado: background5 <= -2.34 (n=60)
#     Zona: 71 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.5799
#     y_true: min=-0.4913, max=1.0640, mean=0.5799
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0016, importance=0.0016
#     Rep 2: permuted_score=-0.0015, importance=0.0015
#     Rep 3: permuted_score=-0.0016, importance=0.0016
#     Importance: 0.001548 ± 0.000049
#   Predicado: background5 > -2.34 (n=82)
#     Zona: 71 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4597, max=1.0571, mean=0.2478
#     y_true: min=-0.4597, max=1.0571, mean=0.2478
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0015, importance=0.0015
#     Rep 2: permuted_score=-0.0016, importance=0.0016
#     Rep 3: permuted_score=-0.0016, importance=0.0016
#     Importance: 0.001530 ± 0.000050
#   Predicado: background5 <= 3.41 (n=89)
#     Zona: 71 colunas
#     Usando permutação manual do bloco
#     Tipo de tarefa: regression
#     Predições baseline (regressão): min=-0.4913, max=1.0640, mean=0.4744
# ...
#     y_true: min=-0.0978, max=1.0372, mean=0.4706
#     Baseline score: -0.0000
#     Rep 1: permuted_score=-0.0057, importance=0.0057
#     Rep 2: permuted_score=-0.0062, importance=0.0062
#     Rep 3: permuted_score=-0.0057, importance=0.0057
#     Importance: 0.005792 ± 0.000185
#
# ======================================================================
# RESUMO
# ======================================================================
# Folds processados: 5
# Predicados processados: 543
# Predicados ignorados (edge cases): 0
#
#   Bag_1: 110 predicados com importance > 0
#   Bag_2: 111 predicados com importance > 0
#   Bag_3: 104 predicados com importance > 0
#   Bag_4: 108 predicados com importance > 0
#   Bag_5: 110 predicados com importance > 0
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 67
# Removida aresta Ti ka > -15.10 -> Ti ka <= 31.35 (peso 56.0)
# Mantida aresta Ti ka <= 31.35 -> Ti ka > -15.10 (peso 224.0)
#
# ======================================================================
#
# Removida aresta Cu > -28.05 -> Cu > -8.52 (peso 57.0)
# Mantida aresta Cu > -8.52 -> Cu > -28.05 (peso 171.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= -15.10 -> Cu > -8.52 (peso 2.0)
# Mantida aresta Cu > -8.52 -> Ti ka <= -15.10 (peso 2.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu > -33.81 -> Cu > -28.05 (peso 114.0)
# Mantida aresta Cu > -28.05 -> Cu > -33.81 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= -15.10 -> Cu > -33.81 (peso 49.0)
# Mantida aresta Cu > -33.81 -> Ti ka <= -15.10 (peso 49.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -23.18 -> Cu > -33.81 (peso 66.0)
# Mantida aresta Cu > -33.81 -> Ca ka > -23.18 (peso 66.0)
#
# ======================================================================
#
# Removida aresta Cu > -37.01 -> Ca ka > -23.18 (peso 86.0)
# Mantida aresta Ca ka > -23.18 -> Cu > -37.01 (peso 172.0)
#
# ======================================================================
#
# Removida aresta Fe ka > -78.61 -> Ti kb > -35.94 (peso 43.0)
# Mantida aresta Ti kb > -35.94 -> Fe ka > -78.61 (peso 86.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 7.64 -> Ti kb > -12.29 (peso 114.0)
# Mantida aresta Ti kb > -12.29 -> Ti kb > 7.64 (peso 342.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= -17.00 -> Ti kb <= 25.84 (peso 48.0)
# Mantida aresta Ti kb <= 25.84 -> Ag ka scattering <= -17.00 (peso 48.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 25.84 -> Ti kb <= 25.84 (peso 0.0)
# Mantida aresta Ti kb <= 25.84 -> Ti kb > 25.84 (peso 0.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 25.84 -> Fe ka > -87.71 (peso 42.0)
# Mantida aresta Fe ka > -87.71 -> Ti kb > 25.84 (peso 42.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 7.64 -> Ag ka scattering <= -1.33 (peso 74.0)
# Mantida aresta Ag ka scattering <= -1.33 -> Ti kb <= 7.64 (peso 222.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= -23.18 -> Ti kb <= 7.64 (peso 71.0)
# Mantida aresta Ti kb <= 7.64 -> Ca ka <= -23.18 (peso 71.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 7.59 -> Ag ka scattering <= -1.33 (peso 114.0)
# Mantida aresta Ag ka scattering <= -1.33 -> Ag ka scattering <= 7.59 (peso 228.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= -23.18 -> Ag ka scattering <= 7.59 (peso 93.0)
# Mantida aresta Ag ka scattering <= 7.59 -> Ca ka <= -23.18 (peso 93.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= -23.18 -> Ag ka scattering <= 16.12 (peso 124.0)
# Mantida aresta Ag ka scattering <= 16.12 -> Ca ka <= -23.18 (peso 372.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 7.59 -> Ag ka scattering > -17.00 (peso 114.0)
# Mantida aresta Ag ka scattering > -17.00 -> Ag ka scattering > 7.59 (peso 456.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > -17.00 -> Ag ka scattering > -1.33 (peso 170.0)
# Mantida aresta Ag ka scattering > -1.33 -> Ag ka scattering > -17.00 (peso 170.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -16.92 -> Ca kb > -25.56 (peso 340.0)
# Mantida aresta Ca kb > -25.56 -> Ca kb > -16.92 (peso 510.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= -12.29 -> Ca kb > -6.98 (peso 84.0)
# Mantida aresta Ca kb > -6.98 -> Ti kb <= -12.29 (peso 168.0)
#
# ======================================================================
#
# Removida aresta Ca kb > -6.98 -> Fe kb > -20.48 (peso 36.0)
# Mantida aresta Fe kb > -20.48 -> Ca kb > -6.98 (peso 72.0)
#
# ======================================================================
#
# Removida aresta background4 <= 30.03 -> background4 <= 59.25 (peso 170.0)
# Mantida aresta background4 <= 59.25 -> background4 <= 30.03 (peso 340.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= -2.98 -> background4 <= 59.25 (peso 95.0)
# Mantida aresta background4 <= 59.25 -> background6 <= -2.98 (peso 95.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= -12.62 -> Fe kb > -20.48 (peso 10.0)
# Mantida aresta Fe kb > -20.48 -> background6 <= -12.62 (peso 10.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= -12.62 -> background4 <= 30.03 (peso 37.0)
# Mantida aresta background4 <= 30.03 -> background6 <= -12.62 (peso 37.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= -2.98 -> background6 <= -12.62 (peso 57.0)
# Mantida aresta background6 <= -12.62 -> background6 <= -2.98 (peso 57.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= -2.98 -> background6 <= 4.68 (peso 114.0)
# Mantida aresta background6 <= 4.68 -> background6 <= -2.98 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= -10.57 -> background6 <= 12.05 (peso 98.0)
# Mantida aresta background6 <= 12.05 -> background4 <= -10.57 (peso 98.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= -10.57 -> Fe kb > -26.06 (peso 71.0)
# Mantida aresta Fe kb > -26.06 -> background4 <= -10.57 (peso 71.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 > -59.98 -> background6 <= 12.05 (peso 175.0)
# Mantida aresta background6 <= 12.05 -> background4 > -59.98 (peso 175.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb > -23.43 -> background6 <= 12.05 (peso 95.0)
# Mantida aresta background6 <= 12.05 -> Fe kb > -23.43 (peso 95.0)
#
# ======================================================================
#
# Removida aresta background4 > -59.98 -> Fe kb > -23.43 (peso 87.0)
# Mantida aresta Fe kb > -23.43 -> background4 > -59.98 (peso 261.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb > -26.06 -> background4 <= -59.98 (peso 38.0)
# Mantida aresta background4 <= -59.98 -> Fe kb > -26.06 (peso 38.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 59.25 -> Ca ka <= -67.03 (peso 17.0)
# Mantida aresta Ca ka <= -67.03 -> background4 > 59.25 (peso 17.0)
#
# ======================================================================
#
# Removida aresta background4 > 30.03 -> background4 > -10.57 (peso 114.0)
# Mantida aresta background4 > -10.57 -> background4 > 30.03 (peso 228.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 4.68 -> background6 > -2.98 (peso 114.0)
# Mantida aresta background6 > -2.98 -> background6 > 4.68 (peso 114.0)
#
# ======================================================================
#
# Removida aresta background6 > 12.05 -> Cu <= -8.52 (peso 44.0)
# Mantida aresta Cu <= -8.52 -> background6 > 12.05 (peso 88.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= -8.52 -> Ca kb > 37.90 (peso 56.0)
# Mantida aresta Ca kb > 37.90 -> Cu <= -8.52 (peso 56.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 12.05 -> background4 > 59.25 (peso 11.0)
# Mantida aresta background4 > 59.25 -> background6 > 12.05 (peso 11.0)
#
# ======================================================================
#
# Removida aresta background6 > 4.68 -> background6 > 12.05 (peso 57.0)
# Mantida aresta background6 > 12.05 -> background6 > 4.68 (peso 114.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= -6.98 -> Cu <= -28.05 (peso 100.0)
# Mantida aresta Cu <= -28.05 -> Ca kb <= -6.98 (peso 300.0)
#
# ======================================================================
#
# Removida aresta Cu <= -33.81 -> Ca kb <= -6.98 (peso 66.0)
# Mantida aresta Ca kb <= -6.98 -> Cu <= -33.81 (peso 198.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= -37.01 -> background2 > -11.03 (peso 38.0)
# Mantida aresta background2 > -11.03 -> Cu <= -37.01 (peso 38.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > -6.67 -> Cu <= -37.01 (peso 23.0)
# Mantida aresta Cu <= -37.01 -> background2 > -6.67 (peso 23.0)
#
# ======================================================================
#
# Removida aresta background2 <= 11.97 -> background5 <= 10.35 (peso 180.0)
# Mantida aresta background5 <= 10.35 -> background2 <= 11.97 (peso 360.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= -16.92 -> background5 <= 3.41 (peso 71.0)
# Mantida aresta background5 <= 3.41 -> Ca kb <= -16.92 (peso 71.0)
#
# ======================================================================
#
# Removida aresta background2 > 0.19 -> background2 <= 11.97 (peso 57.0)
# Mantida aresta background2 <= 11.97 -> background2 > 0.19 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 3.41 -> background5 > -10.87 (peso 226.0)
# Mantida aresta background5 > -10.87 -> background5 <= 3.41 (peso 226.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= -2.34 -> background2 <= 0.19 (peso 138.0)
# Mantida aresta background2 <= 0.19 -> background5 <= -2.34 (peso 138.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > 2.61 -> background1 > -2.14 (peso 114.0)
# Mantida aresta background1 > -2.14 -> background1 > 2.61 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 > 2.61 -> background1 <= 7.73 (peso 57.0)
# Mantida aresta background1 <= 7.73 -> background1 > 2.61 (peso 57.0)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= -2.14 -> background1 > -7.55 (peso 57.0)
# Mantida aresta background1 > -7.55 -> background1 <= -2.14 (peso 57.0)
#
# ======================================================================
#
# Removida aresta background1 <= 7.73 -> background1 <= 2.61 (peso 340.0)
# Mantida aresta background1 <= 2.61 -> background1 <= 7.73 (peso 510.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= -6.67 -> background5 > 10.35 (peso 25.0)
# Mantida aresta background5 > 10.35 -> background2 <= -6.67 (peso 25.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 5.57 -> background5 > 10.35 (peso 43.0)
# Mantida aresta background5 > 10.35 -> Ar ka + Ag L <= 5.57 (peso 86.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= -2.13 -> Ar ka + Ag L <= 1.73 (peso 114.0)
# Mantida aresta Ar ka + Ag L <= 1.73 -> Ar ka + Ag L <= -2.13 (peso 228.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= -5.42 -> Ar ka + Ag L <= -2.13 (peso 57.0)
# Mantida aresta Ar ka + Ag L <= -2.13 -> Ar ka + Ag L <= -5.42 (peso 57.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > -5.42 -> Ar ka + Ag L <= -5.42 (peso 0.0)
# Mantida aresta Ar ka + Ag L <= -5.42 -> Ar ka + Ag L > -5.42 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > -2.13 -> Ar ka + Ag L > 1.73 (peso 113.0)
# Mantida aresta Ar ka + Ag L > 1.73 -> Ar ka + Ag L > -2.13 (peso 339.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -85.11 -> Fe ka <= -78.61 (peso 114.0)
# Mantida aresta Fe ka <= -78.61 -> Fe ka <= -85.11 (peso 114.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > 5.57 -> Fe ka <= -78.61 (peso 45.0)
# Mantida aresta Fe ka <= -78.61 -> Ar ka + Ag L > 5.57 (peso 45.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -85.11 -> Fe ka <= -82.70 (peso 228.0)
# Mantida aresta Fe ka <= -82.70 -> Fe ka <= -85.11 (peso 228.0)
#
# ======================================================================
#
# Removida aresta background3 > -3.66 -> background3 > -1.76 (peso 170.0)
# Mantida aresta background3 > -1.76 -> background3 > -3.66 (peso 340.0)
#
# ======================================================================
#
# Removida aresta background3 > 1.02 -> background3 > -3.66 (peso 114.0)
# Mantida aresta background3 > -3.66 -> background3 > 1.02 (peso 228.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= -23.43 -> background3 > -3.66 (peso 127.0)
# Mantida aresta background3 > -3.66 -> Fe kb <= -23.43 (peso 127.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= -3.66 -> background3 <= 1.02 (peso 57.0)
# Mantida aresta background3 <= 1.02 -> background3 <= -3.66 (peso 57.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 387
# Total de arestas removidas por bidirecionalidade: 67
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 120
# Total de nós terminais: 2
#
#
# Processando LRC do grafo...
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#          Predicate_Seed_0
# 0          Ti ka > -93.99
# 1          Ti ka <= 69.02
# 2          Ti ka > -15.10
# 3          Ca ka > -84.19
# 4          Ti ka <= 31.35
# ..                    ...
# 117    background3 > 1.02
# 118       Fe kb <= -28.54
# 119  background3 <= -3.66
# 120               Class_A
# 121               Class_B
#
# [122 rows x 1 columns]

# %% [markdown]
# ## VIP, Regression Coefficients e SHAP (como no original)

# %%
# VIP scores por energia
vip_scores_df = pd.DataFrame({
    'energy': vip_scores_mat.T.index,
    'VIP_Score': vip_scores_mat.T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in vip_scores_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip)
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# Coeficientes de regressão do PLS
reg_vet = pd.DataFrame(pls_model.coef_, columns=pls_model.feature_names_in_).T
reg_vet.insert(0, 'energy', reg_vet.index)
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy','Reg_coef']
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs()
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
energy_to_zone_reg = {}
for zone_name, start, end in spectral_cuts:
    for e in reg_vet['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_reg[e] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg)
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# vamos agora extrair as variaveis mais importantes atraves do método SHAP
# import shap

# # Para PLSRegression, usamos KernelExplainer porque não há explainer dedicado muito rápido
# explainer_pls = shap.KernelExplainer(plsda_results[3].predict, Xcalclass_prep)
# shap_values_pls = explainer_pls(Xcalclass_prep)

# shap_global_importance = pd.DataFrame({
#     'energy': Xpredclass_prep.columns,
#     'Mean_Abs_SHAP': np.abs(shap_values_pls.values).mean(axis=0)}) # tomando a importancia global como a media dos valores absolutos dos valores SHAP para cada feature
# shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False, inplace=True)

# # vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
# energy_to_zone_shap = {}
# for zone_name, start, end in spectral_cuts:
#     for i in shap_global_importance['energy']:
#         i_float = float(i)
#         if start <= i_float <= end:
#             energy_to_zone_shap[i] = zone_name
# shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# # agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
# shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
# shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
# shap_unique_df.to_csv('shap_bank_notes.csv', index=False, sep=';')
shap_unique_df = pd.read_csv('shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df

# %%
lrc_unique_df
# Out:
#                         Node  Local_Reaching_Centrality              Zone  \
# 0             Ti ka > -93.99                   2.780567             Ti ka
# 1             Ca ka > -84.19                   2.284704             Ca ka
# 2                Cu > -33.81                   2.217283                Cu
# 3   Ag ka scattering <= 7.59                   1.852764  Ag ka scattering
# 4              Ti kb > 25.84                   1.780477             Ti kb
# 5             Fe ka > -82.70                   1.564818             Fe ka
# 6             Ca kb > -25.56                   1.387077             Ca kb
# 7       background4 <= 59.25                   1.290253       background4
# 8             Fe kb > -28.54                   1.277467             Fe kb
# 9       background6 > -12.62                   1.259330       background6
# 10      background2 > -11.03                   0.980329       background2
# 11      background5 <= 10.35                   0.748675       background5
# 12       background1 <= 2.61                   0.621471       background1
# 13       Ar ka + Ag L > 1.73                   0.566796      Ar ka + Ag L
# 14       background3 <= 1.02                   0.176186       background3
# 15                   Class_A                   0.000000              None
#
#    Threshold Operator  Seed
# 0     -93.99        >     0
# 1     -84.19        >     0
# 2     -33.81        >     0
# 3       7.59       <=     0
# 4      25.84        >     0
# 5     -82.70        >     0
# 6     -25.56        >     0
# 7      59.25       <=     0
# 8     -28.54        >     0
# 9     -12.62        >     0
# 10    -11.03        >     0
# 11     10.35       <=     0
# 12      2.61       <=     0
# 13      1.73        >     0
# 14      1.02       <=     0
# 15      None     None     0

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(lrc_unique_df['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Vip': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_coef': pad_list(reg_vet_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
})

for seed, lrc_unique_df in lrc_unique_by_seed.items():
    features_importance[f'LRC_Seed_{seed}'] = pad_list(lrc_unique_df['Zone'].tolist(), max_len)

#features_importance

# vamos exportar o df features_importance para um arquivo excel onde vamos nomear a sheet de acordo com as comparacoes feitas
features_importance.to_excel('features_importance_bank_notes.xlsx', index=False, sheet_name='Perm')
features_importance
# Out:
#                  Vip          Reg_coef              Shap        LRC_Seed_0
# 0              Fe ka             Ti ka             Ti ka             Ti ka
# 1              Ca ka             Ti kb             Ca ka             Ca ka
# 2              Ti ka  Ag ka scattering                Cu                Cu
# 3                 Cu             Ca ka             Fe ka  Ag ka scattering
# 4              Fe kb                Cu             Ti kb             Ti kb
# 5              Ca kb       background6  Ag ka scattering             Fe ka
# 6              Ti kb             Ca kb       background6             Ca kb
# 7   Ag ka scattering       background4       background4       background4
# 8        background6       background2       background5             Fe kb
# 9        background4      Ar ka + Ag L       background1       background6
# 10       background2       background5       background2       background2
# 11      Ar ka + Ag L             Fe ka             Ca kb       background5
# 12       background5       background1             Fe kb       background1
# 13       background1       background3       background3      Ar ka + Ag L
# 14       background3             Fe kb      Ar ka + Ag L       background3
# 15              None              None              None              None

# %%
# RBO (Rank-Biased Overlap) para comparar rankings
import rbo
rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if x is not None]
methods = ['Reg_coef', 'Shap'] + [f'LRC_Seed_{seed}' for seed in random_seeds]
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if x is not None]
    # Truncate both lists to the same length (minimum of both)
    min_len = min(len(reference_list), len(compare_list))
    ref_trunc = reference_list[:min_len]
    cmp_trunc = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trunc, cmp_trunc).rbo(p=0.7, k=15)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method','RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_results.to_excel('rbo_bank_notes.xlsx', index=False, sheet_name='perm')
rbo_results
# Out:
#   Reference      Method  RBO_Score
# 1       Vip        Shap   0.484458
# 2       Vip  LRC_Seed_0   0.459043
# 0       Vip    Reg_coef   0.256693
