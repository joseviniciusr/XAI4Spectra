# %% [markdown]
# ## Loading data

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/soil_types/plsda/soil_types.csv', sep=';') # local copy of Toledo and Guarapuava soil datasets
data = data_complete.loc[:, '1':'15']

# Split dataset by class and create calibration/prediction sets using Kennard-Stone (as in original pipeline)
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1':'15'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1':'15'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)

from modeling import pls_optimized

# performing PLS-DA with optimized latent variables
plsda_results = pls_optimized(Xcalclass_prep, 
                              ycalclass,
                              LVmax=2,
                              Xpred=Xpredclass_prep,
                              ypred=ypredclass,
                              aim='classification',
                              cv=10)
plsda_results[0]


# Convenience references used later
pls_model = plsda_results[3]               # fitted PLS model
vip_scores_mat = plsda_results[4]          # VIP scores matrix (features × LV)
y_pred_cont = plsda_results[5].iloc[:, -1] # continuous predictions for Xcalclass (used for MI/Cov)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-20 10:05:16,981 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-20 10:05:17,494 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-20 10:05:17,624 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-20 10:05:17,890 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# ## Spectral cuts (domain knowledge)

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('background1', 1.0, 1.33),
('Al', 1.34, 1.63),
('Si', 1.64, 1.86),
('P', 1.87, 2.19),
('S', 2.20, 2.44),
('background2', 2.45, 2.55),
('Rh L + Ar', 2.56, 3.21),
('K', 3.22, 3.53),
('Ca ka', 3.54, 3.84),
('Ca kb', 3.86, 4.14),
('background3', 4.15, 4.37),
('Ti ka', 4.38, 4.66),
('background4', 4.67, 4.75),
('Ti kb', 4.76, 5.12),
('Cr', 5.13, 5.77),
('Mn', 5.78, 6.13),
('Fe ka', 6.14, 6.80),
('Fe kb', 6.81, 7.30),
('background5', 7.31, 7.91),
('Cu', 7.92, 8.20),
('background6', 8.21, 10.69),
('Fe ka + Ti ka', 10.7, 11.14),
('background7', 11.15, 12.55),
('sum Fe' , 12.56, 13.1),
('background8', 13.11, 15.0)
]

import explaining as exp
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_sums_df = exp.aggregate_spectral_zones(spectral_zones_class, aggregator='sum')
predicates_quantiles = exp.predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8])
co_occurrence_matrix_df = predicates_quantiles[2]
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=y_pred_cont
)

# %% [markdown]
# ## VIP, Regression Coefficients e SHAP (como no original)

# %%
# VIP scores por energia
vip_scores_df = pd.DataFrame({
    'energy': vip_scores_mat.T.index,
    'VIP_Score': vip_scores_mat.T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in vip_scores_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip)
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# Coeficientes de regressão do PLS
reg_vet = pd.DataFrame(pls_model.coef_, columns=pls_model.feature_names_in_).T
reg_vet.insert(0, 'energy', reg_vet.index)
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy','Reg_coef']
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs()
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
energy_to_zone_reg = {}
for zone_name, start, end in spectral_cuts:
    for e in reg_vet['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_reg[e] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg)
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# # vamos agora extrair as variaveis mais importantes atraves do método SHAP
# import shap

# # Para PLSRegression, usamos KernelExplainer porque não há explainer dedicado muito rápido
# explainer_pls = shap.KernelExplainer(plsda_results[3].predict, Xcalclass_prep)
# shap_values_pls = explainer_pls(Xcalclass_prep)

# shap_global_importance = pd.DataFrame({
#     'energy': Xpredclass_prep.columns,
#     'Mean_Abs_SHAP': np.abs(shap_values_pls.values).mean(axis=0)}) # tomando a importancia global como a media dos valores absolutos dos valores SHAP para cada feature
# shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False, inplace=True)

# # vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
# energy_to_zone_shap = {}
# for zone_name, start, end in spectral_cuts:
#     for i in shap_global_importance['energy']:
#         i_float = float(i)
#         if start <= i_float <= end:
#             energy_to_zone_shap[i] = zone_name
# shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# # agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
# shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
# shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
# shap_unique_df.to_csv('shap_soil.csv', index=False, sep=';')
shap_unique_df = pd.read_csv('shap_soil_types.csv', sep=';') # loading previously saved shap_unique_df

# %%
from permutation import calculate_predicate_metrics_permutation

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 42]

all_results = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.5), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.1), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    # Calcular MI

    perm_results = calculate_predicate_metrics_permutation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        y_calclass=ycalclass,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        scoring='accuracy',
        n_repeats=10,  # Usar 10-20 em produção para resultados mais estáveis
        random_state=0,
        n_jobs=-1,
        verbose=True,
        save_detailed_results=True
    )

    # Remove todos os valores iguais a zero de todos os bags em perm_results[bag]["Permutation"] e salva como perm_results_thresholded
    perm_results_thresholded = {}
    for bag, df in perm_results.items():
        # Verifica se é um DataFrame e se a coluna 'Permutation' existe
        if isinstance(df, pd.DataFrame) and 'Permutation' in df.columns:
            filtered_df = df[df['Permutation'] > 0].copy()
            perm_results_thresholded[bag] = filtered_df
        else:
            # Se não for DataFrame esperado, apenas copia
            perm_results_thresholded[bag] = df


    # Salvar no dicionário principal
    all_results[seed] = {
        'bags_result': bags_result_seed,
        'mi_results_dict': perm_results_thresholded
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")

# Construir grafo para esta semente
    DG = exp.build_predicate_graph(
        bags_result=all_results[seed]['bags_result'],
        mi_results_dict=all_results[seed]['mi_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )

    # Armazenar grafo
    graphs_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_by_seed[seed] = lrc_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_df_seed = lrc_by_seed[seed].rename(columns={'Node': f'Predicate_Seed_{seed}'})
    lrc_all_seeds_df = pd.concat([lrc_all_seeds_df, lrc_df_seed[[f'Predicate_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_unique_by_seed = {}
for seed, lrc_df in lrc_by_seed.items():
    lrc_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_unique_df = lrc_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_unique_by_seed[seed] = lrc_unique_df

lrc_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ✓ Funções de Permutation Importance para Predicados carregadas com sucesso!
#   - calculate_predicate_metrics_permutation()
#   - get_zone_columns_from_predicate()
#   - compare_importance_methods()
#   - _manual_block_permutation()
#
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 188 | Descartados: 12
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 180 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 187 | Descartados: 13
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 173 | Descartados: 27
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 167 | Descartados: 33
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 170 | Descartados: 30
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 174 | Descartados: 26
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 176 | Descartados: 24
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 167 | Descartados: 33
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 164 | Descartados: 36
# ======================================================================
# PERMUTATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Métrica de scoring: accuracy
# Número de repetições: 10
# Random state: 0
# Total de folds: 10
#
#
# [Bag_1] Processando 188 predicados...
#   Predicado: background1 <= -0.44 (n=52)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([50,  2], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 2, 50], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 > -0.44 (n=198)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 77, 121], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([121,  77], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 <= -0.17 (n=102)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([97,  5], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 5, 97], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 > -0.17 (n=148)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 30, 118], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([118,  30], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 <= 0.13 (n=145)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([123,  22], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 22, 123], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 > 0.13 (n=105)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([  4, 101], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([101,   4], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 <= 0.46 (n=198)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([127,  71], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 71, 127], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background1 > 0.46 (n=52)
#     Zona: 17 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['B'], dtype='<U1'), array([52], dtype=int64))
#     y_true: (array(['A'], dtype=object), array([52], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al > -1.90 (n=201)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 94, 107], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([107,  94], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al <= -0.73 (n=98)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([69, 29], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([29, 69], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al > -0.73 (n=152)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([58, 94], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([94, 58], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al <= 0.38 (n=146)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([104,  42], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 42, 104], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al > 0.38 (n=104)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([23, 81], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([81, 23], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al <= 1.95 (n=195)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([123,  72], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 72, 123], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Al > 1.95 (n=55)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 4, 51], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([51,  4], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si <= -3.35 (n=50)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([42,  8], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 8, 42], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si > -3.35 (n=200)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 85, 115], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([115,  85], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si <= -1.65 (n=96)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([80, 16], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([16, 80], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si > -1.65 (n=154)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 47, 107], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([107,  47], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si <= 0.57 (n=149)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([114,  35], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 35, 114], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si > 0.57 (n=101)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([13, 88], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([88, 13], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Si <= 3.24 (n=203)
#     Zona: 12 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([126,  77], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 77, 126], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P <= -1.00 (n=54)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([18, 36], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([36, 18], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P > -1.00 (n=196)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([109,  87], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 87, 109], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P <= -0.50 (n=99)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([33, 66], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([66, 33], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P > -0.50 (n=151)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([94, 57], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([57, 94], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P <= 0.07 (n=148)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([63, 85], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([85, 63], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P > 0.07 (n=102)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([64, 38], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([38, 64], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P <= 0.91 (n=198)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 88, 110], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([110,  88], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: P > 0.91 (n=52)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([39, 13], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([13, 39], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S > -0.48 (n=204)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 95, 109], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([109,  95], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S <= -0.19 (n=96)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([58, 38], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([38, 58], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S > -0.19 (n=154)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([69, 85], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([85, 69], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S <= 0.09 (n=145)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([80, 65], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([65, 80], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S > 0.09 (n=105)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([47, 58], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([58, 47], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S <= 0.49 (n=197)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([103,  94], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 94, 103], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: S > 0.49 (n=53)
#     Zona: 13 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([24, 29], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([29, 24], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 > -0.17 (n=207)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 85, 122], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([122,  85], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 <= -0.06 (n=97)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([90,  7], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 7, 90], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 > -0.06 (n=153)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 37, 116], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([116,  37], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 <= 0.05 (n=150)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([115,  35], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 35, 115], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 > 0.05 (n=100)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([12, 88], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([88, 12], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 <= 0.16 (n=194)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([124,  70], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 70, 124], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background2 > 0.16 (n=56)
#     Zona: 5 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 3, 53], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([53,  3], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar > -3.36 (n=203)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 80, 123], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([123,  80], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar <= -1.90 (n=96)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A'], dtype='<U1'), array([96], dtype=int64))
#     y_true: (array(['B'], dtype=object), array([96], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar > -1.90 (n=154)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 31, 123], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([123,  31], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar <= 1.72 (n=148)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([127,  21], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 21, 127], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar > 1.72 (n=102)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['B'], dtype='<U1'), array([102], dtype=int64))
#     y_true: (array(['A'], dtype=object), array([102], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar <= 3.58 (n=194)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([127,  67], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 67, 127], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Rh L + Ar > 3.58 (n=56)
#     Zona: 33 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['B'], dtype='<U1'), array([56], dtype=int64))
#     y_true: (array(['A'], dtype=object), array([56], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K > -1.18 (n=204)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 89, 115], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([115,  89], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K <= -0.59 (n=101)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([70, 31], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([31, 70], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K > -0.59 (n=149)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([57, 92], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([92, 57], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K <= 0.03 (n=149)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([95, 54], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([54, 95], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K > 0.03 (n=101)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([32, 69], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([69, 32], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K <= 0.76 (n=199)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([119,  80], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 80, 119], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: K > 0.76 (n=51)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 8, 43], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([43,  8], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca ka <= -6.16 (n=54)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([33, 21], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([21, 33], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca ka > -6.16 (n=196)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 94, 102], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([102,  94], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0051, importance=-0.0051
#     Rep 2: permuted_score=0.0102, importance=-0.0102
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: -0.005612 ± 0.002748
#   Predicado: Ca ka <= -4.12 (n=104)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([69, 35], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([35, 69], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca ka > -4.12 (n=146)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([58, 88], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([88, 58], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0068, importance=-0.0068
#     Importance: -0.002740 ± 0.003355
#   Predicado: Ca ka <= -1.28 (n=150)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([91, 59], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([59, 91], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca ka > -1.28 (n=100)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([36, 64], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([64, 36], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0100, importance=-0.0100
#     Rep 3: permuted_score=0.0100, importance=-0.0100
#     Importance: -0.005000 ± 0.005000
#   Predicado: Ca ka <= 5.46 (n=199)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([108,  91], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 91, 108], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0050, importance=-0.0050
#     Rep 2: permuted_score=0.0050, importance=-0.0050
#     Rep 3: permuted_score=0.0050, importance=-0.0050
#     Importance: -0.003518 ± 0.002303
#   Predicado: Ca ka > 5.46 (n=51)
#     Zona: 16 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([19, 32], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([32, 19], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: -0.007843 ± 0.009606
#   Predicado: Ca kb <= -1.76 (n=54)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([52,  2], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 2, 52], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca kb > -1.76 (n=196)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 75, 121], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([121,  75], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca kb <= -0.77 (n=98)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([86, 12], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([12, 86], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca kb > -0.77 (n=152)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 41, 111], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([111,  41], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca kb <= 0.16 (n=143)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([101,  42], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 42, 101], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca kb > 0.16 (n=107)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([26, 81], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([81, 26], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ca kb <= 1.47 (n=203)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([116,  87], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 87, 116], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 <= -0.90 (n=56)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([52,  4], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 4, 52], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 > -0.90 (n=194)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 75, 119], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([119,  75], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 <= -0.16 (n=98)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([83, 15], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([15, 83], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 > -0.16 (n=152)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 44, 108], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([108,  44], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 <= 0.28 (n=148)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([109,  39], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 39, 109], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 > 0.28 (n=102)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([18, 84], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([84, 18], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 <= 0.87 (n=193)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([126,  67], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 67, 126], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background3 > 0.87 (n=57)
#     Zona: 11 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 1, 56], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([56,  1], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti ka <= -6.95 (n=50)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([29, 21], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([21, 29], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti ka > -6.95 (n=200)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 98, 102], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([102,  98], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0050, importance=-0.0050
#     Rep 3: permuted_score=0.0050, importance=-0.0050
#     Importance: -0.001500 ± 0.002291
#   Predicado: Ti ka <= -2.07 (n=104)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([66, 38], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([38, 66], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti ka > -2.07 (n=146)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([61, 85], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([85, 61], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: -0.000685 ± 0.002055
#   Predicado: Ti ka <= 2.06 (n=154)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([94, 60], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([60, 94], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti ka > 2.06 (n=96)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([33, 63], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([63, 33], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti ka <= 6.53 (n=197)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([114,  83], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 83, 114], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0051, importance=-0.0051
#     Rep 3: permuted_score=0.0051, importance=-0.0051
#     Importance: -0.003046 ± 0.002487
#   Predicado: Ti ka > 6.53 (n=53)
#     Zona: 15 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([13, 40], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([40, 13], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 <= -0.81 (n=55)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A'], dtype='<U1'), array([55], dtype=int64))
#     y_true: (array(['B'], dtype=object), array([55], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 > -0.81 (n=195)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 72, 123], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([123,  72], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 <= -0.38 (n=96)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([93,  3], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 3, 93], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 > -0.38 (n=154)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 34, 120], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([120,  34], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 <= 0.14 (n=149)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([125,  24], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 24, 125], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 > 0.14 (n=101)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([ 2, 99], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([99,  2], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: background4 <= 0.96 (n=202)
#     Zona: 4 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([127,  75], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 75, 127], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti kb <= -3.81 (n=59)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([52,  7], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 7, 52], dtype=int64))
#     Baseline score: 0.0000
#     Rep 1: permuted_score=0.0000, importance=0.0000
#     Rep 2: permuted_score=0.0000, importance=0.0000
#     Rep 3: permuted_score=0.0000, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#   Predicado: Ti kb > -3.81 (n=191)
#     Zona: 19 colunas
#     Usando permutação manual do bloco
# ...
#     Importance: 0.000000 ± 0.000000
#   Predicado: background8 <= 2.86 (n=202)
#     Zona: 95 colunas
#     Usando permutação manual do bloco
#     Predições baseline: (array(['A', 'B'], dtype='<U1'), array([127,  75], dtype=int64))
#     y_true: (array(['A', 'B'], dtype=object), array([ 76, 126], dtype=int64))
#     Baseline score: 0.0050
#     Rep 1: permuted_score=0.0050, importance=0.0000
#     Rep 2: permuted_score=0.0050, importance=0.0000
#     Rep 3: permuted_score=0.0050, importance=0.0000
#     Importance: 0.000000 ± 0.000000
#
# ======================================================================
# RESUMO
# ======================================================================
# Folds processados: 10
# Predicados processados: 1770
# Predicados ignorados (edge cases): 0
#
#   Bag_1: 172 predicados com importance > 0
#   Bag_2: 186 predicados com importance > 0
#   Bag_3: 172 predicados com importance > 0
#   Bag_4: 179 predicados com importance > 0
#   Bag_5: 167 predicados com importance > 0
#   Bag_6: 184 predicados com importance > 0
#   Bag_7: 178 predicados com importance > 0
#   Bag_8: 185 predicados com importance > 0
#   Bag_9: 179 predicados com importance > 0
#   Bag_10: 168 predicados com importance > 0
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 18
# Removida aresta Fe ka <= 47.71 -> Fe ka > -42.15 (peso 900.0)
# Mantida aresta Fe ka > -42.15 -> Fe ka <= 47.71 (peso 2100.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 18.68 -> Fe ka > -22.92 (peso 100.0)
# Mantida aresta Fe ka > -22.92 -> Fe ka <= 18.68 (peso 900.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= -42.15 -> Ca ka > 5.46 (peso 19.0)
# Mantida aresta Ca ka > 5.46 -> Fe ka <= -42.15 (peso 19.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= -8.24 -> Fe ka <= -22.92 (peso 199.0)
# Mantida aresta Fe ka <= -22.92 -> Fe kb <= -8.24 (peso 199.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -1.28 -> Ca ka > -6.16 (peso 201.0)
# Mantida aresta Ca ka > -6.16 -> Ca ka > -1.28 (peso 402.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 6.53 -> Ca ka > -6.16 (peso 323.0)
# Mantida aresta Ca ka > -6.16 -> Ti ka <= 6.53 (peso 323.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 6.39 -> Ca ka > -6.16 (peso 233.0)
# Mantida aresta Ca ka > -6.16 -> Fe kb <= 6.39 (peso 233.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -1.28 -> Ca ka > -4.12 (peso 201.0)
# Mantida aresta Ca ka > -4.12 -> Ca ka > -1.28 (peso 402.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 5.46 -> Fe kb <= 6.39 (peso 246.0)
# Mantida aresta Fe kb <= 6.39 -> Ca ka <= 5.46 (peso 246.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -4.12 -> Ti ka <= 6.53 (peso 232.0)
# Mantida aresta Ti ka <= 6.53 -> Ca ka > -4.12 (peso 232.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 6.53 -> Ti ka <= 2.06 (peso 301.0)
# Mantida aresta Ti ka <= 2.06 -> Ti ka <= 6.53 (peso 301.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -6.95 -> Ca ka > -4.12 (peso 241.0)
# Mantida aresta Ca ka > -4.12 -> Ti ka > -6.95 (peso 241.0)
#
# ======================================================================
#
# Removida aresta Ti ka > -2.07 -> Ti ka > -6.95 (peso 301.0)
# Mantida aresta Ti ka > -6.95 -> Ti ka > -2.07 (peso 602.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 17.60 -> Ti ka > -6.95 (peso 308.0)
# Mantida aresta Ti ka > -6.95 -> Fe kb <= 17.60 (peso 308.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 6.39 -> Ti ka > -2.07 (peso 148.0)
# Mantida aresta Ti ka > -2.07 -> Fe kb <= 6.39 (peso 296.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -2.07 -> Fe kb > -15.50 (peso 298.0)
# Mantida aresta Fe kb > -15.50 -> Ti ka > -2.07 (peso 298.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 17.60 -> Fe kb <= 6.39 (peso 301.0)
# Mantida aresta Fe kb <= 6.39 -> Fe kb <= 17.60 (peso 301.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= -2.07 -> Fe kb <= 17.60 (peso 180.0)
# Mantida aresta Fe kb <= 17.60 -> Ti ka <= -2.07 (peso 180.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 144
# Total de arestas removidas por bidirecionalidade: 18
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 30
# Total de nós terminais: 2
#
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 17
# Removida aresta Fe ka <= 47.71 -> Fe ka > -42.15 (peso 300.0)
# Mantida aresta Fe ka > -42.15 -> Fe ka <= 47.71 (peso 2700.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 5.46 -> Fe kb <= 17.60 (peso 311.0)
# Mantida aresta Fe kb <= 17.60 -> Ca ka <= 5.46 (peso 622.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 5.46 -> Ca ka <= -4.12 (peso 201.0)
# Mantida aresta Ca ka <= -4.12 -> Ca ka <= 5.46 (peso 201.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 2.06 -> Ti ka <= 6.53 (peso 301.0)
# Mantida aresta Ti ka <= 6.53 -> Ti ka <= 2.06 (peso 301.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 6.53 -> Fe kb <= 6.39 (peso 281.0)
# Mantida aresta Fe kb <= 6.39 -> Ti ka <= 6.53 (peso 281.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 6.53 -> Ca ka > -4.12 (peso 232.0)
# Mantida aresta Ca ka > -4.12 -> Ti ka <= 6.53 (peso 232.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= -22.92 -> Ca ka > -1.28 (peso 69.0)
# Mantida aresta Ca ka > -1.28 -> Fe ka <= -22.92 (peso 138.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -6.95 -> Fe ka <= -22.92 (peso 140.0)
# Mantida aresta Fe ka <= -22.92 -> Ti ka > -6.95 (peso 140.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -4.12 -> Fe kb <= 6.39 (peso 161.0)
# Mantida aresta Fe kb <= 6.39 -> Ca ka > -4.12 (peso 322.0)
#
# ======================================================================
#
# Removida aresta Ti ka > -2.07 -> Ti ka <= 2.06 (peso 101.0)
# Mantida aresta Ti ka <= 2.06 -> Ti ka > -2.07 (peso 202.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -2.07 -> Fe kb <= 17.60 (peso 220.0)
# Mantida aresta Fe kb <= 17.60 -> Ti ka > -2.07 (peso 220.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -2.07 -> Ca ka > -6.16 (peso 240.0)
# Mantida aresta Ca ka > -6.16 -> Ti ka > -2.07 (peso 240.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 2.06 -> Ca ka > -4.12 (peso 168.0)
# Mantida aresta Ca ka > -4.12 -> Ti ka <= 2.06 (peso 336.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -4.12 -> Mn > -2.66 (peso 211.0)
# Mantida aresta Mn > -2.66 -> Ca ka > -4.12 (peso 211.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -4.12 -> Ti ka <= -2.07 (peso 116.0)
# Mantida aresta Ti ka <= -2.07 -> Ca ka > -4.12 (peso 116.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 17.60 -> Ca ka > -6.16 (peso 323.0)
# Mantida aresta Ca ka > -6.16 -> Fe kb <= 17.60 (peso 646.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= -4.12 -> Fe kb > -15.50 (peso 150.0)
# Mantida aresta Fe kb > -15.50 -> Ca ka <= -4.12 (peso 300.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 145
# Total de arestas removidas por bidirecionalidade: 17
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 30
# Total de nós terminais: 2
#
#
# ======================================================================
# Processando Grafo - Semente: 42
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 19
# Empate! Removida aresta Fe ka <= 47.71 -> Fe ka > -42.15 (peso 1500.0)
# Mantida aresta Fe ka > -42.15 -> Fe ka <= 47.71 (peso 1500.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 18.68 -> Fe ka > -22.92 (peso 100.0)
# Mantida aresta Fe ka > -22.92 -> Fe ka <= 18.68 (peso 900.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -1.28 -> Ca ka > -6.16 (peso 201.0)
# Mantida aresta Ca ka > -6.16 -> Ca ka > -1.28 (peso 201.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 5.46 -> Ca ka > -6.16 (peso 300.0)
# Mantida aresta Ca ka > -6.16 -> Ca ka <= 5.46 (peso 300.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= -2.07 -> Ca ka > -1.28 (peso 164.0)
# Mantida aresta Ca ka > -1.28 -> Ti ka <= -2.07 (peso 164.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -1.28 -> Ti ka <= 2.06 (peso 119.0)
# Mantida aresta Ti ka <= 2.06 -> Ca ka > -1.28 (peso 119.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > -1.28 -> Ca ka > -4.12 (peso 201.0)
# Mantida aresta Ca ka > -4.12 -> Ca ka > -1.28 (peso 201.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -4.12 -> Ti ka <= -2.07 (peso 116.0)
# Mantida aresta Ti ka <= -2.07 -> Ca ka > -4.12 (peso 232.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= -2.07 -> Ti ka <= 6.53 (peso 200.0)
# Mantida aresta Ti ka <= 6.53 -> Ti ka <= -2.07 (peso 200.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 2.06 -> Ti ka <= -2.07 (peso 200.0)
# Mantida aresta Ti ka <= -2.07 -> Ti ka <= 2.06 (peso 400.0)
#
# ======================================================================
#
# Removida aresta Ca ka > -4.12 -> Fe kb > -15.50 (peso 250.0)
# Mantida aresta Fe kb > -15.50 -> Ca ka > -4.12 (peso 500.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 17.60 -> Ti ka <= 6.53 (peso 351.0)
# Mantida aresta Ti ka <= 6.53 -> Fe kb <= 17.60 (peso 351.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 6.53 -> Fe kb <= 6.39 (peso 281.0)
# Mantida aresta Fe kb <= 6.39 -> Ti ka <= 6.53 (peso 562.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -6.95 -> Fe kb <= 17.60 (peso 308.0)
# Mantida aresta Fe kb <= 17.60 -> Ti ka > -6.95 (peso 308.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= -4.12 -> Fe kb <= 17.60 (peso 161.0)
# Mantida aresta Fe kb <= 17.60 -> Ca ka <= -4.12 (peso 161.0)
#
# ======================================================================
#
# Removida aresta Fe kb > -15.50 -> Ca ka <= -4.12 (peso 150.0)
# Mantida aresta Ca ka <= -4.12 -> Fe kb > -15.50 (peso 300.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 5.46 -> Ti ka > -6.95 (peso 320.0)
# Mantida aresta Ti ka > -6.95 -> Ca ka <= 5.46 (peso 320.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > -2.07 -> Ti ka > 2.06 (peso 200.0)
# Mantida aresta Ti ka > 2.06 -> Ti ka > -2.07 (peso 200.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 5.46 -> Ti ka <= 2.06 (peso 64.0)
# Mantida aresta Ti ka <= 2.06 -> Ca ka > 5.46 (peso 64.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 133
# Total de arestas removidas por bidirecionalidade: 19
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 29
# Total de nós terminais: 2
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
#        Predicate_Seed_0     Predicate_Seed_1   Predicate_Seed_42
# 0        Fe ka > -42.15       Fe ka > -42.15      Fe ka > -42.15
# 1        Fe ka <= 47.71       Fe ka <= 47.71      Fe ka <= 47.71
# 2        Fe ka > -22.92       Fe ka > -22.92      Fe ka > -22.92
# 3         Ca ka > -4.12        Ca ka > -1.28       Fe kb > -8.24
# 4         Ca ka <= 5.46        Ca ka > -6.16      Fe kb <= 17.60
# 5         Ti ka > -6.95        Fe kb > -8.24          Mn > -4.64
# 6        Fe ka <= 18.68        Ti ka <= 6.53      Fe kb > -15.50
# 7        Ca ka <= -4.12        Ti ka > -6.95       Ca ka > -6.16
# 8        Fe kb <= -8.24       Fe kb <= 17.60       Ca ka > -1.28
# 9   background6 > -6.10       Fe kb > -15.50       Ca ka <= 5.46
# 10  background6 > -1.83         Ti ka > 2.06      Ca ka <= -4.12
# 11        Ti ka <= 6.53        Ca ka <= 5.46      Ca ka <= -1.28
# 12           Mn > -2.66        Ti ka <= 2.06       Ti ka > -6.95
# 13        Ca ka > -6.16       Fe ka <= 18.68       Fe kb <= 6.39
# 14       Fe kb <= 17.60           Mn > -4.64       Ti ka <= 6.53
# 15        Fe kb <= 6.39        Fe kb <= 6.39       Ca ka > -4.12
# 16        Ti ka > -2.07           Mn > -2.66        Ti ka > 2.06
# 17        Fe kb > -8.24        Ti ka > -2.07          Mn > -2.66
# 18      Fe ka <= -42.15         Ca ka > 5.46      Fe ka <= 18.68
# 19           Mn > -4.64        Ca ka > -4.12        Ca ka > 5.46
# 20       Fe kb > -15.50  background6 > -1.83      Ti ka <= -2.07
# 21        Ti ka <= 2.06      Fe ka <= -22.92       Ti ka > -2.07
# 22         Ti ka > 2.06        Ca kb > -1.76       Ti ka <= 2.06
# 23      Fe ka <= -22.92       Ca ka <= -4.12  background6 > 1.25
# 24        Ca ka > -1.28       Ca ka <= -1.28     Fe ka <= -22.92
# 25   background6 > 6.42       Ti ka <= -2.07      Fe kb <= -8.24
# 26       Ti ka <= -2.07      Fe ka <= -42.15     Fe ka <= -42.15
# 27         Ca ka > 5.46   background6 > 1.25  background6 > 6.42
# 28   background6 > 1.25       Ti ka <= -6.95      Ti ka <= -6.95
# 29       Ca ka <= -1.28       Fe kb <= -8.24             Class_A
# 30              Class_A              Class_A             Class_B
# 31              Class_B              Class_B                 NaN

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(lrc_unique_df['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Vip': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_coef': pad_list(reg_vet_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
})

for seed, lrc_unique_df in lrc_unique_by_seed.items():
    features_importance[f'LRC_Seed_{seed}'] = pad_list(lrc_unique_df['Zone'].iloc[:10].tolist(), max_len)

#features_importance

# vamos exportar o df features_importance para um arquivo excel onde vamos nomear a sheet de acordo com as comparacoes feitas
features_importance.to_excel('features_importance_soil_type.xlsx', index=False, sheet_name='Perm')
features_importance
# Out:
#               Vip       Reg_coef           Shap   LRC_Seed_0   LRC_Seed_1  \
# 0           Fe ka          Fe ka          Fe ka        Fe ka        Fe ka
# 1           Fe kb          Ca ka          Ca ka        Ca ka        Ca ka
# 2           Ti ka          Ti ka          Ti ka        Ti ka        Fe kb
# 3           Ca ka          Fe kb             Mn        Fe kb        Ti ka
# 4              Mn             Mn          Fe kb  background6           Mn
# 5          sum Fe             Al             Al           Mn  background6
# 6           Ti kb      Rh L + Ar    background6         None        Ca kb
# 7              Al          Ca kb  Fe ka + Ti ka         None         None
# 8              Si              K    background7         None         None
# 9     background4          Ti kb    background8         None         None
# 10             Cr             Cu    background1         None         None
# 11      Rh L + Ar    background6         sum Fe         None         None
# 12             Cu         sum Fe      Rh L + Ar         None         None
# 13          Ca kb             Cr              K         None         None
# 14    background8              P             Cu         None         None
# 15              K    background3          Ca kb         None         None
# 16    background3    background7    background3         None         None
# 17              P    background5             Si         None         None
# 18    background6  Fe ka + Ti ka              S         None         None
# 19  Fe ka + Ti ka    background2    background2         None         None
# 20    background7             Si              P         None         None
# 21    background5    background8    background5         None         None
# 22    background2              S          Ti kb         None         None
# 23    background1    background4             Cr         None         None
# 24              S    background1    background4         None         None
#
#     LRC_Seed_42
# 0         Fe ka
# 1         Fe kb
# 2            Mn
# 3         Ca ka
# 4         Ti ka
# 5   background6
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None
# 20         None
# 21         None
# 22         None
# 23         None
# 24         None

# %%
# RBO (Rank-Biased Overlap) para comparar rankings
import rbo
rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if x is not None]
methods = ['Reg_coef', 'Shap'] + [f'LRC_Seed_{seed}' for seed in random_seeds]
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if x is not None]
    # Truncate both lists to the same length (minimum of both)
    min_len = min(len(reference_list), len(compare_list))
    ref_trunc = reference_list[:min_len]
    cmp_trunc = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trunc, cmp_trunc).rbo(p=0.7, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method','RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_results.to_excel('rbo_soil_type.xlsx', index=False, sheet_name='perm')
rbo_results
# Out:
#   Reference       Method  RBO_Score
# 4       Vip  LRC_Seed_42   0.799223
# 0       Vip     Reg_coef   0.783692
# 1       Vip         Shap   0.756756
# 3       Vip   LRC_Seed_1   0.745158
# 2       Vip   LRC_Seed_0   0.705542
