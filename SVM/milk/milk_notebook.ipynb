# %% [markdown]
# # **Model**

# %% [markdown]
# # **XRF milk database**

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/milk/plsda/milk.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '2.66':'22.62']

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.66':'22.62'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.66':'22.62'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-28 14:04:11,291 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-28 14:04:11,320 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-28 14:04:11,465 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-28 14:04:11,743 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array

# %%
# calculando a covariancia entre cada variável espectral e a predição do modelo SVM
cov_scores = []
for col in Xcalclass_prep.columns:
    x_values = Xcalclass_prep[col].values
    covariance = np.cov(x_values, y_pred)[0, 1] # covariance between x and y
    cov_scores.append(covariance)
cov_scores_df = pd.DataFrame(cov_scores, index=Xcalclass_prep.columns, columns=['Covariance'])
cov_scores_df = np.abs(cov_scores_df)
cov_scores_df.plot()

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvetor['importance'].plot()

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Ag La', 2.66, 3.10),
('Ag Lb', 3.10, 3.46),
('Ca', 3.46, 3.92),
('background', 3.92, 6.12),
('Fe', 6.12, 6.68),
('Cu', 6.70, 8.37),
('Zn', 8.37, 9.10),
('Bremsstrahlung', 9.10, 20.06),
('Ag compton', 20.06, 21.62),
('Ag ka', 21.48, 22.62)
]

# %%
import explaining as exp
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_sums_df = exp.aggregate_spectral_zones(spectral_zones_class, aggregator='extreme')
predicates_quantiles = exp.predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8])
co_occurrence_matrix_df = predicates_quantiles[2]
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=y_pred
)

# %% [markdown]
# ## Pvector and SHAP

# %%
# VIP scores por energia
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df = pvector_unique_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
pvector_unique_df
#shap_unique_df = pd.read_csv('shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df
# Out:
#   energy    Pvector            Zone
# 0  22.23  72.456491           Ag ka
# 1   2.99  54.182196           Ag La
# 2   8.75  43.305839              Zn
# 3   3.22  41.848390           Ag Lb
# 4  17.99  38.304185  Bremsstrahlung
# 5   6.42  36.324355              Fe
# 6  21.41  29.586439      Ag compton
# 7   4.81  26.811026      background
# 8   3.89  26.299280              Ca
# 9   7.80  23.374915              Cu

# %% [markdown]
# # **bagging - covariance**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = pd.Series(y_pred) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graphv2(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',  # ou 'Covariance' se mudar a métrica
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 54
# Removida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 4.4877)
# Mantida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 6.8185)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 1.0008)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 4.4688)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 1.1132)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 3.3575)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.2982)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 2.4813)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Ag ka <= 5.20 (peso 0.2399)
# Mantida aresta Ag ka <= 5.20 -> Bremsstrahlung <= 3.46 (peso 0.8900)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag ka <= 5.20 (peso 0.1358)
# Mantida aresta Ag ka <= 5.20 -> Ag compton > -2.89 (peso 0.5093)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Bremsstrahlung <= 3.46 (peso 0.2081)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag ka > -7.93 (peso 0.2436)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Bremsstrahlung <= 3.46 (peso 0.2009)
# Mantida aresta Bremsstrahlung <= 3.46 -> Fe <= 2.10 (peso 0.4216)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Bremsstrahlung <= 3.46 (peso 0.2526)
# Mantida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung <= 3.06 (peso 0.4747)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag compton > -2.89 (peso 0.1386)
# Mantida aresta Ag compton > -2.89 -> Ag compton <= 2.58 (peso 0.7690)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ca <= 1.99 (peso 0.3201)
# Mantida aresta Ca <= 1.99 -> Ag compton <= 2.58 (peso 0.4573)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Fe <= 2.10 (peso 0.1699)
# Mantida aresta Fe <= 2.10 -> Zn > -1.89 (peso 0.3446)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Zn > -1.89 (peso 0.1555)
# Mantida aresta Zn > -1.89 -> Fe > -1.71 (peso 0.6742)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Bremsstrahlung > -3.10 (peso 0.1524)
# Mantida aresta Bremsstrahlung > -3.10 -> Zn > -1.89 (peso 0.2120)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.2934)
# Mantida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.3329)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Fe <= 2.10 (peso 0.1431)
# Mantida aresta Fe <= 2.10 -> Ca <= 1.99 (peso 0.2296)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ca <= 1.99 (peso 0.1470)
# Mantida aresta Ca <= 1.99 -> Fe > -1.71 (peso 0.3208)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Bremsstrahlung > -3.10 (peso 0.1310)
# Mantida aresta Bremsstrahlung > -3.10 -> Ca <= 1.99 (peso 0.1480)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Bremsstrahlung > -3.10 (peso 0.0927)
# Mantida aresta Bremsstrahlung > -3.10 -> Ag La > 2.83 (peso 0.1122)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Ca <= 2.47 (peso 0.0746)
# Mantida aresta Ca <= 2.47 -> Ag compton <= -2.03 (peso 0.1405)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ca <= 2.47 (peso 0.0903)
# Mantida aresta Ca <= 2.47 -> Cu <= 2.01 (peso 0.2355)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ca <= 2.47 (peso 0.0618)
# Mantida aresta Ca <= 2.47 -> Zn <= 2.28 (peso 0.1975)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton > -2.03 (peso 0.0714)
# Mantida aresta Ag compton > -2.03 -> Ag Lb > 2.77 (peso 0.0897)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Zn > -1.35 (peso 0.0505)
# Mantida aresta Zn > -1.35 -> Ag Lb > 2.77 (peso 0.0662)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton <= -2.03 (peso 0.0649)
# Mantida aresta Ag compton <= -2.03 -> Ag Lb > 2.77 (peso 0.1226)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ag Lb > 2.77 (peso 0.0586)
# Mantida aresta Ag Lb > 2.77 -> Cu <= 2.01 (peso 0.0717)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Zn <= 2.28 (peso 0.0669)
# Mantida aresta Zn <= 2.28 -> Ag compton > -2.03 (peso 0.0900)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Ag compton > -2.03 (peso 0.0735)
# Mantida aresta Ag compton > -2.03 -> background <= 2.38 (peso 0.1401)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ag compton > -2.03 (peso 0.0927)
# Mantida aresta Ag compton > -2.03 -> background <= 2.73 (peso 0.2314)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ag compton > -2.03 (peso 0.0558)
# Mantida aresta Ag compton > -2.03 -> Fe > -1.30 (peso 0.0726)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Cu <= 2.01 (peso 0.0247)
# Mantida aresta Cu <= 2.01 -> Zn <= 2.28 (peso 0.0959)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ag La > 2.83 (peso 0.0783)
# Mantida aresta Ag La > 2.83 -> Zn <= 2.28 (peso 0.1338)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag ka <= -3.39 (peso 0.0987)
# Mantida aresta Ag ka <= -3.39 -> Ag La > 2.83 (peso 0.0996)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Zn > -1.35 (peso 0.0722)
# Mantida aresta Zn > -1.35 -> background <= 2.38 (peso 0.0911)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Zn > -1.35 (peso 0.0438)
# Mantida aresta Zn > -1.35 -> Fe > -1.30 (peso 0.0492)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Fe <= 1.63 (peso 0.0576)
# Mantida aresta Fe <= 1.63 -> Ag compton <= -2.03 (peso 0.0594)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> background <= 2.73 (peso 0.0592)
# Mantida aresta background <= 2.73 -> Fe > -1.30 (peso 0.0675)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ca > -1.26 (peso 0.0561)
# Mantida aresta Ca > -1.26 -> Fe > -1.30 (peso 0.0593)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag La > -8.20 (peso 0.0442)
# Mantida aresta Ag La > -8.20 -> Bremsstrahlung > -2.45 (peso 0.0577)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Bremsstrahlung > -2.45 (peso 0.0508)
# Mantida aresta Bremsstrahlung > -2.45 -> Zn > 1.85 (peso 0.1012)
#
# ======================================================================
#
# Removida aresta background <= 2.11 -> Bremsstrahlung > -2.45 (peso 0.0167)
# Mantida aresta Bremsstrahlung > -2.45 -> background <= 2.11 (peso 0.0945)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Ca > -1.26 (peso 0.0558)
# Mantida aresta Ca > -1.26 -> background <= 2.38 (peso 0.0684)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Zn <= 1.85 (peso 0.0443)
# Mantida aresta Zn <= 1.85 -> Ca > -1.26 (peso 0.0694)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ca > -1.26 (peso 0.0371)
# Mantida aresta Ca > -1.26 -> Zn > 1.85 (peso 0.0493)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ca > -1.96 (peso 0.0435)
# Mantida aresta Ca > -1.96 -> Bremsstrahlung <= -2.45 (peso 0.0507)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Bremsstrahlung <= -2.45 (peso 0.0247)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag Lb > 3.70 (peso 0.0460)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Cu > -2.02 (peso 0.0178)
# Mantida aresta Cu > -2.02 -> Ca <= -1.26 (peso 0.0289)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Zn <= 1.85 (peso 0.0143)
# Mantida aresta Zn <= 1.85 -> Cu <= 2.71 (peso 0.0381)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Zn > 1.85 (peso 0.0325)
# Mantida aresta Zn > 1.85 -> Cu <= 2.71 (peso 0.0341)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ag Lb > 3.70 (peso 0.0336)
# Mantida aresta Ag Lb > 3.70 -> Zn > 1.85 (peso 0.0679)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Zn <= -1.35 (peso 0.0276)
# Mantida aresta Zn <= -1.35 -> Ca <= -1.26 (peso 0.0396)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> background > -1.72 (peso 0.0158)
# Mantida aresta background > -1.72 -> Ag La > 4.26 (peso 0.0160)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> background > 2.11 (peso 0.0145)
# Mantida aresta background > 2.11 -> Ca > 1.99 (peso 0.0159)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Ag Lb > -6.25 (peso 0.0116)
# Mantida aresta Ag Lb > -6.25 -> Fe > 1.63 (peso 0.0286)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 378
# Total de arestas removidas por bidirecionalidade: 54
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 55
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 1.0460)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 3.9706)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag ka <= 10.15 (peso 1.0301)
# Mantida aresta Ag ka <= 10.15 -> Ag ka > -3.39 (peso 1.1495)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 0.9978)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 1.5413)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.7149)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 1.3323)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Cu <= 2.35 (peso 0.0281)
# Mantida aresta Cu <= 2.35 -> Ag ka > -7.93 (peso 0.0370)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Bremsstrahlung <= 3.46 (peso 0.2128)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag ka > -7.93 (peso 0.2764)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag ka <= 5.20 (peso 0.1777)
# Mantida aresta Ag ka <= 5.20 -> Fe <= 2.10 (peso 0.3751)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Fe > -1.71 (peso 0.1725)
# Mantida aresta Fe > -1.71 -> Ag ka <= 5.20 (peso 0.2831)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Ca <= 1.99 (peso 0.1616)
# Mantida aresta Ca <= 1.99 -> Ag ka <= 5.20 (peso 0.1828)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.1442)
# Mantida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.4453)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Fe > -1.71 (peso 0.1708)
# Mantida aresta Fe > -1.71 -> Ag compton <= 2.58 (peso 0.3074)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Fe > -1.71 (peso 0.1207)
# Mantida aresta Fe > -1.71 -> Ca <= 2.47 (peso 0.1681)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ca <= 1.99 (peso 0.1820)
# Mantida aresta Ca <= 1.99 -> Bremsstrahlung <= 3.06 (peso 0.4544)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ca <= 1.99 (peso 0.1580)
# Mantida aresta Ca <= 1.99 -> Zn > -1.89 (peso 0.3273)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.2033)
# Mantida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.5843)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag compton <= 2.58 (peso 0.1635)
# Mantida aresta Ag compton <= 2.58 -> Zn > -1.89 (peso 0.4956)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag compton > -2.89 (peso 0.1636)
# Mantida aresta Ag compton > -2.89 -> Zn > -1.89 (peso 0.2233)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag compton <= 2.58 (peso 0.1827)
# Mantida aresta Ag compton <= 2.58 -> Ag compton > -2.89 (peso 0.3834)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ca <= 2.47 (peso 0.1233)
# Mantida aresta Ca <= 2.47 -> Ag compton <= 2.58 (peso 0.1609)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ag La > -8.20 (peso 0.1058)
# Mantida aresta Ag La > -8.20 -> background <= 2.73 (peso 0.1439)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background <= 2.38 (peso 0.1005)
# Mantida aresta background <= 2.38 -> background <= 2.73 (peso 0.1318)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> background <= 2.73 (peso 0.0896)
# Mantida aresta background <= 2.73 -> Zn <= 2.28 (peso 0.0952)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Bremsstrahlung > -3.10 (peso 0.1633)
# Mantida aresta Bremsstrahlung > -3.10 -> Ca <= 2.47 (peso 0.1868)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> background <= 2.38 (peso 0.0731)
# Mantida aresta background <= 2.38 -> Zn > -1.35 (peso 0.1505)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Zn > -1.35 (peso 0.0646)
# Mantida aresta Zn > -1.35 -> Ca > -1.26 (peso 0.2152)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ag Lb > 2.77 (peso 0.0596)
# Mantida aresta Ag Lb > 2.77 -> Fe > -1.30 (peso 0.0659)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag La > 2.83 (peso 0.0697)
# Mantida aresta Ag La > 2.83 -> Ag Lb > 2.77 (peso 0.1394)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag Lb > 2.77 (peso 0.0712)
# Mantida aresta Ag Lb > 2.77 -> Zn > -1.35 (peso 0.1212)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag Lb > 2.77 (peso 0.0519)
# Mantida aresta Ag Lb > 2.77 -> Bremsstrahlung > -2.45 (peso 0.0674)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ag compton <= -2.03 (peso 0.0649)
# Mantida aresta Ag compton <= -2.03 -> Fe > -1.30 (peso 0.1254)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe > -1.30 (peso 0.0270)
# Mantida aresta Fe > -1.30 -> Fe <= 1.63 (peso 0.0340)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag compton <= -2.03 (peso 0.0651)
# Mantida aresta Ag compton <= -2.03 -> Zn > -1.35 (peso 0.0705)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag compton > -2.03 (peso 0.0678)
# Mantida aresta Ag compton > -2.03 -> Ag La > 2.83 (peso 0.1979)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ag Lb > 3.70 (peso 0.0318)
# Mantida aresta Ag Lb > 3.70 -> Bremsstrahlung <= -2.45 (peso 0.0403)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ca <= -1.26 (peso 0.0234)
# Mantida aresta Ca <= -1.26 -> Fe <= 1.63 (peso 0.0443)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ca <= -1.26 (peso 0.0343)
# Mantida aresta Ca <= -1.26 -> Ag Lb > -6.25 (peso 0.0400)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Ca <= -1.26 (peso 0.0272)
# Mantida aresta Ca <= -1.26 -> Ag Lb > 3.70 (peso 0.0298)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Ag Lb > -6.25 (peso 0.0196)
# Mantida aresta Ag Lb > -6.25 -> background > 2.38 (peso 0.0259)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Bremsstrahlung > -2.45 (peso 0.0275)
# Mantida aresta Bremsstrahlung > -2.45 -> Cu <= 2.35 (peso 0.0405)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> background <= 2.11 (peso 0.0401)
# Mantida aresta background <= 2.11 -> Zn > 1.85 (peso 0.0730)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Cu <= 2.01 (peso 0.0318)
# Mantida aresta Cu <= 2.01 -> Zn > 1.85 (peso 0.0372)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Zn > 1.85 (peso 0.0276)
# Mantida aresta Zn > 1.85 -> Ag Lb > 3.70 (peso 0.1127)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> background > 2.38 (peso 0.0181)
# Mantida aresta background > 2.38 -> Ag La > 4.26 (peso 0.0295)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Zn <= -1.35 (peso 0.0125)
# Mantida aresta Zn <= -1.35 -> background > 2.38 (peso 0.0269)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ag La > 4.26 (peso 0.0237)
# Mantida aresta Ag La > 4.26 -> Cu > -2.02 (peso 0.0264)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Ag La > 4.26 (peso 0.0200)
# Mantida aresta Ag La > 4.26 -> Cu <= 2.71 (peso 0.0234)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ag Lb > 3.70 (peso 0.0255)
# Mantida aresta Ag Lb > 3.70 -> Cu > -2.02 (peso 0.0316)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Zn <= -1.35 (peso 0.0125)
# Mantida aresta Zn <= -1.35 -> Cu > -2.02 (peso 0.0248)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Ag Lb > 3.70 (peso 0.0298)
# Mantida aresta Ag Lb > 3.70 -> Cu <= 2.35 (peso 0.0330)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Zn <= 1.85 (peso 0.0191)
# Mantida aresta Zn <= 1.85 -> Zn <= -1.35 (peso 0.0225)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Cu > 2.35 (peso 0.0115)
# Mantida aresta Cu > 2.35 -> Zn <= -1.35 (peso 0.0126)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Zn <= 1.85 (peso 0.0172)
# Mantida aresta Zn <= 1.85 -> background > 2.11 (peso 0.0186)
#
# ======================================================================
#
# Removida aresta Cu > 2.01 -> Zn <= 1.85 (peso 0.0111)
# Mantida aresta Zn <= 1.85 -> Cu > 2.01 (peso 0.0155)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Bremsstrahlung > 3.06 (peso 0.0183)
# Mantida aresta Bremsstrahlung > 3.06 -> background > 2.11 (peso 0.0192)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> Cu > 2.01 (peso 0.0141)
# Mantida aresta Cu > 2.01 -> Cu > 2.35 (peso 0.0211)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 394
# Total de arestas removidas por bidirecionalidade: 55
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 50
# Removida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 2.3619)
# Mantida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 9.1201)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > -3.39 (peso 1.1631)
# Mantida aresta Ag ka > -3.39 -> Ag ka <= 10.15 (peso 2.2415)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 0.6746)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 2.7787)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 1.4201)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 2.0791)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.3795)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 1.7932)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Ag compton <= 3.09 (peso 0.2372)
# Mantida aresta Ag compton <= 3.09 -> Bremsstrahlung <= 3.46 (peso 1.3055)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag compton > -2.89 (peso 0.1806)
# Mantida aresta Ag compton > -2.89 -> Zn > -1.89 (peso 0.3772)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.06 (peso 0.4256)
# Mantida aresta Bremsstrahlung <= 3.06 -> Ag compton > -2.89 (peso 0.4407)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.1486)
# Mantida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.1875)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Fe > -1.71 (peso 0.1702)
# Mantida aresta Fe > -1.71 -> Ag compton > -2.89 (peso 0.1964)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Zn > -1.89 (peso 0.1776)
# Mantida aresta Zn > -1.89 -> Ag ka > -7.93 (peso 0.1797)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Zn > -1.89 (peso 0.1538)
# Mantida aresta Zn > -1.89 -> Fe <= 2.10 (peso 0.3465)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Fe <= 2.10 (peso 0.1507)
# Mantida aresta Fe <= 2.10 -> Ca <= 1.99 (peso 0.1771)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ca <= 1.99 (peso 0.1148)
# Mantida aresta Ca <= 1.99 -> Ag ka <= -3.39 (peso 0.1716)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag ka <= 5.20 (peso 0.1629)
# Mantida aresta Ag ka <= 5.20 -> Ca <= 1.99 (peso 0.2965)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Fe > -1.71 (peso 0.1328)
# Mantida aresta Fe > -1.71 -> Bremsstrahlung <= 3.06 (peso 0.1810)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Bremsstrahlung > -3.10 (peso 0.1858)
# Mantida aresta Bremsstrahlung > -3.10 -> Fe > -1.71 (peso 0.2020)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Bremsstrahlung <= 3.46 (peso 0.1272)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag ka <= 5.20 (peso 0.5304)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Bremsstrahlung > -3.10 (peso 0.1356)
# Mantida aresta Bremsstrahlung > -3.10 -> Fe <= 2.10 (peso 0.1808)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.1618)
# Mantida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.2025)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag ka <= -3.39 (peso 0.1595)
# Mantida aresta Ag ka <= -3.39 -> Fe <= 2.10 (peso 0.2761)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka <= 5.20 (peso 0.1147)
# Mantida aresta Ag ka <= 5.20 -> Ag La > -8.20 (peso 0.1454)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Fe > -1.30 (peso 0.0632)
# Mantida aresta Fe > -1.30 -> Ca <= 2.47 (peso 0.0822)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Ag La > 2.83 (peso 0.0934)
# Mantida aresta Ag La > 2.83 -> Ag compton > -2.03 (peso 0.1856)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Ag La > 2.83 (peso 0.0537)
# Mantida aresta Ag La > 2.83 -> Ca > -1.26 (peso 0.1618)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Zn > -1.35 (peso 0.0706)
# Mantida aresta Zn > -1.35 -> background <= 2.73 (peso 0.0786)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Zn > -1.35 (peso 0.0668)
# Mantida aresta Zn > -1.35 -> Ag Lb > 2.77 (peso 0.0809)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ca > -1.26 (peso 0.0640)
# Mantida aresta Ca > -1.26 -> Zn > -1.35 (peso 0.1278)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Zn > -1.35 (peso 0.0666)
# Mantida aresta Zn > -1.35 -> Ag compton <= -2.03 (peso 0.0740)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> background <= 2.73 (peso 0.0972)
# Mantida aresta background <= 2.73 -> Ag ka <= -3.39 (peso 0.1179)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Ag compton <= -2.03 (peso 0.0692)
# Mantida aresta Ag compton <= -2.03 -> Ca > -1.26 (peso 0.0703)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ag compton <= -2.03 (peso 0.0431)
# Mantida aresta Ag compton <= -2.03 -> Cu > -2.02 (peso 0.0488)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton <= -2.03 (peso 0.1234)
# Mantida aresta Ag compton <= -2.03 -> Ag Lb > 2.77 (peso 0.2114)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Bremsstrahlung <= -2.45 (peso 0.0375)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag La > -8.20 (peso 0.0555)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ag Lb > 2.77 (peso 0.0558)
# Mantida aresta Ag Lb > 2.77 -> Fe <= 1.63 (peso 0.1134)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Fe <= 1.63 (peso 0.0315)
# Mantida aresta Fe <= 1.63 -> Cu > -2.02 (peso 0.0897)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe > -1.30 (peso 0.0332)
# Mantida aresta Fe > -1.30 -> Fe <= 1.63 (peso 0.1229)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Bremsstrahlung > -2.45 (peso 0.0513)
# Mantida aresta Bremsstrahlung > -2.45 -> Ag Lb > 2.77 (peso 0.0572)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Bremsstrahlung <= -2.45 (peso 0.0765)
# Mantida aresta Bremsstrahlung <= -2.45 -> Zn > 1.85 (peso 0.0893)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ca > -1.96 (peso 0.0395)
# Mantida aresta Ca > -1.96 -> Bremsstrahlung <= -2.45 (peso 0.0947)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ag Lb > 3.70 (peso 0.0378)
# Mantida aresta Ag Lb > 3.70 -> Zn > 1.85 (peso 0.0599)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Cu > -2.02 (peso 0.0174)
# Mantida aresta Cu > -2.02 -> Bremsstrahlung > -2.45 (peso 0.0463)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag Lb > 3.70 (peso 0.0295)
# Mantida aresta Ag Lb > 3.70 -> Ag Lb > -6.25 (peso 0.0342)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Cu <= 2.35 (peso 0.0246)
# Mantida aresta Cu <= 2.35 -> Ag Lb > 3.70 (peso 0.0255)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Cu > -2.02 (peso 0.0151)
# Mantida aresta Cu > -2.02 -> Zn <= 1.85 (peso 0.0222)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> Bremsstrahlung > 3.06 (peso 0.0146)
# Mantida aresta Bremsstrahlung > 3.06 -> background > -1.72 (peso 0.0158)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> background <= 2.11 (peso 0.0513)
# Mantida aresta background <= 2.11 -> Ca > -1.96 (peso 0.0546)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> background > 2.11 (peso 0.0154)
# Mantida aresta background > 2.11 -> Ca <= -1.26 (peso 0.0188)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> background > -1.72 (peso 0.0135)
# Mantida aresta background > -1.72 -> Zn <= -1.35 (peso 0.0152)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Ag compton > 2.58 (peso 0.0157)
# Mantida aresta Ag compton > 2.58 -> Ca > 1.99 (peso 0.0158)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 373
# Total de arestas removidas por bidirecionalidade: 50
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 55
# Removida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 1.1683)
# Mantida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 10.0976)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 0.4480)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 4.9889)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 0.4843)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 3.1588)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.2351)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 2.7140)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.46 (peso 0.4544)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag compton > -2.89 (peso 0.6938)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ag compton > -2.89 (peso 0.4382)
# Mantida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.06 (peso 0.6517)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.1254)
# Mantida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.1407)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Bremsstrahlung <= 3.06 (peso 0.1755)
# Mantida aresta Bremsstrahlung <= 3.06 -> Zn > -1.89 (peso 0.6204)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ag ka <= 5.20 (peso 0.2313)
# Mantida aresta Ag ka <= 5.20 -> Bremsstrahlung <= 3.06 (peso 0.2515)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background <= 2.38 (peso 0.2227)
# Mantida aresta background <= 2.38 -> background <= 2.73 (peso 0.4780)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> background <= 2.38 (peso 0.0543)
# Mantida aresta background <= 2.38 -> Ag compton > -2.03 (peso 0.2185)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Zn <= 2.28 (peso 0.0533)
# Mantida aresta Zn <= 2.28 -> background <= 2.38 (peso 0.0541)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ca <= 1.99 (peso 0.1253)
# Mantida aresta Ca <= 1.99 -> background <= 2.73 (peso 0.1282)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ag compton <= -2.03 (peso 0.0695)
# Mantida aresta Ag compton <= -2.03 -> background <= 2.73 (peso 0.0834)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ca <= 1.99 (peso 0.1463)
# Mantida aresta Ca <= 1.99 -> Fe > -1.71 (peso 0.1487)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Fe > -1.71 (peso 0.3047)
# Mantida aresta Fe > -1.71 -> Ag compton <= 2.58 (peso 0.5093)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ag ka <= 5.20 (peso 0.1375)
# Mantida aresta Ag ka <= 5.20 -> Fe > -1.71 (peso 0.1969)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.3087)
# Mantida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.3153)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ca <= 1.99 (peso 0.1550)
# Mantida aresta Ca <= 1.99 -> Fe <= 2.10 (peso 0.3156)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Fe <= 2.10 (peso 0.1178)
# Mantida aresta Fe <= 2.10 -> Ag ka <= -3.39 (peso 0.1435)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> background <= 2.11 (peso 0.1344)
# Mantida aresta background <= 2.11 -> Zn > -1.89 (peso 0.1401)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Zn > -1.89 (peso 0.2984)
# Mantida aresta Zn > -1.89 -> Ca <= 1.99 (peso 0.4801)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag ka <= 5.20 (peso 0.1812)
# Mantida aresta Ag ka <= 5.20 -> Zn > -1.89 (peso 0.2106)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Zn > -1.89 (peso 0.1715)
# Mantida aresta Zn > -1.89 -> Ag compton <= 2.58 (peso 0.1724)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag ka <= -3.39 (peso 0.1260)
# Mantida aresta Ag ka <= -3.39 -> Ca <= 1.99 (peso 0.1305)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Bremsstrahlung > -3.10 (peso 0.1120)
# Mantida aresta Bremsstrahlung > -3.10 -> Ca <= 1.99 (peso 0.1843)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag ka <= -3.39 (peso 0.0557)
# Mantida aresta Ag ka <= -3.39 -> Ag Lb > 2.77 (peso 0.0739)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Ag compton <= 2.58 (peso 0.1005)
# Mantida aresta Ag compton <= 2.58 -> Bremsstrahlung > -3.10 (peso 0.4448)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Bremsstrahlung > -3.10 (peso 0.1288)
# Mantida aresta Bremsstrahlung > -3.10 -> Ag ka <= 5.20 (peso 0.3140)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Cu <= 2.01 (peso 0.0802)
# Mantida aresta Cu <= 2.01 -> Ag compton > -2.03 (peso 0.0960)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Cu <= 2.01 (peso 0.0713)
# Mantida aresta Cu <= 2.01 -> Fe > -1.30 (peso 0.1542)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Cu <= 2.01 (peso 0.0903)
# Mantida aresta Cu <= 2.01 -> Ag La > 2.83 (peso 0.0911)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Ag La > 2.83 (peso 0.0943)
# Mantida aresta Ag La > 2.83 -> Ag compton > -2.03 (peso 0.1809)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ag ka <= 5.20 (peso 0.0503)
# Mantida aresta Ag ka <= 5.20 -> Ca <= 2.47 (peso 0.0926)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Bremsstrahlung <= -2.45 (peso 0.0424)
# Mantida aresta Bremsstrahlung <= -2.45 -> Cu <= 2.35 (peso 0.0444)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Ag Lb > 3.70 (peso 0.0175)
# Mantida aresta Ag Lb > 3.70 -> Cu <= 2.35 (peso 0.0192)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Ag Lb > 2.77 (peso 0.0635)
# Mantida aresta Ag Lb > 2.77 -> Ag ka <= 5.20 (peso 0.0773)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Zn > 1.85 (peso 0.0468)
# Mantida aresta Zn > 1.85 -> Ag Lb > 2.77 (peso 0.0528)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ag La > 2.83 (peso 0.0299)
# Mantida aresta Ag La > 2.83 -> Fe <= 1.63 (peso 0.0529)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Fe <= 1.63 (peso 0.0311)
# Mantida aresta Fe <= 1.63 -> Bremsstrahlung > -2.45 (peso 0.0364)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag Lb > 3.70 (peso 0.0311)
# Mantida aresta Ag Lb > 3.70 -> Bremsstrahlung > -2.45 (peso 0.0329)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Zn <= 1.85 (peso 0.0292)
# Mantida aresta Zn <= 1.85 -> Ag Lb > 3.70 (peso 0.0337)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Cu <= 2.71 (peso 0.0469)
# Mantida aresta Cu <= 2.71 -> Zn <= 1.85 (peso 0.0479)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ag La > 4.26 (peso 0.0289)
# Mantida aresta Ag La > 4.26 -> Zn <= 2.28 (peso 0.0402)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Zn <= 2.28 (peso 0.0305)
# Mantida aresta Zn <= 2.28 -> Bremsstrahlung > -2.45 (peso 0.0385)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Ca <= -1.26 (peso 0.0200)
# Mantida aresta Ca <= -1.26 -> Ca > -1.96 (peso 0.0212)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Cu > -2.02 (peso 0.0268)
# Mantida aresta Cu > -2.02 -> Bremsstrahlung > -2.45 (peso 0.0487)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ag Lb > -6.25 (peso 0.0141)
# Mantida aresta Ag Lb > -6.25 -> Cu > -2.02 (peso 0.0257)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Ca <= -1.26 (peso 0.0228)
# Mantida aresta Ca <= -1.26 -> Ca > 1.99 (peso 0.0491)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Ca <= -1.26 (peso 0.0190)
# Mantida aresta Ca <= -1.26 -> Zn <= -1.35 (peso 0.0222)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Ca > 1.99 (peso 0.0149)
# Mantida aresta Ca > 1.99 -> background > 2.38 (peso 0.0244)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Zn <= -1.35 (peso 0.0156)
# Mantida aresta Zn <= -1.35 -> background > 2.38 (peso 0.0401)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> Bremsstrahlung > 3.06 (peso 0.0149)
# Mantida aresta Bremsstrahlung > 3.06 -> Cu > 2.35 (peso 0.0268)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Bremsstrahlung > 3.06 (peso 0.0133)
# Mantida aresta Bremsstrahlung > 3.06 -> Fe <= -1.30 (peso 0.0218)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Ag compton > 2.58 (peso 0.0113)
# Mantida aresta Ag compton > 2.58 -> background > 2.11 (peso 0.0126)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 377
# Total de arestas removidas por bidirecionalidade: 55
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_Cov_Seed_0   Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0         Ag La <= 2.83          Ag La <= 2.83        Ag La <= 2.83
# 1         Ag La <= 4.26          Ag La <= 4.26        Ag La <= 4.26
# 2         Ag Lb <= 2.77          Ag Lb <= 2.77        Ag Lb <= 2.77
# 3         Ag La <= 5.23          Ag Lb <= 3.70        Ag Lb <= 3.70
# 4         Ag Lb <= 3.70          Ag La <= 5.23        Ag La <= 5.23
# ..                  ...                    ...                  ...
# 57          Zn <= -1.35  Bremsstrahlung > 3.06            Cu > 2.35
# 58          Ca <= -1.26      background > 2.38          Fe <= -1.30
# 59    background > 2.11      background > 2.11            Cu > 2.01
# 60              Class_A                Class_A              Class_A
# 61              Class_B                Class_B              Class_B
#
#    Predicate_Cov_Seed_3
# 0         Ag La <= 2.83
# 1         Ag La <= 4.26
# 2         Ag Lb <= 2.77
# 3         Ag Lb <= 3.70
# 4         Ag La <= 5.23
# ..                  ...
# 57    background > 2.38
# 58   background > -1.72
# 59          Ca <= -1.26
# 60              Class_A
# 61              Class_B
#
# [62 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df = lrc_summed_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.83                  20.099039           Ag La
# 1            Ag Lb <= 2.77                  12.640839           Ag Lb
# 2            Ag ka > -3.39                   4.238952           Ag ka
# 3       Ag compton <= 3.09                   1.057431      Ag compton
# 4   Bremsstrahlung <= 3.46                   0.881678  Bremsstrahlung
# 5               Zn > -1.89                   0.623939              Zn
# 6               Fe > -1.71                   0.577991              Fe
# 7               Ca <= 1.99                   0.540351              Ca
# 8       background <= 2.38                   0.351784      background
# 9               Cu <= 2.01                   0.271681              Cu
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator
# 0       2.83       <=
# 1       2.77       <=
# 2      -3.39        >
# 3       3.09       <=
# 4       3.46       <=
# 5      -1.89        >
# 6      -1.71        >
# 7       1.99       <=
# 8       2.38       <=
# 9       2.01       <=
# 10      None     None

# %% [markdown]
# # **Perturbation**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = pd.Series(y_pred) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='mean', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Remove todos os valores iguais a zero de todos os bags em perm_results[bag]["Permutation"] e salva como perm_results_thresholded
    # pert_results_seed_thresholded = {}
    # for bag, df in perm_results_seed.items():
    #     # Verifica se é um DataFrame e se a coluna 'Permutation' existe
    #     if isinstance(df, pd.DataFrame) and 'Permutation' in df.columns:
    #         filtered_df = df[df['Permutation'] > 0].copy()
    #         pert_results_seed_thresholded[bag] = filtered_df
    #     else:
    #         # Se não for DataFrame esperado, apenas copia
    #         pert_results_seed_thresholded[bag] = df

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graphv2(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',  # ou 'Covariance' se mudar a métrica
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa (aim): classification
# Modo de perturbação: mean
# Fonte das estatísticas: full
# Métrica: probability_shift
# Total de folds: 10
#
#
# [Bag_1] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=174)
#     Zona: 18 colunas
#     Importance: 0.067630
#   Predicado: Ag La <= 2.83 (n=83)
#     Zona: 18 colunas
#     Importance: 0.236912
#   Predicado: Ag La > 2.83 (n=131)
#     Zona: 18 colunas
#     Importance: 0.053965
#   Predicado: Ag La <= 4.26 (n=126)
#     Zona: 18 colunas
#     Importance: 0.166567
#   Predicado: Ag La > 4.26 (n=88)
#     Zona: 18 colunas
#     Importance: 0.065291
#   Predicado: Ag La <= 5.23 (n=169)
#     Zona: 18 colunas
#     Importance: 0.142570
#   Predicado: Ag Lb > -6.25 (n=173)
#     Zona: 15 colunas
#     Importance: 0.047220
#   Predicado: Ag Lb <= 2.77 (n=83)
#     Zona: 15 colunas
#     Importance: 0.168686
#   Predicado: Ag Lb > 2.77 (n=131)
#     Zona: 15 colunas
#     Importance: 0.041906
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.120569
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.048852
#   Predicado: Ag Lb <= 4.33 (n=173)
#     Zona: 15 colunas
#     Importance: 0.099690
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.004976
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.003851
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.005718
#   Predicado: Ca <= 1.99 (n=127)
#     Zona: 19 colunas
#     Importance: 0.003408
#   Predicado: Ca > 1.99 (n=87)
#     Zona: 19 colunas
#     Importance: 0.007267
#   Predicado: Ca <= 2.47 (n=169)
#     Zona: 19 colunas
#     Importance: 0.003542
#   Predicado: background > -1.72 (n=176)
#     Zona: 87 colunas
#     Importance: 0.012753
#   Predicado: background <= 2.11 (n=82)
#     Zona: 87 colunas
#     Importance: 0.014899
#   Predicado: background > 2.11 (n=132)
#     Zona: 87 colunas
#     Importance: 0.012234
#   Predicado: background <= 2.38 (n=123)
#     Zona: 87 colunas
#     Importance: 0.013054
#   Predicado: background > 2.38 (n=91)
#     Zona: 87 colunas
#     Importance: 0.013527
#   Predicado: background <= 2.73 (n=170)
#     Zona: 87 colunas
#     Importance: 0.013173
#   Predicado: Fe > -1.71 (n=174)
#     Zona: 23 colunas
#     Importance: 0.006118
#   Predicado: Fe <= -1.30 (n=80)
#     Zona: 23 colunas
#     Importance: 0.005931
#   Predicado: Fe > -1.30 (n=134)
#     Zona: 23 colunas
#     Importance: 0.006486
#   Predicado: Fe <= 1.63 (n=125)
#     Zona: 23 colunas
#     Importance: 0.005370
#   Predicado: Fe > 1.63 (n=89)
#     Zona: 23 colunas
#     Importance: 0.007555
#   Predicado: Fe <= 2.10 (n=170)
#     Zona: 23 colunas
#     Importance: 0.005557
#   Predicado: Cu > -2.02 (n=169)
#     Zona: 66 colunas
#     Importance: 0.009528
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.009494
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.010296
#   Predicado: Cu <= 2.35 (n=134)
#     Zona: 66 colunas
#     Importance: 0.009509
#   Predicado: Cu > 2.35 (n=80)
#     Zona: 66 colunas
#     Importance: 0.010772
#   Predicado: Cu <= 2.71 (n=174)
#     Zona: 66 colunas
#     Importance: 0.008922
#   Predicado: Zn > -1.89 (n=170)
#     Zona: 29 colunas
#     Importance: 0.007036
#   Predicado: Zn <= -1.35 (n=91)
#     Zona: 29 colunas
#     Importance: 0.008904
#   Predicado: Zn > -1.35 (n=123)
#     Zona: 29 colunas
#     Importance: 0.007402
#   Predicado: Zn <= 1.85 (n=131)
#     Zona: 29 colunas
#     Importance: 0.007908
#   Predicado: Zn > 1.85 (n=83)
#     Zona: 29 colunas
#     Importance: 0.008251
#   Predicado: Zn <= 2.28 (n=174)
#     Zona: 29 colunas
#     Importance: 0.007505
#   Predicado: Bremsstrahlung > -3.10 (n=175)
#     Zona: 429 colunas
#     Importance: 0.078526
#   Predicado: Bremsstrahlung <= -2.45 (n=87)
#     Zona: 429 colunas
#     Importance: 0.105108
#   Predicado: Bremsstrahlung > -2.45 (n=127)
#     Zona: 429 colunas
#     Importance: 0.071490
#   Predicado: Bremsstrahlung <= 3.06 (n=127)
#     Zona: 429 colunas
#     Importance: 0.097207
#   Predicado: Bremsstrahlung > 3.06 (n=87)
#     Zona: 429 colunas
#     Importance: 0.067566
#   Predicado: Bremsstrahlung <= 3.46 (n=167)
#     Zona: 429 colunas
#     Importance: 0.085946
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.019726
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.022000
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.018534
#   Predicado: Ag compton <= 2.58 (n=128)
#     Zona: 62 colunas
#     Importance: 0.020612
#   Predicado: Ag compton > 2.58 (n=86)
#     Zona: 62 colunas
#     Importance: 0.018867
#   Predicado: Ag compton <= 3.09 (n=171)
#     Zona: 62 colunas
#     Importance: 0.019125
#   Predicado: Ag ka > -7.93 (n=169)
#     Zona: 45 colunas
#     Importance: 0.107547
#   Predicado: Ag ka <= -3.39 (n=85)
#     Zona: 45 colunas
#     Importance: 0.119502
#   Predicado: Ag ka > -3.39 (n=129)
#     Zona: 45 colunas
#     Importance: 0.103001
#   Predicado: Ag ka <= 5.20 (n=125)
#     Zona: 45 colunas
#     Importance: 0.111815
#   Predicado: Ag ka > 5.20 (n=89)
#     Zona: 45 colunas
#     Importance: 0.106382
#   Predicado: Ag ka <= 10.15 (n=172)
#     Zona: 45 colunas
#     Importance: 0.097018
#
# [Bag_2] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=170)
#     Zona: 18 colunas
#     Importance: 0.066451
#   Predicado: Ag La <= 2.83 (n=88)
#     Zona: 18 colunas
#     Importance: 0.247637
#   Predicado: Ag La > 2.83 (n=126)
#     Zona: 18 colunas
#     Importance: 0.051864
#   Predicado: Ag La <= 4.26 (n=132)
#     Zona: 18 colunas
#     Importance: 0.175952
#   Predicado: Ag La > 4.26 (n=82)
#     Zona: 18 colunas
#     Importance: 0.062210
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.149974
#   Predicado: Ag Lb > -6.25 (n=169)
#     Zona: 15 colunas
#     Importance: 0.046703
#   Predicado: Ag Lb <= 2.77 (n=87)
#     Zona: 15 colunas
#     Importance: 0.173871
#   Predicado: Ag Lb > 2.77 (n=127)
#     Zona: 15 colunas
#     Importance: 0.039645
#   Predicado: Ag Lb <= 3.70 (n=130)
#     Zona: 15 colunas
#     Importance: 0.125201
#   Predicado: Ag Lb > 3.70 (n=84)
#     Zona: 15 colunas
#     Importance: 0.046257
#   Predicado: Ag Lb <= 4.33 (n=175)
#     Zona: 15 colunas
#     Importance: 0.104954
#   Predicado: Ca > -1.96 (n=173)
#     Zona: 19 colunas
#     Importance: 0.004991
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.003664
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.005677
#   Predicado: Ca <= 1.99 (n=129)
#     Zona: 19 colunas
#     Importance: 0.003422
#   Predicado: Ca > 1.99 (n=85)
#     Zona: 19 colunas
#     Importance: 0.007064
#   Predicado: Ca <= 2.47 (n=173)
#     Zona: 19 colunas
#     Importance: 0.003494
#   Predicado: background > -1.72 (n=168)
#     Zona: 87 colunas
#     Importance: 0.011430
#   Predicado: background <= 2.11 (n=89)
#     Zona: 87 colunas
#     Importance: 0.014707
#   Predicado: background > 2.11 (n=125)
#     Zona: 87 colunas
#     Importance: 0.010796
#   Predicado: background <= 2.38 (n=133)
#     Zona: 87 colunas
#     Importance: 0.012724
#   Predicado: background > 2.38 (n=81)
#     Zona: 87 colunas
#     Importance: 0.011928
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012724
#   Predicado: Fe > -1.71 (n=173)
#     Zona: 23 colunas
#     Importance: 0.006014
#   Predicado: Fe <= -1.30 (n=85)
#     Zona: 23 colunas
#     Importance: 0.005687
#   Predicado: Fe > -1.30 (n=129)
#     Zona: 23 colunas
#     Importance: 0.006409
#   Predicado: Fe <= 1.63 (n=127)
#     Zona: 23 colunas
#     Importance: 0.005198
#   Predicado: Fe > 1.63 (n=87)
#     Zona: 23 colunas
#     Importance: 0.007471
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.005449
#   Predicado: Cu > -2.02 (n=173)
#     Zona: 66 colunas
#     Importance: 0.008890
#   Predicado: Cu <= 2.01 (n=81)
#     Zona: 66 colunas
#     Importance: 0.008556
#   Predicado: Cu > 2.01 (n=133)
#     Zona: 66 colunas
#     Importance: 0.009651
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.008734
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.009957
#   Predicado: Cu <= 2.71 (n=168)
#     Zona: 66 colunas
#     Importance: 0.007988
#   Predicado: Zn > -1.89 (n=174)
#     Zona: 29 colunas
#     Importance: 0.006565
#   Predicado: Zn <= -1.35 (n=86)
#     Zona: 29 colunas
#     Importance: 0.009385
#   Predicado: Zn > -1.35 (n=128)
#     Zona: 29 colunas
#     Importance: 0.006252
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007903
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.006905
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.007460
#   Predicado: Bremsstrahlung > -3.10 (n=173)
#     Zona: 429 colunas
#     Importance: 0.073789
#   Predicado: Bremsstrahlung <= -2.45 (n=88)
#     Zona: 429 colunas
#     Importance: 0.101752
#   Predicado: Bremsstrahlung > -2.45 (n=126)
#     Zona: 429 colunas
#     Importance: 0.065864
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.092624
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.062047
#   Predicado: Bremsstrahlung <= 3.46 (n=176)
#     Zona: 429 colunas
#     Importance: 0.080155
#   Predicado: Ag compton > -2.89 (n=171)
#     Zona: 62 colunas
#     Importance: 0.018918
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.022552
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.017887
#   Predicado: Ag compton <= 2.58 (n=128)
#     Zona: 62 colunas
#     Importance: 0.020182
#   Predicado: Ag compton > 2.58 (n=86)
#     Zona: 62 colunas
#     Importance: 0.019082
#   Predicado: Ag compton <= 3.09 (n=172)
#     Zona: 62 colunas
#     Importance: 0.018978
#   Predicado: Ag ka > -7.93 (n=168)
#     Zona: 45 colunas
#     Importance: 0.114710
#   Predicado: Ag ka <= -3.39 (n=86)
#     Zona: 45 colunas
#     Importance: 0.117995
#   Predicado: Ag ka > -3.39 (n=128)
#     Zona: 45 colunas
#     Importance: 0.117268
#   Predicado: Ag ka <= 5.20 (n=124)
#     Zona: 45 colunas
#     Importance: 0.116156
#   Predicado: Ag ka > 5.20 (n=90)
#     Zona: 45 colunas
#     Importance: 0.119495
#   Predicado: Ag ka <= 10.15 (n=166)
#     Zona: 45 colunas
#     Importance: 0.099782
#
# [Bag_3] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=175)
#     Zona: 18 colunas
#     Importance: 0.069792
#   Predicado: Ag La <= 2.83 (n=84)
#     Zona: 18 colunas
#     Importance: 0.236254
#   Predicado: Ag La > 2.83 (n=130)
#     Zona: 18 colunas
#     Importance: 0.051572
#   Predicado: Ag La <= 4.26 (n=126)
#     Zona: 18 colunas
#     Importance: 0.167902
#   Predicado: Ag La > 4.26 (n=88)
#     Zona: 18 colunas
#     Importance: 0.061296
#   Predicado: Ag La <= 5.23 (n=168)
#     Zona: 18 colunas
#     Importance: 0.142253
#   Predicado: Ag Lb > -6.25 (n=174)
#     Zona: 15 colunas
#     Importance: 0.048655
#   Predicado: Ag Lb <= 2.77 (n=84)
#     Zona: 15 colunas
#     Importance: 0.162343
#   Predicado: Ag Lb > 2.77 (n=130)
#     Zona: 15 colunas
#     Importance: 0.041706
#   Predicado: Ag Lb <= 3.70 (n=129)
#     Zona: 15 colunas
#     Importance: 0.114895
#   Predicado: Ag Lb > 3.70 (n=85)
#     Zona: 15 colunas
#     Importance: 0.049850
#   Predicado: Ag Lb <= 4.33 (n=172)
#     Zona: 15 colunas
#     Importance: 0.097984
#   Predicado: Ca > -1.96 (n=174)
#     Zona: 19 colunas
#     Importance: 0.005098
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.003791
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.005816
#   Predicado: Ca <= 1.99 (n=132)
#     Zona: 19 colunas
#     Importance: 0.003402
#   Predicado: Ca > 1.99 (n=82)
#     Zona: 19 colunas
#     Importance: 0.007578
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003619
#   Predicado: background > -1.72 (n=168)
#     Zona: 87 colunas
#     Importance: 0.011555
#   Predicado: background <= 2.11 (n=88)
#     Zona: 87 colunas
#     Importance: 0.014347
#   Predicado: background > 2.11 (n=126)
#     Zona: 87 colunas
#     Importance: 0.011317
#   Predicado: background <= 2.38 (n=128)
#     Zona: 87 colunas
#     Importance: 0.012625
#   Predicado: background > 2.38 (n=86)
#     Zona: 87 colunas
#     Importance: 0.012470
#   Predicado: background <= 2.73 (n=171)
#     Zona: 87 colunas
#     Importance: 0.012389
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.005610
#   Predicado: Fe <= -1.30 (n=87)
#     Zona: 23 colunas
#     Importance: 0.006445
#   Predicado: Fe > -1.30 (n=127)
#     Zona: 23 colunas
#     Importance: 0.005945
#   Predicado: Fe <= 1.63 (n=128)
#     Zona: 23 colunas
#     Importance: 0.005452
#   Predicado: Fe > 1.63 (n=86)
#     Zona: 23 colunas
#     Importance: 0.007184
#   Predicado: Fe <= 2.10 (n=170)
#     Zona: 23 colunas
#     Importance: 0.005457
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009467
#   Predicado: Cu <= 2.01 (n=86)
#     Zona: 66 colunas
#     Importance: 0.009607
#   Predicado: Cu > 2.01 (n=128)
#     Zona: 66 colunas
#     Importance: 0.010354
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.009982
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.010157
#   Predicado: Cu <= 2.71 (n=167)
#     Zona: 66 colunas
#     Importance: 0.009484
#   Predicado: Zn > -1.89 (n=169)
#     Zona: 29 colunas
#     Importance: 0.006966
#   Predicado: Zn <= -1.35 (n=87)
#     Zona: 29 colunas
#     Importance: 0.008533
#   Predicado: Zn > -1.35 (n=127)
#     Zona: 29 colunas
#     Importance: 0.006932
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007391
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.007880
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.007000
#   Predicado: Bremsstrahlung > -3.10 (n=170)
#     Zona: 429 colunas
#     Importance: 0.076381
#   Predicado: Bremsstrahlung <= -2.45 (n=87)
#     Zona: 429 colunas
#     Importance: 0.092452
#   Predicado: Bremsstrahlung > -2.45 (n=127)
#     Zona: 429 colunas
#     Importance: 0.074071
#   Predicado: Bremsstrahlung <= 3.06 (n=127)
#     Zona: 429 colunas
#     Importance: 0.091976
#   Predicado: Bremsstrahlung > 3.06 (n=87)
#     Zona: 429 colunas
#     Importance: 0.066315
#   Predicado: Bremsstrahlung <= 3.46 (n=169)
#     Zona: 429 colunas
#     Importance: 0.081653
#   Predicado: Ag compton > -2.89 (n=169)
#     Zona: 62 colunas
#     Importance: 0.018883
#   Predicado: Ag compton <= -2.03 (n=88)
#     Zona: 62 colunas
#     Importance: 0.021257
#   Predicado: Ag compton > -2.03 (n=126)
#     Zona: 62 colunas
#     Importance: 0.017919
#   Predicado: Ag compton <= 2.58 (n=130)
#     Zona: 62 colunas
#     Importance: 0.019217
#   Predicado: Ag compton > 2.58 (n=84)
#     Zona: 62 colunas
#     Importance: 0.019407
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.018657
#   Predicado: Ag ka > -7.93 (n=169)
#     Zona: 45 colunas
#     Importance: 0.114829
#   Predicado: Ag ka <= -3.39 (n=89)
#     Zona: 45 colunas
#     Importance: 0.120476
#   Predicado: Ag ka > -3.39 (n=125)
#     Zona: 45 colunas
#     Importance: 0.113414
#   Predicado: Ag ka <= 5.20 (n=132)
#     Zona: 45 colunas
#     Importance: 0.110509
#   Predicado: Ag ka > 5.20 (n=82)
#     Zona: 45 colunas
#     Importance: 0.125756
#   Predicado: Ag ka <= 10.15 (n=170)
#     Zona: 45 colunas
#     Importance: 0.099169
#
# [Bag_4] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.071550
#   Predicado: Ag La <= 2.83 (n=85)
#     Zona: 18 colunas
#     Importance: 0.243176
#   Predicado: Ag La > 2.83 (n=129)
#     Zona: 18 colunas
#     Importance: 0.056259
#   Predicado: Ag La <= 4.26 (n=130)
#     Zona: 18 colunas
#     Importance: 0.170961
#   Predicado: Ag La > 4.26 (n=84)
#     Zona: 18 colunas
#     Importance: 0.067886
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.146699
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.049555
#   Predicado: Ag Lb <= 2.77 (n=87)
#     Zona: 15 colunas
#     Importance: 0.167141
#   Predicado: Ag Lb > 2.77 (n=127)
#     Zona: 15 colunas
#     Importance: 0.045061
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.124899
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.051439
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.105783
#   Predicado: Ca > -1.96 (n=168)
#     Zona: 19 colunas
#     Importance: 0.005452
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.004027
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.006225
#   Predicado: Ca <= 1.99 (n=130)
#     Zona: 19 colunas
#     Importance: 0.003552
#   Predicado: Ca > 1.99 (n=84)
#     Zona: 19 colunas
#     Importance: 0.008111
#   Predicado: Ca <= 2.47 (n=173)
#     Zona: 19 colunas
#     Importance: 0.003828
#   Predicado: background > -1.72 (n=174)
#     Zona: 87 colunas
#     Importance: 0.013197
#   Predicado: background <= 2.11 (n=82)
#     Zona: 87 colunas
#     Importance: 0.014756
#   Predicado: background > 2.11 (n=132)
#     Zona: 87 colunas
#     Importance: 0.012566
#   Predicado: background <= 2.38 (n=126)
#     Zona: 87 colunas
#     Importance: 0.012893
#   Predicado: background > 2.38 (n=88)
#     Zona: 87 colunas
#     Importance: 0.014139
#   Predicado: background <= 2.73 (n=167)
#     Zona: 87 colunas
#     Importance: 0.013126
#   Predicado: Fe > -1.71 (n=179)
#     Zona: 23 colunas
#     Importance: 0.006270
#   Predicado: Fe <= -1.30 (n=78)
#     Zona: 23 colunas
#     Importance: 0.005576
#   Predicado: Fe > -1.30 (n=136)
#     Zona: 23 colunas
#     Importance: 0.006759
#   Predicado: Fe <= 1.63 (n=119)
#     Zona: 23 colunas
#     Importance: 0.005167
#   Predicado: Fe > 1.63 (n=95)
#     Zona: 23 colunas
#     Importance: 0.007782
#   Predicado: Fe <= 2.10 (n=169)
#     Zona: 23 colunas
#     Importance: 0.005403
#   Predicado: Cu > -2.02 (n=175)
#     Zona: 66 colunas
#     Importance: 0.009769
#   Predicado: Cu <= 2.01 (n=80)
#     Zona: 66 colunas
#     Importance: 0.009237
#   Predicado: Cu > 2.01 (n=134)
#     Zona: 66 colunas
#     Importance: 0.010859
#   Predicado: Cu <= 2.35 (n=125)
#     Zona: 66 colunas
#     Importance: 0.009818
#   Predicado: Cu > 2.35 (n=89)
#     Zona: 66 colunas
#     Importance: 0.010864
#   Predicado: Cu <= 2.71 (n=167)
#     Zona: 66 colunas
#     Importance: 0.009293
#   Predicado: Zn > -1.89 (n=177)
#     Zona: 29 colunas
#     Importance: 0.007023
#   Predicado: Zn <= -1.35 (n=84)
#     Zona: 29 colunas
#     Importance: 0.009274
#   Predicado: Zn > -1.35 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007233
#   Predicado: Zn <= 1.85 (n=128)
#     Zona: 29 colunas
#     Importance: 0.007935
#   Predicado: Zn > 1.85 (n=86)
#     Zona: 29 colunas
#     Importance: 0.008182
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.007538
#   Predicado: Bremsstrahlung > -3.10 (n=174)
#     Zona: 429 colunas
#     Importance: 0.074192
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.097646
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.069267
#   Predicado: Bremsstrahlung <= 3.06 (n=129)
#     Zona: 429 colunas
#     Importance: 0.091664
#   Predicado: Bremsstrahlung > 3.06 (n=85)
#     Zona: 429 colunas
#     Importance: 0.063655
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.081338
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.018320
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.021797
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.017482
#   Predicado: Ag compton <= 2.58 (n=131)
#     Zona: 62 colunas
#     Importance: 0.019717
#   Predicado: Ag compton > 2.58 (n=83)
#     Zona: 62 colunas
#     Importance: 0.018374
#   Predicado: Ag compton <= 3.09 (n=172)
#     Zona: 62 colunas
#     Importance: 0.018857
#   Predicado: Ag ka > -7.93 (n=167)
#     Zona: 45 colunas
#     Importance: 0.116103
#   Predicado: Ag ka <= -3.39 (n=87)
#     Zona: 45 colunas
#     Importance: 0.120961
#   Predicado: Ag ka > -3.39 (n=127)
#     Zona: 45 colunas
#     Importance: 0.108852
#   Predicado: Ag ka <= 5.20 (n=133)
#     Zona: 45 colunas
#     Importance: 0.113495
#   Predicado: Ag ka > 5.20 (n=81)
#     Zona: 45 colunas
#     Importance: 0.114234
#   Predicado: Ag ka <= 10.15 (n=175)
#     Zona: 45 colunas
#     Importance: 0.100383
#
# [Bag_5] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=169)
#     Zona: 18 colunas
#     Importance: 0.066716
#   Predicado: Ag La <= 2.83 (n=86)
#     Zona: 18 colunas
#     Importance: 0.246761
#   Predicado: Ag La > 2.83 (n=128)
#     Zona: 18 colunas
#     Importance: 0.053924
#   Predicado: Ag La <= 4.26 (n=127)
#     Zona: 18 colunas
#     Importance: 0.176448
#   Predicado: Ag La > 4.26 (n=87)
#     Zona: 18 colunas
#     Importance: 0.065687
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.148306
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.049337
#   Predicado: Ag Lb <= 2.77 (n=88)
#     Zona: 15 colunas
#     Importance: 0.168452
#   Predicado: Ag Lb > 2.77 (n=126)
#     Zona: 15 colunas
#     Importance: 0.041472
#   Predicado: Ag Lb <= 3.70 (n=133)
#     Zona: 15 colunas
#     Importance: 0.121013
#   Predicado: Ag Lb > 3.70 (n=81)
#     Zona: 15 colunas
#     Importance: 0.048821
#   Predicado: Ag Lb <= 4.33 (n=176)
#     Zona: 15 colunas
#     Importance: 0.103236
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.005042
#   Predicado: Ca <= -1.26 (n=84)
#     Zona: 19 colunas
#     Importance: 0.003614
#   Predicado: Ca > -1.26 (n=130)
#     Zona: 19 colunas
#     Importance: 0.005738
#   Predicado: Ca <= 1.99 (n=130)
#     Zona: 19 colunas
#     Importance: 0.003357
#   Predicado: Ca > 1.99 (n=84)
#     Zona: 19 colunas
#     Importance: 0.007300
#   Predicado: Ca <= 2.47 (n=172)
#     Zona: 19 colunas
#     Importance: 0.003714
#   Predicado: background > -1.72 (n=170)
#     Zona: 87 colunas
#     Importance: 0.012324
#   Predicado: background <= 2.11 (n=85)
#     Zona: 87 colunas
#     Importance: 0.014335
#   Predicado: background > 2.11 (n=129)
#     Zona: 87 colunas
#     Importance: 0.012300
#   Predicado: background <= 2.38 (n=125)
#     Zona: 87 colunas
#     Importance: 0.012801
#   Predicado: background > 2.38 (n=89)
#     Zona: 87 colunas
#     Importance: 0.013540
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.013185
#   Predicado: Fe > -1.71 (n=172)
#     Zona: 23 colunas
#     Importance: 0.006266
#   Predicado: Fe <= -1.30 (n=80)
#     Zona: 23 colunas
#     Importance: 0.006147
#   Predicado: Fe > -1.30 (n=134)
#     Zona: 23 colunas
#     Importance: 0.006760
#   Predicado: Fe <= 1.63 (n=120)
#     Zona: 23 colunas
#     Importance: 0.005634
#   Predicado: Fe > 1.63 (n=94)
#     Zona: 23 colunas
#     Importance: 0.007676
#   Predicado: Fe <= 2.10 (n=168)
#     Zona: 23 colunas
#     Importance: 0.005621
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009441
#   Predicado: Cu <= 2.01 (n=83)
#     Zona: 66 colunas
#     Importance: 0.009343
#   Predicado: Cu > 2.01 (n=131)
#     Zona: 66 colunas
#     Importance: 0.010426
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.009981
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.010041
#   Predicado: Cu <= 2.71 (n=169)
#     Zona: 66 colunas
#     Importance: 0.009332
#   Predicado: Zn > -1.89 (n=171)
#     Zona: 29 colunas
#     Importance: 0.006930
#   Predicado: Zn <= -1.35 (n=88)
#     Zona: 29 colunas
#     Importance: 0.009414
#   Predicado: Zn > -1.35 (n=126)
#     Zona: 29 colunas
#     Importance: 0.006925
#   Predicado: Zn <= 1.85 (n=134)
#     Zona: 29 colunas
#     Importance: 0.007971
#   Predicado: Zn > 1.85 (n=80)
#     Zona: 29 colunas
#     Importance: 0.007912
#   Predicado: Zn <= 2.28 (n=175)
#     Zona: 29 colunas
#     Importance: 0.007612
#   Predicado: Bremsstrahlung > -3.10 (n=171)
#     Zona: 429 colunas
#     Importance: 0.077504
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.096176
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.072781
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.090471
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.069077
#   Predicado: Bremsstrahlung <= 3.46 (n=174)
#     Zona: 429 colunas
#     Importance: 0.081542
#   Predicado: Ag compton > -2.89 (n=170)
#     Zona: 62 colunas
#     Importance: 0.019069
#   Predicado: Ag compton <= -2.03 (n=87)
#     Zona: 62 colunas
#     Importance: 0.021671
#   Predicado: Ag compton > -2.03 (n=127)
#     Zona: 62 colunas
#     Importance: 0.018642
#   Predicado: Ag compton <= 2.58 (n=133)
#     Zona: 62 colunas
#     Importance: 0.019945
#   Predicado: Ag compton > 2.58 (n=81)
#     Zona: 62 colunas
#     Importance: 0.019755
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.018965
#   Predicado: Ag ka > -7.93 (n=168)
#     Zona: 45 colunas
#     Importance: 0.115053
#   Predicado: Ag ka <= -3.39 (n=81)
#     Zona: 45 colunas
#     Importance: 0.115062
#   Predicado: Ag ka > -3.39 (n=133)
#     Zona: 45 colunas
#     Importance: 0.117423
#   Predicado: Ag ka <= 5.20 (n=126)
#     Zona: 45 colunas
#     Importance: 0.109429
#   Predicado: Ag ka > 5.20 (n=88)
#     Zona: 45 colunas
#     Importance: 0.126696
#   Predicado: Ag ka <= 10.15 (n=170)
#     Zona: 45 colunas
#     Importance: 0.096140
#
# [Bag_6] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=170)
#     Zona: 18 colunas
#     Importance: 0.068691
#   Predicado: Ag La <= 2.83 (n=83)
#     Zona: 18 colunas
#     Importance: 0.251584
#   Predicado: Ag La > 2.83 (n=131)
#     Zona: 18 colunas
#     Importance: 0.057365
#   Predicado: Ag La <= 4.26 (n=125)
#     Zona: 18 colunas
#     Importance: 0.178164
#   Predicado: Ag La > 4.26 (n=89)
#     Zona: 18 colunas
#     Importance: 0.068829
#   Predicado: Ag La <= 5.23 (n=170)
#     Zona: 18 colunas
#     Importance: 0.149586
#   Predicado: Ag Lb > -6.25 (n=169)
#     Zona: 15 colunas
#     Importance: 0.047876
#   Predicado: Ag Lb <= 2.77 (n=85)
#     Zona: 15 colunas
#     Importance: 0.173670
#   Predicado: Ag Lb > 2.77 (n=129)
#     Zona: 15 colunas
#     Importance: 0.046760
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.127658
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.053512
#   Predicado: Ag Lb <= 4.33 (n=171)
#     Zona: 15 colunas
#     Importance: 0.107335
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.004992
#   Predicado: Ca <= -1.26 (n=83)
#     Zona: 19 colunas
#     Importance: 0.003771
#   Predicado: Ca > -1.26 (n=131)
#     Zona: 19 colunas
#     Importance: 0.005519
#   Predicado: Ca <= 1.99 (n=129)
#     Zona: 19 colunas
#     Importance: 0.003412
#   Predicado: Ca > 1.99 (n=85)
#     Zona: 19 colunas
#     Importance: 0.007008
#   Predicado: Ca <= 2.47 (n=170)
#     Zona: 19 colunas
#     Importance: 0.003763
#   Predicado: background > -1.72 (n=165)
#     Zona: 87 colunas
#     Importance: 0.012621
#   Predicado: background <= 2.11 (n=94)
#     Zona: 87 colunas
#     Importance: 0.014112
#   Predicado: background > 2.11 (n=120)
#     Zona: 87 colunas
#     Importance: 0.012177
#   Predicado: background <= 2.38 (n=133)
#     Zona: 87 colunas
#     Importance: 0.012214
#   Predicado: background > 2.38 (n=81)
#     Zona: 87 colunas
#     Importance: 0.014361
#   Predicado: background <= 2.73 (n=175)
#     Zona: 87 colunas
#     Importance: 0.012599
#   Predicado: Fe > -1.71 (n=173)
#     Zona: 23 colunas
#     Importance: 0.006462
#   Predicado: Fe <= -1.30 (n=89)
#     Zona: 23 colunas
#     Importance: 0.006763
#   Predicado: Fe > -1.30 (n=125)
#     Zona: 23 colunas
#     Importance: 0.007035
#   Predicado: Fe <= 1.63 (n=132)
#     Zona: 23 colunas
#     Importance: 0.006033
#   Predicado: Fe > 1.63 (n=82)
#     Zona: 23 colunas
#     Importance: 0.008353
#   Predicado: Fe <= 2.10 (n=173)
#     Zona: 23 colunas
#     Importance: 0.006231
#   Predicado: Cu > -2.02 (n=166)
#     Zona: 66 colunas
#     Importance: 0.009657
#   Predicado: Cu <= 2.01 (n=87)
#     Zona: 66 colunas
#     Importance: 0.009900
#   Predicado: Cu > 2.01 (n=127)
#     Zona: 66 colunas
#     Importance: 0.010337
#   Predicado: Cu <= 2.35 (n=131)
#     Zona: 66 colunas
#     Importance: 0.009997
#   Predicado: Cu > 2.35 (n=83)
#     Zona: 66 colunas
#     Importance: 0.010416
#   Predicado: Cu <= 2.71 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009460
#   Predicado: Zn > -1.89 (n=167)
#     Zona: 29 colunas
#     Importance: 0.007231
#   Predicado: Zn <= -1.35 (n=88)
#     Zona: 29 colunas
#     Importance: 0.009375
#   Predicado: Zn > -1.35 (n=126)
#     Zona: 29 colunas
#     Importance: 0.007252
#   Predicado: Zn <= 1.85 (n=127)
#     Zona: 29 colunas
#     Importance: 0.008028
#   Predicado: Zn > 1.85 (n=87)
#     Zona: 29 colunas
#     Importance: 0.008267
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.007719
#   Predicado: Bremsstrahlung > -3.10 (n=169)
#     Zona: 429 colunas
#     Importance: 0.080413
#   Predicado: Bremsstrahlung <= -2.45 (n=93)
#     Zona: 429 colunas
#     Importance: 0.098874
#   Predicado: Bremsstrahlung > -2.45 (n=121)
#     Zona: 429 colunas
#     Importance: 0.074549
#   Predicado: Bremsstrahlung <= 3.06 (n=135)
#     Zona: 429 colunas
#     Importance: 0.092837
#   Predicado: Bremsstrahlung > 3.06 (n=79)
#     Zona: 429 colunas
#     Importance: 0.071932
#   Predicado: Bremsstrahlung <= 3.46 (n=176)
#     Zona: 429 colunas
#     Importance: 0.082932
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.019044
#   Predicado: Ag compton <= -2.03 (n=89)
#     Zona: 62 colunas
#     Importance: 0.020004
#   Predicado: Ag compton > -2.03 (n=125)
#     Zona: 62 colunas
#     Importance: 0.017587
#   Predicado: Ag compton <= 2.58 (n=132)
#     Zona: 62 colunas
#     Importance: 0.019142
#   Predicado: Ag compton > 2.58 (n=82)
#     Zona: 62 colunas
#     Importance: 0.017706
#   Predicado: Ag compton <= 3.09 (n=176)
#     Zona: 62 colunas
#     Importance: 0.017966
#   Predicado: Ag ka > -7.93 (n=170)
#     Zona: 45 colunas
#     Importance: 0.114596
#   Predicado: Ag ka <= -3.39 (n=81)
#     Zona: 45 colunas
#     Importance: 0.121451
#   Predicado: Ag ka > -3.39 (n=133)
#     Zona: 45 colunas
#     Importance: 0.111860
#   Predicado: Ag ka <= 5.20 (n=129)
#     Zona: 45 colunas
#     Importance: 0.114464
#   Predicado: Ag ka > 5.20 (n=85)
#     Zona: 45 colunas
#     Importance: 0.117047
#   Predicado: Ag ka <= 10.15 (n=174)
#     Zona: 45 colunas
#     Importance: 0.099421
#
# [Bag_7] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.070523
#   Predicado: Ag La <= 2.83 (n=86)
#     Zona: 18 colunas
#     Importance: 0.255081
#   Predicado: Ag La > 2.83 (n=128)
#     Zona: 18 colunas
#     Importance: 0.053620
#   Predicado: Ag La <= 4.26 (n=127)
#     Zona: 18 colunas
#     Importance: 0.182153
#   Predicado: Ag La > 4.26 (n=87)
#     Zona: 18 colunas
#     Importance: 0.065137
#   Predicado: Ag La <= 5.23 (n=174)
#     Zona: 18 colunas
#     Importance: 0.151368
#   Predicado: Ag Lb > -6.25 (n=173)
#     Zona: 15 colunas
#     Importance: 0.052893
#   Predicado: Ag Lb <= 2.77 (n=88)
#     Zona: 15 colunas
#     Importance: 0.171888
#   Predicado: Ag Lb > 2.77 (n=126)
#     Zona: 15 colunas
#     Importance: 0.043339
#   Predicado: Ag Lb <= 3.70 (n=131)
#     Zona: 15 colunas
#     Importance: 0.124868
#   Predicado: Ag Lb > 3.70 (n=83)
#     Zona: 15 colunas
#     Importance: 0.050953
#   Predicado: Ag Lb <= 4.33 (n=172)
#     Zona: 15 colunas
#     Importance: 0.106595
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.005286
#   Predicado: Ca <= -1.26 (n=83)
#     Zona: 19 colunas
#     Importance: 0.004005
#   Predicado: Ca > -1.26 (n=131)
#     Zona: 19 colunas
#     Importance: 0.005907
#   Predicado: Ca <= 1.99 (n=125)
#     Zona: 19 colunas
#     Importance: 0.003657
#   Predicado: Ca > 1.99 (n=89)
#     Zona: 19 colunas
#     Importance: 0.007294
#   Predicado: Ca <= 2.47 (n=170)
#     Zona: 19 colunas
#     Importance: 0.003737
#   Predicado: background > -1.72 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012334
#   Predicado: background <= 2.11 (n=85)
#     Zona: 87 colunas
#     Importance: 0.015364
#   Predicado: background > 2.11 (n=129)
#     Zona: 87 colunas
#     Importance: 0.011565
#   Predicado: background <= 2.38 (n=129)
#     Zona: 87 colunas
#     Importance: 0.012922
#   Predicado: background > 2.38 (n=85)
#     Zona: 87 colunas
#     Importance: 0.013305
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012501
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.006223
#   Predicado: Fe <= -1.30 (n=83)
#     Zona: 23 colunas
#     Importance: 0.006295
#   Predicado: Fe > -1.30 (n=131)
#     Zona: 23 colunas
#     Importance: 0.006626
#   Predicado: Fe <= 1.63 (n=123)
#     Zona: 23 colunas
#     Importance: 0.005405
#   Predicado: Fe > 1.63 (n=91)
#     Zona: 23 colunas
#     Importance: 0.007975
#   Predicado: Fe <= 2.10 (n=172)
#     Zona: 23 colunas
#     Importance: 0.005556
#   Predicado: Cu > -2.02 (n=173)
#     Zona: 66 colunas
#     Importance: 0.009130
#   Predicado: Cu <= 2.01 (n=86)
#     Zona: 66 colunas
#     Importance: 0.009666
#   Predicado: Cu > 2.01 (n=128)
#     Zona: 66 colunas
#     Importance: 0.010088
#   Predicado: Cu <= 2.35 (n=130)
#     Zona: 66 colunas
#     Importance: 0.009776
#   Predicado: Cu > 2.35 (n=84)
#     Zona: 66 colunas
#     Importance: 0.010137
#   Predicado: Cu <= 2.71 (n=174)
#     Zona: 66 colunas
#     Importance: 0.008937
#   Predicado: Zn > -1.89 (n=169)
#     Zona: 29 colunas
#     Importance: 0.007328
#   Predicado: Zn <= -1.35 (n=86)
#     Zona: 29 colunas
#     Importance: 0.009052
#   Predicado: Zn > -1.35 (n=128)
#     Zona: 29 colunas
#     Importance: 0.007194
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007830
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.008111
#   Predicado: Zn <= 2.28 (n=170)
#     Zona: 29 colunas
#     Importance: 0.007394
#   Predicado: Bremsstrahlung > -3.10 (n=175)
#     Zona: 429 colunas
#     Importance: 0.075396
#   Predicado: Bremsstrahlung <= -2.45 (n=82)
#     Zona: 429 colunas
#     Importance: 0.101259
#   Predicado: Bremsstrahlung > -2.45 (n=132)
#     Zona: 429 colunas
#     Importance: 0.069856
#   Predicado: Bremsstrahlung <= 3.06 (n=128)
#     Zona: 429 colunas
#     Importance: 0.092695
#   Predicado: Bremsstrahlung > 3.06 (n=86)
#     Zona: 429 colunas
#     Importance: 0.065805
#   Predicado: Bremsstrahlung <= 3.46 (n=168)
#     Zona: 429 colunas
#     Importance: 0.080847
#   Predicado: Ag compton > -2.89 (n=175)
#     Zona: 62 colunas
#     Importance: 0.019097
#   Predicado: Ag compton <= -2.03 (n=79)
#     Zona: 62 colunas
#     Importance: 0.022331
#   Predicado: Ag compton > -2.03 (n=135)
#     Zona: 62 colunas
#     Importance: 0.018240
#   Predicado: Ag compton <= 2.58 (n=124)
#     Zona: 62 colunas
#     Importance: 0.019679
#   Predicado: Ag compton > 2.58 (n=90)
#     Zona: 62 colunas
#     Importance: 0.019847
#   Predicado: Ag compton <= 3.09 (n=168)
#     Zona: 62 colunas
#     Importance: 0.018719
#   Predicado: Ag ka > -7.93 (n=171)
#     Zona: 45 colunas
#     Importance: 0.113574
#   Predicado: Ag ka <= -3.39 (n=83)
#     Zona: 45 colunas
#     Importance: 0.125101
#   Predicado: Ag ka > -3.39 (n=131)
#     Zona: 45 colunas
#     Importance: 0.106884
#   Predicado: Ag ka <= 5.20 (n=130)
#     Zona: 45 colunas
#     Importance: 0.114414
#   Predicado: Ag ka > 5.20 (n=84)
#     Zona: 45 colunas
#     Importance: 0.113230
#   Predicado: Ag ka <= 10.15 (n=172)
#     Zona: 45 colunas
#     Importance: 0.100831
#
# [Bag_8] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=168)
#     Zona: 18 colunas
#     Importance: 0.071364
#   Predicado: Ag La <= 2.83 (n=82)
#     Zona: 18 colunas
#     Importance: 0.269257
#   Predicado: Ag La > 2.83 (n=132)
#     Zona: 18 colunas
#     Importance: 0.054411
#   Predicado: Ag La <= 4.26 (n=124)
#     Zona: 18 colunas
#     Importance: 0.188693
#   Predicado: Ag La > 4.26 (n=90)
#     Zona: 18 colunas
#     Importance: 0.065150
#   Predicado: Ag La <= 5.23 (n=172)
#     Zona: 18 colunas
#     Importance: 0.154650
#   Predicado: Ag Lb > -6.25 (n=168)
#     Zona: 15 colunas
#     Importance: 0.051116
#   Predicado: Ag Lb <= 2.77 (n=83)
#     Zona: 15 colunas
#     Importance: 0.185824
#   Predicado: Ag Lb > 2.77 (n=131)
#     Zona: 15 colunas
#     Importance: 0.043254
#   Predicado: Ag Lb <= 3.70 (n=127)
#     Zona: 15 colunas
#     Importance: 0.132041
#   Predicado: Ag Lb > 3.70 (n=87)
#     Zona: 15 colunas
#     Importance: 0.049660
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.111375
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.004835
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.003429
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.005514
#   Predicado: Ca <= 1.99 (n=131)
#     Zona: 19 colunas
#     Importance: 0.003126
#   Predicado: Ca > 1.99 (n=83)
#     Zona: 19 colunas
#     Importance: 0.007149
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003459
#   Predicado: background > -1.72 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012797
#   Predicado: background <= 2.11 (n=87)
#     Zona: 87 colunas
#     Importance: 0.012653
#   Predicado: background > 2.11 (n=127)
#     Zona: 87 colunas
#     Importance: 0.013150
#   Predicado: background <= 2.38 (n=132)
#     Zona: 87 colunas
#     Importance: 0.011549
#   Predicado: background > 2.38 (n=82)
#     Zona: 87 colunas
#     Importance: 0.015199
#   Predicado: background <= 2.73 (n=169)
#     Zona: 87 colunas
#     Importance: 0.012100
#   Predicado: Fe > -1.71 (n=168)
#     Zona: 23 colunas
#     Importance: 0.006325
#   Predicado: Fe <= -1.30 (n=88)
#     Zona: 23 colunas
#     Importance: 0.006329
#   Predicado: Fe > -1.30 (n=126)
#     Zona: 23 colunas
#     Importance: 0.006771
#   Predicado: Fe <= 1.63 (n=134)
#     Zona: 23 colunas
#     Importance: 0.005648
#   Predicado: Fe > 1.63 (n=80)
#     Zona: 23 colunas
#     Importance: 0.008167
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.005648
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009303
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.007957
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.010302
#   Predicado: Cu <= 2.35 (n=127)
#     Zona: 66 colunas
#     Importance: 0.008437
#   Predicado: Cu > 2.35 (n=87)
#     Zona: 66 colunas
#     Importance: 0.010761
#   Predicado: Cu <= 2.71 (n=172)
#     Zona: 66 colunas
#     Importance: 0.008458
#   Predicado: Zn > -1.89 (n=171)
#     Zona: 29 colunas
#     Importance: 0.006762
#   Predicado: Zn <= -1.35 (n=85)
#     Zona: 29 colunas
#     Importance: 0.009095
#   Predicado: Zn > -1.35 (n=129)
#     Zona: 29 colunas
#     Importance: 0.006853
#   Predicado: Zn <= 1.85 (n=126)
#     Zona: 29 colunas
#     Importance: 0.007694
#   Predicado: Zn > 1.85 (n=88)
#     Zona: 29 colunas
#     Importance: 0.007813
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.007424
#   Predicado: Bremsstrahlung > -3.10 (n=172)
#     Zona: 429 colunas
#     Importance: 0.076495
#   Predicado: Bremsstrahlung <= -2.45 (n=86)
#     Zona: 429 colunas
#     Importance: 0.099632
#   Predicado: Bremsstrahlung > -2.45 (n=128)
#     Zona: 429 colunas
#     Importance: 0.070613
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.096723
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.059914
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.084686
#   Predicado: Ag compton > -2.89 (n=171)
#     Zona: 62 colunas
#     Importance: 0.018624
#   Predicado: Ag compton <= -2.03 (n=86)
#     Zona: 62 colunas
#     Importance: 0.021475
#   Predicado: Ag compton > -2.03 (n=128)
#     Zona: 62 colunas
#     Importance: 0.017083
#   Predicado: Ag compton <= 2.58 (n=131)
#     Zona: 62 colunas
#     Importance: 0.019843
#   Predicado: Ag compton > 2.58 (n=83)
#     Zona: 62 colunas
#     Importance: 0.017277
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.018560
#   Predicado: Ag ka > -7.93 (n=173)
#     Zona: 45 colunas
#     Importance: 0.113858
#   Predicado: Ag ka <= -3.39 (n=79)
#     Zona: 45 colunas
#     Importance: 0.133563
#   Predicado: Ag ka > -3.39 (n=135)
#     Zona: 45 colunas
#     Importance: 0.108910
#   Predicado: Ag ka <= 5.20 (n=126)
#     Zona: 45 colunas
#     Importance: 0.119509
#   Predicado: Ag ka > 5.20 (n=88)
#     Zona: 45 colunas
#     Importance: 0.115865
#   Predicado: Ag ka <= 10.15 (n=168)
#     Zona: 45 colunas
#     Importance: 0.101564
#
# [Bag_9] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.069955
#   Predicado: Ag La <= 2.83 (n=88)
#     Zona: 18 colunas
#     Importance: 0.241524
#   Predicado: Ag La > 2.83 (n=126)
#     Zona: 18 colunas
#     Importance: 0.055160
#   Predicado: Ag La <= 4.26 (n=130)
#     Zona: 18 colunas
#     Importance: 0.172876
#   Predicado: Ag La > 4.26 (n=84)
#     Zona: 18 colunas
#     Importance: 0.068218
#   Predicado: Ag La <= 5.23 (n=169)
#     Zona: 18 colunas
#     Importance: 0.149690
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.049826
#   Predicado: Ag Lb <= 2.77 (n=85)
#     Zona: 15 colunas
#     Importance: 0.174484
#   Predicado: Ag Lb > 2.77 (n=129)
#     Zona: 15 colunas
#     Importance: 0.042711
#   Predicado: Ag Lb <= 3.70 (n=125)
#     Zona: 15 colunas
#     Importance: 0.126263
#   Predicado: Ag Lb > 3.70 (n=89)
#     Zona: 15 colunas
#     Importance: 0.051214
#   Predicado: Ag Lb <= 4.33 (n=169)
#     Zona: 15 colunas
#     Importance: 0.106284
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.005102
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.003676
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.005776
#   Predicado: Ca <= 1.99 (n=128)
#     Zona: 19 colunas
#     Importance: 0.003348
#   Predicado: Ca > 1.99 (n=86)
#     Zona: 19 colunas
#     Importance: 0.007315
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003569
#   Predicado: background > -1.72 (n=171)
#     Zona: 87 colunas
#     Importance: 0.012256
#   Predicado: background <= 2.11 (n=83)
#     Zona: 87 colunas
#     Importance: 0.012981
#   Predicado: background > 2.11 (n=131)
#     Zona: 87 colunas
#     Importance: 0.012812
#   Predicado: background <= 2.38 (n=128)
#     Zona: 87 colunas
#     Importance: 0.011747
#   Predicado: background > 2.38 (n=86)
#     Zona: 87 colunas
#     Importance: 0.014559
#   Predicado: background <= 2.73 (n=168)
#     Zona: 87 colunas
#     Importance: 0.012192
#   Predicado: Fe > -1.71 (n=172)
#     Zona: 23 colunas
#     Importance: 0.005452
#   Predicado: Fe <= -1.30 (n=83)
#     Zona: 23 colunas
#     Importance: 0.006503
#   Predicado: Fe > -1.30 (n=131)
#     Zona: 23 colunas
#     Importance: 0.005460
#   Predicado: Fe <= 1.63 (n=131)
#     Zona: 23 colunas
#     Importance: 0.005529
#   Predicado: Fe > 1.63 (n=83)
#     Zona: 23 colunas
#     Importance: 0.006395
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.005311
#   Predicado: Cu > -2.02 (n=170)
#     Zona: 66 colunas
#     Importance: 0.009303
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.008985
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.010388
#   Predicado: Cu <= 2.35 (n=129)
#     Zona: 66 colunas
#     Importance: 0.009851
#   Predicado: Cu > 2.35 (n=85)
#     Zona: 66 colunas
#     Importance: 0.009815
#   Predicado: Cu <= 2.71 (n=171)
#     Zona: 66 colunas
#     Importance: 0.009103
#   Predicado: Zn > -1.89 (n=177)
#     Zona: 29 colunas
#     Importance: 0.006982
#   Predicado: Zn <= -1.35 (n=79)
#     Zona: 29 colunas
#     Importance: 0.008206
#   Predicado: Zn > -1.35 (n=135)
#     Zona: 29 colunas
#     Importance: 0.007012
#   Predicado: Zn <= 1.85 (n=127)
#     Zona: 29 colunas
#     Importance: 0.007134
#   Predicado: Zn > 1.85 (n=87)
#     Zona: 29 colunas
#     Importance: 0.007918
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.006815
#   Predicado: Bremsstrahlung > -3.10 (n=172)
#     Zona: 429 colunas
#     Importance: 0.077950
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.097626
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.071847
#   Predicado: Bremsstrahlung <= 3.06 (n=129)
#     Zona: 429 colunas
#     Importance: 0.092938
#   Predicado: Bremsstrahlung > 3.06 (n=85)
#     Zona: 429 colunas
#     Importance: 0.065618
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.082350
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.019363
#   Predicado: Ag compton <= -2.03 (n=83)
#     Zona: 62 colunas
#     Importance: 0.020577
#   Predicado: Ag compton > -2.03 (n=131)
#     Zona: 62 colunas
#     Importance: 0.018522
#   Predicado: Ag compton <= 2.58 (n=130)
#     Zona: 62 colunas
#     Importance: 0.019039
#   Predicado: Ag compton > 2.58 (n=84)
#     Zona: 62 colunas
#     Importance: 0.019753
#   Predicado: Ag compton <= 3.09 (n=171)
#     Zona: 62 colunas
#     Importance: 0.018499
#   Predicado: Ag ka > -7.93 (n=172)
#     Zona: 45 colunas
#     Importance: 0.114212
#   Predicado: Ag ka <= -3.39 (n=83)
#     Zona: 45 colunas
#     Importance: 0.121642
#   Predicado: Ag ka > -3.39 (n=131)
#     Zona: 45 colunas
#     Importance: 0.114668
#   Predicado: Ag ka <= 5.20 (n=127)
#     Zona: 45 colunas
#     Importance: 0.117988
#   Predicado: Ag ka > 5.20 (n=87)
#     Zona: 45 colunas
#     Importance: 0.116476
#   Predicado: Ag ka <= 10.15 (n=169)
#     Zona: 45 colunas
#     Importance: 0.103427
#
# [Bag_10] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=174)
#     Zona: 18 colunas
#     Importance: 0.069928
#   Predicado: Ag La <= 2.83 (n=79)
#     Zona: 18 colunas
#     Importance: 0.249917
#   Predicado: Ag La > 2.83 (n=135)
#     Zona: 18 colunas
#     Importance: 0.054532
#   Predicado: Ag La <= 4.26 (n=122)
#     Zona: 18 colunas
#     Importance: 0.174241
#   Predicado: Ag La > 4.26 (n=92)
#     Zona: 18 colunas
#     Importance: 0.063564
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.144282
#   Predicado: Ag Lb > -6.25 (n=174)
#     Zona: 15 colunas
#     Importance: 0.049584
#   Predicado: Ag Lb <= 2.77 (n=79)
#     Zona: 15 colunas
#     Importance: 0.171400
#   Predicado: Ag Lb > 2.77 (n=135)
#     Zona: 15 colunas
#     Importance: 0.042469
#   Predicado: Ag Lb <= 3.70 (n=123)
#     Zona: 15 colunas
#     Importance: 0.119497
#   Predicado: Ag Lb > 3.70 (n=91)
#     Zona: 15 colunas
#     Importance: 0.050284
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.100647
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.004946
#   Predicado: Ca <= -1.26 (n=90)
#     Zona: 19 colunas
#     Importance: 0.003983
#   Predicado: Ca > -1.26 (n=124)
#     Zona: 19 colunas
#     Importance: 0.005665
#   Predicado: Ca <= 1.99 (n=132)
#     Zona: 19 colunas
#     Importance: 0.003576
#   Predicado: Ca > 1.99 (n=82)
#     Zona: 19 colunas
#     Importance: 0.007181
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003916
#   Predicado: background > -1.72 (n=169)
#     Zona: 87 colunas
#     Importance: 0.012356
#   Predicado: background <= 2.11 (n=91)
#     Zona: 87 colunas
#     Importance: 0.013829
#   Predicado: background > 2.11 (n=123)
#     Zona: 87 colunas
#     Importance: 0.012033
#   Predicado: background <= 2.38 (n=136)
#     Zona: 87 colunas
#     Importance: 0.011639
#   Predicado: background > 2.38 (n=78)
#     Zona: 87 colunas
#     Importance: 0.014816
#   Predicado: background <= 2.73 (n=178)
#     Zona: 87 colunas
#     Importance: 0.012064
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.005830
#   Predicado: Fe <= -1.30 (n=84)
#     Zona: 23 colunas
#     Importance: 0.005881
#   Predicado: Fe > -1.30 (n=130)
#     Zona: 23 colunas
#     Importance: 0.006070
#   Predicado: Fe <= 1.63 (n=128)
#     Zona: 23 colunas
#     Importance: 0.005117
#   Predicado: Fe > 1.63 (n=86)
#     Zona: 23 colunas
#     Importance: 0.007304
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
# ...
# Mantida aresta Cu > 2.01 -> Cu > 2.35 (peso 0.0406)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Cu > 2.35 (peso 0.0094)
# Mantida aresta Cu > 2.35 -> Cu <= 2.71 (peso 0.0193)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Cu > -2.02 (peso 0.0093)
# Mantida aresta Cu > -2.02 -> Cu <= 2.71 (peso 0.0377)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Zn > 1.85 (peso 0.0166)
# Mantida aresta Zn > 1.85 -> Zn <= 1.85 (peso 0.0421)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Zn > 1.85 (peso 0.0080)
# Mantida aresta Zn > 1.85 -> Fe > 1.63 (peso 0.0085)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Ca > 1.99 (peso 0.0083)
# Mantida aresta Ca > 1.99 -> Zn <= 1.85 (peso 0.0155)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Zn <= 2.28 (peso 0.0071)
# Mantida aresta Zn <= 2.28 -> Zn > -1.89 (peso 0.0234)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Fe > 1.63 (peso 0.0078)
# Mantida aresta Fe > 1.63 -> Zn <= 2.28 (peso 0.0080)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Zn > -1.35 (peso 0.0222)
# Mantida aresta Zn > -1.35 -> Zn > -1.89 (peso 0.0296)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Fe > 1.63 (peso 0.0073)
# Mantida aresta Fe > 1.63 -> Zn > -1.35 (peso 0.0141)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Fe > 1.63 (peso 0.0080)
# Mantida aresta Fe > 1.63 -> Ca > 1.99 (peso 0.0303)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Fe <= -1.30 (peso 0.0120)
# Mantida aresta Fe <= -1.30 -> Ca > -1.26 (peso 0.0184)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Fe > -1.71 (peso 0.0061)
# Mantida aresta Fe > -1.71 -> Fe <= -1.30 (peso 0.0253)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ca > -1.26 (peso 0.0060)
# Mantida aresta Ca > -1.26 -> Fe > -1.71 (peso 0.0065)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.0055)
# Mantida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.0060)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe <= 2.10 (peso 0.0170)
# Mantida aresta Fe <= 2.10 -> Fe <= 1.63 (peso 0.0223)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe <= 1.63 (peso 0.0054)
# Mantida aresta Fe <= 1.63 -> Ca > -1.96 (peso 0.0218)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ca > -1.26 (peso 0.0111)
# Mantida aresta Ca > -1.26 -> Fe <= 2.10 (peso 0.0236)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca <= -1.26 (peso 0.0110)
# Mantida aresta Ca <= -1.26 -> Ca <= 2.47 (peso 0.0277)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 232
# Total de arestas removidas por bidirecionalidade: 61
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Perturbation
#
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 53
# Removida aresta Ag Lb <= 2.77 -> Ag La <= 4.26 (peso 0.5298)
# Mantida aresta Ag La <= 4.26 -> Ag Lb <= 2.77 (peso 1.2476)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Ag ka > -7.93 (peso 0.1204)
# Mantida aresta Ag ka > -7.93 -> Ag Lb <= 3.70 (peso 0.2325)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag Lb <= 3.70 (peso 0.1297)
# Mantida aresta Ag Lb <= 3.70 -> Ag ka <= -3.39 (peso 0.3881)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag ka > 5.20 (peso 0.1173)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= -3.39 (peso 0.4775)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag ka > 5.20 (peso 0.1135)
# Mantida aresta Ag ka > 5.20 -> Ag ka > -7.93 (peso 0.3378)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka <= 5.20 (peso 0.1145)
# Mantida aresta Ag ka <= 5.20 -> Ag ka > 5.20 (peso 0.2341)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag Lb <= 4.33 (peso 0.2174)
# Mantida aresta Ag Lb <= 4.33 -> Ag ka > -3.39 (peso 0.2179)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 4.33 -> Ag ka <= 5.20 (peso 0.1058)
# Mantida aresta Ag ka <= 5.20 -> Ag Lb <= 4.33 (peso 0.4346)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ag Lb <= 4.33 (peso 0.1013)
# Mantida aresta Ag Lb <= 4.33 -> Bremsstrahlung <= -2.45 (peso 0.4188)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag Lb <= 4.33 (peso 0.1033)
# Mantida aresta Ag Lb <= 4.33 -> Ag ka <= 10.15 (peso 0.2017)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Bremsstrahlung <= -2.45 (peso 0.1005)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag ka <= 10.15 (peso 0.4977)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ag ka <= 10.15 (peso 0.1842)
# Mantida aresta Ag ka <= 10.15 -> Bremsstrahlung <= 3.06 (peso 0.5834)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Bremsstrahlung > -2.45 (peso 0.2197)
# Mantida aresta Bremsstrahlung > -2.45 -> Ag La > -8.20 (peso 0.2762)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Ag La > -8.20 (peso 0.0694)
# Mantida aresta Ag La > -8.20 -> Bremsstrahlung > 3.06 (peso 0.1369)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Ag La > -8.20 (peso 0.1296)
# Mantida aresta Ag La > -8.20 -> Ag La > 4.26 (peso 0.2001)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Bremsstrahlung > 3.06 (peso 0.1983)
# Mantida aresta Bremsstrahlung > 3.06 -> Ag La > 4.26 (peso 0.4024)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag Lb > 3.70 (peso 0.0978)
# Mantida aresta Ag Lb > 3.70 -> Ag Lb > -6.25 (peso 0.4102)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag compton > 2.58 (peso 0.0400)
# Mantida aresta Ag compton > 2.58 -> Ag compton <= 2.58 (peso 0.0588)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Ag compton > -2.89 (peso 0.0391)
# Mantida aresta Ag compton > -2.89 -> Ag compton > 2.58 (peso 0.0915)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag compton > -2.89 (peso 0.0359)
# Mantida aresta Ag compton > -2.89 -> Ag compton <= 3.09 (peso 0.0758)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Ag compton <= 3.09 (peso 0.0184)
# Mantida aresta Ag compton <= 3.09 -> Ag compton > -2.03 (peso 0.1296)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> background <= 2.11 (peso 0.0589)
# Mantida aresta background <= 2.11 -> background > 2.38 (peso 0.0748)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> background <= 2.11 (peso 0.0116)
# Mantida aresta background <= 2.11 -> background > -1.72 (peso 0.0285)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> background <= 2.73 (peso 0.0255)
# Mantida aresta background <= 2.73 -> background <= 2.38 (peso 0.0474)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> background <= 2.38 (peso 0.0249)
# Mantida aresta background <= 2.38 -> background > 2.11 (peso 0.0372)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background > -1.72 (peso 0.0507)
# Mantida aresta background > -1.72 -> background <= 2.73 (peso 0.0627)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> background > 2.11 (peso 0.0245)
# Mantida aresta background > 2.11 -> background > -1.72 (peso 0.0372)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> Cu > 2.01 (peso 0.0317)
# Mantida aresta Cu > 2.01 -> Cu > 2.35 (peso 0.0519)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu > 2.35 (peso 0.0095)
# Mantida aresta Cu > 2.35 -> Cu <= 2.35 (peso 0.0409)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Cu > 2.35 (peso 0.0106)
# Mantida aresta Cu > 2.35 -> Zn <= -1.35 (peso 0.0193)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu <= 2.01 (peso 0.0091)
# Mantida aresta Cu <= 2.01 -> Cu <= 2.35 (peso 0.0187)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu > -2.02 (peso 0.0203)
# Mantida aresta Cu > -2.02 -> Cu <= 2.35 (peso 0.0281)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Zn <= -1.35 (peso 0.0088)
# Mantida aresta Zn <= -1.35 -> Cu <= 2.71 (peso 0.0272)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Cu > -2.02 (peso 0.0089)
# Mantida aresta Cu > -2.02 -> Cu <= 2.71 (peso 0.0474)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Cu <= 2.71 (peso 0.0090)
# Mantida aresta Cu <= 2.71 -> Cu <= 2.01 (peso 0.0462)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Cu <= 2.01 (peso 0.0081)
# Mantida aresta Cu <= 2.01 -> Zn <= 1.85 (peso 0.0092)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Zn > 1.85 (peso 0.0164)
# Mantida aresta Zn > 1.85 -> Zn <= 1.85 (peso 0.0401)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ca > 1.99 (peso 0.0070)
# Mantida aresta Ca > 1.99 -> Zn > 1.85 (peso 0.0074)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Fe > 1.63 (peso 0.0159)
# Mantida aresta Fe > 1.63 -> Zn <= 1.85 (peso 0.0165)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Fe > 1.63 (peso 0.0073)
# Mantida aresta Fe > 1.63 -> Ca > 1.99 (peso 0.0298)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Zn <= 2.28 (peso 0.0153)
# Mantida aresta Zn <= 2.28 -> Ca > 1.99 (peso 0.0221)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Zn <= 2.28 (peso 0.0148)
# Mantida aresta Zn <= 2.28 -> Fe > 1.63 (peso 0.0299)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Fe > 1.63 (peso 0.0068)
# Mantida aresta Fe > 1.63 -> Zn > -1.89 (peso 0.0075)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Zn > -1.89 (peso 0.0215)
# Mantida aresta Zn > -1.89 -> Zn > -1.35 (peso 0.0485)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Zn > -1.89 (peso 0.0069)
# Mantida aresta Zn > -1.89 -> Fe > -1.30 (peso 0.0143)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Fe > -1.30 (peso 0.0190)
# Mantida aresta Fe > -1.30 -> Fe <= -1.30 (peso 0.0195)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ca > -1.26 (peso 0.0239)
# Mantida aresta Ca > -1.26 -> Fe > -1.71 (peso 0.0301)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Fe <= -1.30 (peso 0.0056)
# Mantida aresta Fe <= -1.30 -> Ca > -1.26 (peso 0.0063)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Fe > -1.71 (peso 0.0129)
# Mantida aresta Fe > -1.71 -> Fe <= -1.30 (peso 0.0182)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.0054)
# Mantida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.0057)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe <= 2.10 (peso 0.0111)
# Mantida aresta Fe <= 2.10 -> Fe <= 1.63 (peso 0.0336)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe <= 1.63 (peso 0.0050)
# Mantida aresta Fe <= 1.63 -> Ca > -1.96 (peso 0.0328)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca <= -1.26 (peso 0.0146)
# Mantida aresta Ca <= -1.26 -> Ca <= 2.47 (peso 0.0231)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 208
# Total de arestas removidas por bidirecionalidade: 53
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Perturbation
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0          Ag La <= 2.83         Ag La <= 2.83         Ag La <= 2.83
# 1          Ag La <= 4.26         Ag La <= 4.26         Ag La <= 4.26
# 2          Ag Lb <= 2.77         Ag Lb <= 2.77         Ag Lb <= 2.77
# 3          Ag La <= 5.23         Ag La <= 5.23         Ag La <= 5.23
# 4          Ag Lb <= 4.33        Ag ka <= -3.39         Ag ka > -3.39
# ..                   ...                   ...                   ...
# 57           Ca <= -1.26           Ca <= -1.26           Ca <= -1.26
# 58            Ca <= 2.47            Ca <= 2.47            Ca <= 2.47
# 59            Ca <= 1.99            Ca <= 1.99            Ca <= 1.99
# 60               Class_A               Class_A               Class_A
# 61               Class_B               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0          Ag La <= 4.26
# 1          Ag La <= 2.83
# 2          Ag Lb <= 2.77
# 3          Ag La <= 5.23
# 4          Ag ka > -7.93
# ..                   ...
# 57           Ca <= -1.26
# 58            Ca <= 2.47
# 59            Ca <= 1.99
# 60               Class_A
# 61               Class_B
#
# [62 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_9']
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[12], line 1
#
# ----> 1 all_results_pert[0]['pert_results_dict']['Bag_9']
#
#
#
# NameError: name 'all_results_pert' is not defined

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df = lrc_summed_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                          Node  Local_Reaching_Centrality              Zone  \
# 0              Ti ka <= -3.08                  19.951264             Ti ka
# 1              Ca ka <= -9.12                   5.980030             Ca ka
# 2             Fe ka <= -10.00                   1.064709             Fe ka
# 3   Ag ka scattering <= -1.94                   0.876688  Ag ka scattering
# 4              Cu ka <= -4.31                   0.786209             Cu ka
# 5              Ti kb <= -2.36                   0.625074             Ti kb
# 6         background4 <= 2.89                   0.501688       background4
# 7               Fe kb > -3.14                   0.465026             Fe kb
# 8         background6 <= 2.28                   0.414660       background6
# 9              Ca kb <= -3.42                   0.335439             Ca kb
# 10         background1 > 2.53                   0.080554       background1
# 11               Cu kb > 1.49                   0.040906             Cu kb
# 12        background5 <= 2.48                   0.038757       background5
# 13        background2 <= 2.16                   0.035211       background2
# 14      Ar ka + Ag L <= -1.64                   0.028316      Ar ka + Ag L
# 15               Zn kb > 2.27                   0.021536             Zn kb
# 16         background3 > 2.09                   0.016991       background3
# 17             Zn ka <= -1.46                   0.016982             Zn ka
# 18                    Class_A                   0.000000              None
#
#    Threshold Operator
# 0      -3.08       <=
# 1      -9.12       <=
# 2     -10.00       <=
# 3      -1.94       <=
# 4      -4.31       <=
# 5      -2.36       <=
# 6       2.89       <=
# 7      -3.14        >
# 8       2.28       <=
# 9      -3.42       <=
# 10      2.53        >
# 11      1.49        >
# 12      2.48       <=
# 13      2.16       <=
# 14     -1.64       <=
# 15      2.27        >
# 16      2.09        >
# 17     -1.46       <=
# 18      None     None

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    #len(shap_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'pvector': pad_list(pvector_unique_df['Zone'], max_len),
    #'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

#features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#              pvector  LRC_perturbation    LRC_covariance
# 0              Fe ka             Ti ka             Fe ka
# 1              Ti ka             Ca ka             Ca ka
# 2              Cu ka             Fe ka             Ti ka
# 3              Fe kb  Ag ka scattering             Fe kb
# 4              Ti kb             Cu ka             Ca kb
# 5              Ca ka             Ti kb             Ti kb
# 6   Ag ka scattering       background4             Cu ka
# 7        background6             Fe kb             Cu kb
# 8              Cu kb       background6       background2
# 9              Ca kb             Ca kb             Zn ka
# 10       background4       background1       background5
# 11       background5             Cu kb       background4
# 12             Zn ka       background5  Ag ka scattering
# 13       background2       background2       background6
# 14       background3      Ar ka + Ag L       background1
# 15      Ar ka + Ag L             Zn kb      Ar ka + Ag L
# 16       background1       background3       background3
# 17             Zn kb             Zn ka             Zn kb
# 18              None              None              None

# %%
# RBO (Rank-Biased Overlap) para comparar rankings
import rbo
rbo_results = {}
reference_list = [x for x in features_importance['pvector'].tolist() if x is not None]
methods = ['LRC_covariance', 'LRC_perturbation']
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if x is not None]
    # Truncate both lists to the same length (minimum of both)
    min_len = min(len(reference_list), len(compare_list))
    ref_trunc = reference_list[:min_len]
    cmp_trunc = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trunc, cmp_trunc).rbo(p=0.7, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method','RBO_Score'])
rbo_results.insert(0, 'Reference', 'pvector')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
#rbo_results.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_results
# Out:
#   Reference            Method  RBO_Score
# 0   pvector    LRC_covariance   0.737329
# 1   pvector  LRC_perturbation   0.417824
