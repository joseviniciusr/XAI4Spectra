# %% [markdown]
# # **Model**

# %% [markdown]
# # **XRF milk database**

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/milk/plsda/milk.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '2.66':'22.62']

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.66':'22.62'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.66':'22.62'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-29 05:17:06,276 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-29 05:17:06,301 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-29 05:17:06,359 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-29 05:17:06,449 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from modeling import svm_optimized

svm_model = svm_optimized(Xcalclass_prep, ycalclass, Xpredclass_prep, ypredclass, aim='classification', kernel='rbf')
svm_model[0]
y_pred = svm_model[4]['SVC'].values # using the continuous predictions from SVM, extracting as 1D array

# %%
# calculando a covariancia entre cada variável espectral e a predição do modelo SVM
cov_scores = []
for col in Xcalclass_prep.columns:
    x_values = Xcalclass_prep[col].values
    covariance = np.cov(x_values, y_pred)[0, 1] # covariance between x and y
    cov_scores.append(covariance)
cov_scores_df = pd.DataFrame(cov_scores, index=Xcalclass_prep.columns, columns=['Covariance'])
cov_scores_df = np.abs(cov_scores_df)
cov_scores_df.plot()

# %%
X_sv = svm_model[3].support_vectors_            # shape (n_SV, n_features)
alpha_dual = svm_model[3].dual_coef_.ravel()    # shape (n_SV,)

# Calculando os coeficientes p usando os vetores de suporte e os multiplicadores de Lagrange
pvetor = pd.DataFrame({'energia' : Xcalclass.columns,
                       'importance': (X_sv.T) @ alpha_dual})
pvetor['importance'] = np.abs(pvetor['importance'])
pvetor['importance'].plot()

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Ag La', 2.66, 3.10),
('Ag Lb', 3.10, 3.46),
('Ca', 3.46, 3.92),
('background', 3.92, 6.12),
('Fe', 6.12, 6.68),
('Cu', 6.70, 8.37),
('Zn', 8.37, 9.10),
('Bremsstrahlung', 9.10, 20.06),
('Ag compton', 20.06, 21.62),
('Ag ka', 21.48, 22.62)
]

# %%
import explaining as exp
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_sums_df = exp.aggregate_spectral_zones(spectral_zones_class, aggregator='extreme')
predicates_quantiles = exp.predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8])
co_occurrence_matrix_df = predicates_quantiles[2]
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=y_pred
)

# %% [markdown]
# ## Pvector and SHAP

# %%
# VIP scores por energia
pvector_df = pd.DataFrame({
    'energy': pvetor['energia'],
    'Pvector': pvetor['importance'].values
})
pvector_df = pvector_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in pvector_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
pvector_df['Zone'] = pvector_df['energy'].map(energy_to_zone_vip)
pvector_unique_df = pvector_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
pvector_unique_df = pvector_unique_df.sort_values(by='Pvector', ascending=False).reset_index(drop=True)
pvector_unique_df
shap_unique_df = pd.read_csv('shap_milk.csv', sep=';') # loading previously saved shap_unique_df

# %% [markdown]
# # permutation

# %%
# Permutation importance baseado em mudança nas probabilidades previstas (predict_proba)
# Medimos a média da diferença absoluta entre as probabilidades originais e as probabilidades
# obtidas após permutar cada variável. Isso fornece uma métrica contínua de importância.
n_repeats = 10
rng = np.random.RandomState(42)
# Probabilidades base (classe 'B' mapeada para 1)
baseline_proba = svm_model[3].predict_proba(Xcalclass_prep)[:, 1]
importance_list = []
X_arr = Xcalclass_prep.copy()
for col in Xcalclass_prep.columns:
    diffs = []
    for _ in range(n_repeats):
        X_perm = X_arr.copy()
        X_perm[col] = rng.permutation(X_perm[col].values)
        perm_proba = svm_model[3].predict_proba(X_perm)[:, 1]
        diffs.append(np.mean(np.abs(baseline_proba - perm_proba)))
    importance_list.append(np.mean(diffs))

permutation_df = pd.DataFrame({
    'energy': Xcalclass_prep.columns,
    'Permutation_importance_proba': importance_list
})
permutation_df.sort_values(by='Permutation_importance_proba', ascending=False, inplace=True)
energy_to_zone_vip = {}
for zone_name, start, end in spectral_cuts:
    for e in permutation_df['energy']:
        ef = float(e)
        if start <= ef <= end:
            energy_to_zone_vip[e] = zone_name
permutation_df['Zone'] = permutation_df['energy'].map(energy_to_zone_vip)
permutation_unique_df = permutation_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
permutation_unique_df = permutation_unique_df.sort_values(by='Permutation_importance_proba', ascending=False)
permutation_unique_df
# Out:
#   energy  Permutation_importance_proba            Zone
# 0  22.23                      0.025344           Ag ka
# 1   3.02                      0.017719           Ag La
# 2   3.17                      0.009976           Ag Lb
# 3   8.73                      0.003917              Zn
# 4  17.99                      0.003799  Bremsstrahlung
# 5  21.41                      0.003572      Ag compton
# 6   6.35                      0.003284              Fe
# 7   7.80                      0.002201              Cu
# 8   3.89                      0.002133              Ca
# 9   4.84                      0.001953      background

# %% [markdown]
# # **bagging - covariance**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = pd.Series(y_pred) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graphv2(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',  # ou 'Covariance' se mudar a métrica
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 54
# Removida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 4.4652)
# Mantida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 6.8001)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 1.0007)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 4.4690)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 1.1109)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 3.3543)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.2987)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 2.4751)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag ka <= 5.20 (peso 0.1371)
# Mantida aresta Ag ka <= 5.20 -> Ag compton > -2.89 (peso 0.7528)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Ag ka <= 5.20 (peso 0.2393)
# Mantida aresta Ag ka <= 5.20 -> Bremsstrahlung <= 3.46 (peso 0.6372)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag compton > -2.89 (peso 0.1384)
# Mantida aresta Ag compton > -2.89 -> Ag compton <= 2.58 (peso 0.3659)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag compton > -2.89 (peso 0.1762)
# Mantida aresta Ag compton > -2.89 -> Zn > -1.89 (peso 0.1889)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Bremsstrahlung <= 3.46 (peso 0.2093)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag ka > -7.93 (peso 0.2438)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Bremsstrahlung <= 3.46 (peso 0.2014)
# Mantida aresta Bremsstrahlung <= 3.46 -> Fe <= 2.10 (peso 0.4214)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Bremsstrahlung <= 3.46 (peso 0.2514)
# Mantida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung <= 3.06 (peso 0.4743)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Zn > -1.89 (peso 0.1822)
# Mantida aresta Zn > -1.89 -> Ag compton <= 2.58 (peso 0.1881)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton <= 2.58 (peso 0.3139)
# Mantida aresta Ag compton <= 2.58 -> Ca <= 1.99 (peso 0.3196)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Zn > -1.89 (peso 0.1541)
# Mantida aresta Zn > -1.89 -> Fe <= 2.10 (peso 0.1699)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Zn > -1.89 (peso 0.1557)
# Mantida aresta Zn > -1.89 -> Fe > -1.71 (peso 0.6725)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Bremsstrahlung > -3.10 (peso 0.1519)
# Mantida aresta Bremsstrahlung > -3.10 -> Zn > -1.89 (peso 0.2122)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.1640)
# Mantida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.4407)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ca <= 1.99 (peso 0.1456)
# Mantida aresta Ca <= 1.99 -> Fe > -1.71 (peso 0.3213)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ca <= 2.47 (peso 0.1247)
# Mantida aresta Ca <= 2.47 -> Bremsstrahlung <= 3.06 (peso 0.1466)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Ca <= 1.99 (peso 0.1484)
# Mantida aresta Ca <= 1.99 -> Bremsstrahlung > -3.10 (peso 0.2745)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Bremsstrahlung > -3.10 (peso 0.0924)
# Mantida aresta Bremsstrahlung > -3.10 -> Ag La > 2.83 (peso 0.1127)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Ca <= 2.47 (peso 0.0742)
# Mantida aresta Ca <= 2.47 -> Ag compton <= -2.03 (peso 0.1408)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ca <= 2.47 (peso 0.0613)
# Mantida aresta Ca <= 2.47 -> Zn <= 2.28 (peso 0.0901)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag Lb > 2.77 (peso 0.0662)
# Mantida aresta Ag Lb > 2.77 -> Zn > -1.35 (peso 0.1220)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton <= -2.03 (peso 0.0649)
# Mantida aresta Ag compton <= -2.03 -> Ag Lb > 2.77 (peso 0.1217)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag ka <= -3.39 (peso 0.0983)
# Mantida aresta Ag ka <= -3.39 -> Ag La > 2.83 (peso 0.0999)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Zn <= 2.28 (peso 0.0670)
# Mantida aresta Zn <= 2.28 -> Ag compton > -2.03 (peso 0.0898)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Ag compton > -2.03 (peso 0.0740)
# Mantida aresta Ag compton > -2.03 -> background <= 2.38 (peso 0.1403)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ag compton > -2.03 (peso 0.0561)
# Mantida aresta Ag compton > -2.03 -> Fe > -1.30 (peso 0.0727)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ag compton > -2.03 (peso 0.0932)
# Mantida aresta Ag compton > -2.03 -> background <= 2.73 (peso 0.1638)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ag La > 2.83 (peso 0.0778)
# Mantida aresta Ag La > 2.83 -> Zn <= 2.28 (peso 0.1331)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Zn > -1.35 (peso 0.0729)
# Mantida aresta Zn > -1.35 -> background <= 2.38 (peso 0.0909)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Zn > -1.35 (peso 0.0439)
# Mantida aresta Zn > -1.35 -> Fe > -1.30 (peso 0.0491)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Fe <= 1.63 (peso 0.0572)
# Mantida aresta Fe <= 1.63 -> Ag compton <= -2.03 (peso 0.0595)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> background <= 2.73 (peso 0.0594)
# Mantida aresta background <= 2.73 -> Fe > -1.30 (peso 0.0678)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ca > -1.26 (peso 0.0562)
# Mantida aresta Ca > -1.26 -> Fe > -1.30 (peso 0.0598)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Bremsstrahlung > -2.45 (peso 0.0508)
# Mantida aresta Bremsstrahlung > -2.45 -> Zn > 1.85 (peso 0.1015)
#
# ======================================================================
#
# Removida aresta background <= 2.11 -> Bremsstrahlung > -2.45 (peso 0.0174)
# Mantida aresta Bremsstrahlung > -2.45 -> background <= 2.11 (peso 0.0945)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Bremsstrahlung <= -2.45 (peso 0.0443)
# Mantida aresta Bremsstrahlung <= -2.45 -> Bremsstrahlung > -2.45 (peso 0.0494)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ag La > -8.20 (peso 0.0426)
# Mantida aresta Ag La > -8.20 -> Bremsstrahlung <= -2.45 (peso 0.0500)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ca > -1.26 (peso 0.0567)
# Mantida aresta Ca > -1.26 -> Ag Lb > -6.25 (peso 0.0603)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Zn <= 1.85 (peso 0.0445)
# Mantida aresta Zn <= 1.85 -> Ca > -1.26 (peso 0.0689)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ca > -1.26 (peso 0.0371)
# Mantida aresta Ca > -1.26 -> Zn > 1.85 (peso 0.0495)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ca > -1.96 (peso 0.0434)
# Mantida aresta Ca > -1.96 -> Bremsstrahlung <= -2.45 (peso 0.0514)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Bremsstrahlung <= -2.45 (peso 0.0246)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag Lb > 3.70 (peso 0.0458)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Fe <= 1.63 (peso 0.0596)
# Mantida aresta Fe <= 1.63 -> Ag Lb > -6.25 (peso 0.0927)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Cu > -2.02 (peso 0.0178)
# Mantida aresta Cu > -2.02 -> Ca <= -1.26 (peso 0.0287)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Zn > 1.85 (peso 0.0331)
# Mantida aresta Zn > 1.85 -> Cu <= 2.71 (peso 0.0341)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ag Lb > 3.70 (peso 0.0336)
# Mantida aresta Ag Lb > 3.70 -> Zn > 1.85 (peso 0.0676)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Zn <= -1.35 (peso 0.0277)
# Mantida aresta Zn <= -1.35 -> Ca <= -1.26 (peso 0.0396)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> background > -1.72 (peso 0.0151)
# Mantida aresta background > -1.72 -> Ag La > 4.26 (peso 0.0160)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Ag Lb > -6.25 (peso 0.0181)
# Mantida aresta Ag Lb > -6.25 -> background > 2.38 (peso 0.0230)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> background > 2.11 (peso 0.0144)
# Mantida aresta background > 2.11 -> Ca > 1.99 (peso 0.0160)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Cu > 2.01 (peso 0.0120)
# Mantida aresta Cu > 2.01 -> Zn <= 1.85 (peso 0.0137)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 383
# Total de arestas removidas por bidirecionalidade: 54
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 63
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 1.0467)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 3.9698)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag ka <= 10.15 (peso 1.0317)
# Mantida aresta Ag ka <= 10.15 -> Ag ka > -3.39 (peso 1.1472)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 0.9957)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 1.5370)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.7161)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 1.3281)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Cu <= 2.35 (peso 0.0287)
# Mantida aresta Cu <= 2.35 -> Ag ka > -7.93 (peso 0.0378)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Ag ka > -7.93 (peso 0.0514)
# Mantida aresta Ag ka > -7.93 -> Ag compton <= -2.03 (peso 0.0762)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Bremsstrahlung <= 3.46 (peso 0.2134)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag ka > -7.93 (peso 0.2762)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag ka <= 5.20 (peso 0.1781)
# Mantida aresta Ag ka <= 5.20 -> Fe <= 2.10 (peso 0.3712)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Fe > -1.71 (peso 0.1710)
# Mantida aresta Fe > -1.71 -> Ag ka <= 5.20 (peso 0.2837)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Ca <= 1.99 (peso 0.1597)
# Mantida aresta Ca <= 1.99 -> Ag ka <= 5.20 (peso 0.1831)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.1444)
# Mantida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.4467)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Fe > -1.71 (peso 0.1708)
# Mantida aresta Fe > -1.71 -> Ag compton <= 2.58 (peso 0.3078)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Fe > -1.71 (peso 0.1634)
# Mantida aresta Fe > -1.71 -> Zn > -1.89 (peso 0.3322)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Fe > -1.71 (peso 0.1210)
# Mantida aresta Fe > -1.71 -> Ca <= 2.47 (peso 0.1680)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ca <= 1.99 (peso 0.1818)
# Mantida aresta Ca <= 1.99 -> Bremsstrahlung <= 3.06 (peso 0.4550)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ca <= 1.99 (peso 0.1575)
# Mantida aresta Ca <= 1.99 -> Zn > -1.89 (peso 0.3273)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.2036)
# Mantida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.5870)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag compton <= 2.58 (peso 0.1629)
# Mantida aresta Ag compton <= 2.58 -> Zn > -1.89 (peso 0.3252)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag compton <= 2.58 (peso 0.1837)
# Mantida aresta Ag compton <= 2.58 -> Ag compton > -2.89 (peso 0.5528)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ca <= 2.47 (peso 0.1231)
# Mantida aresta Ca <= 2.47 -> Ag compton <= 2.58 (peso 0.1610)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Bremsstrahlung <= -2.45 (peso 0.0562)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag La > -8.20 (peso 0.0719)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag compton > -2.03 (peso 0.0856)
# Mantida aresta Ag compton > -2.03 -> Ag La > -8.20 (peso 0.1125)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ag La > -8.20 (peso 0.0562)
# Mantida aresta Ag La > -8.20 -> Ca <= 2.47 (peso 0.1034)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background <= 2.38 (peso 0.2003)
# Mantida aresta background <= 2.38 -> background <= 2.73 (peso 0.2127)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> background <= 2.73 (peso 0.0891)
# Mantida aresta background <= 2.73 -> Zn <= 2.28 (peso 0.0958)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Bremsstrahlung > -3.10 (peso 0.1634)
# Mantida aresta Bremsstrahlung > -3.10 -> Ca <= 2.47 (peso 0.1871)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Bremsstrahlung > -2.45 (peso 0.0324)
# Mantida aresta Bremsstrahlung > -2.45 -> Ca > -1.96 (peso 0.0763)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Ca <= -1.26 (peso 0.0202)
# Mantida aresta Ca <= -1.26 -> Ca > -1.96 (peso 0.0330)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> background <= 2.38 (peso 0.0751)
# Mantida aresta background <= 2.38 -> Ca > -1.26 (peso 0.2356)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> background <= 2.38 (peso 0.0731)
# Mantida aresta background <= 2.38 -> Zn > -1.35 (peso 0.0797)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ca > -1.26 (peso 0.0744)
# Mantida aresta Ca > -1.26 -> Zn > -1.35 (peso 0.1367)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ag Lb > 2.77 (peso 0.0598)
# Mantida aresta Ag Lb > 2.77 -> Fe > -1.30 (peso 0.0660)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag La > 2.83 (peso 0.0696)
# Mantida aresta Ag La > 2.83 -> Ag Lb > 2.77 (peso 0.1389)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag Lb > 2.77 (peso 0.0713)
# Mantida aresta Ag Lb > 2.77 -> Zn > -1.35 (peso 0.1212)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag Lb > 2.77 (peso 0.0520)
# Mantida aresta Ag Lb > 2.77 -> Bremsstrahlung > -2.45 (peso 0.0674)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ag compton <= -2.03 (peso 0.0651)
# Mantida aresta Ag compton <= -2.03 -> Fe > -1.30 (peso 0.1243)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Fe <= 1.63 (peso 0.0342)
# Mantida aresta Fe <= 1.63 -> Fe > -1.30 (peso 0.0791)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Fe > -1.30 (peso 0.0562)
# Mantida aresta Fe > -1.30 -> Bremsstrahlung <= -2.45 (peso 0.0607)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag compton <= -2.03 (peso 0.0651)
# Mantida aresta Ag compton <= -2.03 -> Zn > -1.35 (peso 0.0700)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag compton > -2.03 (peso 0.0675)
# Mantida aresta Ag compton > -2.03 -> Ag La > 2.83 (peso 0.1980)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag compton > -2.03 (peso 0.0545)
# Mantida aresta Ag compton > -2.03 -> Zn > -1.35 (peso 0.0850)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ca <= -1.26 (peso 0.0232)
# Mantida aresta Ca <= -1.26 -> Fe <= 1.63 (peso 0.0444)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Ca <= -1.26 (peso 0.0150)
# Mantida aresta Ca <= -1.26 -> Ag La > 4.26 (peso 0.0433)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Zn <= 1.85 (peso 0.0265)
# Mantida aresta Zn <= 1.85 -> Ca <= -1.26 (peso 0.0342)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Ca <= -1.26 (peso 0.0270)
# Mantida aresta Ca <= -1.26 -> Ag Lb > 3.70 (peso 0.0299)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Fe <= 1.63 (peso 0.0259)
# Mantida aresta Fe <= 1.63 -> Bremsstrahlung > -2.45 (peso 0.0441)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Fe <= 1.63 (peso 0.0164)
# Mantida aresta Fe <= 1.63 -> Zn <= 1.85 (peso 0.0332)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Cu <= 2.71 (peso 0.0245)
# Mantida aresta Cu <= 2.71 -> Fe <= 1.63 (peso 0.0274)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Bremsstrahlung > -2.45 (peso 0.0271)
# Mantida aresta Bremsstrahlung > -2.45 -> Cu <= 2.35 (peso 0.0404)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Zn > 1.85 (peso 0.0311)
# Mantida aresta Zn > 1.85 -> Cu > -2.02 (peso 0.0323)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Zn > 1.85 (peso 0.0275)
# Mantida aresta Zn > 1.85 -> Ag Lb > 3.70 (peso 0.0803)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Cu <= 2.01 (peso 0.0228)
# Mantida aresta Cu <= 2.01 -> Ag La > 4.26 (peso 0.0382)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> background > 2.38 (peso 0.0200)
# Mantida aresta background > 2.38 -> Ag La > 4.26 (peso 0.0293)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Zn <= -1.35 (peso 0.0125)
# Mantida aresta Zn <= -1.35 -> background > 2.38 (peso 0.0269)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> background > 2.38 (peso 0.0183)
# Mantida aresta background > 2.38 -> Ca > 1.99 (peso 0.0196)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ag La > 4.26 (peso 0.0234)
# Mantida aresta Ag La > 4.26 -> Cu > -2.02 (peso 0.0272)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Ag Lb > 3.70 (peso 0.0295)
# Mantida aresta Ag Lb > 3.70 -> Cu <= 2.35 (peso 0.0521)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Zn <= 1.85 (peso 0.0191)
# Mantida aresta Zn <= 1.85 -> Zn <= -1.35 (peso 0.0223)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Cu > 2.35 (peso 0.0115)
# Mantida aresta Cu > 2.35 -> Zn <= -1.35 (peso 0.0126)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Zn <= -1.35 (peso 0.0190)
# Mantida aresta Zn <= -1.35 -> Cu <= 2.35 (peso 0.0278)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Zn <= 1.85 (peso 0.0172)
# Mantida aresta Zn <= 1.85 -> background > 2.11 (peso 0.0176)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Ag compton > 2.58 (peso 0.0152)
# Mantida aresta Ag compton > 2.58 -> Fe > 1.63 (peso 0.0252)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> Cu > 2.01 (peso 0.0141)
# Mantida aresta Cu > 2.01 -> Cu > 2.35 (peso 0.0211)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 390
# Total de arestas removidas por bidirecionalidade: 63
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 55
# Removida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 2.3497)
# Mantida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 9.0940)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > -3.39 (peso 1.1603)
# Mantida aresta Ag ka > -3.39 -> Ag ka <= 10.15 (peso 2.2417)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 0.6737)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 2.7789)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 1.4152)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 2.0757)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.3806)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 1.7852)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Ag compton <= 3.09 (peso 0.2370)
# Mantida aresta Ag compton <= 3.09 -> Bremsstrahlung <= 3.46 (peso 1.3095)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag ka <= -3.39 (peso 0.1058)
# Mantida aresta Ag ka <= -3.39 -> Ag compton > -2.89 (peso 0.1592)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.06 (peso 0.2474)
# Mantida aresta Bremsstrahlung <= 3.06 -> Ag compton > -2.89 (peso 0.4403)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.1488)
# Mantida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.1887)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Fe > -1.71 (peso 0.1713)
# Mantida aresta Fe > -1.71 -> Ag compton > -2.89 (peso 0.1966)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag compton <= 2.58 (peso 0.1792)
# Mantida aresta Ag compton <= 2.58 -> Zn > -1.89 (peso 0.4542)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Zn > -1.89 (peso 0.1540)
# Mantida aresta Zn > -1.89 -> Fe <= 2.10 (peso 0.5254)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Bremsstrahlung <= 3.06 (peso 0.1408)
# Mantida aresta Bremsstrahlung <= 3.06 -> Ca <= 1.99 (peso 0.1771)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ca <= 1.99 (peso 0.1149)
# Mantida aresta Ca <= 1.99 -> Ag ka <= -3.39 (peso 0.1719)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag ka <= 5.20 (peso 0.1630)
# Mantida aresta Ag ka <= 5.20 -> Ca <= 1.99 (peso 0.2931)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Fe > -1.71 (peso 0.2026)
# Mantida aresta Fe > -1.71 -> Bremsstrahlung > -3.10 (peso 0.3687)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Fe > -1.71 (peso 0.1325)
# Mantida aresta Fe > -1.71 -> Bremsstrahlung <= 3.06 (peso 0.1811)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Bremsstrahlung <= 3.46 (peso 0.1252)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag ka <= 5.20 (peso 0.5305)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.1622)
# Mantida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.2025)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag ka <= -3.39 (peso 0.1599)
# Mantida aresta Ag ka <= -3.39 -> Fe <= 2.10 (peso 0.1700)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Bremsstrahlung <= 3.06 (peso 0.1777)
# Mantida aresta Bremsstrahlung <= 3.06 -> Fe <= 2.10 (peso 0.2538)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Bremsstrahlung > -3.10 (peso 0.1208)
# Mantida aresta Bremsstrahlung > -3.10 -> Ca <= 2.47 (peso 0.1387)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ca <= 2.47 (peso 0.0641)
# Mantida aresta Ca <= 2.47 -> Zn > -1.35 (peso 0.0925)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ag La > -8.20 (peso 0.0780)
# Mantida aresta Ag La > -8.20 -> Ca <= 2.47 (peso 0.1427)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> background <= 2.73 (peso 0.1033)
# Mantida aresta background <= 2.73 -> Ca <= 2.47 (peso 0.2197)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Fe > -1.30 (peso 0.0634)
# Mantida aresta Fe > -1.30 -> Ca <= 2.47 (peso 0.0826)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Ag La > 2.83 (peso 0.0937)
# Mantida aresta Ag La > 2.83 -> Ag compton > -2.03 (peso 0.1851)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Zn <= 2.28 (peso 0.0609)
# Mantida aresta Zn <= 2.28 -> Ag La > 2.83 (peso 0.0658)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Zn > -1.35 (peso 0.0708)
# Mantida aresta Zn > -1.35 -> background <= 2.73 (peso 0.0787)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Zn > -1.35 (peso 0.0669)
# Mantida aresta Zn > -1.35 -> Ag Lb > 2.77 (peso 0.0809)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Zn > -1.35 (peso 0.0534)
# Mantida aresta Zn > -1.35 -> Ca > -1.26 (peso 0.0640)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Cu <= 2.01 (peso 0.0508)
# Mantida aresta Cu <= 2.01 -> Zn > -1.35 (peso 0.0645)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Zn > -1.35 (peso 0.0661)
# Mantida aresta Zn > -1.35 -> Ag compton <= -2.03 (peso 0.0741)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> background <= 2.73 (peso 0.1054)
# Mantida aresta background <= 2.73 -> Ag ka <= -3.39 (peso 0.2154)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Ag compton <= -2.03 (peso 0.0694)
# Mantida aresta Ag compton <= -2.03 -> Ca > -1.26 (peso 0.1260)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ag compton <= -2.03 (peso 0.0427)
# Mantida aresta Ag compton <= -2.03 -> Cu > -2.02 (peso 0.0483)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton <= -2.03 (peso 0.1232)
# Mantida aresta Ag compton <= -2.03 -> Ag Lb > 2.77 (peso 0.2100)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Ca > -1.96 (peso 0.0569)
# Mantida aresta Ca > -1.96 -> Ag compton <= -2.03 (peso 0.0572)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ag La > -8.20 (peso 0.0519)
# Mantida aresta Ag La > -8.20 -> Cu <= 2.01 (peso 0.0766)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag Lb > -6.25 (peso 0.0466)
# Mantida aresta Ag Lb > -6.25 -> Ag La > -8.20 (peso 0.1324)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ag Lb > 2.77 (peso 0.0555)
# Mantida aresta Ag Lb > 2.77 -> Fe <= 1.63 (peso 0.1134)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> background <= 2.11 (peso 0.0273)
# Mantida aresta background <= 2.11 -> Fe <= 1.63 (peso 0.0525)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe > -1.30 (peso 0.0333)
# Mantida aresta Fe > -1.30 -> Fe <= 1.63 (peso 0.0644)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Bremsstrahlung > -2.45 (peso 0.0513)
# Mantida aresta Bremsstrahlung > -2.45 -> Ag Lb > 2.77 (peso 0.0573)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Bremsstrahlung <= -2.45 (peso 0.0402)
# Mantida aresta Bremsstrahlung <= -2.45 -> Zn > 1.85 (peso 0.0890)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ca > -1.96 (peso 0.0393)
# Mantida aresta Ca > -1.96 -> Bremsstrahlung <= -2.45 (peso 0.0408)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Zn > 1.85 (peso 0.0189)
# Mantida aresta Zn > 1.85 -> background > 2.11 (peso 0.0214)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Zn > 1.85 (peso 0.0235)
# Mantida aresta Zn > 1.85 -> Ag Lb > 3.70 (peso 0.0741)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Cu > -2.02 (peso 0.0172)
# Mantida aresta Cu > -2.02 -> Bremsstrahlung > -2.45 (peso 0.0460)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Ca <= -1.26 (peso 0.0277)
# Mantida aresta Ca <= -1.26 -> Ag Lb > 3.70 (peso 0.0577)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> Bremsstrahlung > 3.06 (peso 0.0145)
# Mantida aresta Bremsstrahlung > 3.06 -> background > -1.72 (peso 0.0158)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Bremsstrahlung > 3.06 (peso 0.0128)
# Mantida aresta Bremsstrahlung > 3.06 -> Fe <= -1.30 (peso 0.0195)
#
# ======================================================================
#
# Removida aresta background <= 2.11 -> Ca > -1.96 (peso 0.0593)
# Mantida aresta Ca > -1.96 -> background <= 2.11 (peso 0.1077)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> background > -1.72 (peso 0.0135)
# Mantida aresta background > -1.72 -> Zn <= -1.35 (peso 0.0151)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Ag compton > 2.58 (peso 0.0155)
# Mantida aresta Ag compton > 2.58 -> Ca > 1.99 (peso 0.0160)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 375
# Total de arestas removidas por bidirecionalidade: 55
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 55
# Removida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 1.1624)
# Mantida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 10.0698)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -3.39 (peso 0.4469)
# Mantida aresta Ag ka > -3.39 -> Ag ka > 5.20 (peso 4.9887)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > 5.20 (peso 0.4833)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= 10.15 (peso 3.1563)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka <= 10.15 (peso 0.2358)
# Mantida aresta Ag ka <= 10.15 -> Ag compton <= 3.09 (peso 2.7059)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.46 (peso 0.4564)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag compton > -2.89 (peso 0.6937)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.06 (peso 0.6552)
# Mantida aresta Bremsstrahlung <= 3.06 -> Ag compton > -2.89 (peso 0.6677)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.1267)
# Mantida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.1406)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Bremsstrahlung <= 3.06 (peso 0.1750)
# Mantida aresta Bremsstrahlung <= 3.06 -> Zn > -1.89 (peso 0.6190)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background <= 2.38 (peso 0.2236)
# Mantida aresta background <= 2.38 -> background <= 2.73 (peso 0.2690)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> background <= 2.38 (peso 0.0737)
# Mantida aresta background <= 2.38 -> Ag La > -8.20 (peso 0.1295)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> background <= 2.38 (peso 0.0542)
# Mantida aresta background <= 2.38 -> Ag compton > -2.03 (peso 0.2202)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> background <= 2.38 (peso 0.0536)
# Mantida aresta background <= 2.38 -> Zn <= 2.28 (peso 0.0541)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ca <= 1.99 (peso 0.1261)
# Mantida aresta Ca <= 1.99 -> background <= 2.73 (peso 0.1283)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Ag compton <= -2.03 (peso 0.0700)
# Mantida aresta Ag compton <= -2.03 -> background <= 2.73 (peso 0.1646)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ca <= 1.99 (peso 0.1465)
# Mantida aresta Ca <= 1.99 -> Fe > -1.71 (peso 0.1486)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Fe > -1.71 (peso 0.3041)
# Mantida aresta Fe > -1.71 -> Ag compton <= 2.58 (peso 0.5099)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ag ka <= 5.20 (peso 0.1380)
# Mantida aresta Ag ka <= 5.20 -> Fe > -1.71 (peso 0.1951)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Ag La > -8.20 (peso 0.0181)
# Mantida aresta Ag La > -8.20 -> Ca <= -1.26 (peso 0.0339)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.3082)
# Mantida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.3165)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ca <= 1.99 (peso 0.1551)
# Mantida aresta Ca <= 1.99 -> Fe <= 2.10 (peso 0.3160)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Fe <= 2.10 (peso 0.1178)
# Mantida aresta Fe <= 2.10 -> Ag ka <= -3.39 (peso 0.1440)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> background <= 2.11 (peso 0.1339)
# Mantida aresta background <= 2.11 -> Zn > -1.89 (peso 0.1406)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Zn > -1.89 (peso 0.2992)
# Mantida aresta Zn > -1.89 -> Ca <= 1.99 (peso 0.4790)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag ka <= 5.20 (peso 0.1810)
# Mantida aresta Ag ka <= 5.20 -> Zn > -1.89 (peso 0.2095)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Zn > -1.89 (peso 0.1715)
# Mantida aresta Zn > -1.89 -> Ag compton <= 2.58 (peso 0.1720)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag ka <= -3.39 (peso 0.1262)
# Mantida aresta Ag ka <= -3.39 -> Ca <= 1.99 (peso 0.1308)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Bremsstrahlung > -3.10 (peso 0.1122)
# Mantida aresta Bremsstrahlung > -3.10 -> Ca <= 1.99 (peso 0.1848)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag ka <= -3.39 (peso 0.0557)
# Mantida aresta Ag ka <= -3.39 -> Ag Lb > 2.77 (peso 0.0740)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Ag compton <= 2.58 (peso 0.1007)
# Mantida aresta Ag compton <= 2.58 -> Bremsstrahlung > -3.10 (peso 0.4433)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Bremsstrahlung > -3.10 (peso 0.1279)
# Mantida aresta Bremsstrahlung > -3.10 -> Ag ka <= 5.20 (peso 0.3145)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Cu <= 2.01 (peso 0.0805)
# Mantida aresta Cu <= 2.01 -> Ag compton > -2.03 (peso 0.0968)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Cu <= 2.01 (peso 0.0715)
# Mantida aresta Cu <= 2.01 -> Fe > -1.30 (peso 0.1556)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Cu <= 2.01 (peso 0.0897)
# Mantida aresta Cu <= 2.01 -> Ag La > 2.83 (peso 0.0917)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Ag La > 2.83 (peso 0.0945)
# Mantida aresta Ag La > 2.83 -> Ag compton > -2.03 (peso 0.1799)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Bremsstrahlung <= -2.45 (peso 0.0427)
# Mantida aresta Bremsstrahlung <= -2.45 -> Cu <= 2.35 (peso 0.0443)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Ag Lb > 3.70 (peso 0.0180)
# Mantida aresta Ag Lb > 3.70 -> Cu <= 2.35 (peso 0.0189)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Zn > 1.85 (peso 0.0468)
# Mantida aresta Zn > 1.85 -> Ag Lb > 2.77 (peso 0.0529)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Zn > -1.35 (peso 0.0642)
# Mantida aresta Zn > -1.35 -> Ag La > 2.83 (peso 0.0678)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Ag compton <= -2.03 (peso 0.0627)
# Mantida aresta Ag compton <= -2.03 -> Ag ka <= 5.20 (peso 0.0655)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ag La > 2.83 (peso 0.0297)
# Mantida aresta Ag La > 2.83 -> Fe <= 1.63 (peso 0.0524)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Fe <= 1.63 (peso 0.0310)
# Mantida aresta Fe <= 1.63 -> Bremsstrahlung > -2.45 (peso 0.0360)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag Lb > 3.70 (peso 0.0311)
# Mantida aresta Ag Lb > 3.70 -> Bremsstrahlung > -2.45 (peso 0.0328)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Zn <= 1.85 (peso 0.0292)
# Mantida aresta Zn <= 1.85 -> Ag Lb > 3.70 (peso 0.0340)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag Lb > 3.70 (peso 0.0158)
# Mantida aresta Ag Lb > 3.70 -> Ag Lb > -6.25 (peso 0.0268)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Cu <= 2.71 (peso 0.0467)
# Mantida aresta Cu <= 2.71 -> Zn <= 1.85 (peso 0.0479)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Bremsstrahlung <= -2.45 (peso 0.0829)
# Mantida aresta Bremsstrahlung <= -2.45 -> Zn > 1.85 (peso 0.0850)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ca > -1.96 (peso 0.0387)
# Mantida aresta Ca > -1.96 -> Bremsstrahlung <= -2.45 (peso 0.0415)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe > 1.63 (peso 0.0206)
# Mantida aresta Fe > 1.63 -> Ca > -1.96 (peso 0.0242)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Cu > -2.02 (peso 0.0281)
# Mantida aresta Cu > -2.02 -> Ag Lb > -6.25 (peso 0.0485)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Zn <= -1.35 (peso 0.0222)
# Mantida aresta Zn <= -1.35 -> Ca <= -1.26 (peso 0.0392)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ca <= -1.26 (peso 0.0162)
# Mantida aresta Ca <= -1.26 -> Ag Lb > -6.25 (peso 0.0212)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Ca <= -1.26 (peso 0.0225)
# Mantida aresta Ca <= -1.26 -> Ca > 1.99 (peso 0.0244)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> Zn <= -1.35 (peso 0.0155)
# Mantida aresta Zn <= -1.35 -> background > 2.38 (peso 0.0402)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Cu > 2.35 (peso 0.0127)
# Mantida aresta Cu > 2.35 -> Ag La > 4.26 (peso 0.0128)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Bremsstrahlung > 3.06 (peso 0.0132)
# Mantida aresta Bremsstrahlung > 3.06 -> Fe <= -1.30 (peso 0.0218)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 380
# Total de arestas removidas por bidirecionalidade: 55
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#      Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0           Ag La <= 2.83        Ag La <= 2.83        Ag La <= 2.83
# 1           Ag La <= 4.26        Ag La <= 4.26        Ag La <= 4.26
# 2           Ag Lb <= 2.77        Ag Lb <= 2.77        Ag Lb <= 2.77
# 3           Ag La <= 5.23        Ag Lb <= 3.70        Ag Lb <= 3.70
# 4           Ag Lb <= 3.70        Ag La <= 5.23        Ag La <= 5.23
# ..                    ...                  ...                  ...
# 57           Ag Lb > 3.70    background > 2.38    background > 2.11
# 58  Bremsstrahlung > 3.06    background > 2.11            Cu > 2.35
# 59            Zn <= -1.35          Fe <= -1.30          Fe <= -1.30
# 60                Class_A              Class_A              Class_A
# 61                Class_B              Class_B              Class_B
#
#    Predicate_Cov_Seed_3
# 0         Ag La <= 2.83
# 1         Ag La <= 4.26
# 2         Ag Lb <= 2.77
# 3         Ag Lb <= 3.70
# 4         Ag La <= 5.23
# ..                  ...
# 57            Cu > 2.01
# 58   background > -1.72
# 59          Zn <= -1.35
# 60              Class_A
# 61              Class_B
#
# [62 rows x 4 columns]

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df = lrc_summed_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.83                  20.095455           Ag La
# 1            Ag Lb <= 2.77                  12.617765           Ag Lb
# 2            Ag ka > -3.39                   4.254481           Ag ka
# 3       Ag compton <= 3.09                   1.088527      Ag compton
# 4   Bremsstrahlung <= 3.46                   0.869578  Bremsstrahlung
# 5               Zn > -1.89                   0.605299              Zn
# 6               Fe <= 2.10                   0.593155              Fe
# 7               Ca <= 1.99                   0.518877              Ca
# 8       background <= 2.38                   0.321484      background
# 9               Cu <= 2.01                   0.259845              Cu
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator
# 0       2.83       <=
# 1       2.77       <=
# 2      -3.39        >
# 3       3.09       <=
# 4       3.46       <=
# 5      -1.89        >
# 6       2.10       <=
# 7       1.99       <=
# 8       2.38       <=
# 9       2.01       <=
# 10      None     None

# %% [markdown]
# # **Perturbation**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = pd.Series(y_pred) # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=svm_model[3],
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='mean', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        #metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        aim='classification',
        metric='probability_shift', 
        verbose=True
    )

    # Remove todos os valores iguais a zero de todos os bags em perm_results[bag]["Permutation"] e salva como perm_results_thresholded
    # pert_results_seed_thresholded = {}
    # for bag, df in perm_results_seed.items():
    #     # Verifica se é um DataFrame e se a coluna 'Permutation' existe
    #     if isinstance(df, pd.DataFrame) and 'Permutation' in df.columns:
    #         filtered_df = df[df['Permutation'] > 0].copy()
    #         pert_results_seed_thresholded[bag] = filtered_df
    #     else:
    #         # Se não for DataFrame esperado, apenas copia
    #         pert_results_seed_thresholded[bag] = df

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graphv2(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',  # ou 'Covariance' se mudar a métrica
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Tipo de tarefa (aim): classification
# Modo de perturbação: mean
# Fonte das estatísticas: full
# Métrica: probability_shift
# Total de folds: 10
#
#
# [Bag_1] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=174)
#     Zona: 18 colunas
#     Importance: 0.066815
#   Predicado: Ag La <= 2.83 (n=83)
#     Zona: 18 colunas
#     Importance: 0.233198
#   Predicado: Ag La > 2.83 (n=131)
#     Zona: 18 colunas
#     Importance: 0.053372
#   Predicado: Ag La <= 4.26 (n=126)
#     Zona: 18 colunas
#     Importance: 0.164051
#   Predicado: Ag La > 4.26 (n=88)
#     Zona: 18 colunas
#     Importance: 0.064509
#   Predicado: Ag La <= 5.23 (n=169)
#     Zona: 18 colunas
#     Importance: 0.140496
#   Predicado: Ag Lb > -6.25 (n=173)
#     Zona: 15 colunas
#     Importance: 0.046463
#   Predicado: Ag Lb <= 2.77 (n=83)
#     Zona: 15 colunas
#     Importance: 0.164813
#   Predicado: Ag Lb > 2.77 (n=131)
#     Zona: 15 colunas
#     Importance: 0.041382
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.117902
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.048236
#   Predicado: Ag Lb <= 4.33 (n=173)
#     Zona: 15 colunas
#     Importance: 0.097619
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.005033
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.003858
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.005797
#   Predicado: Ca <= 1.99 (n=127)
#     Zona: 19 colunas
#     Importance: 0.003515
#   Predicado: Ca > 1.99 (n=87)
#     Zona: 19 colunas
#     Importance: 0.007234
#   Predicado: Ca <= 2.47 (n=169)
#     Zona: 19 colunas
#     Importance: 0.003621
#   Predicado: background > -1.72 (n=176)
#     Zona: 87 colunas
#     Importance: 0.012700
#   Predicado: background <= 2.11 (n=82)
#     Zona: 87 colunas
#     Importance: 0.014732
#   Predicado: background > 2.11 (n=132)
#     Zona: 87 colunas
#     Importance: 0.012185
#   Predicado: background <= 2.38 (n=123)
#     Zona: 87 colunas
#     Importance: 0.012962
#   Predicado: background > 2.38 (n=91)
#     Zona: 87 colunas
#     Importance: 0.013430
#   Predicado: background <= 2.73 (n=170)
#     Zona: 87 colunas
#     Importance: 0.013080
#   Predicado: Fe > -1.71 (n=174)
#     Zona: 23 colunas
#     Importance: 0.006202
#   Predicado: Fe <= -1.30 (n=80)
#     Zona: 23 colunas
#     Importance: 0.005885
#   Predicado: Fe > -1.30 (n=134)
#     Zona: 23 colunas
#     Importance: 0.006592
#   Predicado: Fe <= 1.63 (n=125)
#     Zona: 23 colunas
#     Importance: 0.005353
#   Predicado: Fe > 1.63 (n=89)
#     Zona: 23 colunas
#     Importance: 0.007696
#   Predicado: Fe <= 2.10 (n=170)
#     Zona: 23 colunas
#     Importance: 0.005562
#   Predicado: Cu > -2.02 (n=169)
#     Zona: 66 colunas
#     Importance: 0.009505
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.009348
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.010287
#   Predicado: Cu <= 2.35 (n=134)
#     Zona: 66 colunas
#     Importance: 0.009378
#   Predicado: Cu > 2.35 (n=80)
#     Zona: 66 colunas
#     Importance: 0.010823
#   Predicado: Cu <= 2.71 (n=174)
#     Zona: 66 colunas
#     Importance: 0.008832
#   Predicado: Zn > -1.89 (n=170)
#     Zona: 29 colunas
#     Importance: 0.007010
#   Predicado: Zn <= -1.35 (n=91)
#     Zona: 29 colunas
#     Importance: 0.008926
#   Predicado: Zn > -1.35 (n=123)
#     Zona: 29 colunas
#     Importance: 0.007339
#   Predicado: Zn <= 1.85 (n=131)
#     Zona: 29 colunas
#     Importance: 0.007935
#   Predicado: Zn > 1.85 (n=83)
#     Zona: 29 colunas
#     Importance: 0.008139
#   Predicado: Zn <= 2.28 (n=174)
#     Zona: 29 colunas
#     Importance: 0.007540
#   Predicado: Bremsstrahlung > -3.10 (n=175)
#     Zona: 429 colunas
#     Importance: 0.078176
#   Predicado: Bremsstrahlung <= -2.45 (n=87)
#     Zona: 429 colunas
#     Importance: 0.103209
#   Predicado: Bremsstrahlung > -2.45 (n=127)
#     Zona: 429 colunas
#     Importance: 0.071524
#   Predicado: Bremsstrahlung <= 3.06 (n=127)
#     Zona: 429 colunas
#     Importance: 0.095767
#   Predicado: Bremsstrahlung > 3.06 (n=87)
#     Zona: 429 colunas
#     Importance: 0.067820
#   Predicado: Bremsstrahlung <= 3.46 (n=167)
#     Zona: 429 colunas
#     Importance: 0.084870
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.019809
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.021692
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.018754
#   Predicado: Ag compton <= 2.58 (n=128)
#     Zona: 62 colunas
#     Importance: 0.020409
#   Predicado: Ag compton > 2.58 (n=86)
#     Zona: 62 colunas
#     Importance: 0.019194
#   Predicado: Ag compton <= 3.09 (n=171)
#     Zona: 62 colunas
#     Importance: 0.019036
#   Predicado: Ag ka > -7.93 (n=169)
#     Zona: 45 colunas
#     Importance: 0.106674
#   Predicado: Ag ka <= -3.39 (n=85)
#     Zona: 45 colunas
#     Importance: 0.118264
#   Predicado: Ag ka > -3.39 (n=129)
#     Zona: 45 colunas
#     Importance: 0.102323
#   Predicado: Ag ka <= 5.20 (n=125)
#     Zona: 45 colunas
#     Importance: 0.110748
#   Predicado: Ag ka > 5.20 (n=89)
#     Zona: 45 colunas
#     Importance: 0.105715
#   Predicado: Ag ka <= 10.15 (n=172)
#     Zona: 45 colunas
#     Importance: 0.096203
#
# [Bag_2] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=170)
#     Zona: 18 colunas
#     Importance: 0.065582
#   Predicado: Ag La <= 2.83 (n=88)
#     Zona: 18 colunas
#     Importance: 0.243686
#   Predicado: Ag La > 2.83 (n=126)
#     Zona: 18 colunas
#     Importance: 0.051230
#   Predicado: Ag La <= 4.26 (n=132)
#     Zona: 18 colunas
#     Importance: 0.173284
#   Predicado: Ag La > 4.26 (n=82)
#     Zona: 18 colunas
#     Importance: 0.061291
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.147730
#   Predicado: Ag Lb > -6.25 (n=169)
#     Zona: 15 colunas
#     Importance: 0.045936
#   Predicado: Ag Lb <= 2.77 (n=87)
#     Zona: 15 colunas
#     Importance: 0.169791
#   Predicado: Ag Lb > 2.77 (n=127)
#     Zona: 15 colunas
#     Importance: 0.039151
#   Predicado: Ag Lb <= 3.70 (n=130)
#     Zona: 15 colunas
#     Importance: 0.122391
#   Predicado: Ag Lb > 3.70 (n=84)
#     Zona: 15 colunas
#     Importance: 0.045633
#   Predicado: Ag Lb <= 4.33 (n=175)
#     Zona: 15 colunas
#     Importance: 0.102729
#   Predicado: Ca > -1.96 (n=173)
#     Zona: 19 colunas
#     Importance: 0.005000
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.003677
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.005695
#   Predicado: Ca <= 1.99 (n=129)
#     Zona: 19 colunas
#     Importance: 0.003484
#   Predicado: Ca > 1.99 (n=85)
#     Zona: 19 colunas
#     Importance: 0.007010
#   Predicado: Ca <= 2.47 (n=173)
#     Zona: 19 colunas
#     Importance: 0.003520
#   Predicado: background > -1.72 (n=168)
#     Zona: 87 colunas
#     Importance: 0.011378
#   Predicado: background <= 2.11 (n=89)
#     Zona: 87 colunas
#     Importance: 0.014516
#   Predicado: background > 2.11 (n=125)
#     Zona: 87 colunas
#     Importance: 0.010747
#   Predicado: background <= 2.38 (n=133)
#     Zona: 87 colunas
#     Importance: 0.012596
#   Predicado: background > 2.38 (n=81)
#     Zona: 87 colunas
#     Importance: 0.011852
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012599
#   Predicado: Fe > -1.71 (n=173)
#     Zona: 23 colunas
#     Importance: 0.006053
#   Predicado: Fe <= -1.30 (n=85)
#     Zona: 23 colunas
#     Importance: 0.005613
#   Predicado: Fe > -1.30 (n=129)
#     Zona: 23 colunas
#     Importance: 0.006461
#   Predicado: Fe <= 1.63 (n=127)
#     Zona: 23 colunas
#     Importance: 0.005160
#   Predicado: Fe > 1.63 (n=87)
#     Zona: 23 colunas
#     Importance: 0.007532
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.005415
#   Predicado: Cu > -2.02 (n=173)
#     Zona: 66 colunas
#     Importance: 0.008843
#   Predicado: Cu <= 2.01 (n=81)
#     Zona: 66 colunas
#     Importance: 0.008478
#   Predicado: Cu > 2.01 (n=133)
#     Zona: 66 colunas
#     Importance: 0.009615
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.008633
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.009973
#   Predicado: Cu <= 2.71 (n=168)
#     Zona: 66 colunas
#     Importance: 0.007919
#   Predicado: Zn > -1.89 (n=174)
#     Zona: 29 colunas
#     Importance: 0.006530
#   Predicado: Zn <= -1.35 (n=86)
#     Zona: 29 colunas
#     Importance: 0.009398
#   Predicado: Zn > -1.35 (n=128)
#     Zona: 29 colunas
#     Importance: 0.006199
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007887
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.006861
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.007458
#   Predicado: Bremsstrahlung > -3.10 (n=173)
#     Zona: 429 colunas
#     Importance: 0.073324
#   Predicado: Bremsstrahlung <= -2.45 (n=88)
#     Zona: 429 colunas
#     Importance: 0.099934
#   Predicado: Bremsstrahlung > -2.45 (n=126)
#     Zona: 429 colunas
#     Importance: 0.065735
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.091280
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.062029
#   Predicado: Bremsstrahlung <= 3.46 (n=176)
#     Zona: 429 colunas
#     Importance: 0.079134
#   Predicado: Ag compton > -2.89 (n=171)
#     Zona: 62 colunas
#     Importance: 0.019009
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.022232
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.018045
#   Predicado: Ag compton <= 2.58 (n=128)
#     Zona: 62 colunas
#     Importance: 0.019937
#   Predicado: Ag compton > 2.58 (n=86)
#     Zona: 62 colunas
#     Importance: 0.019366
#   Predicado: Ag compton <= 3.09 (n=172)
#     Zona: 62 colunas
#     Importance: 0.018865
#   Predicado: Ag ka > -7.93 (n=168)
#     Zona: 45 colunas
#     Importance: 0.113739
#   Predicado: Ag ka <= -3.39 (n=86)
#     Zona: 45 colunas
#     Importance: 0.116763
#   Predicado: Ag ka > -3.39 (n=128)
#     Zona: 45 colunas
#     Importance: 0.116403
#   Predicado: Ag ka <= 5.20 (n=124)
#     Zona: 45 colunas
#     Importance: 0.115042
#   Predicado: Ag ka > 5.20 (n=90)
#     Zona: 45 colunas
#     Importance: 0.118621
#   Predicado: Ag ka <= 10.15 (n=166)
#     Zona: 45 colunas
#     Importance: 0.098918
#
# [Bag_3] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=175)
#     Zona: 18 colunas
#     Importance: 0.068875
#   Predicado: Ag La <= 2.83 (n=84)
#     Zona: 18 colunas
#     Importance: 0.232448
#   Predicado: Ag La > 2.83 (n=130)
#     Zona: 18 colunas
#     Importance: 0.050919
#   Predicado: Ag La <= 4.26 (n=126)
#     Zona: 18 colunas
#     Importance: 0.165258
#   Predicado: Ag La > 4.26 (n=88)
#     Zona: 18 colunas
#     Importance: 0.060484
#   Predicado: Ag La <= 5.23 (n=168)
#     Zona: 18 colunas
#     Importance: 0.140074
#   Predicado: Ag Lb > -6.25 (n=174)
#     Zona: 15 colunas
#     Importance: 0.047803
#   Predicado: Ag Lb <= 2.77 (n=84)
#     Zona: 15 colunas
#     Importance: 0.158488
#   Predicado: Ag Lb > 2.77 (n=130)
#     Zona: 15 colunas
#     Importance: 0.041131
#   Predicado: Ag Lb <= 3.70 (n=129)
#     Zona: 15 colunas
#     Importance: 0.112299
#   Predicado: Ag Lb > 3.70 (n=85)
#     Zona: 15 colunas
#     Importance: 0.049099
#   Predicado: Ag Lb <= 4.33 (n=172)
#     Zona: 15 colunas
#     Importance: 0.095896
#   Predicado: Ca > -1.96 (n=174)
#     Zona: 19 colunas
#     Importance: 0.005130
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.003824
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.005865
#   Predicado: Ca <= 1.99 (n=132)
#     Zona: 19 colunas
#     Importance: 0.003492
#   Predicado: Ca > 1.99 (n=82)
#     Zona: 19 colunas
#     Importance: 0.007545
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003681
#   Predicado: background > -1.72 (n=168)
#     Zona: 87 colunas
#     Importance: 0.011512
#   Predicado: background <= 2.11 (n=88)
#     Zona: 87 colunas
#     Importance: 0.014153
#   Predicado: background > 2.11 (n=126)
#     Zona: 87 colunas
#     Importance: 0.011271
#   Predicado: background <= 2.38 (n=128)
#     Zona: 87 colunas
#     Importance: 0.012489
#   Predicado: background > 2.38 (n=86)
#     Zona: 87 colunas
#     Importance: 0.012408
#   Predicado: background <= 2.73 (n=171)
#     Zona: 87 colunas
#     Importance: 0.012275
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.005662
#   Predicado: Fe <= -1.30 (n=87)
#     Zona: 23 colunas
#     Importance: 0.006393
#   Predicado: Fe > -1.30 (n=127)
#     Zona: 23 colunas
#     Importance: 0.006006
#   Predicado: Fe <= 1.63 (n=128)
#     Zona: 23 colunas
#     Importance: 0.005426
#   Predicado: Fe > 1.63 (n=86)
#     Zona: 23 colunas
#     Importance: 0.007260
#   Predicado: Fe <= 2.10 (n=170)
#     Zona: 23 colunas
#     Importance: 0.005437
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009393
#   Predicado: Cu <= 2.01 (n=86)
#     Zona: 66 colunas
#     Importance: 0.009530
#   Predicado: Cu > 2.01 (n=128)
#     Zona: 66 colunas
#     Importance: 0.010286
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.009855
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.010164
#   Predicado: Cu <= 2.71 (n=167)
#     Zona: 66 colunas
#     Importance: 0.009382
#   Predicado: Zn > -1.89 (n=169)
#     Zona: 29 colunas
#     Importance: 0.006921
#   Predicado: Zn <= -1.35 (n=87)
#     Zona: 29 colunas
#     Importance: 0.008523
#   Predicado: Zn > -1.35 (n=127)
#     Zona: 29 colunas
#     Importance: 0.006876
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007389
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.007788
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.007008
#   Predicado: Bremsstrahlung > -3.10 (n=170)
#     Zona: 429 colunas
#     Importance: 0.075962
#   Predicado: Bremsstrahlung <= -2.45 (n=87)
#     Zona: 429 colunas
#     Importance: 0.090688
#   Predicado: Bremsstrahlung > -2.45 (n=127)
#     Zona: 429 colunas
#     Importance: 0.073979
#   Predicado: Bremsstrahlung <= 3.06 (n=127)
#     Zona: 429 colunas
#     Importance: 0.090664
#   Predicado: Bremsstrahlung > 3.06 (n=87)
#     Zona: 429 colunas
#     Importance: 0.066332
#   Predicado: Bremsstrahlung <= 3.46 (n=169)
#     Zona: 429 colunas
#     Importance: 0.080625
#   Predicado: Ag compton > -2.89 (n=169)
#     Zona: 62 colunas
#     Importance: 0.019018
#   Predicado: Ag compton <= -2.03 (n=88)
#     Zona: 62 colunas
#     Importance: 0.020895
#   Predicado: Ag compton > -2.03 (n=126)
#     Zona: 62 colunas
#     Importance: 0.018150
#   Predicado: Ag compton <= 2.58 (n=130)
#     Zona: 62 colunas
#     Importance: 0.018974
#   Predicado: Ag compton > 2.58 (n=84)
#     Zona: 62 colunas
#     Importance: 0.019751
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.018544
#   Predicado: Ag ka > -7.93 (n=169)
#     Zona: 45 colunas
#     Importance: 0.113903
#   Predicado: Ag ka <= -3.39 (n=89)
#     Zona: 45 colunas
#     Importance: 0.119233
#   Predicado: Ag ka > -3.39 (n=125)
#     Zona: 45 colunas
#     Importance: 0.112633
#   Predicado: Ag ka <= 5.20 (n=132)
#     Zona: 45 colunas
#     Importance: 0.109493
#   Predicado: Ag ka > 5.20 (n=82)
#     Zona: 45 colunas
#     Importance: 0.124851
#   Predicado: Ag ka <= 10.15 (n=170)
#     Zona: 45 colunas
#     Importance: 0.098387
#
# [Bag_4] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.070616
#   Predicado: Ag La <= 2.83 (n=85)
#     Zona: 18 colunas
#     Importance: 0.239259
#   Predicado: Ag La > 2.83 (n=129)
#     Zona: 18 colunas
#     Importance: 0.055623
#   Predicado: Ag La <= 4.26 (n=130)
#     Zona: 18 colunas
#     Importance: 0.168301
#   Predicado: Ag La > 4.26 (n=84)
#     Zona: 18 colunas
#     Importance: 0.067063
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.144494
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.048742
#   Predicado: Ag Lb <= 2.77 (n=87)
#     Zona: 15 colunas
#     Importance: 0.163296
#   Predicado: Ag Lb > 2.77 (n=127)
#     Zona: 15 colunas
#     Importance: 0.044474
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.122126
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.050763
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.103545
#   Predicado: Ca > -1.96 (n=168)
#     Zona: 19 colunas
#     Importance: 0.005507
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.004056
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.006299
#   Predicado: Ca <= 1.99 (n=130)
#     Zona: 19 colunas
#     Importance: 0.003673
#   Predicado: Ca > 1.99 (n=84)
#     Zona: 19 colunas
#     Importance: 0.008067
#   Predicado: Ca <= 2.47 (n=173)
#     Zona: 19 colunas
#     Importance: 0.003913
#   Predicado: background > -1.72 (n=174)
#     Zona: 87 colunas
#     Importance: 0.013142
#   Predicado: background <= 2.11 (n=82)
#     Zona: 87 colunas
#     Importance: 0.014591
#   Predicado: background > 2.11 (n=132)
#     Zona: 87 colunas
#     Importance: 0.012521
#   Predicado: background <= 2.38 (n=126)
#     Zona: 87 colunas
#     Importance: 0.012796
#   Predicado: background > 2.38 (n=88)
#     Zona: 87 colunas
#     Importance: 0.014057
#   Predicado: background <= 2.73 (n=167)
#     Zona: 87 colunas
#     Importance: 0.013037
#   Predicado: Fe > -1.71 (n=179)
#     Zona: 23 colunas
#     Importance: 0.006342
#   Predicado: Fe <= -1.30 (n=78)
#     Zona: 23 colunas
#     Importance: 0.005553
#   Predicado: Fe > -1.30 (n=136)
#     Zona: 23 colunas
#     Importance: 0.006849
#   Predicado: Fe <= 1.63 (n=119)
#     Zona: 23 colunas
#     Importance: 0.005168
#   Predicado: Fe > 1.63 (n=95)
#     Zona: 23 colunas
#     Importance: 0.007892
#   Predicado: Fe <= 2.10 (n=169)
#     Zona: 23 colunas
#     Importance: 0.005403
#   Predicado: Cu > -2.02 (n=175)
#     Zona: 66 colunas
#     Importance: 0.009670
#   Predicado: Cu <= 2.01 (n=80)
#     Zona: 66 colunas
#     Importance: 0.009076
#   Predicado: Cu > 2.01 (n=134)
#     Zona: 66 colunas
#     Importance: 0.010749
#   Predicado: Cu <= 2.35 (n=125)
#     Zona: 66 colunas
#     Importance: 0.009606
#   Predicado: Cu > 2.35 (n=89)
#     Zona: 66 colunas
#     Importance: 0.010850
#   Predicado: Cu <= 2.71 (n=167)
#     Zona: 66 colunas
#     Importance: 0.009155
#   Predicado: Zn > -1.89 (n=177)
#     Zona: 29 colunas
#     Importance: 0.007002
#   Predicado: Zn <= -1.35 (n=84)
#     Zona: 29 colunas
#     Importance: 0.009314
#   Predicado: Zn > -1.35 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007175
#   Predicado: Zn <= 1.85 (n=128)
#     Zona: 29 colunas
#     Importance: 0.007967
#   Predicado: Zn > 1.85 (n=86)
#     Zona: 29 colunas
#     Importance: 0.008085
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.007582
#   Predicado: Bremsstrahlung > -3.10 (n=174)
#     Zona: 429 colunas
#     Importance: 0.073683
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.095840
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.069027
#   Predicado: Bremsstrahlung <= 3.06 (n=129)
#     Zona: 429 colunas
#     Importance: 0.090381
#   Predicado: Bremsstrahlung > 3.06 (n=85)
#     Zona: 429 colunas
#     Importance: 0.063433
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.080291
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.018409
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.021465
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.017681
#   Predicado: Ag compton <= 2.58 (n=131)
#     Zona: 62 colunas
#     Importance: 0.019500
#   Predicado: Ag compton > 2.58 (n=83)
#     Zona: 62 colunas
#     Importance: 0.018686
#   Predicado: Ag compton <= 3.09 (n=172)
#     Zona: 62 colunas
#     Importance: 0.018759
#   Predicado: Ag ka > -7.93 (n=167)
#     Zona: 45 colunas
#     Importance: 0.115213
#   Predicado: Ag ka <= -3.39 (n=87)
#     Zona: 45 colunas
#     Importance: 0.119671
#   Predicado: Ag ka > -3.39 (n=127)
#     Zona: 45 colunas
#     Importance: 0.108199
#   Predicado: Ag ka <= 5.20 (n=133)
#     Zona: 45 colunas
#     Importance: 0.112393
#   Predicado: Ag ka > 5.20 (n=81)
#     Zona: 45 colunas
#     Importance: 0.113634
#   Predicado: Ag ka <= 10.15 (n=175)
#     Zona: 45 colunas
#     Importance: 0.099512
#
# [Bag_5] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=169)
#     Zona: 18 colunas
#     Importance: 0.065958
#   Predicado: Ag La <= 2.83 (n=86)
#     Zona: 18 colunas
#     Importance: 0.242814
#   Predicado: Ag La > 2.83 (n=128)
#     Zona: 18 colunas
#     Importance: 0.053378
#   Predicado: Ag La <= 4.26 (n=127)
#     Zona: 18 colunas
#     Importance: 0.173737
#   Predicado: Ag La > 4.26 (n=87)
#     Zona: 18 colunas
#     Importance: 0.064939
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.146127
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.048572
#   Predicado: Ag Lb <= 2.77 (n=88)
#     Zona: 15 colunas
#     Importance: 0.164489
#   Predicado: Ag Lb > 2.77 (n=126)
#     Zona: 15 colunas
#     Importance: 0.041030
#   Predicado: Ag Lb <= 3.70 (n=133)
#     Zona: 15 colunas
#     Importance: 0.118323
#   Predicado: Ag Lb > 3.70 (n=81)
#     Zona: 15 colunas
#     Importance: 0.048246
#   Predicado: Ag Lb <= 4.33 (n=176)
#     Zona: 15 colunas
#     Importance: 0.101070
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.005089
#   Predicado: Ca <= -1.26 (n=84)
#     Zona: 19 colunas
#     Importance: 0.003630
#   Predicado: Ca > -1.26 (n=130)
#     Zona: 19 colunas
#     Importance: 0.005803
#   Predicado: Ca <= 1.99 (n=130)
#     Zona: 19 colunas
#     Importance: 0.003436
#   Predicado: Ca > 1.99 (n=84)
#     Zona: 19 colunas
#     Importance: 0.007293
#   Predicado: Ca <= 2.47 (n=172)
#     Zona: 19 colunas
#     Importance: 0.003750
#   Predicado: background > -1.72 (n=170)
#     Zona: 87 colunas
#     Importance: 0.012294
#   Predicado: background <= 2.11 (n=85)
#     Zona: 87 colunas
#     Importance: 0.014164
#   Predicado: background > 2.11 (n=129)
#     Zona: 87 colunas
#     Importance: 0.012247
#   Predicado: background <= 2.38 (n=125)
#     Zona: 87 colunas
#     Importance: 0.012692
#   Predicado: background > 2.38 (n=89)
#     Zona: 87 colunas
#     Importance: 0.013452
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.013070
#   Predicado: Fe > -1.71 (n=172)
#     Zona: 23 colunas
#     Importance: 0.006356
#   Predicado: Fe <= -1.30 (n=80)
#     Zona: 23 colunas
#     Importance: 0.006098
#   Predicado: Fe > -1.30 (n=134)
#     Zona: 23 colunas
#     Importance: 0.006866
#   Predicado: Fe <= 1.63 (n=120)
#     Zona: 23 colunas
#     Importance: 0.005612
#   Predicado: Fe > 1.63 (n=94)
#     Zona: 23 colunas
#     Importance: 0.007813
#   Predicado: Fe <= 2.10 (n=168)
#     Zona: 23 colunas
#     Importance: 0.005622
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009352
#   Predicado: Cu <= 2.01 (n=83)
#     Zona: 66 colunas
#     Importance: 0.009231
#   Predicado: Cu > 2.01 (n=131)
#     Zona: 66 colunas
#     Importance: 0.010333
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.009825
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.010021
#   Predicado: Cu <= 2.71 (n=169)
#     Zona: 66 colunas
#     Importance: 0.009195
#   Predicado: Zn > -1.89 (n=171)
#     Zona: 29 colunas
#     Importance: 0.006864
#   Predicado: Zn <= -1.35 (n=88)
#     Zona: 29 colunas
#     Importance: 0.009399
#   Predicado: Zn > -1.35 (n=126)
#     Zona: 29 colunas
#     Importance: 0.006839
#   Predicado: Zn <= 1.85 (n=134)
#     Zona: 29 colunas
#     Importance: 0.007940
#   Predicado: Zn > 1.85 (n=80)
#     Zona: 29 colunas
#     Importance: 0.007811
#   Predicado: Zn <= 2.28 (n=175)
#     Zona: 29 colunas
#     Importance: 0.007591
#   Predicado: Bremsstrahlung > -3.10 (n=171)
#     Zona: 429 colunas
#     Importance: 0.077154
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.094516
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.072730
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.089248
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.069212
#   Predicado: Bremsstrahlung <= 3.46 (n=174)
#     Zona: 429 colunas
#     Importance: 0.080621
#   Predicado: Ag compton > -2.89 (n=170)
#     Zona: 62 colunas
#     Importance: 0.019178
#   Predicado: Ag compton <= -2.03 (n=87)
#     Zona: 62 colunas
#     Importance: 0.021450
#   Predicado: Ag compton > -2.03 (n=127)
#     Zona: 62 colunas
#     Importance: 0.018814
#   Predicado: Ag compton <= 2.58 (n=133)
#     Zona: 62 colunas
#     Importance: 0.019784
#   Predicado: Ag compton > 2.58 (n=81)
#     Zona: 62 colunas
#     Importance: 0.020053
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.018893
#   Predicado: Ag ka > -7.93 (n=168)
#     Zona: 45 colunas
#     Importance: 0.114229
#   Predicado: Ag ka <= -3.39 (n=81)
#     Zona: 45 colunas
#     Importance: 0.114028
#   Predicado: Ag ka > -3.39 (n=133)
#     Zona: 45 colunas
#     Importance: 0.116714
#   Predicado: Ag ka <= 5.20 (n=126)
#     Zona: 45 colunas
#     Importance: 0.108613
#   Predicado: Ag ka > 5.20 (n=88)
#     Zona: 45 colunas
#     Importance: 0.125840
#   Predicado: Ag ka <= 10.15 (n=170)
#     Zona: 45 colunas
#     Importance: 0.095558
#
# [Bag_6] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=170)
#     Zona: 18 colunas
#     Importance: 0.067883
#   Predicado: Ag La <= 2.83 (n=83)
#     Zona: 18 colunas
#     Importance: 0.247752
#   Predicado: Ag La > 2.83 (n=131)
#     Zona: 18 colunas
#     Importance: 0.056724
#   Predicado: Ag La <= 4.26 (n=125)
#     Zona: 18 colunas
#     Importance: 0.175557
#   Predicado: Ag La > 4.26 (n=89)
#     Zona: 18 colunas
#     Importance: 0.067974
#   Predicado: Ag La <= 5.23 (n=170)
#     Zona: 18 colunas
#     Importance: 0.147453
#   Predicado: Ag Lb > -6.25 (n=169)
#     Zona: 15 colunas
#     Importance: 0.047210
#   Predicado: Ag Lb <= 2.77 (n=85)
#     Zona: 15 colunas
#     Importance: 0.169696
#   Predicado: Ag Lb > 2.77 (n=129)
#     Zona: 15 colunas
#     Importance: 0.046261
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.124942
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.052831
#   Predicado: Ag Lb <= 4.33 (n=171)
#     Zona: 15 colunas
#     Importance: 0.105204
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.005015
#   Predicado: Ca <= -1.26 (n=83)
#     Zona: 19 colunas
#     Importance: 0.003792
#   Predicado: Ca > -1.26 (n=131)
#     Zona: 19 colunas
#     Importance: 0.005554
#   Predicado: Ca <= 1.99 (n=129)
#     Zona: 19 colunas
#     Importance: 0.003477
#   Predicado: Ca > 1.99 (n=85)
#     Zona: 19 colunas
#     Importance: 0.006985
#   Predicado: Ca <= 2.47 (n=170)
#     Zona: 19 colunas
#     Importance: 0.003809
#   Predicado: background > -1.72 (n=165)
#     Zona: 87 colunas
#     Importance: 0.012556
#   Predicado: background <= 2.11 (n=94)
#     Zona: 87 colunas
#     Importance: 0.013945
#   Predicado: background > 2.11 (n=120)
#     Zona: 87 colunas
#     Importance: 0.012116
#   Predicado: background <= 2.38 (n=133)
#     Zona: 87 colunas
#     Importance: 0.012075
#   Predicado: background > 2.38 (n=81)
#     Zona: 87 colunas
#     Importance: 0.014306
#   Predicado: background <= 2.73 (n=175)
#     Zona: 87 colunas
#     Importance: 0.012464
#   Predicado: Fe > -1.71 (n=173)
#     Zona: 23 colunas
#     Importance: 0.006496
#   Predicado: Fe <= -1.30 (n=89)
#     Zona: 23 colunas
#     Importance: 0.006662
#   Predicado: Fe > -1.30 (n=125)
#     Zona: 23 colunas
#     Importance: 0.007104
#   Predicado: Fe <= 1.63 (n=132)
#     Zona: 23 colunas
#     Importance: 0.005976
#   Predicado: Fe > 1.63 (n=82)
#     Zona: 23 colunas
#     Importance: 0.008439
#   Predicado: Fe <= 2.10 (n=173)
#     Zona: 23 colunas
#     Importance: 0.006190
#   Predicado: Cu > -2.02 (n=166)
#     Zona: 66 colunas
#     Importance: 0.009575
#   Predicado: Cu <= 2.01 (n=87)
#     Zona: 66 colunas
#     Importance: 0.009818
#   Predicado: Cu > 2.01 (n=127)
#     Zona: 66 colunas
#     Importance: 0.010231
#   Predicado: Cu <= 2.35 (n=131)
#     Zona: 66 colunas
#     Importance: 0.009852
#   Predicado: Cu > 2.35 (n=83)
#     Zona: 66 colunas
#     Importance: 0.010395
#   Predicado: Cu <= 2.71 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009351
#   Predicado: Zn > -1.89 (n=167)
#     Zona: 29 colunas
#     Importance: 0.007157
#   Predicado: Zn <= -1.35 (n=88)
#     Zona: 29 colunas
#     Importance: 0.009365
#   Predicado: Zn > -1.35 (n=126)
#     Zona: 29 colunas
#     Importance: 0.007151
#   Predicado: Zn <= 1.85 (n=127)
#     Zona: 29 colunas
#     Importance: 0.008005
#   Predicado: Zn > 1.85 (n=87)
#     Zona: 29 colunas
#     Importance: 0.008145
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.007702
#   Predicado: Bremsstrahlung > -3.10 (n=169)
#     Zona: 429 colunas
#     Importance: 0.079965
#   Predicado: Bremsstrahlung <= -2.45 (n=93)
#     Zona: 429 colunas
#     Importance: 0.097240
#   Predicado: Bremsstrahlung > -2.45 (n=121)
#     Zona: 429 colunas
#     Importance: 0.074429
#   Predicado: Bremsstrahlung <= 3.06 (n=135)
#     Zona: 429 colunas
#     Importance: 0.091590
#   Predicado: Bremsstrahlung > 3.06 (n=79)
#     Zona: 429 colunas
#     Importance: 0.071957
#   Predicado: Bremsstrahlung <= 3.46 (n=176)
#     Zona: 429 colunas
#     Importance: 0.081966
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.019124
#   Predicado: Ag compton <= -2.03 (n=89)
#     Zona: 62 colunas
#     Importance: 0.019777
#   Predicado: Ag compton > -2.03 (n=125)
#     Zona: 62 colunas
#     Importance: 0.017770
#   Predicado: Ag compton <= 2.58 (n=132)
#     Zona: 62 colunas
#     Importance: 0.018987
#   Predicado: Ag compton > 2.58 (n=82)
#     Zona: 62 colunas
#     Importance: 0.017988
#   Predicado: Ag compton <= 3.09 (n=176)
#     Zona: 62 colunas
#     Importance: 0.017908
#   Predicado: Ag ka > -7.93 (n=170)
#     Zona: 45 colunas
#     Importance: 0.113611
#   Predicado: Ag ka <= -3.39 (n=81)
#     Zona: 45 colunas
#     Importance: 0.120318
#   Predicado: Ag ka > -3.39 (n=133)
#     Zona: 45 colunas
#     Importance: 0.111016
#   Predicado: Ag ka <= 5.20 (n=129)
#     Zona: 45 colunas
#     Importance: 0.113469
#   Predicado: Ag ka > 5.20 (n=85)
#     Zona: 45 colunas
#     Importance: 0.116156
#   Predicado: Ag ka <= 10.15 (n=174)
#     Zona: 45 colunas
#     Importance: 0.098691
#
# [Bag_7] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.069654
#   Predicado: Ag La <= 2.83 (n=86)
#     Zona: 18 colunas
#     Importance: 0.251292
#   Predicado: Ag La > 2.83 (n=128)
#     Zona: 18 colunas
#     Importance: 0.052980
#   Predicado: Ag La <= 4.26 (n=127)
#     Zona: 18 colunas
#     Importance: 0.179554
#   Predicado: Ag La > 4.26 (n=87)
#     Zona: 18 colunas
#     Importance: 0.064244
#   Predicado: Ag La <= 5.23 (n=174)
#     Zona: 18 colunas
#     Importance: 0.149220
#   Predicado: Ag Lb > -6.25 (n=173)
#     Zona: 15 colunas
#     Importance: 0.052008
#   Predicado: Ag Lb <= 2.77 (n=88)
#     Zona: 15 colunas
#     Importance: 0.167978
#   Predicado: Ag Lb > 2.77 (n=126)
#     Zona: 15 colunas
#     Importance: 0.042812
#   Predicado: Ag Lb <= 3.70 (n=131)
#     Zona: 15 colunas
#     Importance: 0.122130
#   Predicado: Ag Lb > 3.70 (n=83)
#     Zona: 15 colunas
#     Importance: 0.050330
#   Predicado: Ag Lb <= 4.33 (n=172)
#     Zona: 15 colunas
#     Importance: 0.104415
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.005327
#   Predicado: Ca <= -1.26 (n=83)
#     Zona: 19 colunas
#     Importance: 0.004019
#   Predicado: Ca > -1.26 (n=131)
#     Zona: 19 colunas
#     Importance: 0.005968
#   Predicado: Ca <= 1.99 (n=125)
#     Zona: 19 colunas
#     Importance: 0.003739
#   Predicado: Ca > 1.99 (n=89)
#     Zona: 19 colunas
#     Importance: 0.007281
#   Predicado: Ca <= 2.47 (n=170)
#     Zona: 19 colunas
#     Importance: 0.003793
#   Predicado: background > -1.72 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012279
#   Predicado: background <= 2.11 (n=85)
#     Zona: 87 colunas
#     Importance: 0.015155
#   Predicado: background > 2.11 (n=129)
#     Zona: 87 colunas
#     Importance: 0.011520
#   Predicado: background <= 2.38 (n=129)
#     Zona: 87 colunas
#     Importance: 0.012777
#   Predicado: background > 2.38 (n=85)
#     Zona: 87 colunas
#     Importance: 0.013248
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012375
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.006291
#   Predicado: Fe <= -1.30 (n=83)
#     Zona: 23 colunas
#     Importance: 0.006226
#   Predicado: Fe > -1.30 (n=131)
#     Zona: 23 colunas
#     Importance: 0.006710
#   Predicado: Fe <= 1.63 (n=123)
#     Zona: 23 colunas
#     Importance: 0.005343
#   Predicado: Fe > 1.63 (n=91)
#     Zona: 23 colunas
#     Importance: 0.008116
#   Predicado: Fe <= 2.10 (n=172)
#     Zona: 23 colunas
#     Importance: 0.005527
#   Predicado: Cu > -2.02 (n=173)
#     Zona: 66 colunas
#     Importance: 0.009082
#   Predicado: Cu <= 2.01 (n=86)
#     Zona: 66 colunas
#     Importance: 0.009661
#   Predicado: Cu > 2.01 (n=128)
#     Zona: 66 colunas
#     Importance: 0.010001
#   Predicado: Cu <= 2.35 (n=130)
#     Zona: 66 colunas
#     Importance: 0.009695
#   Predicado: Cu > 2.35 (n=84)
#     Zona: 66 colunas
#     Importance: 0.010127
#   Predicado: Cu <= 2.71 (n=174)
#     Zona: 66 colunas
#     Importance: 0.008859
#   Predicado: Zn > -1.89 (n=169)
#     Zona: 29 colunas
#     Importance: 0.007258
#   Predicado: Zn <= -1.35 (n=86)
#     Zona: 29 colunas
#     Importance: 0.009006
#   Predicado: Zn > -1.35 (n=128)
#     Zona: 29 colunas
#     Importance: 0.007121
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.007811
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.007982
#   Predicado: Zn <= 2.28 (n=170)
#     Zona: 29 colunas
#     Importance: 0.007380
#   Predicado: Bremsstrahlung > -3.10 (n=175)
#     Zona: 429 colunas
#     Importance: 0.074995
#   Predicado: Bremsstrahlung <= -2.45 (n=82)
#     Zona: 429 colunas
#     Importance: 0.099528
#   Predicado: Bremsstrahlung > -2.45 (n=132)
#     Zona: 429 colunas
#     Importance: 0.069755
#   Predicado: Bremsstrahlung <= 3.06 (n=128)
#     Zona: 429 colunas
#     Importance: 0.091432
#   Predicado: Bremsstrahlung > 3.06 (n=86)
#     Zona: 429 colunas
#     Importance: 0.065879
#   Predicado: Bremsstrahlung <= 3.46 (n=168)
#     Zona: 429 colunas
#     Importance: 0.079874
#   Predicado: Ag compton > -2.89 (n=175)
#     Zona: 62 colunas
#     Importance: 0.019213
#   Predicado: Ag compton <= -2.03 (n=79)
#     Zona: 62 colunas
#     Importance: 0.022002
#   Predicado: Ag compton > -2.03 (n=135)
#     Zona: 62 colunas
#     Importance: 0.018440
#   Predicado: Ag compton <= 2.58 (n=124)
#     Zona: 62 colunas
#     Importance: 0.019449
#   Predicado: Ag compton > 2.58 (n=90)
#     Zona: 62 colunas
#     Importance: 0.020176
#   Predicado: Ag compton <= 3.09 (n=168)
#     Zona: 62 colunas
#     Importance: 0.018624
#   Predicado: Ag ka > -7.93 (n=171)
#     Zona: 45 colunas
#     Importance: 0.112641
#   Predicado: Ag ka <= -3.39 (n=83)
#     Zona: 45 colunas
#     Importance: 0.124059
#   Predicado: Ag ka > -3.39 (n=131)
#     Zona: 45 colunas
#     Importance: 0.106096
#   Predicado: Ag ka <= 5.20 (n=130)
#     Zona: 45 colunas
#     Importance: 0.113532
#   Predicado: Ag ka > 5.20 (n=84)
#     Zona: 45 colunas
#     Importance: 0.112337
#   Predicado: Ag ka <= 10.15 (n=172)
#     Zona: 45 colunas
#     Importance: 0.100147
#
# [Bag_8] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=168)
#     Zona: 18 colunas
#     Importance: 0.070421
#   Predicado: Ag La <= 2.83 (n=82)
#     Zona: 18 colunas
#     Importance: 0.265026
#   Predicado: Ag La > 2.83 (n=132)
#     Zona: 18 colunas
#     Importance: 0.053740
#   Predicado: Ag La <= 4.26 (n=124)
#     Zona: 18 colunas
#     Importance: 0.185777
#   Predicado: Ag La > 4.26 (n=90)
#     Zona: 18 colunas
#     Importance: 0.064328
#   Predicado: Ag La <= 5.23 (n=172)
#     Zona: 18 colunas
#     Importance: 0.152326
#   Predicado: Ag Lb > -6.25 (n=168)
#     Zona: 15 colunas
#     Importance: 0.050234
#   Predicado: Ag Lb <= 2.77 (n=83)
#     Zona: 15 colunas
#     Importance: 0.181435
#   Predicado: Ag Lb > 2.77 (n=131)
#     Zona: 15 colunas
#     Importance: 0.042685
#   Predicado: Ag Lb <= 3.70 (n=127)
#     Zona: 15 colunas
#     Importance: 0.129039
#   Predicado: Ag Lb > 3.70 (n=87)
#     Zona: 15 colunas
#     Importance: 0.048999
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.108966
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.004841
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.003425
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.005531
#   Predicado: Ca <= 1.99 (n=131)
#     Zona: 19 colunas
#     Importance: 0.003188
#   Predicado: Ca > 1.99 (n=83)
#     Zona: 19 colunas
#     Importance: 0.007072
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003487
#   Predicado: background > -1.72 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012699
#   Predicado: background <= 2.11 (n=87)
#     Zona: 87 colunas
#     Importance: 0.012464
#   Predicado: background > 2.11 (n=127)
#     Zona: 87 colunas
#     Importance: 0.013053
#   Predicado: background <= 2.38 (n=132)
#     Zona: 87 colunas
#     Importance: 0.011430
#   Predicado: background > 2.38 (n=82)
#     Zona: 87 colunas
#     Importance: 0.015041
#   Predicado: background <= 2.73 (n=169)
#     Zona: 87 colunas
#     Importance: 0.011969
#   Predicado: Fe > -1.71 (n=168)
#     Zona: 23 colunas
#     Importance: 0.006396
#   Predicado: Fe <= -1.30 (n=88)
#     Zona: 23 colunas
#     Importance: 0.006252
#   Predicado: Fe > -1.30 (n=126)
#     Zona: 23 colunas
#     Importance: 0.006865
#   Predicado: Fe <= 1.63 (n=134)
#     Zona: 23 colunas
#     Importance: 0.005606
#   Predicado: Fe > 1.63 (n=80)
#     Zona: 23 colunas
#     Importance: 0.008301
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.005619
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.009232
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.007810
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.010236
#   Predicado: Cu <= 2.35 (n=127)
#     Zona: 66 colunas
#     Importance: 0.008302
#   Predicado: Cu > 2.35 (n=87)
#     Zona: 66 colunas
#     Importance: 0.010716
#   Predicado: Cu <= 2.71 (n=172)
#     Zona: 66 colunas
#     Importance: 0.008330
#   Predicado: Zn > -1.89 (n=171)
#     Zona: 29 colunas
#     Importance: 0.006690
#   Predicado: Zn <= -1.35 (n=85)
#     Zona: 29 colunas
#     Importance: 0.009076
#   Predicado: Zn > -1.35 (n=129)
#     Zona: 29 colunas
#     Importance: 0.006764
#   Predicado: Zn <= 1.85 (n=126)
#     Zona: 29 colunas
#     Importance: 0.007667
#   Predicado: Zn > 1.85 (n=88)
#     Zona: 29 colunas
#     Importance: 0.007704
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.007409
#   Predicado: Bremsstrahlung > -3.10 (n=172)
#     Zona: 429 colunas
#     Importance: 0.075874
#   Predicado: Bremsstrahlung <= -2.45 (n=86)
#     Zona: 429 colunas
#     Importance: 0.097823
#   Predicado: Bremsstrahlung > -2.45 (n=128)
#     Zona: 429 colunas
#     Importance: 0.070322
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.095355
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.059736
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.083596
#   Predicado: Ag compton > -2.89 (n=171)
#     Zona: 62 colunas
#     Importance: 0.018717
#   Predicado: Ag compton <= -2.03 (n=86)
#     Zona: 62 colunas
#     Importance: 0.021180
#   Predicado: Ag compton > -2.03 (n=128)
#     Zona: 62 colunas
#     Importance: 0.017278
#   Predicado: Ag compton <= 2.58 (n=131)
#     Zona: 62 colunas
#     Importance: 0.019644
#   Predicado: Ag compton > 2.58 (n=83)
#     Zona: 62 colunas
#     Importance: 0.017586
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.018481
#   Predicado: Ag ka > -7.93 (n=173)
#     Zona: 45 colunas
#     Importance: 0.112801
#   Predicado: Ag ka <= -3.39 (n=79)
#     Zona: 45 colunas
#     Importance: 0.132131
#   Predicado: Ag ka > -3.39 (n=135)
#     Zona: 45 colunas
#     Importance: 0.107982
#   Predicado: Ag ka <= 5.20 (n=126)
#     Zona: 45 colunas
#     Importance: 0.118287
#   Predicado: Ag ka > 5.20 (n=88)
#     Zona: 45 colunas
#     Importance: 0.114907
#   Predicado: Ag ka <= 10.15 (n=168)
#     Zona: 45 colunas
#     Importance: 0.100640
#
# [Bag_9] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.069033
#   Predicado: Ag La <= 2.83 (n=88)
#     Zona: 18 colunas
#     Importance: 0.237725
#   Predicado: Ag La > 2.83 (n=126)
#     Zona: 18 colunas
#     Importance: 0.054462
#   Predicado: Ag La <= 4.26 (n=130)
#     Zona: 18 colunas
#     Importance: 0.170250
#   Predicado: Ag La > 4.26 (n=84)
#     Zona: 18 colunas
#     Importance: 0.067256
#   Predicado: Ag La <= 5.23 (n=169)
#     Zona: 18 colunas
#     Importance: 0.147484
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.048980
#   Predicado: Ag Lb <= 2.77 (n=85)
#     Zona: 15 colunas
#     Importance: 0.170394
#   Predicado: Ag Lb > 2.77 (n=129)
#     Zona: 15 colunas
#     Importance: 0.042149
#   Predicado: Ag Lb <= 3.70 (n=125)
#     Zona: 15 colunas
#     Importance: 0.123408
#   Predicado: Ag Lb > 3.70 (n=89)
#     Zona: 15 colunas
#     Importance: 0.050502
#   Predicado: Ag Lb <= 4.33 (n=169)
#     Zona: 15 colunas
#     Importance: 0.104031
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.005138
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.003679
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.005828
#   Predicado: Ca <= 1.99 (n=128)
#     Zona: 19 colunas
#     Importance: 0.003400
#   Predicado: Ca > 1.99 (n=86)
#     Zona: 19 colunas
#     Importance: 0.007318
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003604
#   Predicado: background > -1.72 (n=171)
#     Zona: 87 colunas
#     Importance: 0.012200
#   Predicado: background <= 2.11 (n=83)
#     Zona: 87 colunas
#     Importance: 0.012742
#   Predicado: background > 2.11 (n=131)
#     Zona: 87 colunas
#     Importance: 0.012778
#   Predicado: background <= 2.38 (n=128)
#     Zona: 87 colunas
#     Importance: 0.011597
#   Predicado: background > 2.38 (n=86)
#     Zona: 87 colunas
#     Importance: 0.014501
#   Predicado: background <= 2.73 (n=168)
#     Zona: 87 colunas
#     Importance: 0.012058
#   Predicado: Fe > -1.71 (n=172)
#     Zona: 23 colunas
#     Importance: 0.005476
#   Predicado: Fe <= -1.30 (n=83)
#     Zona: 23 colunas
#     Importance: 0.006410
#   Predicado: Fe > -1.30 (n=131)
#     Zona: 23 colunas
#     Importance: 0.005515
#   Predicado: Fe <= 1.63 (n=131)
#     Zona: 23 colunas
#     Importance: 0.005455
#   Predicado: Fe > 1.63 (n=83)
#     Zona: 23 colunas
#     Importance: 0.006505
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.005257
#   Predicado: Cu > -2.02 (n=170)
#     Zona: 66 colunas
#     Importance: 0.009241
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.008939
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.010274
#   Predicado: Cu <= 2.35 (n=129)
#     Zona: 66 colunas
#     Importance: 0.009729
#   Predicado: Cu > 2.35 (n=85)
#     Zona: 66 colunas
#     Importance: 0.009782
#   Predicado: Cu <= 2.71 (n=171)
#     Zona: 66 colunas
#     Importance: 0.008985
#   Predicado: Zn > -1.89 (n=177)
#     Zona: 29 colunas
#     Importance: 0.006908
#   Predicado: Zn <= -1.35 (n=79)
#     Zona: 29 colunas
#     Importance: 0.008200
#   Predicado: Zn > -1.35 (n=135)
#     Zona: 29 colunas
#     Importance: 0.006914
#   Predicado: Zn <= 1.85 (n=127)
#     Zona: 29 colunas
#     Importance: 0.007134
#   Predicado: Zn > 1.85 (n=87)
#     Zona: 29 colunas
#     Importance: 0.007760
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.006818
#   Predicado: Bremsstrahlung > -3.10 (n=172)
#     Zona: 429 colunas
#     Importance: 0.077376
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.095699
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.071673
#   Predicado: Bremsstrahlung <= 3.06 (n=129)
#     Zona: 429 colunas
#     Importance: 0.091528
#   Predicado: Bremsstrahlung > 3.06 (n=85)
#     Zona: 429 colunas
#     Importance: 0.065566
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.081191
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.019452
#   Predicado: Ag compton <= -2.03 (n=83)
#     Zona: 62 colunas
#     Importance: 0.020251
#   Predicado: Ag compton > -2.03 (n=131)
#     Zona: 62 colunas
#     Importance: 0.018719
#   Predicado: Ag compton <= 2.58 (n=130)
#     Zona: 62 colunas
#     Importance: 0.018804
#   Predicado: Ag compton > 2.58 (n=84)
#     Zona: 62 colunas
#     Importance: 0.020102
#   Predicado: Ag compton <= 3.09 (n=171)
#     Zona: 62 colunas
#     Importance: 0.018404
#   Predicado: Ag ka > -7.93 (n=172)
#     Zona: 45 colunas
#     Importance: 0.113336
#   Predicado: Ag ka <= -3.39 (n=83)
#     Zona: 45 colunas
#     Importance: 0.120225
#   Predicado: Ag ka > -3.39 (n=131)
#     Zona: 45 colunas
#     Importance: 0.113975
#   Predicado: Ag ka <= 5.20 (n=127)
#     Zona: 45 colunas
#     Importance: 0.116749
#   Predicado: Ag ka > 5.20 (n=87)
#     Zona: 45 colunas
#     Importance: 0.115888
#   Predicado: Ag ka <= 10.15 (n=169)
#     Zona: 45 colunas
#     Importance: 0.102491
#
# [Bag_10] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=174)
#     Zona: 18 colunas
#     Importance: 0.069066
#   Predicado: Ag La <= 2.83 (n=79)
#     Zona: 18 colunas
#     Importance: 0.246028
#   Predicado: Ag La > 2.83 (n=135)
#     Zona: 18 colunas
#     Importance: 0.053916
#   Predicado: Ag La <= 4.26 (n=122)
#     Zona: 18 colunas
#     Importance: 0.171677
#   Predicado: Ag La > 4.26 (n=92)
#     Zona: 18 colunas
#     Importance: 0.062720
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.142179
#   Predicado: Ag Lb > -6.25 (n=174)
#     Zona: 15 colunas
#     Importance: 0.048771
#   Predicado: Ag Lb <= 2.77 (n=79)
#     Zona: 15 colunas
#     Importance: 0.167382
#   Predicado: Ag Lb > 2.77 (n=135)
#     Zona: 15 colunas
#     Importance: 0.041922
#   Predicado: Ag Lb <= 3.70 (n=123)
#     Zona: 15 colunas
#     Importance: 0.116820
#   Predicado: Ag Lb > 3.70 (n=91)
#     Zona: 15 colunas
#     Importance: 0.049602
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.098531
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.004971
#   Predicado: Ca <= -1.26 (n=90)
#     Zona: 19 colunas
#     Importance: 0.004014
#   Predicado: Ca > -1.26 (n=124)
#     Zona: 19 colunas
#     Importance: 0.005703
#   Predicado: Ca <= 1.99 (n=132)
#     Zona: 19 colunas
#     Importance: 0.003652
#   Predicado: Ca > 1.99 (n=82)
#     Zona: 19 colunas
#     Importance: 0.007151
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.003968
#   Predicado: background > -1.72 (n=169)
#     Zona: 87 colunas
#     Importance: 0.012327
#   Predicado: background <= 2.11 (n=91)
#     Zona: 87 colunas
#     Importance: 0.013691
#   Predicado: background > 2.11 (n=123)
#     Zona: 87 colunas
#     Importance: 0.012012
#   Predicado: background <= 2.38 (n=136)
#     Zona: 87 colunas
#     Importance: 0.011556
#   Predicado: background > 2.38 (n=78)
#     Zona: 87 colunas
#     Importance: 0.014767
#   Predicado: background <= 2.73 (n=178)
#     Zona: 87 colunas
#     Importance: 0.011990
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.005889
#   Predicado: Fe <= -1.30 (n=84)
#     Zona: 23 colunas
#     Importance: 0.005867
#   Predicado: Fe > -1.30 (n=130)
#     Zona: 23 colunas
#     Importance: 0.006147
#   Predicado: Fe <= 1.63 (n=128)
#     Zona: 23 colunas
#     Importance: 0.005120
#   Predicado: Fe > 1.63 (n=86)
#     Zona: 23 colunas
#     Importance: 0.007401
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
# ...
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Ca > 1.99 (peso 0.0084)
# Mantida aresta Ca > 1.99 -> Zn <= 1.85 (peso 0.0155)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Zn <= 1.85 (peso 0.0084)
# Mantida aresta Zn <= 1.85 -> Fe > 1.63 (peso 0.0086)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ca > 1.99 (peso 0.0153)
# Mantida aresta Ca > 1.99 -> Zn <= 2.28 (peso 0.0155)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Zn <= 2.28 (peso 0.0071)
# Mantida aresta Zn <= 2.28 -> Zn > -1.89 (peso 0.0158)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Zn > -1.35 (peso 0.0286)
# Mantida aresta Zn > -1.35 -> Zn > -1.89 (peso 0.0291)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Fe > 1.63 (peso 0.0073)
# Mantida aresta Fe > 1.63 -> Zn > -1.35 (peso 0.0077)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ca > 1.99 (peso 0.0072)
# Mantida aresta Ca > 1.99 -> Zn > -1.35 (peso 0.0073)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Fe > 1.63 (peso 0.0141)
# Mantida aresta Fe > 1.63 -> Zn > -1.89 (peso 0.0211)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Fe > 1.63 (peso 0.0147)
# Mantida aresta Fe > 1.63 -> Ca > 1.99 (peso 0.0149)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Fe > -1.71 (peso 0.0062)
# Mantida aresta Fe > -1.71 -> Ca > -1.26 (peso 0.0433)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe <= 2.10 (peso 0.0222)
# Mantida aresta Fe <= 2.10 -> Fe <= 1.63 (peso 0.0280)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe <= 1.63 (peso 0.0052)
# Mantida aresta Fe <= 1.63 -> Ca > -1.96 (peso 0.0220)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ca > -1.26 (peso 0.0054)
# Mantida aresta Ca > -1.26 -> Fe <= 2.10 (peso 0.0057)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe <= 2.10 (peso 0.0054)
# Mantida aresta Fe <= 2.10 -> Ca > -1.96 (peso 0.0163)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca <= -1.26 (peso 0.0111)
# Mantida aresta Ca <= -1.26 -> Ca <= 2.47 (peso 0.0278)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 231
# Total de arestas removidas por bidirecionalidade: 65
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Perturbation
#
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 56
# Removida aresta Ag Lb <= 2.77 -> Ag La <= 4.26 (peso 0.3504)
# Mantida aresta Ag La <= 4.26 -> Ag Lb <= 2.77 (peso 1.3966)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag Lb <= 3.70 (peso 0.1216)
# Mantida aresta Ag Lb <= 3.70 -> Ag ka > 5.20 (peso 0.2439)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag Lb <= 3.70 (peso 0.1285)
# Mantida aresta Ag Lb <= 3.70 -> Ag ka <= -3.39 (peso 0.5004)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag ka > 5.20 (peso 0.2292)
# Mantida aresta Ag ka > 5.20 -> Ag ka <= -3.39 (peso 0.3527)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka <= 5.20 (peso 0.2222)
# Mantida aresta Ag ka <= 5.20 -> Ag ka > 5.20 (peso 0.2320)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag ka > -7.93 (peso 0.2269)
# Mantida aresta Ag ka > -7.93 -> Ag ka > 5.20 (peso 0.2300)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 4.33 -> Ag ka > -3.39 (peso 0.1069)
# Mantida aresta Ag ka > -3.39 -> Ag Lb <= 4.33 (peso 0.4301)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 4.33 -> Ag ka <= 5.20 (peso 0.1035)
# Mantida aresta Ag ka <= 5.20 -> Ag Lb <= 4.33 (peso 0.3221)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag Lb <= 4.33 (peso 0.1994)
# Mantida aresta Ag Lb <= 4.33 -> Ag ka <= 10.15 (peso 0.2060)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Bremsstrahlung <= -2.45 (peso 0.1955)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag ka <= 10.15 (peso 0.6867)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Bremsstrahlung <= 3.46 (peso 0.0819)
# Mantida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung > -3.10 (peso 0.7344)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Bremsstrahlung > -2.45 (peso 0.1445)
# Mantida aresta Bremsstrahlung > -2.45 -> Ag La > -8.20 (peso 0.3483)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Ag La > -8.20 (peso 0.0695)
# Mantida aresta Ag La > -8.20 -> Bremsstrahlung > 3.06 (peso 0.2740)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Ag La > -8.20 (peso 0.1278)
# Mantida aresta Ag La > -8.20 -> Ag La > 4.26 (peso 0.1312)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Bremsstrahlung > 3.06 (peso 0.0645)
# Mantida aresta Bremsstrahlung > 3.06 -> Ag La > 4.26 (peso 0.5337)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag Lb > 3.70 (peso 0.0963)
# Mantida aresta Ag Lb > 3.70 -> Ag Lb > -6.25 (peso 0.4048)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag compton > 2.58 (peso 0.0588)
# Mantida aresta Ag compton > 2.58 -> Ag compton <= 2.58 (peso 0.0600)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag compton > 2.58 (peso 0.0365)
# Mantida aresta Ag compton > 2.58 -> Ag compton > -2.89 (peso 0.0778)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag compton > 2.58 (peso 0.0176)
# Mantida aresta Ag compton > 2.58 -> Ag compton <= 3.09 (peso 0.0182)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag compton <= 2.58 (peso 0.0192)
# Mantida aresta Ag compton <= 2.58 -> Ag compton > -2.89 (peso 0.0961)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag compton > -2.89 (peso 0.0181)
# Mantida aresta Ag compton > -2.89 -> Ag compton <= 3.09 (peso 0.1120)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Ag compton <= 3.09 (peso 0.0379)
# Mantida aresta Ag compton <= 3.09 -> Ag compton > -2.03 (peso 0.1099)
#
# ======================================================================
#
# Removida aresta background > 2.38 -> background <= 2.11 (peso 0.0586)
# Mantida aresta background <= 2.11 -> background > 2.38 (peso 0.0738)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> background <= 2.11 (peso 0.0115)
# Mantida aresta background <= 2.11 -> background > -1.72 (peso 0.0281)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> background > -1.72 (peso 0.0120)
# Mantida aresta background > -1.72 -> background <= 2.38 (peso 0.0248)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> background <= 2.38 (peso 0.0247)
# Mantida aresta background <= 2.38 -> background > 2.11 (peso 0.0368)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> background <= 2.73 (peso 0.0132)
# Mantida aresta background <= 2.73 -> background <= 2.38 (peso 0.0469)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background > -1.72 (peso 0.0383)
# Mantida aresta background > -1.72 -> background <= 2.73 (peso 0.0742)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> background > 2.11 (peso 0.0126)
# Mantida aresta background > 2.11 -> background > -1.72 (peso 0.0371)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> Cu > 2.01 (peso 0.0317)
# Mantida aresta Cu > 2.01 -> Cu > 2.35 (peso 0.0515)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Cu > 2.35 (peso 0.0105)
# Mantida aresta Cu > 2.35 -> Zn <= -1.35 (peso 0.0289)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu > 2.35 (peso 0.0094)
# Mantida aresta Cu > 2.35 -> Cu <= 2.35 (peso 0.0310)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Zn <= -1.35 (peso 0.0186)
# Mantida aresta Zn <= -1.35 -> Cu <= 2.35 (peso 0.0274)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Zn <= -1.35 (peso 0.0093)
# Mantida aresta Zn <= -1.35 -> Cu > -2.02 (peso 0.0277)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Zn <= -1.35 (peso 0.0088)
# Mantida aresta Zn <= -1.35 -> Cu <= 2.71 (peso 0.0090)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Cu <= 2.35 (peso 0.0186)
# Mantida aresta Cu <= 2.35 -> Cu > -2.02 (peso 0.0383)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu <= 2.01 (peso 0.0090)
# Mantida aresta Cu <= 2.01 -> Cu <= 2.35 (peso 0.0092)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Cu <= 2.71 (peso 0.0090)
# Mantida aresta Cu <= 2.71 -> Cu <= 2.01 (peso 0.0544)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Cu <= 2.01 (peso 0.0081)
# Mantida aresta Cu <= 2.01 -> Zn <= 1.85 (peso 0.0261)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Zn <= 1.85 (peso 0.0242)
# Mantida aresta Zn <= 1.85 -> Zn > 1.85 (peso 0.0319)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Zn <= 1.85 (peso 0.0168)
# Mantida aresta Zn <= 1.85 -> Fe > 1.63 (peso 0.0311)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Zn <= 2.28 (peso 0.0074)
# Mantida aresta Zn <= 2.28 -> Zn > 1.85 (peso 0.0078)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Zn <= 2.28 (peso 0.0226)
# Mantida aresta Zn <= 2.28 -> Ca > 1.99 (peso 0.0372)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ca > 1.99 (peso 0.0067)
# Mantida aresta Ca > 1.99 -> Zn > -1.89 (peso 0.0292)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Zn > -1.89 (peso 0.0143)
# Mantida aresta Zn > -1.89 -> Zn > -1.35 (peso 0.0481)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Zn > -1.89 (peso 0.0066)
# Mantida aresta Zn > -1.89 -> Fe > -1.30 (peso 0.0141)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Fe <= -1.30 (peso 0.0131)
# Mantida aresta Fe <= -1.30 -> Fe > -1.30 (peso 0.0188)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Fe > -1.71 (peso 0.0179)
# Mantida aresta Fe > -1.71 -> Ca > -1.26 (peso 0.0366)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe > -1.71 (peso 0.0054)
# Mantida aresta Fe > -1.71 -> Fe <= 1.63 (peso 0.0060)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Fe <= -1.30 (peso 0.0061)
# Mantida aresta Fe <= -1.30 -> Fe > -1.71 (peso 0.0127)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Ca > -1.26 (peso 0.0062)
# Mantida aresta Ca > -1.26 -> Fe <= -1.30 (peso 0.0180)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ca > -1.26 (peso 0.0054)
# Mantida aresta Ca > -1.26 -> Fe <= 2.10 (peso 0.0120)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Fe <= 2.10 (peso 0.0109)
# Mantida aresta Fe <= 2.10 -> Fe <= 1.63 (peso 0.0328)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe <= 2.10 (peso 0.0051)
# Mantida aresta Fe <= 2.10 -> Ca > -1.96 (peso 0.0165)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Fe <= 1.63 (peso 0.0056)
# Mantida aresta Fe <= 1.63 -> Ca > -1.96 (peso 0.0269)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca <= -1.26 (peso 0.0147)
# Mantida aresta Ca <= -1.26 -> Ca <= 2.47 (peso 0.0232)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 218
# Total de arestas removidas por bidirecionalidade: 56
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Perturbation
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0          Ag La <= 2.83         Ag La <= 2.83         Ag La <= 2.83
# 1          Ag La <= 4.26         Ag La <= 4.26         Ag La <= 4.26
# 2          Ag Lb <= 2.77         Ag Lb <= 2.77         Ag Lb <= 2.77
# 3          Ag Lb <= 4.33         Ag La <= 5.23         Ag ka > -7.93
# 4          Ag La <= 5.23         Ag Lb <= 3.70         Ag La <= 5.23
# ..                   ...                   ...                   ...
# 57           Ca <= -1.26           Ca <= -1.26           Ca <= -1.26
# 58            Ca <= 2.47            Ca <= 2.47            Ca <= 2.47
# 59            Ca <= 1.99            Ca <= 1.99            Ca <= 1.99
# 60               Class_A               Class_A               Class_A
# 61               Class_B               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0          Ag La <= 2.83
# 1          Ag La <= 4.26
# 2          Ag Lb <= 2.77
# 3          Ag ka > -7.93
# 4          Ag La <= 5.23
# ..                   ...
# 57           Ca <= -1.26
# 58            Ca <= 2.47
# 59            Ca <= 1.99
# 60               Class_A
# 61               Class_B
#
# [62 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_9']
# Out:
#                   Predicate  Perturbation
# 0             Ag La <= 2.83      0.237725
# 1             Ag Lb <= 2.77      0.170394
# 2             Ag La <= 4.26      0.170250
# 3             Ag La <= 5.23      0.147484
# 4             Ag Lb <= 3.70      0.123408
# 5            Ag ka <= -3.39      0.120225
# 6             Ag ka <= 5.20      0.116749
# 7              Ag ka > 5.20      0.115888
# 8             Ag ka > -3.39      0.113975
# 9             Ag ka > -7.93      0.113336
# 10            Ag Lb <= 4.33      0.104031
# 11           Ag ka <= 10.15      0.102491
# 12  Bremsstrahlung <= -2.45      0.095699
# 13   Bremsstrahlung <= 3.06      0.091528
# 14   Bremsstrahlung <= 3.46      0.081191
# 15   Bremsstrahlung > -3.10      0.077376
# 16   Bremsstrahlung > -2.45      0.071673
# 17            Ag La > -8.20      0.069033
# 18             Ag La > 4.26      0.067256
# 19    Bremsstrahlung > 3.06      0.065566
# 20             Ag La > 2.83      0.054462
# 21             Ag Lb > 3.70      0.050502
# 22            Ag Lb > -6.25      0.048980
# 23             Ag Lb > 2.77      0.042149
# 24      Ag compton <= -2.03      0.020251
# 25        Ag compton > 2.58      0.020102
# 26       Ag compton > -2.89      0.019452
# 27       Ag compton <= 2.58      0.018804
# 28       Ag compton > -2.03      0.018719
# 29       Ag compton <= 3.09      0.018404
# 30        background > 2.38      0.014501
# 31        background > 2.11      0.012778
# 32       background <= 2.11      0.012742
# 33       background > -1.72      0.012200
# 34       background <= 2.73      0.012058
# 35       background <= 2.38      0.011597
# 36                Cu > 2.01      0.010274
# 37                Cu > 2.35      0.009782
# 38               Cu <= 2.35      0.009729
# 39               Cu > -2.02      0.009241
# 40               Cu <= 2.71      0.008985
# 41               Cu <= 2.01      0.008939
# 42              Zn <= -1.35      0.008200
# 43                Zn > 1.85      0.007760
# 44                Ca > 1.99      0.007318
# 45               Zn <= 1.85      0.007134
# 46               Zn > -1.35      0.006914
# 47               Zn > -1.89      0.006908
# 48               Zn <= 2.28      0.006818
# 49                Fe > 1.63      0.006505
# 50              Fe <= -1.30      0.006410
# 51               Ca > -1.26      0.005828
# 52               Fe > -1.30      0.005515
# 53               Fe > -1.71      0.005476
# 54               Fe <= 1.63      0.005455
# 55               Fe <= 2.10      0.005257
# 56               Ca > -1.96      0.005138
# 57              Ca <= -1.26      0.003679
# 58               Ca <= 2.47      0.003604
# 59               Ca <= 1.99      0.003400

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df = lrc_summed_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                        Node  Local_Reaching_Centrality            Zone  \
# 0             Ag La <= 2.83                   4.456668           Ag La
# 1             Ag Lb <= 2.77                   3.266337           Ag Lb
# 2             Ag ka > -7.93                   2.421633           Ag ka
# 3   Bremsstrahlung <= -2.45                   2.188708  Bremsstrahlung
# 4       Ag compton <= -2.03                   0.254472      Ag compton
# 5        background <= 2.73                   0.127305      background
# 6                Cu <= 2.35                   0.078723              Cu
# 7               Zn <= -1.35                   0.062805              Zn
# 8                 Fe > 1.63                   0.049418              Fe
# 9                 Ca > 1.99                   0.046837              Ca
# 10                  Class_B                   0.000000            None
#
#    Threshold Operator
# 0       2.83       <=
# 1       2.77       <=
# 2      -7.93        >
# 3      -2.45       <=
# 4      -2.03       <=
# 5       2.73       <=
# 6       2.35       <=
# 7      -1.35       <=
# 8       1.63        >
# 9       1.99        >
# 10      None     None

# %%
import numpy as np

max_len = max(
    len(pvector_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(permutation_unique_df['Zone']),
    len(lrc_summed_unique_df_pert['Zone']),
    len(lrc_summed_unique_df_cov['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'SVM_pvector': pad_list(pvector_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'Permutation': pad_list(permutation_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#        SVM_pvector            Shap     Permutation LRC_perturbation  \
# 0            Ag ka           Ag La           Ag ka            Ag La
# 1            Ag La           Ag ka           Ag La            Ag Lb
# 2               Zn           Ag Lb           Ag Lb            Ag ka
# 3            Ag Lb              Zn              Zn   Bremsstrahlung
# 4   Bremsstrahlung  Bremsstrahlung  Bremsstrahlung       Ag compton
# 5               Fe      Ag compton      Ag compton       background
# 6       Ag compton              Fe              Fe               Cu
# 7       background              Ca              Cu               Zn
# 8               Ca      background              Ca               Fe
# 9               Cu              Cu      background               Ca
# 10            None            None            None             None
#
#     LRC_covariance
# 0            Ag La
# 1            Ag Lb
# 2            Ag ka
# 3       Ag compton
# 4   Bremsstrahlung
# 5               Zn
# 6               Fe
# 7               Ca
# 8       background
# 9               Cu
# 10            None

# %%
import rbo

rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        list_1 = features_importance[method_1].tolist()
        list_2 = features_importance[method_2].tolist()
        rbo_score = rbo.RankingSimilarity(list_1, list_2).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16480\3888930707.py:12: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#            Method_1          Method_2  RBO_Score
# 9  LRC_perturbation    LRC_covariance   0.919442
# 1       SVM_pvector       Permutation   0.909339
# 6              Shap    LRC_covariance   0.826621
# 5              Shap  LRC_perturbation   0.800036
# 4              Shap       Permutation   0.666743
# 0       SVM_pvector              Shap   0.611261
# 8       Permutation    LRC_covariance   0.521612
# 7       Permutation  LRC_perturbation   0.503124
# 3       SVM_pvector    LRC_covariance   0.466130
# 2       SVM_pvector  LRC_perturbation   0.445720
