# %% [markdown]
# # **Model**

# %% [markdown]
# # **XRF ecigar database**

# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks

# loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv('XRF_databases/ecigar/plsda/ecigar.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '0.997':'20.007']
#data.insert(0, 'exCa', data_complete['exCa'])  # inserting the target variable (e.g., exCa (exchangeable calcium))

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '0.997':'20.007'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '0.997':'20.007'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)

from modeling import pls_optimized

# performing PLS-DA with optimized latent variables
plsda_results = pls_optimized(Xcalclass_prep, 
                              ycalclass,
                              LVmax=3,
                              Xpred=Xpredclass_prep,
                              ypred=ypredclass,
                              aim='classification',
                              cv=10)
plsda_results[0]
# Out:
# 2026-01-06 11:09:06,295 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
#
# 2026-01-06 11:09:06,299 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
#
# 2026-01-06 11:09:06,406 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
#
# 2026-01-06 11:09:06,409 - kennard_stone.utils._pairwise:114[INFO] - Calculating pairwise distances using scikit-learn.
#    LVs  Accuracy Cal  Sensitivity Cal  Specificity Cal             CM Cal  \
# 0    1          0.68         0.333333           0.8750  [[14, 2], [6, 3]]
# 1    2          0.80         0.555556           0.9375  [[15, 1], [4, 5]]
# 2    3          0.84         0.777778           0.8750  [[14, 2], [2, 7]]
#
#    Accuracy CV  Sensitivity CV  Specificity CV              CM CV  \
# 0         0.64        0.222222           0.875  [[14, 2], [7, 2]]
# 1         0.56        0.222222           0.750  [[12, 4], [7, 2]]
# 2         0.56        0.222222           0.750  [[12, 4], [7, 2]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred           CM Pred  \
# 0       0.545455              0.00          0.857143  [[6, 1], [4, 0]]
# 1       0.818182              0.50          1.000000  [[7, 0], [2, 2]]
# 2       0.909091              0.75          1.000000  [[7, 0], [1, 3]]
#
#    X Cum Exp Var  Y Cum Exp Var  X Ind Exp Var  Y Ind Exp Var
# 0      63.224546       7.669394      63.224546       7.669394
# 1      69.628977      19.133399       6.404431      11.464005
# 2      88.071593      22.397397      18.442616       3.263998

# %% [markdown]
# # **VIP and SHAP**

# %%
pd.options.plotting.backend = 'plotly' # setting plotly as the backend for pandas plotting 
Xcalclass.T.plot() # easily plotting the spectra

# %%
# plotando o vip scores
plsda_results[4].T.plot()

# %%
from explaining import extract_spectral_zones
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Si', 0.997, 1.920),
('background1', 1.930, 2.413),
('Cl', 2.413, 2.984),
('background2', 2.984, 3.134),
('K', 3.134, 3.479),
('Ca', 3.479, 3.839),
('Fe ka', 6.161, 6.732),
('Fe kb', 6.732, 7.242),
('Ni', 7.242, 7.712),
('Cu', 7.712, 8.348),
('Zn ka', 8.348, 8.963),
('Ga', 8.963, 9.414),
('Zn kb', 9.414, 9.739),
('background3', 9.739, 10.379),
('Pb La', 10.379, 10.725),
('background4', 10.725, 12.391),
('Pb Lb', 12.391, 12.831),
('background5', 12.831, 15.333),
('Mo compton scattering', 15.333, 17.215),
('Mo rayleigh scattering', 17.215, 17.765),
('background6', 17.765, 20.007),
]
spectral_zones_class = extract_spectral_zones(Xcalclass_prep, spectral_cuts) # extracting the spectral zones
spectral_zones_class['Ca'].T.plot(title='spectral zone') # plotting the Al ka spectral zone

# %%
import numpy as np
import pandas as pd

# vip
vip_scores_df = pd.DataFrame({
    'energy' : plsda_results[4].T.index,
    'VIP_Score' : plsda_results[4].T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# vamos gerar uma nova coluna em vip_scores_df com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_vip = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
	for i in vip_scores_df['energy']: # iterando sobre cada valor de energia no vip_scores_df
		i_float = float(i)
		if start <= i_float <= end:
			energy_to_zone_vip[i] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_vip

# vamos filtrar vip_scores_df para manter apenas as zonas espectrais únicas com maior VIP score
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# reg vet
reg_vet = pd.DataFrame(plsda_results[3].coef_, columns=plsda_results[3].feature_names_in_) # creating a DataFrame with regression coefficients
reg_vet = reg_vet.T
reg_vet.insert(0, 'energy', reg_vet.index) # adding energy column
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy', 'Reg_coef'] # renaming
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs() # adding absolute value column
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True) # sorting by absolute value

# gerando uma nova coluna em reg_vet com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_reg = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
    for i in reg_vet['energy']: # iterando sobre cada valor de energia no reg_vet
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_reg[i] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_reg

# vamos filtrar reg_vet para manter apenas as zonas espectrais únicas com maior valor absoluto do coeficiente de regressão
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
vip_scores_unique_df
# Out:
#     energy  VIP_Score                    Zone
# 0    2.623   5.332904                      Cl
# 1    6.391   4.394563                   Fe ka
# 2    3.324   4.138549                       K
# 3    8.023   3.352158                      Cu
# 4    8.623   2.735378                   Zn ka
# 5   17.025   1.978706   Mo compton scattering
# 6    17.42   1.962363  Mo rayleigh scattering
# 7    7.467   1.534679                      Ni
# 8    7.047   1.490857                   Fe kb
# 9    3.589   1.395871                      Ca
# 10   1.748   1.137273                      Si
# 11   9.564   0.944476                   Zn kb
# 12   9.244   0.901580                      Ga
# 13  13.377   0.874392             background5
# 14  10.525   0.674914                   Pb La
# 15   2.008   0.669962             background1
# 16  12.581   0.498251                   Pb Lb
# 17  20.007   0.407244             background6
# 18  10.284   0.388750             background3
# 19   3.999   0.359822                     NaN
# 20   3.129   0.244365             background2
# 21  11.846   0.223033             background4

# %%
# vamos agora extrair as variaveis mais importantes atraves do método SHAP
import shap

# Para PLSRegression, usamos KernelExplainer porque não há explainer dedicado muito rápido
explainer_pls = shap.KernelExplainer(plsda_results[3].predict, Xcalclass_prep)
shap_values_pls = explainer_pls(Xcalclass_prep)

shap_global_importance = pd.DataFrame({
    'energy': Xpredclass_prep.columns,
    'Mean_Abs_SHAP': np.abs(shap_values_pls.values).mean(axis=0)}) # tomando a importancia global como a media dos valores absolutos dos valores SHAP para cada feature
shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False, inplace=True)

# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
vip_scores_unique_df.to_csv('XRF_databases/ecigar/plsda/vip_scores_ecigar.csv', index=False, sep=';')
reg_vet_unique_df.to_csv('XRF_databases/ecigar/plsda/reg_vet_ecigar.csv', index=False, sep=';')
shap_unique_df.to_csv('XRF_databases/ecigar/plsda/shap_ecigar.csv', index=False, sep=';')

# %%
# shap_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df
# vip_scores_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/vip_scores_bank_notes.csv', sep=';') # loading previously saved vip_scores_unique_df#
# reg_vet_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/reg_vet_bank_notes.csv', sep=';') # loading previously saved reg_vet_unique_df

# %% [markdown]
# # **SMeX**

# %%
from explaining import extract_spectral_zones
from explaining import aggregate_spectral_zones
from explaining import predicates_by_quantiles
from explaining import create_predicate_info_dict
from explaining import bagging_predicates, calculate_predicate_metrics
from explaining import build_predicate_graph
import numpy as np
import pandas as pd

spectral_zones_class = extract_spectral_zones(Xcalclass_prep, spectral_cuts) # extracting the spectral zones
zone_sums_df = aggregate_spectral_zones(spectral_zones_class, aggregator='max')
predicates_quantiles = predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8]) # getting predicates for quartiles
co_occurrence_matrix_df=predicates_quantiles[2]

# Criar dicionário de informações
predicate_info_dict = create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=plsda_results[5].iloc[:, -1]
)

# LISTA DE SEMENTES A TESTAR

random_seeds = [0, 1, 42]

all_results = {}

training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    
    # Bagging
    bags_result_seed = bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=60,
        #n_predicates_per_bag=int(training_samples*0.6), # 60 % da base para predicados (convertido para int)
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.25), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    mi_results_dict_seed = calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance',
        threshold=0.001, # threshold para cortar predicados irrelevantes
        n_neighbors=2
    )
    
    # Salvar no dicionário principal
    all_results[seed] = {
        'bags_result': bags_result_seed,
        'mi_results_dict': mi_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)

# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente
    DG = build_predicate_graph(
        bags_result=all_results[seed]['bags_result'],
        mi_results_dict=all_results[seed]['mi_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )
    
    # Armazenar grafo
    graphs_by_seed[seed] = DG  

# vamos calcular a LRC de acordo com as diferentes sementes
import networkx as nx

lrc_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    local_reaching_centrality = {
        node: nx.local_reaching_centrality(DG, node, weight='weight') 
        for node in DG.nodes()
    }

    # Ordenar por LRC
    sorted_lrc = sorted(local_reaching_centrality.items(), key=lambda x: x[1], reverse=True)
    
    # Criar DataFrame com LRC
    lrc_df_seed = pd.DataFrame(sorted_lrc, columns=['Node', 'Local_Reaching_Centrality'])
    
    # Extrair informações dos predicados (zona, threshold, operador)
    zones = []
    thresholds = []
    operators = []
    
    for node in lrc_df_seed['Node']:
        if node.startswith('Class_'):
            zones.append(None)
            thresholds.append(None)
            operators.append(None)
        else:
            pred_row = predicates_quantiles[0][predicates_quantiles[0]['rule'] == node].iloc[0]
            zones.append(pred_row['zone'])
            thresholds.append(pred_row['thresholds'])
            operators.append(pred_row['operator'])
    
    lrc_df_seed['Zone'] = zones
    lrc_df_seed['Threshold'] = thresholds
    lrc_df_seed['Operator'] = operators
    lrc_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    
    # Armazenar LRC
    lrc_by_seed[seed] = lrc_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe

lrc_all_seeds_df = pd.DataFrame() # 
for seed in random_seeds:
    lrc_df_seed = lrc_by_seed[seed]
    lrc_df_seed = lrc_df_seed.rename(columns={
        'Node': f'Predicate_Seed_{seed}'
    })
    lrc_all_seeds_df = pd.concat([lrc_all_seeds_df, lrc_df_seed[[f'Predicate_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_unique_by_seed = {}
for seed, lrc_df in lrc_by_seed.items():
    lrc_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_unique_df = lrc_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_unique_by_seed[seed] = lrc_unique_df

lrc_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 124 | Descartados: 44
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 123 | Descartados: 45
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 124 | Descartados: 44
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 124 | Descartados: 44
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 125 | Descartados: 43
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 125 | Descartados: 43
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
#
# ======================================================================
# Calculando Covariance para Predicados
# ======================================================================
# Métrica: covariance
# Threshold: 0.001
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 125 | Descartados: 43
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
#
# ======================================================================
# Calculando Covariance para Predicados
# ======================================================================
# Métrica: covariance
# Threshold: 0.001
# ======================================================================
# Processando semente: 42
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 125 | Descartados: 43
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 124 | Descartados: 44
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 125 | Descartados: 43
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 127 | Descartados: 41
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 126 | Descartados: 42
#
# ======================================================================
# Calculando Covariance para Predicados
# ======================================================================
# Métrica: covariance
# Threshold: 0.001
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 1118
# Removida aresta Mo rayleigh scattering > -7.45 -> Cl > -1.90 (peso 70.0)
# Mantida aresta Cl > -1.90 -> Mo rayleigh scattering > -7.45 (peso 238.0)
#
# ======================================================================
#
# Removida aresta Ni > 1.98 -> Cl > -1.90 (peso 30.0)
# Mantida aresta Cl > -1.90 -> Ni > 1.98 (peso 50.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo rayleigh scattering > 9.26 -> Cl > -1.90 (peso 60.0)
# Mantida aresta Cl > -1.90 -> Mo rayleigh scattering > 9.26 (peso 60.0)
#
# ======================================================================
#
# Removida aresta Cl > -1.90 -> Zn ka > -1.77 (peso 30.0)
# Mantida aresta Zn ka > -1.77 -> Cl > -1.90 (peso 45.0)
#
# ======================================================================
#
# Removida aresta Cl > -0.72 -> Cl > -1.90 (peso 15.0)
# Mantida aresta Cl > -1.90 -> Cl > -0.72 (peso 165.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -15.07 -> Cl > -1.90 (peso 36.0)
# Mantida aresta Cl > -1.90 -> Mo rayleigh scattering > -15.07 (peso 54.0)
#
# ======================================================================
#
# Removida aresta Si > 18.46 -> Cl > -1.90 (peso 10.0)
# Mantida aresta Cl > -1.90 -> Si > 18.46 (peso 20.0)
#
# ======================================================================
#
# Removida aresta Cl > -1.90 -> Mo compton scattering > -7.08 (peso 13.0)
# Mantida aresta Mo compton scattering > -7.08 -> Cl > -1.90 (peso 39.0)
#
# ======================================================================
#
# Removida aresta Cl > -1.90 -> Cl > 0.80 (peso 10.0)
# Mantida aresta Cl > 0.80 -> Cl > -1.90 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > -9.76 -> Cl > -1.90 (peso 54.0)
# Mantida aresta Cl > -1.90 -> Mo compton scattering > -9.76 (peso 54.0)
#
# ======================================================================
#
# Removida aresta Cu > -1.34 -> Cl > -1.90 (peso 15.0)
# Mantida aresta Cl > -1.90 -> Cu > -1.34 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > -9.76 -> Mo rayleigh scattering > -7.45 (peso 28.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Mo compton scattering > -9.76 (peso 28.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -7.45 -> Mo rayleigh scattering > 9.26 (peso 120.0)
# Mantida aresta Mo rayleigh scattering > 9.26 -> Mo rayleigh scattering > -7.45 (peso 140.0)
#
# ======================================================================
#
# Removida aresta Zn ka > 1.39 -> Mo rayleigh scattering > -7.45 (peso 10.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Zn ka > 1.39 (peso 40.0)
#
# ======================================================================
#
# Removida aresta Ni > 1.98 -> Mo rayleigh scattering > -7.45 (peso 10.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Ni > 1.98 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -15.07 -> Mo rayleigh scattering > -7.45 (peso 45.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Mo rayleigh scattering > -15.07 (peso 210.0)
#
# ======================================================================
#
# Removida aresta Cl > -0.72 -> Mo rayleigh scattering > -7.45 (peso 36.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Cl > -0.72 (peso 72.0)
#
# ======================================================================
#
# Removida aresta Cu > -1.34 -> Mo rayleigh scattering > -7.45 (peso 42.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Cu > -1.34 (peso 70.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > 24.16 -> Mo rayleigh scattering > -7.45 (peso 18.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Mo compton scattering > 24.16 (peso 18.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo rayleigh scattering > -7.45 -> Si > 18.46 (peso 8.0)
# Mantida aresta Si > 18.46 -> Mo rayleigh scattering > -7.45 (peso 8.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu > -2.04 -> Mo rayleigh scattering > -7.45 (peso 15.0)
# Mantida aresta Mo rayleigh scattering > -7.45 -> Cu > -2.04 (peso 15.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo rayleigh scattering > -7.45 -> Cl > 0.80 (peso 9.0)
# Mantida aresta Cl > 0.80 -> Mo rayleigh scattering > -7.45 (peso 9.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -9.76 -> Mo rayleigh scattering > -15.07 (peso 54.0)
# Mantida aresta Mo rayleigh scattering > -15.07 -> Mo compton scattering > -9.76 (peso 126.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -9.76 -> Cu > -2.04 (peso 126.0)
# Mantida aresta Cu > -2.04 -> Mo compton scattering > -9.76 (peso 198.0)
#
# ======================================================================
#
# Removida aresta K > 4.62 -> Mo compton scattering > -9.76 (peso 9.0)
# Mantida aresta Mo compton scattering > -9.76 -> K > 4.62 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -7.08 -> Mo compton scattering > -9.76 (peso 42.0)
# Mantida aresta Mo compton scattering > -9.76 -> Mo compton scattering > -7.08 (peso 154.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -9.76 -> Ni > 1.98 (peso 80.0)
# Mantida aresta Ni > 1.98 -> Mo compton scattering > -9.76 (peso 130.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > 24.16 -> Mo compton scattering > -9.76 (peso 40.0)
# Mantida aresta Mo compton scattering > -9.76 -> Mo compton scattering > 24.16 (peso 50.0)
#
# ======================================================================
#
# Empate! Removida aresta Cl > 0.80 -> Mo compton scattering > -9.76 (peso 20.0)
# Mantida aresta Mo compton scattering > -9.76 -> Cl > 0.80 (peso 20.0)
#
# ======================================================================
#
# Empate! Removida aresta Cl > -0.72 -> Mo compton scattering > -9.76 (peso 14.0)
# Mantida aresta Mo compton scattering > -9.76 -> Cl > -0.72 (peso 14.0)
#
# ======================================================================
#
# Removida aresta K > -4.12 -> Mo compton scattering > -9.76 (peso 19.0)
# Mantida aresta Mo compton scattering > -9.76 -> K > -4.12 (peso 57.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -9.76 -> Zn ka > 1.39 (peso 10.0)
# Mantida aresta Zn ka > 1.39 -> Mo compton scattering > -9.76 (peso 40.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -1.77 -> Mo compton scattering > -9.76 (peso 30.0)
# Mantida aresta Mo compton scattering > -9.76 -> Zn ka > -1.77 (peso 60.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > -9.76 -> Zn kb > 2.28 (peso 10.0)
# Mantida aresta Zn kb > 2.28 -> Mo compton scattering > -9.76 (peso 10.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La > 2.26 -> Mo compton scattering > -9.76 (peso 10.0)
# Mantida aresta Mo compton scattering > -9.76 -> Pb La > 2.26 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -7.08 -> Mo rayleigh scattering > -15.07 (peso 14.0)
# Mantida aresta Mo rayleigh scattering > -15.07 -> Mo compton scattering > -7.08 (peso 56.0)
#
# ======================================================================
#
# Removida aresta Zn ka > 1.39 -> Mo rayleigh scattering > -15.07 (peso 50.0)
# Mantida aresta Mo rayleigh scattering > -15.07 -> Zn ka > 1.39 (peso 70.0)
#
# ======================================================================
#
# Removida aresta Cu > -2.04 -> Mo rayleigh scattering > -15.07 (peso 36.0)
# Mantida aresta Mo rayleigh scattering > -15.07 -> Cu > -2.04 (peso 54.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -15.07 -> Cl > -0.72 (peso 26.0)
# Mantida aresta Cl > -0.72 -> Mo rayleigh scattering > -15.07 (peso 65.0)
#
# ======================================================================
#
# Removida aresta Cu > -1.34 -> Mo rayleigh scattering > -15.07 (peso 112.0)
# Mantida aresta Mo rayleigh scattering > -15.07 -> Cu > -1.34 (peso 238.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> Mo rayleigh scattering > -15.07 (peso 20.0)
# Mantida aresta Mo rayleigh scattering > -15.07 -> Cl > 0.80 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -15.07 -> Mo rayleigh scattering > 9.26 (peso 40.0)
# Mantida aresta Mo rayleigh scattering > 9.26 -> Mo rayleigh scattering > -15.07 (peso 70.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -15.07 -> Ni > 1.98 (peso 20.0)
# Mantida aresta Ni > 1.98 -> Mo rayleigh scattering > -15.07 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > -15.07 -> Mo compton scattering > 24.16 (peso 10.0)
# Mantida aresta Mo compton scattering > 24.16 -> Mo rayleigh scattering > -15.07 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > 24.16 -> Mo compton scattering > -7.08 (peso 60.0)
# Mantida aresta Mo compton scattering > -7.08 -> Mo compton scattering > 24.16 (peso 100.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.77 -> Mo compton scattering > -7.08 (peso 84.0)
# Mantida aresta Mo compton scattering > -7.08 -> Zn ka > -1.77 (peso 84.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> Mo compton scattering > -7.08 (peso 16.0)
# Mantida aresta Mo compton scattering > -7.08 -> Cl > 0.80 (peso 32.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -7.08 -> Cu > -2.04 (peso 26.0)
# Mantida aresta Cu > -2.04 -> Mo compton scattering > -7.08 (peso 52.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > -2.83 -> Mo compton scattering > -7.08 (peso 13.0)
# Mantida aresta Mo compton scattering > -7.08 -> Zn kb > -2.83 (peso 13.0)
#
# ======================================================================
#
# Removida aresta Ni > -0.76 -> Mo compton scattering > -7.08 (peso 13.0)
# Mantida aresta Mo compton scattering > -7.08 -> Ni > -0.76 (peso 65.0)
#
# ======================================================================
#
# Removida aresta K > -0.94 -> Mo compton scattering > -7.08 (peso 36.0)
# Mantida aresta Mo compton scattering > -7.08 -> K > -0.94 (peso 72.0)
#
# ======================================================================
#
# Empate! Removida aresta K > -4.12 -> Mo compton scattering > -7.08 (peso 42.0)
# Mantida aresta Mo compton scattering > -7.08 -> K > -4.12 (peso 42.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > -7.08 -> Ca > 0.73 (peso 11.0)
# Mantida aresta Ca > 0.73 -> Mo compton scattering > -7.08 (peso 11.0)
#
# ======================================================================
#
# Removida aresta Si > 18.46 -> Mo compton scattering > -7.08 (peso 7.0)
# Mantida aresta Mo compton scattering > -7.08 -> Si > 18.46 (peso 14.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -7.08 -> Cl > -0.72 (peso 10.0)
# Mantida aresta Cl > -0.72 -> Mo compton scattering > -7.08 (peso 20.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > -7.08 -> Ni > 1.98 (peso 9.0)
# Mantida aresta Ni > 1.98 -> Mo compton scattering > -7.08 (peso 27.0)
#
# ======================================================================
#
# Removida aresta Cl > -0.72 -> Mo compton scattering > 24.16 (peso 21.0)
# Mantida aresta Mo compton scattering > 24.16 -> Cl > -0.72 (peso 28.0)
#
# ======================================================================
#
# Removida aresta K > -4.12 -> Mo compton scattering > 24.16 (peso 30.0)
# Mantida aresta Mo compton scattering > 24.16 -> K > -4.12 (peso 40.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -2.86 -> Mo compton scattering > 24.16 (peso 9.0)
# Mantida aresta Mo compton scattering > 24.16 -> Zn ka > -2.86 (peso 54.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -1.77 -> Mo compton scattering > 24.16 (peso 45.0)
# Mantida aresta Mo compton scattering > 24.16 -> Zn ka > -1.77 (peso 63.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > 24.16 -> Pb Lb > -1.10 (peso 9.0)
# Mantida aresta Pb Lb > -1.10 -> Mo compton scattering > 24.16 (peso 9.0)
#
# ======================================================================
#
# Removida aresta Si > 18.46 -> Mo compton scattering > 24.16 (peso 5.0)
# Mantida aresta Mo compton scattering > 24.16 -> Si > 18.46 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > 24.16 -> Cl > 0.80 (peso 7.0)
# Mantida aresta Cl > 0.80 -> Mo compton scattering > 24.16 (peso 14.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > 24.16 -> Cu > -2.04 (peso 20.0)
# Mantida aresta Cu > -2.04 -> Mo compton scattering > 24.16 (peso 50.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering > 24.16 -> Pb La > 2.26 (peso 8.0)
# Mantida aresta Pb La > 2.26 -> Mo compton scattering > 24.16 (peso 8.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > 24.16 -> Ni > 1.98 (peso 8.0)
# Mantida aresta Ni > 1.98 -> Mo compton scattering > 24.16 (peso 16.0)
#
# ======================================================================
#
# Removida aresta Ni > -0.76 -> Mo compton scattering > 24.16 (peso 9.0)
# Mantida aresta Mo compton scattering > 24.16 -> Ni > -0.76 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering > 24.16 -> K > -0.94 (peso 9.0)
# Mantida aresta K > -0.94 -> Mo compton scattering > 24.16 (peso 27.0)
#
# ======================================================================
#
# Removida aresta Cl > -0.72 -> Mo rayleigh scattering > 9.26 (peso 63.0)
# Mantida aresta Mo rayleigh scattering > 9.26 -> Cl > -0.72 (peso 99.0)
#
# ======================================================================
#
# Removida aresta Cu > -1.34 -> Cl > -0.72 (peso 52.0)
# Mantida aresta Cl > -0.72 -> Cu > -1.34 (peso 65.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > 1.39 -> Cl > -0.72 (peso 36.0)
# Mantida aresta Cl > -0.72 -> Zn ka > 1.39 (peso 36.0)
#
# ======================================================================
#
# Removida aresta Cl > -0.72 -> Cu > -2.04 (peso 14.0)
# Mantida aresta Cu > -2.04 -> Cl > -0.72 (peso 28.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> Cl > -0.72 (peso 20.0)
# Mantida aresta Cl > -0.72 -> Cl > 0.80 (peso 50.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn ka > -1.77 -> Cl > -0.72 (peso 26.0)
# Mantida aresta Cl > -0.72 -> Zn ka > -1.77 (peso 26.0)
#
# ======================================================================
#
# Removida aresta K > -4.12 -> Cl > -0.72 (peso 13.0)
# Mantida aresta Cl > -0.72 -> K > -4.12 (peso 52.0)
#
# ======================================================================
#
# Empate! Removida aresta Si > -3.95 -> Cl > -0.72 (peso 15.0)
# Mantida aresta Cl > -0.72 -> Si > -3.95 (peso 15.0)
#
# ======================================================================
#
# Empate! Removida aresta Ni > -0.76 -> Cl > -0.72 (peso 12.0)
# Mantida aresta Cl > -0.72 -> Ni > -0.76 (peso 12.0)
#
# ======================================================================
#
# Empate! Removida aresta Ni > -1.81 -> Cl > -0.72 (peso 15.0)
# Mantida aresta Cl > -0.72 -> Ni > -1.81 (peso 15.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering > 9.26 -> Cu > -1.34 (peso 30.0)
# Mantida aresta Cu > -1.34 -> Mo rayleigh scattering > 9.26 (peso 60.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo rayleigh scattering > 9.26 -> Cl > 0.80 (peso 16.0)
# Mantida aresta Cl > 0.80 -> Mo rayleigh scattering > 9.26 (peso 16.0)
#
# ======================================================================
#
# Removida aresta Ni > 1.98 -> Mo rayleigh scattering > 9.26 (peso 8.0)
# Mantida aresta Mo rayleigh scattering > 9.26 -> Ni > 1.98 (peso 24.0)
#
# ======================================================================
#
# Removida aresta K > -0.94 -> K > -4.12 (peso 60.0)
# Mantida aresta K > -4.12 -> K > -0.94 (peso 240.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -2.86 -> K > -4.12 (peso 17.0)
# Mantida aresta K > -4.12 -> Zn ka > -2.86 (peso 51.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka > 0.74 -> K > -4.12 (peso 14.0)
# Mantida aresta K > -4.12 -> Fe ka > 0.74 (peso 14.0)
#
# ======================================================================
#
# Removida aresta Zn ka > 1.39 -> K > -4.12 (peso 9.0)
# Mantida aresta K > -4.12 -> Zn ka > 1.39 (peso 27.0)
#
# ======================================================================
#
# Empate! Removida aresta K > -4.12 -> Ni > 1.98 (peso 18.0)
# Mantida aresta Ni > 1.98 -> K > -4.12 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering <= 86.16 -> K > -4.12 (peso 15.0)
# Mantida aresta K > -4.12 -> Mo compton scattering <= 86.16 (peso 30.0)
#
# ======================================================================
#
# Removida aresta K > -4.12 -> Zn ka > -1.77 (peso 70.0)
# Mantida aresta Zn ka > -1.77 -> K > -4.12 (peso 140.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka > -1.25 -> K > -4.12 (peso 18.0)
# Mantida aresta K > -4.12 -> Fe ka > -1.25 (peso 18.0)
#
# ======================================================================
#
# Empate! Removida aresta K > -4.12 -> Si > 18.46 (peso 30.0)
# Mantida aresta Si > 18.46 -> K > -4.12 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 > 7.87 -> K > -4.12 (peso 18.0)
# Mantida aresta K > -4.12 -> background6 > 7.87 (peso 18.0)
#
# ======================================================================
#
# Removida aresta K > -4.12 -> Ni > -0.76 (peso 42.0)
# Mantida aresta Ni > -0.76 -> K > -4.12 (peso 56.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > 10.84 -> K > -4.12 (peso 10.0)
# Mantida aresta K > -4.12 -> background5 > 10.84 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Pb La > 0.07 -> K > -4.12 (peso 13.0)
# Mantida aresta K > -4.12 -> Pb La > 0.07 (peso 26.0)
#
# ======================================================================
#
# Empate! Removida aresta K > -0.94 -> K > 4.62 (peso 10.0)
# Mantida aresta K > 4.62 -> K > -0.94 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Ni > -0.76 -> K > -0.94 (peso 44.0)
# Mantida aresta K > -0.94 -> Ni > -0.76 (peso 88.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> K > -0.94 (peso 9.0)
# Mantida aresta K > -0.94 -> Cl > 0.80 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Si > 18.46 -> K > -0.94 (peso 18.0)
# Mantida aresta K > -0.94 -> Si > 18.46 (peso 42.0)
#
# ======================================================================
#
# Removida aresta K > -0.94 -> Ga > 1.26 (peso 9.0)
# Mantida aresta Ga > 1.26 -> K > -0.94 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Zn kb > -2.83 -> K > -0.94 (peso 12.0)
# Mantida aresta K > -0.94 -> Zn kb > -2.83 (peso 24.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -2.86 -> K > -0.94 (peso 13.0)
# Mantida aresta K > -0.94 -> Zn ka > -2.86 (peso 78.0)
#
# ======================================================================
#
# Removida aresta K > -0.94 -> Zn ka > -1.77 (peso 11.0)
# Mantida aresta Zn ka > -1.77 -> K > -0.94 (peso 33.0)
#
# ======================================================================
#
# Empate! Removida aresta K > -0.94 -> Ni > 1.98 (peso 18.0)
# Mantida aresta Ni > 1.98 -> K > -0.94 (peso 18.0)
#
# ======================================================================
#
# Removida aresta K > -0.94 -> Ga > 8.60 (peso 5.0)
# Mantida aresta Ga > 8.60 -> K > -0.94 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> K > 4.62 (peso 6.0)
# Mantida aresta K > 4.62 -> Cl > 0.80 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Ga > 1.26 -> K > 4.62 (peso 6.0)
# Mantida aresta K > 4.62 -> Ga > 1.26 (peso 12.0)
#
# ======================================================================
#
# Removida aresta Pb La > 2.26 -> K > 4.62 (peso 25.0)
# Mantida aresta K > 4.62 -> Pb La > 2.26 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Zn kb > 2.28 -> K > 4.62 (peso 16.0)
# Mantida aresta K > 4.62 -> Zn kb > 2.28 (peso 20.0)
#
# ======================================================================
#
# Removida aresta background5 > -0.34 -> K > 4.62 (peso 20.0)
# Mantida aresta K > 4.62 -> background5 > -0.34 (peso 30.0)
#
# ======================================================================
#
# Removida aresta K > 4.62 -> Ni > -1.81 (peso 18.0)
# Mantida aresta Ni > -1.81 -> K > 4.62 (peso 72.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > -0.30 -> K > 4.62 (peso 6.0)
# Mantida aresta K > 4.62 -> Zn kb > -0.30 (peso 6.0)
#
# ======================================================================
#
# Removida aresta K > 4.62 -> Si > -3.95 (peso 9.0)
# Mantida aresta Si > -3.95 -> K > 4.62 (peso 18.0)
#
# ======================================================================
#
# Empate! Removida aresta K > 4.62 -> Fe ka > 4.44 (peso 5.0)
# Mantida aresta Fe ka > 4.44 -> K > 4.62 (peso 5.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La > 0.07 -> K > 4.62 (peso 18.0)
# Mantida aresta K > 4.62 -> Pb La > 0.07 (peso 18.0)
#
# ======================================================================
#
# Removida aresta Zn ka > -2.86 -> K > 4.62 (peso 16.0)
# Mantida aresta K > 4.62 -> Zn ka > -2.86 (peso 24.0)
#
# ======================================================================
#
# Empate! Removida aresta K > 4.62 -> Cu > 1.22 (peso 12.0)
# Mantida aresta Cu > 1.22 -> K > 4.62 (peso 12.0)
#
# ======================================================================
#
# Removida aresta K > 4.62 -> Si > 2.81 (peso 6.0)
# Mantida aresta Si > 2.81 -> K > 4.62 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La > -2.18 -> K > 4.62 (peso 9.0)
# Mantida aresta K > 4.62 -> Pb La > -2.18 (peso 9.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> Ni > 1.98 (peso 28.0)
# Mantida aresta Ni > 1.98 -> Cl > 0.80 (peso 42.0)
#
# ======================================================================
#
# Removida aresta Ni > -0.76 -> Cl > 0.80 (peso 18.0)
# Mantida aresta Cl > 0.80 -> Ni > -0.76 (peso 45.0)
#
# ======================================================================
#
# Empate! Removida aresta Si > 2.81 -> Cl > 0.80 (peso 10.0)
# Mantida aresta Cl > 0.80 -> Si > 2.81 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Cu > -2.04 -> Cl > 0.80 (peso 10.0)
# Mantida aresta Cl > 0.80 -> Cu > -2.04 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > 4.37 -> Cl > 0.80 (peso 8.0)
# Mantida aresta Cl > 0.80 -> background5 > 4.37 (peso 8.0)
#
# ======================================================================
#
# Removida aresta Cl > 0.80 -> Cu > -1.34 (peso 18.0)
# Mantida aresta Cu > -1.34 -> Cl > 0.80 (peso 36.0)
#
# ======================================================================
#
# Empate! Removida aresta Si > 18.46 -> Cl > 0.80 (peso 12.0)
# Mantida aresta Cl > 0.80 -> Si > 18.46 (peso 12.0)
#
# ======================================================================
#
# Empate! Removida aresta Zn kb > -0.30 -> Cl > 0.80 (peso 9.0)
# Mantida aresta Cl > 0.80 -> Zn kb > -0.30 (peso 9.0)
#
# ======================================================================
#
# Removida aresta Ni > 1.98 -> Zn ka > 1.39 (peso 32.0)
# Mantida aresta Zn ka > 1.39 -> Ni > 1.98 (peso 80.0)
#
# ======================================================================
#
# Removida aresta Cu > -2.04 -> Ni > 1.98 (peso 60.0)
# Mantida aresta Ni > 1.98 -> Cu > -2.04 (peso 80.0)
#
# ======================================================================
#
# Removida aresta Cu > 1.22 -> Ni > 1.98 (peso 10.0)
# Mantida aresta Ni > 1.98 -> Cu > 1.22 (peso 50.0)
#
# ======================================================================
#
# Removida aresta Ni > 1.98 -> Si > 18.46 (peso 4.0)
# Mantida aresta Si > 18.46 -> Ni > 1.98 (peso 12.0)
#
# ======================================================================
#
# Empate! Removida aresta Ni > 1.98 -> Zn ka > -1.77 (peso 10.0)
# Mantida aresta Zn ka > -1.77 -> Ni > 1.98 (peso 10.0)
#
# ======================================================================
#
# Removida aresta background5 > -0.34 -> Mo compton scattering <= 86.16 (peso 45.0)
# Mantida aresta Mo compton scattering <= 86.16 -> background5 > -0.34 (peso 105.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering <= 86.16 -> Ca > -2.57 (peso 14.0)
# Mantida aresta Ca > -2.57 -> Mo compton scattering <= 86.16 (peso 42.0)
#
# ======================================================================
#
# Removida aresta Zn kb > -0.30 -> Mo compton scattering <= 86.16 (peso 10.0)
# Mantida aresta Mo compton scattering <= 86.16 -> Zn kb > -0.30 (peso 20.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering <= 86.16 -> Zn kb > 2.28 (peso 25.0)
# Mantida aresta Zn kb > 2.28 -> Mo compton scattering <= 86.16 (peso 25.0)
#
# ======================================================================
#
# Removida aresta background1 > -5.05 -> Mo compton scattering <= 86.16 (peso 15.0)
# Mantida aresta Mo compton scattering <= 86.16 -> background1 > -5.05 (peso 60.0)
#
# ======================================================================
#
# Empate! Removida aresta Ga > 1.26 -> Mo compton scattering <= 86.16 (peso 10.0)
# Mantida aresta Mo compton scattering <= 86.16 -> Ga > 1.26 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Pb Lb > 2.70 -> Mo compton scattering <= 86.16 (peso 5.0)
# Mantida aresta Mo compton scattering <= 86.16 -> Pb Lb > 2.70 (peso 20.0)
#
# ======================================================================
#
# Removida aresta Fe ka > -1.25 -> Mo compton scattering <= 86.16 (peso 15.0)
# Mantida aresta Mo compton scattering <= 86.16 -> Fe ka > -1.25 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering <= 86.16 -> background6 > 0.67 (peso 10.0)
# Mantida aresta background6 > 0.67 -> Mo compton scattering <= 86.16 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering <= 86.16 -> background5 > 4.37 (peso 10.0)
# Mantida aresta background5 > 4.37 -> Mo compton scattering <= 86.16 (peso 10.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka > 0.74 -> Mo compton scattering <= 86.16 (peso 20.0)
# Mantida aresta Mo compton scattering <= 86.16 -> Fe ka > 0.74 (peso 20.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering <= 86.16 -> Pb La > 0.07 (peso 30.0)
# Mantida aresta Pb La > 0.07 -> Mo compton scattering <= 86.16 (peso 40.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka > 4.44 -> Mo compton scattering <= 86.16 (peso 10.0)
# Mantida aresta Mo compton scattering <= 86.16 -> Fe ka > 4.44 (peso 10.0)
#
# ======================================================================
#
# Removida aresta background6 > -1.75 -> Mo compton scattering <= 86.16 (peso 30.0)
# Mantida aresta Mo compton scattering <= 86.16 -> background6 > -1.75 (peso 45.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering <= 86.16 -> background5 > 10.84 (peso 5.0)
# Mantida aresta background5 > 10.84 -> Mo compton scattering <= 86.16 (peso 10.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering <= 86.16 -> Ni > -1.81 (peso 30.0)
# Mantida aresta Ni > -1.81 -> Mo compton scattering <= 86.16 (peso 30.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering <= 86.16 -> Ca <= 26.21 (peso 16.0)
# Mantida aresta Ca <= 26.21 -> Mo compton scattering <= 86.16 (peso 16.0)
#
# ======================================================================
#
# Empate! Removida aresta Mo compton scattering <= 86.16 -> Si <= 44.53 (peso 16.0)
# Mantida aresta Si <= 44.53 -> Mo compton scattering <= 86.16 (peso 16.0)
#
# ======================================================================
#
# Removida aresta Mo compton scattering <= 86.16 -> Si > -3.95 (peso 15.0)
# Mantida aresta Si > -3.95 -> Mo compton scattering <= 86.16 (peso 60.0)
#
# ======================================================================
#
# Removida aresta background5 > -0.34 -> Cu > 1.22 (peso 10.0)
# Mantida aresta Cu > 1.22 -> background5 > -0.34 (peso 20.0)
#
# ======================================================================
#
# Removida aresta background5 > 4.37 -> background5 > -0.34 (peso 60.0)
# Mantida aresta background5 > -0.34 -> background5 > 4.37 (peso 75.0)
#
# ======================================================================
#
# Removida aresta background1 > -5.05 -> background5 > -0.34 (peso 32.0)
# Mantida aresta background5 > -0.34 -> background1 > -5.05 (peso 48.0)
#
# ======================================================================
#
# Removida aresta background5 > -0.34 -> Zn kb > -0.30 (peso 36.0)
# Mantida aresta Zn kb > -0.30 -> background5 > -0.34 (peso 48.0)
#
# ======================================================================
#
# ...
#
# ======================================================================
#
# Removida aresta Ni <= 1.98 -> Zn ka <= -1.77 (peso 20.0)
# Mantida aresta Zn ka <= -1.77 -> Ni <= 1.98 (peso 40.0)
#
# ======================================================================
#
# Removida aresta background3 > 3.03 -> background4 <= 0.32 (peso 4.0)
# Mantida aresta background4 <= 0.32 -> background3 > 3.03 (peso 12.0)
#
# ======================================================================
#
# Removida aresta background6 <= 0.67 -> background4 <= 0.32 (peso 16.0)
# Mantida aresta background4 <= 0.32 -> background6 <= 0.67 (peso 40.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 0.32 -> Fe kb <= 3.99 (peso 27.0)
# Mantida aresta Fe kb <= 3.99 -> background4 <= 0.32 (peso 27.0)
#
# ======================================================================
#
# Removida aresta background4 <= 0.32 -> Zn ka <= -1.77 (peso 9.0)
# Mantida aresta Zn ka <= -1.77 -> background4 <= 0.32 (peso 45.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering <= 9.26 -> background6 <= 17.05 (peso 15.0)
# Mantida aresta background6 <= 17.05 -> Mo rayleigh scattering <= 9.26 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Cu <= 1.22 -> background6 <= 17.05 (peso 30.0)
# Mantida aresta background6 <= 17.05 -> Cu <= 1.22 (peso 45.0)
#
# ======================================================================
#
# Removida aresta background6 <= 17.05 -> Fe kb <= 3.99 (peso 14.0)
# Mantida aresta Fe kb <= 3.99 -> background6 <= 17.05 (peso 28.0)
#
# ======================================================================
#
# Removida aresta Zn ka <= -1.77 -> background6 <= 17.05 (peso 10.0)
# Mantida aresta background6 <= 17.05 -> Zn ka <= -1.77 (peso 20.0)
#
# ======================================================================
#
# Empate! Removida aresta Cl <= 94.61 -> Mo rayleigh scattering <= 9.26 (peso 28.0)
# Mantida aresta Mo rayleigh scattering <= 9.26 -> Cl <= 94.61 (peso 28.0)
#
# ======================================================================
#
# Removida aresta Pb La <= 0.07 -> Mo rayleigh scattering <= 9.26 (peso 10.0)
# Mantida aresta Mo rayleigh scattering <= 9.26 -> Pb La <= 0.07 (peso 40.0)
#
# ======================================================================
#
# Removida aresta Ca <= 0.73 -> Mo rayleigh scattering <= 9.26 (peso 9.0)
# Mantida aresta Mo rayleigh scattering <= 9.26 -> Ca <= 0.73 (peso 27.0)
#
# ======================================================================
#
# Empate! Removida aresta Cl <= -0.72 -> Mo rayleigh scattering <= 9.26 (peso 9.0)
# Mantida aresta Mo rayleigh scattering <= 9.26 -> Cl <= -0.72 (peso 9.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering <= 9.26 -> Zn ka <= -1.77 (peso 10.0)
# Mantida aresta Zn ka <= -1.77 -> Mo rayleigh scattering <= 9.26 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Mo rayleigh scattering <= 9.26 -> Cu <= 1.22 (peso 13.0)
# Mantida aresta Cu <= 1.22 -> Mo rayleigh scattering <= 9.26 (peso 26.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 3.99 -> Cl <= 94.61 (peso 13.0)
# Mantida aresta Cl <= 94.61 -> Fe kb <= 3.99 (peso 13.0)
#
# ======================================================================
#
# Empate! Removida aresta Cl <= 94.61 -> Cl <= -0.72 (peso 10.0)
# Mantida aresta Cl <= -0.72 -> Cl <= 94.61 (peso 10.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 1.22 -> Cl <= 94.61 (peso 14.0)
# Mantida aresta Cl <= 94.61 -> Cu <= 1.22 (peso 14.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 0.68 -> background4 > 4.06 (peso 2.0)
# Mantida aresta background4 > 4.06 -> background2 <= 0.68 (peso 2.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 3.99 -> background4 > 4.06 (peso 3.0)
# Mantida aresta background4 > 4.06 -> Fe kb <= 3.99 (peso 3.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca <= 0.73 -> background4 > 4.06 (peso 0.0)
# Mantida aresta background4 > 4.06 -> Ca <= 0.73 (peso 0.0)
#
# ======================================================================
#
# Removida aresta K <= -0.94 -> background4 > 4.06 (peso 1.0)
# Mantida aresta background4 > 4.06 -> K <= -0.94 (peso 3.0)
#
# ======================================================================
#
# Removida aresta Ga <= 8.60 -> background4 > 4.06 (peso 5.0)
# Mantida aresta background4 > 4.06 -> Ga <= 8.60 (peso 10.0)
#
# ======================================================================
#
# Removida aresta background3 > 3.03 -> background4 > 4.06 (peso 9.0)
# Mantida aresta background4 > 4.06 -> background3 > 3.03 (peso 36.0)
#
# ======================================================================
#
# Removida aresta background6 <= 7.87 -> background4 > 4.06 (peso 2.0)
# Mantida aresta background4 > 4.06 -> background6 <= 7.87 (peso 4.0)
#
# ======================================================================
#
# Removida aresta background4 > 4.06 -> Pb La <= 0.07 (peso 1.0)
# Mantida aresta Pb La <= 0.07 -> background4 > 4.06 (peso 2.0)
#
# ======================================================================
#
# Removida aresta Zn ka <= -1.77 -> Fe kb <= 3.99 (peso 18.0)
# Mantida aresta Fe kb <= 3.99 -> Zn ka <= -1.77 (peso 27.0)
#
# ======================================================================
#
# Removida aresta Cu <= 1.22 -> Fe kb <= 3.99 (peso 24.0)
# Mantida aresta Fe kb <= 3.99 -> Cu <= 1.22 (peso 36.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 3.99 -> Pb La <= 0.07 (peso 30.0)
# Mantida aresta Pb La <= 0.07 -> Fe kb <= 3.99 (peso 60.0)
#
# ======================================================================
#
# Removida aresta background6 <= 0.67 -> Fe kb <= 3.99 (peso 18.0)
# Mantida aresta Fe kb <= 3.99 -> background6 <= 0.67 (peso 36.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 3.99 -> Cl <= -0.72 (peso 9.0)
# Mantida aresta Cl <= -0.72 -> Fe kb <= 3.99 (peso 9.0)
#
# ======================================================================
#
# Removida aresta Zn ka <= -1.77 -> background6 <= 0.67 (peso 9.0)
# Mantida aresta background6 <= 0.67 -> Zn ka <= -1.77 (peso 18.0)
#
# ======================================================================
#
# Empate! Removida aresta K <= -0.94 -> Zn ka <= -1.77 (peso 6.0)
# Mantida aresta Zn ka <= -1.77 -> K <= -0.94 (peso 6.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La <= 0.07 -> background6 <= 0.67 (peso 24.0)
# Mantida aresta background6 <= 0.67 -> Pb La <= 0.07 (peso 24.0)
#
# ======================================================================
#
# Removida aresta background6 <= 0.67 -> background6 <= 7.87 (peso 20.0)
# Mantida aresta background6 <= 7.87 -> background6 <= 0.67 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 0.74 -> background6 <= 0.67 (peso 7.0)
# Mantida aresta background6 <= 0.67 -> Fe ka <= 0.74 (peso 21.0)
#
# ======================================================================
#
# Removida aresta Cl <= -0.72 -> background6 <= 0.67 (peso 7.0)
# Mantida aresta background6 <= 0.67 -> Cl <= -0.72 (peso 49.0)
#
# ======================================================================
#
# Removida aresta Cu <= 1.22 -> background6 <= 0.67 (peso 20.0)
# Mantida aresta background6 <= 0.67 -> Cu <= 1.22 (peso 50.0)
#
# ======================================================================
#
# Removida aresta background6 <= 0.67 -> K <= -0.94 (peso 6.0)
# Mantida aresta K <= -0.94 -> background6 <= 0.67 (peso 48.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 0.67 -> Ga <= 8.60 (peso 5.0)
# Mantida aresta Ga <= 8.60 -> background6 <= 0.67 (peso 5.0)
#
# ======================================================================
#
# Removida aresta Cu <= 1.22 -> Pb La <= 0.07 (peso 30.0)
# Mantida aresta Pb La <= 0.07 -> Cu <= 1.22 (peso 50.0)
#
# ======================================================================
#
# Removida aresta Ca <= 0.73 -> Pb La <= 0.07 (peso 24.0)
# Mantida aresta Pb La <= 0.07 -> Ca <= 0.73 (peso 42.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La <= 0.07 -> K <= -0.94 (peso 12.0)
# Mantida aresta K <= -0.94 -> Pb La <= 0.07 (peso 12.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La <= 0.07 -> Fe ka <= 0.74 (peso 16.0)
# Mantida aresta Fe ka <= 0.74 -> Pb La <= 0.07 (peso 16.0)
#
# ======================================================================
#
# Empate! Removida aresta Pb La <= 0.07 -> background6 <= 7.87 (peso 30.0)
# Mantida aresta background6 <= 7.87 -> Pb La <= 0.07 (peso 30.0)
#
# ======================================================================
#
# Removida aresta Cl <= -0.72 -> Cu <= 1.22 (peso 45.0)
# Mantida aresta Cu <= 1.22 -> Cl <= -0.72 (peso 54.0)
#
# ======================================================================
#
# Removida aresta K <= -0.94 -> Cu <= 1.22 (peso 45.0)
# Mantida aresta Cu <= 1.22 -> K <= -0.94 (peso 72.0)
#
# ======================================================================
#
# Removida aresta Cu <= 1.22 -> Ca <= 0.73 (peso 36.0)
# Mantida aresta Ca <= 0.73 -> Cu <= 1.22 (peso 54.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 1.22 -> Fe ka <= 0.74 (peso 27.0)
# Mantida aresta Fe ka <= 0.74 -> Cu <= 1.22 (peso 27.0)
#
# ======================================================================
#
# Removida aresta background6 <= 7.87 -> Cu <= 1.22 (peso 30.0)
# Mantida aresta Cu <= 1.22 -> background6 <= 7.87 (peso 90.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca <= -2.57 -> Cu <= 1.22 (peso 5.0)
# Mantida aresta Cu <= 1.22 -> Ca <= -2.57 (peso 5.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 1.22 -> background3 > 3.03 (peso 12.0)
# Mantida aresta background3 > 3.03 -> Cu <= 1.22 (peso 12.0)
#
# ======================================================================
#
# Removida aresta Ca <= 0.73 -> Cl <= -0.72 (peso 30.0)
# Mantida aresta Cl <= -0.72 -> Ca <= 0.73 (peso 48.0)
#
# ======================================================================
#
# Empate! Removida aresta Cl <= -0.72 -> background6 <= 7.87 (peso 18.0)
# Mantida aresta background6 <= 7.87 -> Cl <= -0.72 (peso 18.0)
#
# ======================================================================
#
# Removida aresta K <= -0.94 -> Cl <= -0.72 (peso 6.0)
# Mantida aresta Cl <= -0.72 -> K <= -0.94 (peso 12.0)
#
# ======================================================================
#
# Removida aresta Cl <= -0.72 -> Fe ka <= 0.74 (peso 12.0)
# Mantida aresta Fe ka <= 0.74 -> Cl <= -0.72 (peso 36.0)
#
# ======================================================================
#
# Removida aresta background3 > 3.03 -> Ga <= 8.60 (peso 7.0)
# Mantida aresta Ga <= 8.60 -> background3 > 3.03 (peso 28.0)
#
# ======================================================================
#
# Empate! Removida aresta background6 <= 7.87 -> Ga <= 8.60 (peso 10.0)
# Mantida aresta Ga <= 8.60 -> background6 <= 7.87 (peso 10.0)
#
# ======================================================================
#
# Removida aresta background3 > 3.03 -> Fe ka <= 0.74 (peso 6.0)
# Mantida aresta Fe ka <= 0.74 -> background3 > 3.03 (peso 12.0)
#
# ======================================================================
#
# Removida aresta background3 > 3.03 -> background6 <= 7.87 (peso 18.0)
# Mantida aresta background6 <= 7.87 -> background3 > 3.03 (peso 24.0)
#
# ======================================================================
#
# Removida aresta Ca <= 0.73 -> background3 > 3.03 (peso 4.0)
# Mantida aresta background3 > 3.03 -> Ca <= 0.73 (peso 8.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 3.03 -> K <= -0.94 (peso 10.0)
# Mantida aresta K <= -0.94 -> background3 > 3.03 (peso 10.0)
#
# ======================================================================
#
# Removida aresta Ca <= 0.73 -> Fe ka <= 0.74 (peso 30.0)
# Mantida aresta Fe ka <= 0.74 -> Ca <= 0.73 (peso 42.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 0.74 -> K <= -0.94 (peso 28.0)
# Mantida aresta K <= -0.94 -> Fe ka <= 0.74 (peso 70.0)
#
# ======================================================================
#
# Removida aresta background6 <= 7.87 -> Fe ka <= 0.74 (peso 18.0)
# Mantida aresta Fe ka <= 0.74 -> background6 <= 7.87 (peso 36.0)
#
# ======================================================================
#
# Removida aresta K <= -0.94 -> Ca <= 0.73 (peso 27.0)
# Mantida aresta Ca <= 0.73 -> K <= -0.94 (peso 45.0)
#
# ======================================================================
#
# Removida aresta background6 <= 7.87 -> Ca <= 0.73 (peso 45.0)
# Mantida aresta Ca <= 0.73 -> background6 <= 7.87 (peso 54.0)
#
# ======================================================================
#
# Removida aresta Ca <= 0.73 -> Ca <= -2.57 (peso 6.0)
# Mantida aresta Ca <= -2.57 -> Ca <= 0.73 (peso 12.0)
#
# ======================================================================
#
# Removida aresta K <= -0.94 -> background6 <= 7.87 (peso 9.0)
# Mantida aresta background6 <= 7.87 -> K <= -0.94 (peso 27.0)
#
# ======================================================================
#
# Removida aresta Ca <= -2.57 -> background6 <= 7.87 (peso 5.0)
# Mantida aresta background6 <= 7.87 -> Ca <= -2.57 (peso 10.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 3706
# Total de arestas removidas por bidirecionalidade: 1103
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 127
# Total de nós terminais: 2
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#
# /home/jvribeiro/.local/lib/python3.10/site-packages/networkx/algorithms/centrality/reaching.py:193: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#                    Predicate_Seed_0               Predicate_Seed_1  \
# 0                         Cu > 1.22                      K > -4.12
# 1                        Cl > -1.90  Mo rayleigh scattering > 9.26
# 2    Mo rayleigh scattering > -7.45                      Cu > 1.22
# 3     Mo rayleigh scattering > 9.26  Mo compton scattering > -7.08
# 4                         K > -4.12                      Cl > 0.80
# ..                              ...                            ...
# 124                       Ca > 8.01                     Cl <= 0.80
# 125                     Cl <= -0.72                   Fe kb > 3.99
# 126                     Ca <= -2.57             background4 > 4.06
# 127                         Class_A                        Class_A
# 128                         Class_B                        Class_B
#
#                    Predicate_Seed_42
# 0                          Cu > 1.22
# 1                         Cl > -1.90
# 2      Mo rayleigh scattering > 9.26
# 3                         Ni <= 5.95
# 4                       Zn ka > 1.39
# ..                               ...
# 124              background3 <= 5.15
# 125  Mo rayleigh scattering <= -7.45
# 126                     Fe kb > 3.99
# 127                          Class_A
# 128                          Class_B
#
# [129 rows x 3 columns]

# %%
features_importance = pd.DataFrame({
    'Vip' : vip_scores_unique_df['Zone'].values,
    'Reg_coef' : reg_vet_unique_df['Zone'].values,
    'Shap' : shap_unique_df['Zone'].values
    })

for seed, lrc_unique_df in lrc_unique_by_seed.items():
    zones = lrc_unique_df['Zone'].values
    # condição para padronizar o tamanho das listas (usando o tamanho do features_importance)
    if len(zones) < len(features_importance):
        zones = np.concatenate([zones, [None]*(len(features_importance)-len(zones))]) # adicionando None para completar o tamanho
    features_importance[f'LRC_Seed_{seed}'] = zones[:len(features_importance)]
features_importance
# Out:
#                        Vip                Reg_coef                    Shap  \
# 0                       Cl                   Fe ka                       K
# 1                    Fe ka                       K                   Zn ka
# 2                        K                   Zn ka   Mo compton scattering
# 3                       Cu   Mo compton scattering                   Fe ka
# 4                    Zn ka                      Cu                      Cu
# 5    Mo compton scattering                   Fe kb                      Si
# 6   Mo rayleigh scattering                      Ca  Mo rayleigh scattering
# 7                       Ni                      Ni                      Cl
# 8                    Fe kb                      Si             background1
# 9                       Ca  Mo rayleigh scattering             background5
# 10                      Si                      Ga             background4
# 11                   Zn kb             background5                   Pb La
# 12                      Ga                   Zn kb                   Pb Lb
# 13             background5             background6             background6
# 14                   Pb La             background3                     NaN
# 15             background1             background1                      Ca
# 16                   Pb Lb                   Pb La             background2
# 17             background6                      Cl                      Ga
# 18             background3                     NaN                   Zn kb
# 19                     NaN                   Pb Lb             background3
# 20             background2             background2                   Fe kb
# 21             background4             background4                      Ni
#
#                 LRC_Seed_0              LRC_Seed_1             LRC_Seed_42
# 0                       Cu                       K                      Cu
# 1                       Cl  Mo rayleigh scattering                      Cl
# 2   Mo rayleigh scattering                      Cu  Mo rayleigh scattering
# 3                        K   Mo compton scattering                      Ni
# 4                    Zn ka                      Cl                   Zn ka
# 5              background4                      Ni                   Pb Lb
# 6                       Ni             background2             background2
# 7    Mo compton scattering                   Fe kb                   Pb La
# 8              background1                   Pb La             background5
# 9              background2                   Zn ka   Mo compton scattering
# 10                   Fe kb             background5                       K
# 11             background6                   Pb Lb                   Fe kb
# 12                   Pb La             background3                      Ca
# 13             background5                   Zn kb             background4
# 14                      Ca                      Ca             background6
# 15                   Zn kb             background1             background1
# 16                      Ga                   Fe ka             background3
# 17             background3                      Ga                      Ga
# 18                      Si             background4                   Fe ka
# 19                   Fe ka             background6                   Zn kb
# 20                   Pb Lb                      Si                      Si
# 21                    None                    None                    None

# %% [markdown]
# ## **RBO**

# %%
# utilizando o Rank-Biased Overlap (RBO) para comparar as listas de importância de características tendo o vip como referencia
# com p = 1 é rbo equivalente ao overlap simples (interseção sobre união) sem peso para posições iniciais
# quanto menor o p, mais peso é dado para as posições iniciais da lista (mais relevante para nosso caso)
import rbo

rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if pd.notnull(x)]
methods = ['Reg_coef', 'Shap'] + [f'LRC_Seed_{seed}' for seed in random_seeds]
rbo_results = {}
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if pd.notnull(x)]
    # Ensure both lists are the same length for RBO calculation
    min_len = min(len(reference_list), len(compare_list))
    ref_trimmed = reference_list[:min_len]
    comp_trimmed = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trimmed, comp_trimmed).rbo(p=0.7, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method', 'RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_results
# Out:
#   Reference       Method  RBO_Score
# 0       Vip     Reg_coef   0.422178
# 2       Vip   LRC_Seed_0   0.391167
# 4       Vip  LRC_Seed_42   0.326360
# 1       Vip         Shap   0.273888
# 3       Vip   LRC_Seed_1   0.244158

# %%
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from both lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Ensure both lists are the same length for RBO calculation
        min_len = min(len(list_1), len(list_2))
        list_1_trimmed = list_1[:min_len]
        list_2_trimmed = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trimmed, list_2_trimmed).rbo(p=0.7, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison
# Out:
# /tmp/ipykernel_796404/2643269889.py:15: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#       Method_1     Method_2  RBO_Score
# 13  LRC_Seed_0  LRC_Seed_42   0.884147
# 10        Shap   LRC_Seed_1   0.626360
# 5     Reg_coef         Shap   0.480603
# 0          Vip     Reg_coef   0.422178
# 2          Vip   LRC_Seed_0   0.391167
# 12  LRC_Seed_0   LRC_Seed_1   0.331368
# 4          Vip  LRC_Seed_42   0.326360
# 7     Reg_coef   LRC_Seed_1   0.322528
# 14  LRC_Seed_1  LRC_Seed_42   0.288148
# 1          Vip         Shap   0.273888
# 3          Vip   LRC_Seed_1   0.244158
# 9         Shap   LRC_Seed_0   0.154777
# 6     Reg_coef   LRC_Seed_0   0.141593
# 11        Shap  LRC_Seed_42   0.088048
# 8     Reg_coef  LRC_Seed_42   0.076786
