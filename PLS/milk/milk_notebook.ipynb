# %% [markdown]
# # **Model**

# %% [markdown]
# # **XRF milk database**

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks
pd.options.plotting.backend = 'plotly'  # setting plotly as the backend for pandas plotting

# Add parent directory to sys.path so local module 'synthetic' (one level up) can be imported
import sys
from pathlib import Path # for path manipulations
parent_dir = Path.cwd().parent.parent.resolve() # move two levels up from current working directory
if str(parent_dir) not in sys.path: # check to avoid duplicates
    sys.path.insert(0, str(parent_dir)) # insert at the start of sys.path to prioritize local modules

# Loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv(f'{parent_dir}/XRF_databases/milk/plsda/milk.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '2.66':'22.62']

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '2.66':'22.62'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '2.66':'22.62'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-27 10:33:13,320 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-27 10:33:13,344 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-27 10:33:13,384 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-27 10:33:13,446 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# # **VIP and SHAP**

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('Ag La', 2.66, 3.10),
('Ag Lb', 3.10, 3.46),
('Ca', 3.46, 3.92),
('background', 3.92, 6.12),
('Fe', 6.12, 6.68),
('Cu', 6.70, 8.37),
('Zn', 8.37, 9.10),
('Bremsstrahlung', 9.10, 20.06),
('Ag compton', 20.06, 21.62),
('Ag ka', 21.48, 22.62)
]

# %%
# plotando o vip scores rapidamente
vip_scores_mat.T.plot()

# %%
# calculando a covariancia entre cada variável espectral e a predição do modelo PLS-DA
cov_scores = []
y_pred = plsda_results[5].iloc[:,-1].values # using the continuous predictions from LV=3
for col in Xcalclass_prep.columns:
    x_values = Xcalclass_prep[col].values
    covariance = np.cov(x_values, y_pred)[0, 1] # covariance between x and y
    cov_scores.append(covariance)
cov_scores_df = pd.DataFrame(cov_scores, index=Xcalclass_prep.columns, columns=['Covariance'])
cov_scores_df = np.abs(cov_scores_df)
cov_scores_df.plot()

# %%
import numpy as np
import pandas as pd

# vip
vip_scores_df = pd.DataFrame({
    'energy' : plsda_results[4].T.index,
    'VIP_Score' : plsda_results[4].T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# vamos gerar uma nova coluna em vip_scores_df com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_vip = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
	for i in vip_scores_df['energy']: # iterando sobre cada valor de energia no vip_scores_df
		i_float = float(i)
		if start <= i_float <= end:
			energy_to_zone_vip[i] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_vip

# vamos filtrar vip_scores_df para manter apenas as zonas espectrais únicas com maior VIP score
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# reg vet
reg_vet = pd.DataFrame(plsda_results[3].coef_, columns=plsda_results[3].feature_names_in_) # creating a DataFrame with regression coefficients
reg_vet = reg_vet.T
reg_vet.insert(0, 'energy', reg_vet.index) # adding energy column
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy', 'Reg_coef'] # renaming
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs() # adding absolute value column
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True) # sorting by absolute value

# gerando uma nova coluna em reg_vet com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_reg = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
    for i in reg_vet['energy']: # iterando sobre cada valor de energia no reg_vet
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_reg[i] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_reg
reg_vet

# vamos filtrar reg_vet para manter apenas as zonas espectrais únicas com maior valor absoluto do coeficiente de regressão
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)
shap_unique_df = pd.read_csv('shap_milk.csv', sep=';') # loading previously saved shap_unique_df

# %% [markdown]
# # **bagging - covariance**

# %%
import explaining as exp
spectral_zones_class = exp.extract_spectral_zones(Xcalclass_prep, spectral_cuts)
zone_sums_df = exp.aggregate_spectral_zones(spectral_zones_class, aggregator='extreme')
predicates_quantiles = exp.predicates_by_quantiles(zone_sums_df, [0.2, 0.4, 0.6, 0.8])
co_occurrence_matrix_df = predicates_quantiles[2]
predicate_info_dict = exp.create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=y_pred_cont
)

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_cov = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    # Calcular MI
    cov_results_dict_seed = exp.calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance', # covariance ou mutual_information
        threshold=0.01, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    # Salvar no dicionário principal
    all_results_cov[seed] = {
        'bags_result': bags_result_seed,
        'cov_results_dict': cov_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graphv2(
        bags_result=all_results_cov[seed]['bags_result'],
        predicate_ranking_dict=all_results_cov[seed]['cov_results_dict'],
        metric_column='Covariance',  # ou 'Covariance' se mudar a métrica
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_by_seed[seed] = DG

# Calcular LRC usando a função pronta do explaining.py
lrc_cov_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    lrc_cov_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_cov_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_cov_by_seed[seed] = lrc_cov_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_cov_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_cov_df_seed = lrc_cov_by_seed[seed].rename(columns={'Node': f'Predicate_Cov_Seed_{seed}'})
    lrc_cov_all_seeds_df = pd.concat([lrc_cov_all_seeds_df, lrc_cov_df_seed[[f'Predicate_Cov_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_cov_unique_by_seed = {}
for seed, lrc_df in lrc_cov_by_seed.items():
    lrc_cov_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_cov_unique_df = lrc_cov_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_cov_unique_by_seed[seed] = lrc_cov_unique_df

lrc_cov_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 2
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando semente: 3
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Calculando Covariance para Predicados
# Métrica: covariance
# Threshold: 0.01
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 43
# Removida aresta Ag La <= 5.23 -> Ag La <= 2.83 (peso 1.4179)
# Mantida aresta Ag La <= 2.83 -> Ag La <= 5.23 (peso 11.3378)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 1.2459)
# Mantida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 10.5288)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 2.77 -> Ag Lb <= 4.33 (peso 5.2589)
# Mantida aresta Ag Lb <= 4.33 -> Ag Lb <= 2.77 (peso 5.4460)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag ka <= -3.39 (peso 0.3230)
# Mantida aresta Ag ka <= -3.39 -> Ag ka > -3.39 (peso 0.7538)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag La > -8.20 (peso 0.9145)
# Mantida aresta Ag La > -8.20 -> Ag ka <= -3.39 (peso 1.9130)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag ka > -7.93 (peso 0.6689)
# Mantida aresta Ag ka > -7.93 -> Ag ka > -3.39 (peso 1.1968)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag ka > -3.39 (peso 0.2173)
# Mantida aresta Ag ka > -3.39 -> Ag Lb > -6.25 (peso 1.0514)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka > -7.93 (peso 0.4532)
# Mantida aresta Ag ka > -7.93 -> Ag La > -8.20 (peso 1.1123)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag Lb > -6.25 (peso 0.2008)
# Mantida aresta Ag Lb > -6.25 -> Ag compton <= 3.09 (peso 0.2499)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Zn > -1.89 (peso 0.1740)
# Mantida aresta Zn > -1.89 -> Ag compton > -2.89 (peso 0.7130)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag compton <= 3.09 (peso 0.1563)
# Mantida aresta Ag compton <= 3.09 -> Ag compton > -2.89 (peso 0.4481)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ag compton > -2.89 (peso 0.0592)
# Mantida aresta Ag compton > -2.89 -> Bremsstrahlung <= 3.06 (peso 0.1717)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton > -2.89 (peso 0.1375)
# Mantida aresta Ag compton > -2.89 -> Fe <= 2.10 (peso 0.4038)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Fe <= 2.10 (peso 0.2548)
# Mantida aresta Fe <= 2.10 -> Ag compton <= 3.09 (peso 0.3746)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ca <= 1.99 (peso 0.1445)
# Mantida aresta Ca <= 1.99 -> Ag compton <= 3.09 (peso 0.2434)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.1039)
# Mantida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.1128)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton <= 2.58 (peso 0.1170)
# Mantida aresta Ag compton <= 2.58 -> Ca <= 1.99 (peso 0.4419)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag compton <= 2.58 (peso 0.1188)
# Mantida aresta Ag compton <= 2.58 -> Ag ka > 5.20 (peso 0.1383)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag ka > 5.20 (peso 0.1215)
# Mantida aresta Ag ka > 5.20 -> Fe <= 2.10 (peso 0.1246)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Fe > -1.71 (peso 0.0803)
# Mantida aresta Fe > -1.71 -> Ag compton > -2.03 (peso 0.0947)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Ag compton > -2.03 (peso 0.0796)
# Mantida aresta Ag compton > -2.03 -> Bremsstrahlung > -3.10 (peso 0.1524)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag compton > -2.03 (peso 0.0844)
# Mantida aresta Ag compton > -2.03 -> Zn > -1.35 (peso 0.1499)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ag compton > -2.03 (peso 0.0814)
# Mantida aresta Ag compton > -2.03 -> Cu <= 2.01 (peso 0.0921)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Zn > -1.35 (peso 0.0719)
# Mantida aresta Zn > -1.35 -> Fe > -1.71 (peso 0.1015)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Bremsstrahlung > -2.45 (peso 0.0252)
# Mantida aresta Bremsstrahlung > -2.45 -> Ca > -1.26 (peso 0.0363)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Ag compton <= -2.03 (peso 0.0420)
# Mantida aresta Ag compton <= -2.03 -> Zn <= 2.28 (peso 0.0467)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Fe <= 1.63 (peso 0.0750)
# Mantida aresta Fe <= 1.63 -> Bremsstrahlung <= 3.06 (peso 0.0759)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Zn > 1.85 (peso 0.0337)
# Mantida aresta Zn > 1.85 -> Bremsstrahlung <= -2.45 (peso 0.0375)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung > -3.10 (peso 0.0335)
# Mantida aresta Bremsstrahlung > -3.10 -> Bremsstrahlung <= 3.46 (peso 0.0576)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Fe <= 1.63 (peso 0.0297)
# Mantida aresta Fe <= 1.63 -> Ag compton <= -2.03 (peso 0.0497)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton <= -2.03 (peso 0.0562)
# Mantida aresta Ag compton <= -2.03 -> Ag Lb > 2.77 (peso 0.1310)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Ag Lb > 2.77 (peso 0.0369)
# Mantida aresta Ag Lb > 2.77 -> Ca > 1.99 (peso 0.0784)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Cu <= 2.71 (peso 0.0303)
# Mantida aresta Cu <= 2.71 -> Ca <= 2.47 (peso 0.0380)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Ca <= 2.47 (peso 0.0273)
# Mantida aresta Ca <= 2.47 -> Ag La > 4.26 (peso 0.0376)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Ag La > 4.26 (peso 0.0251)
# Mantida aresta Ag La > 4.26 -> Bremsstrahlung <= 3.46 (peso 0.0343)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Zn <= -1.35 (peso 0.0196)
# Mantida aresta Zn <= -1.35 -> Ag La > 4.26 (peso 0.0213)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag compton > 2.58 (peso 0.0347)
# Mantida aresta Ag compton > 2.58 -> Ag La > 2.83 (peso 0.0616)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Zn <= 1.85 (peso 0.0299)
# Mantida aresta Zn <= 1.85 -> Ag compton <= -2.03 (peso 0.0404)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Zn > 1.85 (peso 0.0472)
# Mantida aresta Zn > 1.85 -> Zn <= 1.85 (peso 0.0535)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Bremsstrahlung > 3.06 (peso 0.0179)
# Mantida aresta Bremsstrahlung > 3.06 -> Fe > -1.30 (peso 0.0315)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Ag Lb > 3.70 (peso 0.0149)
# Mantida aresta Ag Lb > 3.70 -> Ca <= -1.26 (peso 0.0214)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Ag Lb > 3.70 (peso 0.0132)
# Mantida aresta Ag Lb > 3.70 -> Bremsstrahlung > 3.06 (peso 0.0311)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Bremsstrahlung > 3.06 (peso 0.0116)
# Mantida aresta Bremsstrahlung > 3.06 -> Fe > 1.63 (peso 0.0283)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 366
# Total de arestas removidas por bidirecionalidade: 43
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 57
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 63
# Removida aresta Ag Lb <= 3.70 -> Ag La <= 2.83 (peso 1.3099)
# Mantida aresta Ag La <= 2.83 -> Ag Lb <= 3.70 (peso 1.4827)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 1.3448)
# Mantida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 11.4896)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 2.77 -> Ag Lb <= 4.33 (peso 5.3129)
# Mantida aresta Ag Lb <= 4.33 -> Ag Lb <= 2.77 (peso 5.4234)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka <= 5.20 (peso 0.4634)
# Mantida aresta Ag ka <= 5.20 -> Ag La > -8.20 (peso 1.5314)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka <= -3.39 (peso 0.8530)
# Mantida aresta Ag ka <= -3.39 -> Ag La > -8.20 (peso 1.9523)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag La > -8.20 (peso 0.4589)
# Mantida aresta Ag La > -8.20 -> Ag ka > -7.93 (peso 0.6932)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag ka > -7.93 (peso 0.1546)
# Mantida aresta Ag ka > -7.93 -> Ag compton > -2.89 (peso 0.2756)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag ka <= -3.39 (peso 0.6395)
# Mantida aresta Ag ka <= -3.39 -> Ag ka > -7.93 (peso 0.7657)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag ka > -7.93 (peso 0.2211)
# Mantida aresta Ag ka > -7.93 -> Ag Lb > -6.25 (peso 0.3144)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag ka > -3.39 (peso 0.1772)
# Mantida aresta Ag ka > -3.39 -> Ag Lb > -6.25 (peso 0.7769)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag Lb > -6.25 (peso 0.2022)
# Mantida aresta Ag Lb > -6.25 -> Zn > -1.89 (peso 0.4338)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Zn > -1.89 (peso 0.1488)
# Mantida aresta Zn > -1.89 -> Ca <= 1.99 (peso 0.1754)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Zn > -1.89 (peso 0.3243)
# Mantida aresta Zn > -1.89 -> Ag compton <= 3.09 (peso 0.4710)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Fe <= 2.10 (peso 0.1372)
# Mantida aresta Fe <= 2.10 -> Ca <= 1.99 (peso 0.3194)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ca <= 1.99 (peso 0.1629)
# Mantida aresta Ca <= 1.99 -> Ag compton <= 2.58 (peso 0.1888)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton > -2.89 (peso 0.1197)
# Mantida aresta Ag compton > -2.89 -> Ca <= 1.99 (peso 0.1350)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.1254)
# Mantida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.1351)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Fe <= 2.10 (peso 0.0988)
# Mantida aresta Fe <= 2.10 -> Ag ka > 5.20 (peso 0.1089)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.1030)
# Mantida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.2663)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Fe > -1.71 (peso 0.0773)
# Mantida aresta Fe > -1.71 -> Ag compton > -2.03 (peso 0.2017)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Bremsstrahlung <= 3.06 (peso 0.0763)
# Mantida aresta Bremsstrahlung <= 3.06 -> Fe > -1.71 (peso 0.1193)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Fe > -1.71 (peso 0.0796)
# Mantida aresta Fe > -1.71 -> Cu <= 2.01 (peso 0.1544)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag ka > 5.20 (peso 0.1146)
# Mantida aresta Ag ka > 5.20 -> Ag compton <= 3.09 (peso 0.1806)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag compton > -2.03 (peso 0.0801)
# Mantida aresta Ag compton > -2.03 -> Ag compton <= 2.58 (peso 0.1786)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Bremsstrahlung <= 3.06 (peso 0.0770)
# Mantida aresta Bremsstrahlung <= 3.06 -> background <= 2.73 (peso 0.1433)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Bremsstrahlung <= 3.06 (peso 0.0709)
# Mantida aresta Bremsstrahlung <= 3.06 -> Zn > -1.35 (peso 0.1093)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> background <= 2.73 (peso 0.0557)
# Mantida aresta background <= 2.73 -> Ca <= 2.47 (peso 0.0572)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Zn <= 2.28 (peso 0.0345)
# Mantida aresta Zn <= 2.28 -> background <= 2.73 (peso 0.0560)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> background <= 2.73 (peso 0.0783)
# Mantida aresta background <= 2.73 -> Ag Lb > 2.77 (peso 0.1136)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Cu <= 2.01 (peso 0.0694)
# Mantida aresta Cu <= 2.01 -> Zn > -1.35 (peso 0.1410)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Cu <= 2.35 (peso 0.0663)
# Mantida aresta Cu <= 2.35 -> Cu <= 2.01 (peso 0.0867)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Zn > -1.35 (peso 0.0932)
# Mantida aresta Zn > -1.35 -> Ag compton > -2.03 (peso 0.1437)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> Fe > -1.30 (peso 0.0285)
# Mantida aresta Fe > -1.30 -> Ca > 1.99 (peso 0.0544)
#
# ======================================================================
#
# Removida aresta background <= 2.11 -> Fe > -1.30 (peso 0.0129)
# Mantida aresta Fe > -1.30 -> background <= 2.11 (peso 0.0309)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Fe > -1.30 (peso 0.0245)
# Mantida aresta Fe > -1.30 -> Ag compton <= -2.03 (peso 0.0377)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton > 2.58 (peso 0.0470)
# Mantida aresta Ag compton > 2.58 -> Ag Lb > 2.77 (peso 0.0480)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ca > -1.26 (peso 0.0624)
# Mantida aresta Ca > -1.26 -> Bremsstrahlung <= -2.45 (peso 0.0748)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Zn > 1.85 (peso 0.0302)
# Mantida aresta Zn > 1.85 -> Ca > -1.26 (peso 0.0438)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Zn <= 2.28 (peso 0.0263)
# Mantida aresta Zn <= 2.28 -> background <= 2.38 (peso 0.0815)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Bremsstrahlung > -3.10 (peso 0.0274)
# Mantida aresta Bremsstrahlung > -3.10 -> Zn <= 2.28 (peso 0.0357)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Zn <= 2.28 (peso 0.0317)
# Mantida aresta Zn <= 2.28 -> Bremsstrahlung <= -2.45 (peso 0.0402)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> background <= 2.38 (peso 0.0273)
# Mantida aresta background <= 2.38 -> Ag La > 4.26 (peso 0.0453)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> background <= 2.38 (peso 0.0294)
# Mantida aresta background <= 2.38 -> Ca > 1.99 (peso 0.0305)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Fe <= 1.63 (peso 0.0338)
# Mantida aresta Fe <= 1.63 -> Bremsstrahlung <= -2.45 (peso 0.0521)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Bremsstrahlung > -2.45 (peso 0.0432)
# Mantida aresta Bremsstrahlung > -2.45 -> Ag compton > 2.58 (peso 0.1053)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Zn > 1.85 (peso 0.0501)
# Mantida aresta Zn > 1.85 -> Ag compton <= -2.03 (peso 0.0752)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Zn <= 1.85 (peso 0.0476)
# Mantida aresta Zn <= 1.85 -> Ag compton <= -2.03 (peso 0.0591)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Ca > 1.99 (peso 0.0301)
# Mantida aresta Ca > 1.99 -> Ag compton <= -2.03 (peso 0.0497)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Zn <= -1.35 (peso 0.0128)
# Mantida aresta Zn <= -1.35 -> Ag compton > 2.58 (peso 0.0197)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Ca <= -1.26 (peso 0.0240)
# Mantida aresta Ca <= -1.26 -> Cu <= 2.71 (peso 0.0327)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> Ca <= -1.26 (peso 0.0205)
# Mantida aresta Ca <= -1.26 -> background > -1.72 (peso 0.0590)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Cu > -2.02 (peso 0.0193)
# Mantida aresta Cu > -2.02 -> Ca <= -1.26 (peso 0.0323)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Zn <= 1.85 (peso 0.0301)
# Mantida aresta Zn <= 1.85 -> Zn > 1.85 (peso 0.0730)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> background <= 2.11 (peso 0.0285)
# Mantida aresta background <= 2.11 -> Zn <= 1.85 (peso 0.0335)
#
# ======================================================================
#
# Removida aresta Zn <= 1.85 -> Ca > 1.99 (peso 0.0249)
# Mantida aresta Ca > 1.99 -> Zn <= 1.85 (peso 0.0642)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Fe <= 1.63 (peso 0.0224)
# Mantida aresta Fe <= 1.63 -> Ag La > 4.26 (peso 0.0284)
#
# ======================================================================
#
# Removida aresta background <= 2.11 -> Bremsstrahlung > 3.06 (peso 0.0179)
# Mantida aresta Bremsstrahlung > 3.06 -> background <= 2.11 (peso 0.0275)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag Lb > 3.70 (peso 0.0188)
# Mantida aresta Ag Lb > 3.70 -> Ag La > 2.83 (peso 0.0218)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> background > -1.72 (peso 0.0158)
# Mantida aresta background > -1.72 -> Ag Lb > 3.70 (peso 0.0190)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Bremsstrahlung > 3.06 (peso 0.0156)
# Mantida aresta Bremsstrahlung > 3.06 -> Ag Lb > 3.70 (peso 0.0156)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Fe > 1.63 (peso 0.0161)
# Mantida aresta Fe > 1.63 -> Ag Lb > 3.70 (peso 0.0179)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Zn <= -1.35 (peso 0.0104)
# Mantida aresta Zn <= -1.35 -> Bremsstrahlung > -3.10 (peso 0.0124)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Ag La > 2.83 (peso 0.0121)
# Mantida aresta Ag La > 2.83 -> Bremsstrahlung > -3.10 (peso 0.0138)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 377
# Total de arestas removidas por bidirecionalidade: 63
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 59
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 2
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 59
# Removida aresta Ag La <= 2.83 -> Ag La <= 4.26 (peso 1.5653)
# Mantida aresta Ag La <= 4.26 -> Ag La <= 2.83 (peso 12.2659)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Ag La <= 2.83 (peso 1.2526)
# Mantida aresta Ag La <= 2.83 -> Ag Lb <= 3.70 (peso 2.9482)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 3.9134)
# Mantida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 9.2331)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 2.77 -> Ag Lb <= 4.33 (peso 5.4808)
# Mantida aresta Ag Lb <= 4.33 -> Ag Lb <= 2.77 (peso 5.5140)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka <= 5.20 (peso 0.4823)
# Mantida aresta Ag ka <= 5.20 -> Ag La > -8.20 (peso 2.0725)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag La > -8.20 (peso 0.3975)
# Mantida aresta Ag La > -8.20 -> Ag ka <= -3.39 (peso 1.0230)
#
# ======================================================================
#
# Removida aresta Ag ka <= -3.39 -> Ag ka > -7.93 (peso 1.0908)
# Mantida aresta Ag ka > -7.93 -> Ag ka <= -3.39 (peso 1.1513)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag La > -8.20 (peso 0.6968)
# Mantida aresta Ag La > -8.20 -> Ag ka > -7.93 (peso 1.1029)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag La > -8.20 (peso 0.2500)
# Mantida aresta Ag La > -8.20 -> Ag Lb > -6.25 (peso 0.2527)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag La > -8.20 (peso 0.2579)
# Mantida aresta Ag La > -8.20 -> Ag ka > -3.39 (peso 0.5474)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag ka > -3.39 (peso 0.2490)
# Mantida aresta Ag ka > -3.39 -> Ag ka > -7.93 (peso 0.2688)
#
# ======================================================================
#
# Removida aresta Ag Lb > -6.25 -> Ag ka > -3.39 (peso 0.4909)
# Mantida aresta Ag ka > -3.39 -> Ag Lb > -6.25 (peso 0.5587)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag Lb > -6.25 (peso 0.1912)
# Mantida aresta Ag Lb > -6.25 -> Ag compton > -2.89 (peso 0.3952)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Zn > -1.89 (peso 0.1665)
# Mantida aresta Zn > -1.89 -> Ag ka > -3.39 (peso 0.1808)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Zn > -1.89 (peso 0.3194)
# Mantida aresta Zn > -1.89 -> Ag compton > -2.89 (peso 0.3206)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Zn > -1.89 (peso 0.1529)
# Mantida aresta Zn > -1.89 -> Ag compton <= 3.09 (peso 0.3205)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag ka > 5.20 (peso 0.1547)
# Mantida aresta Ag ka > 5.20 -> Zn > -1.89 (peso 0.1684)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ag compton <= 3.09 (peso 0.1497)
# Mantida aresta Ag compton <= 3.09 -> Ca <= 1.99 (peso 0.3929)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ag compton <= 3.09 (peso 0.0708)
# Mantida aresta Ag compton <= 3.09 -> Ca <= 2.47 (peso 0.0726)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.89 -> Ag compton <= 3.09 (peso 0.1167)
# Mantida aresta Ag compton <= 3.09 -> Ag compton > -2.89 (peso 0.1974)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton <= 2.58 (peso 0.0748)
# Mantida aresta Ag compton <= 2.58 -> Fe <= 2.10 (peso 0.1180)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Fe <= 2.10 (peso 0.1271)
# Mantida aresta Fe <= 2.10 -> Bremsstrahlung <= 3.06 (peso 0.4822)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.1166)
# Mantida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.2579)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ag compton <= 2.58 (peso 0.1195)
# Mantida aresta Ag compton <= 2.58 -> Bremsstrahlung <= 3.06 (peso 0.1280)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag ka > 5.20 (peso 0.0902)
# Mantida aresta Ag ka > 5.20 -> Ag compton <= 2.58 (peso 0.1430)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Fe > -1.71 (peso 0.1054)
# Mantida aresta Fe > -1.71 -> Ca <= 1.99 (peso 0.1969)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ag ka > 5.20 (peso 0.0260)
# Mantida aresta Ag ka > 5.20 -> Cu <= 2.01 (peso 0.0869)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Bremsstrahlung <= 3.06 (peso 0.0784)
# Mantida aresta Bremsstrahlung <= 3.06 -> Fe > -1.71 (peso 0.1010)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Ag compton > -2.03 (peso 0.1628)
# Mantida aresta Ag compton > -2.03 -> Zn > -1.35 (peso 0.1657)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Ca <= 2.47 (peso 0.0623)
# Mantida aresta Ca <= 2.47 -> Fe <= 1.63 (peso 0.1379)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Cu > -2.02 (peso 0.0233)
# Mantida aresta Cu > -2.02 -> Fe <= 1.63 (peso 0.0342)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Fe <= 1.63 (peso 0.0350)
# Mantida aresta Fe <= 1.63 -> Ag Lb > 2.77 (peso 0.0580)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> background <= 2.11 (peso 0.0720)
# Mantida aresta background <= 2.11 -> Ag compton > -2.03 (peso 0.0994)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> background <= 2.38 (peso 0.0511)
# Mantida aresta background <= 2.38 -> Ag compton > -2.03 (peso 0.0826)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Zn > 1.85 (peso 0.0368)
# Mantida aresta Zn > 1.85 -> Ag compton > 2.58 (peso 0.0435)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ag La > 2.83 (peso 0.0378)
# Mantida aresta Ag La > 2.83 -> Zn > 1.85 (peso 0.0471)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Ca > -1.26 (peso 0.0480)
# Mantida aresta Ca > -1.26 -> Cu <= 2.35 (peso 0.0526)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Ca > -1.26 (peso 0.0432)
# Mantida aresta Ca > -1.26 -> Ag compton > 2.58 (peso 0.0541)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Ca > -1.26 (peso 0.0209)
# Mantida aresta Ca > -1.26 -> Ca > -1.96 (peso 0.0403)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ca > -1.26 (peso 0.0282)
# Mantida aresta Ca > -1.26 -> Fe > -1.30 (peso 0.0490)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Bremsstrahlung <= -2.45 (peso 0.0400)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag Lb > 2.77 (peso 0.0889)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ag compton <= -2.03 (peso 0.0300)
# Mantida aresta Ag compton <= -2.03 -> Bremsstrahlung <= -2.45 (peso 0.0434)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ag compton <= -2.03 (peso 0.0414)
# Mantida aresta Ag compton <= -2.03 -> Ag Lb > 2.77 (peso 0.0427)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Ca > 1.99 (peso 0.0376)
# Mantida aresta Ca > 1.99 -> Ag Lb > 2.77 (peso 0.0518)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Ag compton <= -2.03 (peso 0.0436)
# Mantida aresta Ag compton <= -2.03 -> background <= 2.38 (peso 0.0494)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Bremsstrahlung > -2.45 (peso 0.0534)
# Mantida aresta Bremsstrahlung > -2.45 -> Zn <= 2.28 (peso 0.0561)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag compton > 2.58 (peso 0.0315)
# Mantida aresta Ag compton > 2.58 -> Bremsstrahlung > -2.45 (peso 0.0607)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Cu <= 2.35 (peso 0.0149)
# Mantida aresta Cu <= 2.35 -> Ag Lb > 3.70 (peso 0.0348)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Ca <= -1.26 (peso 0.0230)
# Mantida aresta Ca <= -1.26 -> Cu <= 2.71 (peso 0.0331)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Ca <= -1.26 (peso 0.0223)
# Mantida aresta Ca <= -1.26 -> Fe > -1.30 (peso 0.0233)
#
# ======================================================================
#
# Removida aresta Fe > -1.30 -> Cu > -2.02 (peso 0.0189)
# Mantida aresta Cu > -2.02 -> Fe > -1.30 (peso 0.0432)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Zn <= -1.35 (peso 0.0175)
# Mantida aresta Zn <= -1.35 -> Cu > -2.02 (peso 0.0177)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Cu <= 2.71 (peso 0.0179)
# Mantida aresta Cu <= 2.71 -> Bremsstrahlung > 3.06 (peso 0.0235)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Ag Lb > 3.70 (peso 0.0162)
# Mantida aresta Ag Lb > 3.70 -> Bremsstrahlung > 3.06 (peso 0.0305)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Cu <= 2.71 (peso 0.0115)
# Mantida aresta Cu <= 2.71 -> Ag La > 2.83 (peso 0.0167)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Fe > -1.30 (peso 0.0160)
# Mantida aresta Fe > -1.30 -> Ag La > 2.83 (peso 0.0306)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Ca > -1.96 (peso 0.0142)
# Mantida aresta Ca > -1.96 -> Ag La > 4.26 (peso 0.0183)
#
# ======================================================================
#
# Removida aresta Ag Lb > 3.70 -> Ag La > 4.26 (peso 0.0159)
# Mantida aresta Ag La > 4.26 -> Ag Lb > 3.70 (peso 0.0175)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> Zn <= -1.35 (peso 0.0126)
# Mantida aresta Zn <= -1.35 -> background > -1.72 (peso 0.0158)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 376
# Total de arestas removidas por bidirecionalidade: 59
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 56
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 47
# Removida aresta Ag La <= 5.23 -> Ag La <= 2.83 (peso 1.3358)
# Mantida aresta Ag La <= 2.83 -> Ag La <= 5.23 (peso 11.3287)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Ag La <= 5.23 (peso 1.2990)
# Mantida aresta Ag La <= 5.23 -> Ag Lb <= 3.70 (peso 10.4330)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 2.77 -> Ag Lb <= 4.33 (peso 4.3419)
# Mantida aresta Ag Lb <= 4.33 -> Ag Lb <= 2.77 (peso 6.4304)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka <= -3.39 (peso 1.6900)
# Mantida aresta Ag ka <= -3.39 -> Ag La > -8.20 (peso 1.8866)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag La > -8.20 (peso 0.3157)
# Mantida aresta Ag La > -8.20 -> Ag ka > -7.93 (peso 0.8075)
#
# ======================================================================
#
# Removida aresta Ag ka > -7.93 -> Ag ka <= -3.39 (peso 0.3454)
# Mantida aresta Ag ka <= -3.39 -> Ag ka > -7.93 (peso 1.4584)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Ag ka > -7.93 (peso 0.2964)
# Mantida aresta Ag ka > -7.93 -> Ag ka > -3.39 (peso 0.9425)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Ag Lb > -6.25 (peso 0.3378)
# Mantida aresta Ag Lb > -6.25 -> Zn > -1.89 (peso 1.2290)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Zn > -1.89 (peso 0.1892)
# Mantida aresta Zn > -1.89 -> Ag compton <= 3.09 (peso 0.3761)
#
# ======================================================================
#
# Removida aresta Ag compton <= 3.09 -> Ag compton > -2.89 (peso 0.1427)
# Mantida aresta Ag compton > -2.89 -> Ag compton <= 3.09 (peso 0.6569)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton > -2.89 (peso 0.1323)
# Mantida aresta Ag compton > -2.89 -> Fe <= 2.10 (peso 0.2755)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ag compton <= 3.09 (peso 0.2273)
# Mantida aresta Ag compton <= 3.09 -> Fe <= 2.10 (peso 0.2947)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Ca <= 1.99 (peso 0.1237)
# Mantida aresta Ca <= 1.99 -> Fe <= 2.10 (peso 0.2036)
#
# ======================================================================
#
# Removida aresta Fe <= 2.10 -> Fe > -1.71 (peso 0.0920)
# Mantida aresta Fe > -1.71 -> Fe <= 2.10 (peso 0.1355)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> background <= 2.73 (peso 0.0184)
# Mantida aresta background <= 2.73 -> Ca > 1.99 (peso 0.1182)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> Cu <= 2.01 (peso 0.0648)
# Mantida aresta Cu <= 2.01 -> background <= 2.73 (peso 0.0922)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> Ca <= 2.47 (peso 0.0153)
# Mantida aresta Ca <= 2.47 -> background <= 2.38 (peso 0.0391)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Ag compton <= 2.58 (peso 0.1001)
# Mantida aresta Ag compton <= 2.58 -> Ag ka > 5.20 (peso 0.2084)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Ag compton <= 2.58 (peso 0.0947)
# Mantida aresta Ag compton <= 2.58 -> Fe > -1.71 (peso 0.3584)
#
# ======================================================================
#
# Removida aresta Fe > -1.71 -> Zn > -1.35 (peso 0.0817)
# Mantida aresta Zn > -1.35 -> Fe > -1.71 (peso 0.0987)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Cu <= 2.01 (peso 0.0715)
# Mantida aresta Cu <= 2.01 -> Bremsstrahlung > -3.10 (peso 0.1396)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ca <= 1.99 (peso 0.0696)
# Mantida aresta Ca <= 1.99 -> Cu <= 2.01 (peso 0.2108)
#
# ======================================================================
#
# Removida aresta Ag La > 4.26 -> Cu <= 2.01 (peso 0.0315)
# Mantida aresta Cu <= 2.01 -> Ag La > 4.26 (peso 0.0501)
#
# ======================================================================
#
# Removida aresta Ag Lb > 2.77 -> Cu <= 2.35 (peso 0.0322)
# Mantida aresta Cu <= 2.35 -> Ag Lb > 2.77 (peso 0.0463)
#
# ======================================================================
#
# Removida aresta Ag compton <= 2.58 -> Ag compton > -2.03 (peso 0.0903)
# Mantida aresta Ag compton > -2.03 -> Ag compton <= 2.58 (peso 0.1037)
#
# ======================================================================
#
# Removida aresta Ag compton > -2.03 -> Zn <= 2.28 (peso 0.0716)
# Mantida aresta Zn <= 2.28 -> Ag compton > -2.03 (peso 0.0753)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> background <= 2.11 (peso 0.0420)
# Mantida aresta background <= 2.11 -> Bremsstrahlung <= 3.06 (peso 0.1492)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Bremsstrahlung <= 3.06 (peso 0.0161)
# Mantida aresta Bremsstrahlung <= 3.06 -> Ag compton > 2.58 (peso 0.0669)
#
# ======================================================================
#
# Removida aresta Fe <= 1.63 -> Bremsstrahlung > -3.10 (peso 0.0635)
# Mantida aresta Bremsstrahlung > -3.10 -> Fe <= 1.63 (peso 0.0642)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Zn > 1.85 (peso 0.0371)
# Mantida aresta Zn > 1.85 -> Ag compton > 2.58 (peso 0.0419)
#
# ======================================================================
#
# Removida aresta Zn > 1.85 -> Ag compton <= -2.03 (peso 0.0423)
# Mantida aresta Ag compton <= -2.03 -> Zn > 1.85 (peso 0.0476)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Ag La > 4.26 (peso 0.0174)
# Mantida aresta Ag La > 4.26 -> Fe > 1.63 (peso 0.0193)
#
# ======================================================================
#
# Removida aresta Ag compton > 2.58 -> Ca <= 2.47 (peso 0.0388)
# Mantida aresta Ca <= 2.47 -> Ag compton > 2.58 (peso 0.0543)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Cu <= 2.71 (peso 0.0112)
# Mantida aresta Cu <= 2.71 -> Ca > -1.26 (peso 0.0302)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Ca <= 2.47 (peso 0.0551)
# Mantida aresta Ca <= 2.47 -> Cu > -2.02 (peso 0.0570)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Ca > 1.99 (peso 0.0349)
# Mantida aresta Ca > 1.99 -> Ca > -1.96 (peso 0.0360)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ca > -1.96 (peso 0.0345)
# Mantida aresta Ca > -1.96 -> Ag La > 2.83 (peso 0.0362)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Bremsstrahlung > -2.45 (peso 0.0439)
# Mantida aresta Bremsstrahlung > -2.45 -> Ca <= -1.26 (peso 0.0537)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Zn <= 1.85 (peso 0.0145)
# Mantida aresta Zn <= 1.85 -> Bremsstrahlung > -2.45 (peso 0.0576)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Zn <= 1.85 (peso 0.0302)
# Mantida aresta Zn <= 1.85 -> Ca <= -1.26 (peso 0.0326)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Ca > -1.26 (peso 0.0204)
# Mantida aresta Ca > -1.26 -> Ca <= -1.26 (peso 0.0239)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> Ag compton <= -2.03 (peso 0.0208)
# Mantida aresta Ag compton <= -2.03 -> Ca <= -1.26 (peso 0.0302)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Bremsstrahlung <= -2.45 (peso 0.0634)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ca > -1.26 (peso 0.0866)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Ca > -1.26 (peso 0.0267)
# Mantida aresta Ca > -1.26 -> Ag compton <= -2.03 (peso 0.0466)
#
# ======================================================================
#
# Removida aresta Ag compton <= -2.03 -> Fe > -1.30 (peso 0.0393)
# Mantida aresta Fe > -1.30 -> Ag compton <= -2.03 (peso 0.0494)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Cu > -2.02 (peso 0.0149)
# Mantida aresta Cu > -2.02 -> Ag La > 2.83 (peso 0.0292)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Bremsstrahlung > 3.06 (peso 0.0116)
# Mantida aresta Bremsstrahlung > 3.06 -> Ag La > 2.83 (peso 0.0159)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 364
# Total de arestas removidas por bidirecionalidade: 47
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 57
# Total de nós terminais: 2
# Métrica utilizada para pesos: Covariance
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_Cov_Seed_0 Predicate_Cov_Seed_1 Predicate_Cov_Seed_2  \
# 0         Ag La <= 4.26        Ag La <= 4.26        Ag La <= 4.26
# 1         Ag La <= 2.83        Ag La <= 2.83        Ag La <= 2.83
# 2         Ag La <= 5.23        Ag La <= 5.23        Ag La <= 5.23
# 3         Ag Lb <= 3.70        Ag Lb <= 3.70        Ag Lb <= 3.70
# 4         Ag Lb <= 4.33        Ag Lb <= 4.33        Ag Lb <= 4.33
# ..                  ...                  ...                  ...
# 56            Fe > 1.63          Zn <= -1.35              Class_A
# 57              Class_A    background > 2.38              Class_B
# 58              Class_B            Cu > 2.01                  NaN
# 59                  NaN              Class_A                  NaN
# 60                  NaN              Class_B                  NaN
#
#    Predicate_Cov_Seed_3
# 0         Ag La <= 4.26
# 1         Ag La <= 2.83
# 2         Ag La <= 5.23
# 3         Ag Lb <= 3.70
# 4         Ag Lb <= 2.77
# ..                  ...
# 56    background > 2.38
# 57              Class_A
# 58              Class_B
# 59                  NaN
# 60                  NaN
#
# [61 rows x 4 columns]

# %%
all_results_cov[0]['cov_results_dict']['Bag_1']
# Out:
#                   Predicate  Covariance
# 0             Ag La <= 4.26    1.498562
# 1             Ag La <= 2.83    1.436467
# 2             Ag La <= 5.23    1.231677
# 3             Ag Lb <= 3.70    1.216625
# 4             Ag Lb <= 2.77    1.060606
# 5             Ag Lb <= 4.33    0.999557
# 6            Ag ka <= 10.15    0.667310
# 7             Ag ka <= 5.20    0.422118
# 8            Ag ka <= -3.39    0.394511
# 9             Ag ka > -3.39    0.387425
# 10            Ag ka > -7.93    0.342255
# 11            Ag La > -8.20    0.272209
# 12            Ag Lb > -6.25    0.183758
# 13               Zn > -1.89    0.159758
# 14       Ag compton > -2.89    0.156299
# 15       Ag compton <= 3.09    0.118649
# 16       Ag compton <= 2.58    0.112823
# 17               Fe <= 2.10    0.106680
# 18       Ag compton > -2.03    0.080268
# 19               Fe > -1.71    0.071938
# 20               Zn > -1.35    0.066689
# 21               Cu > -2.02    0.065297
# 22               Ca <= 1.99    0.059840
# 23   Bremsstrahlung > -2.45    0.053612
# 24               Zn <= 2.28    0.053153
# 25   Bremsstrahlung <= 3.06    0.050063
# 26               Cu <= 2.01    0.047998
# 27             Ag ka > 5.20    0.045938
# 28  Bremsstrahlung <= -2.45    0.044789
# 29       background <= 2.11    0.044569
# 30   Bremsstrahlung > -3.10    0.041198
# 31               Fe <= 1.63    0.039952
# 32             Ag Lb > 2.77    0.039251
# 33               Cu <= 2.71    0.038043
# 34               Ca <= 2.47    0.037564
# 35             Ag La > 4.26    0.034319
# 36   Bremsstrahlung <= 3.46    0.033693
# 37        Ag compton > 2.58    0.032622
# 38      Ag compton <= -2.03    0.029865
# 39               Zn <= 1.85    0.029619
# 40               Ca > -1.96    0.027541
# 41               Fe > -1.30    0.025537
# 42                Ca > 1.99    0.024410
# 43                Zn > 1.85    0.023114
# 44              Ca <= -1.26    0.021389
# 45               Ca > -1.26    0.017894
# 46               Cu <= 2.35    0.014949
# 47              Zn <= -1.35    0.014036
# 48    Bremsstrahlung > 3.06    0.013197
# 49             Ag Lb > 3.70    0.011191
# 50       background <= 2.73    0.010810

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_cov_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df = lrc_summed_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_cov = lrc_summed_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_cov = lrc_summed_unique_df_cov.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_cov
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 4.26                  16.538775           Ag La
# 1            Ag Lb <= 3.70                   8.385409           Ag Lb
# 2           Ag ka <= 10.15                   5.319056           Ag ka
# 3               Zn > -1.89                   0.651477              Zn
# 4       Ag compton <= 3.09                   0.603257      Ag compton
# 5               Fe <= 2.10                   0.582293              Fe
# 6               Ca <= 1.99                   0.443690              Ca
# 7   Bremsstrahlung <= 3.06                   0.411927  Bremsstrahlung
# 8               Cu <= 2.01                   0.325747              Cu
# 9       background <= 2.38                   0.319127      background
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator
# 0       4.26       <=
# 1       3.70       <=
# 2      10.15       <=
# 3      -1.89        >
# 4       3.09       <=
# 5       2.10       <=
# 6       1.99       <=
# 7       3.06       <=
# 8       2.01       <=
# 9       2.38       <=
# 10      None     None

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zone_sums_df_original = exp.aggregate_spectral_zones(spectral_zones_original, aggregator='extreme')

# Aplicar o mapeamento
lrc_summed_unique_df_cov_with_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_unique_df_cov,
    zone_sums_preprocessed=zone_sums_df,
    zone_sums_natural=zone_sums_df_original
)
lrc_summed_unique_df_cov_with_natural
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 4.26                  16.538775           Ag La
# 1            Ag Lb <= 3.70                   8.385409           Ag Lb
# 2           Ag ka <= 10.15                   5.319056           Ag ka
# 3               Zn > -1.89                   0.651477              Zn
# 4       Ag compton <= 3.09                   0.603257      Ag compton
# 5               Fe <= 2.10                   0.582293              Fe
# 6               Ca <= 1.99                   0.443690              Ca
# 7   Bremsstrahlung <= 3.06                   0.411927  Bremsstrahlung
# 8               Cu <= 2.01                   0.325747              Cu
# 9       background <= 2.38                   0.319127      background
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       4.26       <=           310.0000                    38.0
# 1       3.70       <=           205.8950                   142.0
# 2      10.15       <=          3290.4200                    57.0
# 3      -1.89        >            42.7895                     7.0
# 4       3.09       <=           707.7890                    40.0
# 5       2.10       <=            21.7895                    19.0
# 6       1.99       <=            36.3684                   117.0
# 7       3.06       <=           675.0000                   164.0
# 8       2.01       <=            36.5263                   103.0
# 9       2.38       <=            15.0000                    73.0
# 10      None     None                NaN                     NaN
#
#     Approximation_Error                  Node_Natural
# 0              0.004828           Ag La <= 310.000000
# 1              0.000239           Ag Lb <= 205.895000
# 2              0.035126          Ag ka <= 3290.420000
# 3              0.001592                Zn > 42.789500
# 4              0.000539      Ag compton <= 707.789000
# 5              0.000690               Fe <= 21.789500
# 6              0.003036               Ca <= 36.368400
# 7              0.001614  Bremsstrahlung <= 675.000000
# 8              0.001116               Cu <= 36.526300
# 9              0.004027       background <= 15.000000
# 10                  NaN                          None

# %% [markdown]
# # **Perturbation**

# %%
import explaining as exp

# LISTA DE SEMENTES A TESTAR
random_seeds = [0, 1, 2, 3]

all_results_pert = {}
training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE
y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    # Bagging
    bags_result_seed = exp.bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=10,
        #n_predicates_per_bag=40,
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.2), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist

    pert_results_seed = exp.calculate_predicate_perturbation(
        estimator=pls_model,
        Xcalclass_prep=Xcalclass_prep,
        folds_struct=bags_result_seed,
        predicates_df=predicates_quantiles[0],
        spectral_cuts=spectral_cuts,
        #perturbation_value=0,
        perturbation_mode='mean', # valores entre 'mean' ou 'min'
        stats_source='full', # full indica usar todas as amostras para calcular estatísticas enquanto que 'fold' usa apenas as amostras do fold atual
        metric='mean_abs_diff',   # Média com sinal (pode ser negativo)
        verbose=True
    )

    # Remove todos os valores iguais a zero de todos os bags em perm_results[bag]["Permutation"] e salva como perm_results_thresholded
    # pert_results_seed_thresholded = {}
    # for bag, df in perm_results_seed.items():
    #     # Verifica se é um DataFrame e se a coluna 'Permutation' existe
    #     if isinstance(df, pd.DataFrame) and 'Permutation' in df.columns:
    #         filtered_df = df[df['Permutation'] > 0].copy()
    #         pert_results_seed_thresholded[bag] = filtered_df
    #     else:
    #         # Se não for DataFrame esperado, apenas copia
    #         pert_results_seed_thresholded[bag] = df

    # Salvar no dicionário principal
    all_results_pert[seed] = {
        'bags_result': bags_result_seed,
        'pert_results_dict': pert_results_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)
# Dicionário para armazenar grafos
graphs_pert_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    # Construir grafo para esta semente
    DG = exp.build_predicate_graphv2(
        bags_result=all_results_pert[seed]['bags_result'],
        predicate_ranking_dict=all_results_pert[seed]['pert_results_dict'],
        metric_column='Perturbation',  # ou 'Covariance' se mudar a métrica
        random_state=seed,
        show_details=True
    )
    # Armazenar grafo
    graphs_pert_by_seed[seed] = DG  

# Calcular LRC usando a função pronta do explaining.py
lrc_pert_by_seed = {}
for seed in random_seeds:
    DG = graphs_pert_by_seed[seed]
    lrc_pert_df_seed = exp.calculate_lrc_single_graph(DG, predicates_quantiles[0])
    lrc_pert_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    lrc_pert_by_seed[seed] = lrc_pert_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe
lrc_pert_all_seeds_df = pd.DataFrame()
for seed in random_seeds:
    lrc_pert_df_seed = lrc_pert_by_seed[seed].rename(columns={'Node': f'Predicate_pert_Seed_{seed}'})
    lrc_pert_all_seeds_df = pd.concat([lrc_pert_all_seeds_df, lrc_pert_df_seed[[f'Predicate_pert_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_pert_unique_by_seed = {}
for seed, lrc_df in lrc_pert_by_seed.items():
    lrc_pert_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_pert_unique_df = lrc_pert_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_pert_unique_by_seed[seed] = lrc_pert_unique_df

lrc_pert_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 60 | Descartados: 20
# ======================================================================
# PERTURBATION IMPORTANCE PARA PREDICADOS
# ======================================================================
# Modo de perturbação: mean
# Fonte das estatísticas: full
# Métrica: mean_abs_diff
# Total de folds: 10
#
#
# [Bag_1] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=174)
#     Zona: 18 colunas
#     Importance: 0.127723
#   Predicado: Ag La <= 2.83 (n=83)
#     Zona: 18 colunas
#     Importance: 0.208989
#   Predicado: Ag La > 2.83 (n=131)
#     Zona: 18 colunas
#     Importance: 0.133057
#   Predicado: Ag La <= 4.26 (n=126)
#     Zona: 18 colunas
#     Importance: 0.173544
#   Predicado: Ag La > 4.26 (n=88)
#     Zona: 18 colunas
#     Importance: 0.146703
#   Predicado: Ag La <= 5.23 (n=169)
#     Zona: 18 colunas
#     Importance: 0.162284
#   Predicado: Ag Lb > -6.25 (n=173)
#     Zona: 15 colunas
#     Importance: 0.075016
#   Predicado: Ag Lb <= 2.77 (n=83)
#     Zona: 15 colunas
#     Importance: 0.126035
#   Predicado: Ag Lb > 2.77 (n=131)
#     Zona: 15 colunas
#     Importance: 0.077949
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.104090
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.085874
#   Predicado: Ag Lb <= 4.33 (n=173)
#     Zona: 15 colunas
#     Importance: 0.098522
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.011274
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.012367
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.011040
#   Predicado: Ca <= 1.99 (n=127)
#     Zona: 19 colunas
#     Importance: 0.011197
#   Predicado: Ca > 1.99 (n=87)
#     Zona: 19 colunas
#     Importance: 0.012106
#   Predicado: Ca <= 2.47 (n=169)
#     Zona: 19 colunas
#     Importance: 0.010664
#   Predicado: background > -1.72 (n=176)
#     Zona: 87 colunas
#     Importance: 0.013605
#   Predicado: background <= 2.11 (n=82)
#     Zona: 87 colunas
#     Importance: 0.013410
#   Predicado: background > 2.11 (n=132)
#     Zona: 87 colunas
#     Importance: 0.013597
#   Predicado: background <= 2.38 (n=123)
#     Zona: 87 colunas
#     Importance: 0.013179
#   Predicado: background > 2.38 (n=91)
#     Zona: 87 colunas
#     Importance: 0.013993
#   Predicado: background <= 2.73 (n=170)
#     Zona: 87 colunas
#     Importance: 0.012882
#   Predicado: Fe > -1.71 (n=174)
#     Zona: 23 colunas
#     Importance: 0.018683
#   Predicado: Fe <= -1.30 (n=80)
#     Zona: 23 colunas
#     Importance: 0.018747
#   Predicado: Fe > -1.30 (n=134)
#     Zona: 23 colunas
#     Importance: 0.019497
#   Predicado: Fe <= 1.63 (n=125)
#     Zona: 23 colunas
#     Importance: 0.016893
#   Predicado: Fe > 1.63 (n=89)
#     Zona: 23 colunas
#     Importance: 0.022480
#   Predicado: Fe <= 2.10 (n=170)
#     Zona: 23 colunas
#     Importance: 0.017916
#   Predicado: Cu > -2.02 (n=169)
#     Zona: 66 colunas
#     Importance: 0.012177
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.010810
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.012994
#   Predicado: Cu <= 2.35 (n=134)
#     Zona: 66 colunas
#     Importance: 0.011797
#   Predicado: Cu > 2.35 (n=80)
#     Zona: 66 colunas
#     Importance: 0.012705
#   Predicado: Cu <= 2.71 (n=174)
#     Zona: 66 colunas
#     Importance: 0.011808
#   Predicado: Zn > -1.89 (n=170)
#     Zona: 29 colunas
#     Importance: 0.024805
#   Predicado: Zn <= -1.35 (n=91)
#     Zona: 29 colunas
#     Importance: 0.024820
#   Predicado: Zn > -1.35 (n=123)
#     Zona: 29 colunas
#     Importance: 0.025679
#   Predicado: Zn <= 1.85 (n=131)
#     Zona: 29 colunas
#     Importance: 0.022149
#   Predicado: Zn > 1.85 (n=83)
#     Zona: 29 colunas
#     Importance: 0.030308
#   Predicado: Zn <= 2.28 (n=174)
#     Zona: 29 colunas
#     Importance: 0.023291
#   Predicado: Bremsstrahlung > -3.10 (n=175)
#     Zona: 429 colunas
#     Importance: 0.101948
#   Predicado: Bremsstrahlung <= -2.45 (n=87)
#     Zona: 429 colunas
#     Importance: 0.122396
#   Predicado: Bremsstrahlung > -2.45 (n=127)
#     Zona: 429 colunas
#     Importance: 0.103426
#   Predicado: Bremsstrahlung <= 3.06 (n=127)
#     Zona: 429 colunas
#     Importance: 0.110811
#   Predicado: Bremsstrahlung > 3.06 (n=87)
#     Zona: 429 colunas
#     Importance: 0.111615
#   Predicado: Bremsstrahlung <= 3.46 (n=167)
#     Zona: 429 colunas
#     Importance: 0.109098
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.043096
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.055341
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.045417
#   Predicado: Ag compton <= 2.58 (n=128)
#     Zona: 62 colunas
#     Importance: 0.045887
#   Predicado: Ag compton > 2.58 (n=86)
#     Zona: 62 colunas
#     Importance: 0.054526
#   Predicado: Ag compton <= 3.09 (n=171)
#     Zona: 62 colunas
#     Importance: 0.044506
#   Predicado: Ag ka > -7.93 (n=169)
#     Zona: 45 colunas
#     Importance: 0.107761
#   Predicado: Ag ka <= -3.39 (n=85)
#     Zona: 45 colunas
#     Importance: 0.141598
#   Predicado: Ag ka > -3.39 (n=129)
#     Zona: 45 colunas
#     Importance: 0.114476
#   Predicado: Ag ka <= 5.20 (n=125)
#     Zona: 45 colunas
#     Importance: 0.122076
#   Predicado: Ag ka > 5.20 (n=89)
#     Zona: 45 colunas
#     Importance: 0.129705
#   Predicado: Ag ka <= 10.15 (n=172)
#     Zona: 45 colunas
#     Importance: 0.120123
#
# [Bag_2] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=170)
#     Zona: 18 colunas
#     Importance: 0.127619
#   Predicado: Ag La <= 2.83 (n=88)
#     Zona: 18 colunas
#     Importance: 0.215913
#   Predicado: Ag La > 2.83 (n=126)
#     Zona: 18 colunas
#     Importance: 0.131779
#   Predicado: Ag La <= 4.26 (n=132)
#     Zona: 18 colunas
#     Importance: 0.178919
#   Predicado: Ag La > 4.26 (n=82)
#     Zona: 18 colunas
#     Importance: 0.146185
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.167720
#   Predicado: Ag Lb > -6.25 (n=169)
#     Zona: 15 colunas
#     Importance: 0.075964
#   Predicado: Ag Lb <= 2.77 (n=87)
#     Zona: 15 colunas
#     Importance: 0.130200
#   Predicado: Ag Lb > 2.77 (n=127)
#     Zona: 15 colunas
#     Importance: 0.078482
#   Predicado: Ag Lb <= 3.70 (n=130)
#     Zona: 15 colunas
#     Importance: 0.107895
#   Predicado: Ag Lb > 3.70 (n=84)
#     Zona: 15 colunas
#     Importance: 0.086527
#   Predicado: Ag Lb <= 4.33 (n=175)
#     Zona: 15 colunas
#     Importance: 0.101647
#   Predicado: Ca > -1.96 (n=173)
#     Zona: 19 colunas
#     Importance: 0.011859
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.013729
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.012010
#   Predicado: Ca <= 1.99 (n=129)
#     Zona: 19 colunas
#     Importance: 0.012279
#   Predicado: Ca > 1.99 (n=85)
#     Zona: 19 colunas
#     Importance: 0.013341
#   Predicado: Ca <= 2.47 (n=173)
#     Zona: 19 colunas
#     Importance: 0.011902
#   Predicado: background > -1.72 (n=168)
#     Zona: 87 colunas
#     Importance: 0.012586
#   Predicado: background <= 2.11 (n=89)
#     Zona: 87 colunas
#     Importance: 0.013882
#   Predicado: background > 2.11 (n=125)
#     Zona: 87 colunas
#     Importance: 0.012103
#   Predicado: background <= 2.38 (n=133)
#     Zona: 87 colunas
#     Importance: 0.013197
#   Predicado: background > 2.38 (n=81)
#     Zona: 87 colunas
#     Importance: 0.012262
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012807
#   Predicado: Fe > -1.71 (n=173)
#     Zona: 23 colunas
#     Importance: 0.019192
#   Predicado: Fe <= -1.30 (n=85)
#     Zona: 23 colunas
#     Importance: 0.018767
#   Predicado: Fe > -1.30 (n=129)
#     Zona: 23 colunas
#     Importance: 0.020062
#   Predicado: Fe <= 1.63 (n=127)
#     Zona: 23 colunas
#     Importance: 0.017125
#   Predicado: Fe > 1.63 (n=87)
#     Zona: 23 colunas
#     Importance: 0.023083
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.017806
#   Predicado: Cu > -2.02 (n=173)
#     Zona: 66 colunas
#     Importance: 0.012476
#   Predicado: Cu <= 2.01 (n=81)
#     Zona: 66 colunas
#     Importance: 0.010814
#   Predicado: Cu > 2.01 (n=133)
#     Zona: 66 colunas
#     Importance: 0.013223
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.012139
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.012557
#   Predicado: Cu <= 2.71 (n=168)
#     Zona: 66 colunas
#     Importance: 0.011910
#   Predicado: Zn > -1.89 (n=174)
#     Zona: 29 colunas
#     Importance: 0.024791
#   Predicado: Zn <= -1.35 (n=86)
#     Zona: 29 colunas
#     Importance: 0.023396
#   Predicado: Zn > -1.35 (n=128)
#     Zona: 29 colunas
#     Importance: 0.026185
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.020455
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.032198
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.022092
#   Predicado: Bremsstrahlung > -3.10 (n=173)
#     Zona: 429 colunas
#     Importance: 0.099709
#   Predicado: Bremsstrahlung <= -2.45 (n=88)
#     Zona: 429 colunas
#     Importance: 0.109951
#   Predicado: Bremsstrahlung > -2.45 (n=126)
#     Zona: 429 colunas
#     Importance: 0.104935
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.103407
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.112555
#   Predicado: Bremsstrahlung <= 3.46 (n=176)
#     Zona: 429 colunas
#     Importance: 0.103886
#   Predicado: Ag compton > -2.89 (n=171)
#     Zona: 62 colunas
#     Importance: 0.041290
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.058128
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.042799
#   Predicado: Ag compton <= 2.58 (n=128)
#     Zona: 62 colunas
#     Importance: 0.046941
#   Predicado: Ag compton > 2.58 (n=86)
#     Zona: 62 colunas
#     Importance: 0.051784
#   Predicado: Ag compton <= 3.09 (n=172)
#     Zona: 62 colunas
#     Importance: 0.044809
#   Predicado: Ag ka > -7.93 (n=168)
#     Zona: 45 colunas
#     Importance: 0.109090
#   Predicado: Ag ka <= -3.39 (n=86)
#     Zona: 45 colunas
#     Importance: 0.139585
#   Predicado: Ag ka > -3.39 (n=128)
#     Zona: 45 colunas
#     Importance: 0.118869
#   Predicado: Ag ka <= 5.20 (n=124)
#     Zona: 45 colunas
#     Importance: 0.124469
#   Predicado: Ag ka > 5.20 (n=90)
#     Zona: 45 colunas
#     Importance: 0.130949
#   Predicado: Ag ka <= 10.15 (n=166)
#     Zona: 45 colunas
#     Importance: 0.120757
#
# [Bag_3] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=175)
#     Zona: 18 colunas
#     Importance: 0.130913
#   Predicado: Ag La <= 2.83 (n=84)
#     Zona: 18 colunas
#     Importance: 0.215266
#   Predicado: Ag La > 2.83 (n=130)
#     Zona: 18 colunas
#     Importance: 0.133006
#   Predicado: Ag La <= 4.26 (n=126)
#     Zona: 18 colunas
#     Importance: 0.177144
#   Predicado: Ag La > 4.26 (n=88)
#     Zona: 18 colunas
#     Importance: 0.148329
#   Predicado: Ag La <= 5.23 (n=168)
#     Zona: 18 colunas
#     Importance: 0.165850
#   Predicado: Ag Lb > -6.25 (n=174)
#     Zona: 15 colunas
#     Importance: 0.076377
#   Predicado: Ag Lb <= 2.77 (n=84)
#     Zona: 15 colunas
#     Importance: 0.127792
#   Predicado: Ag Lb > 2.77 (n=130)
#     Zona: 15 colunas
#     Importance: 0.077230
#   Predicado: Ag Lb <= 3.70 (n=129)
#     Zona: 15 colunas
#     Importance: 0.104592
#   Predicado: Ag Lb > 3.70 (n=85)
#     Zona: 15 colunas
#     Importance: 0.085671
#   Predicado: Ag Lb <= 4.33 (n=172)
#     Zona: 15 colunas
#     Importance: 0.099674
#   Predicado: Ca > -1.96 (n=174)
#     Zona: 19 colunas
#     Importance: 0.011660
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.012439
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.011756
#   Predicado: Ca <= 1.99 (n=132)
#     Zona: 19 colunas
#     Importance: 0.011175
#   Predicado: Ca > 1.99 (n=82)
#     Zona: 19 colunas
#     Importance: 0.013408
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.011210
#   Predicado: background > -1.72 (n=168)
#     Zona: 87 colunas
#     Importance: 0.013205
#   Predicado: background <= 2.11 (n=88)
#     Zona: 87 colunas
#     Importance: 0.013387
#   Predicado: background > 2.11 (n=126)
#     Zona: 87 colunas
#     Importance: 0.012978
#   Predicado: background <= 2.38 (n=128)
#     Zona: 87 colunas
#     Importance: 0.012640
#   Predicado: background > 2.38 (n=86)
#     Zona: 87 colunas
#     Importance: 0.013901
#   Predicado: background <= 2.73 (n=171)
#     Zona: 87 colunas
#     Importance: 0.012287
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.019787
#   Predicado: Fe <= -1.30 (n=87)
#     Zona: 23 colunas
#     Importance: 0.018844
#   Predicado: Fe > -1.30 (n=127)
#     Zona: 23 colunas
#     Importance: 0.020801
#   Predicado: Fe <= 1.63 (n=128)
#     Zona: 23 colunas
#     Importance: 0.017102
#   Predicado: Fe > 1.63 (n=86)
#     Zona: 23 colunas
#     Importance: 0.024327
#   Predicado: Fe <= 2.10 (n=170)
#     Zona: 23 colunas
#     Importance: 0.017997
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.012150
#   Predicado: Cu <= 2.01 (n=86)
#     Zona: 66 colunas
#     Importance: 0.010876
#   Predicado: Cu > 2.01 (n=128)
#     Zona: 66 colunas
#     Importance: 0.012743
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.011733
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.012364
#   Predicado: Cu <= 2.71 (n=167)
#     Zona: 66 colunas
#     Importance: 0.011679
#   Predicado: Zn > -1.89 (n=169)
#     Zona: 29 colunas
#     Importance: 0.025386
#   Predicado: Zn <= -1.35 (n=87)
#     Zona: 29 colunas
#     Importance: 0.025071
#   Predicado: Zn > -1.35 (n=127)
#     Zona: 29 colunas
#     Importance: 0.026032
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.021744
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.031671
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.022561
#   Predicado: Bremsstrahlung > -3.10 (n=170)
#     Zona: 429 colunas
#     Importance: 0.105348
#   Predicado: Bremsstrahlung <= -2.45 (n=87)
#     Zona: 429 colunas
#     Importance: 0.121656
#   Predicado: Bremsstrahlung > -2.45 (n=127)
#     Zona: 429 colunas
#     Importance: 0.107627
#   Predicado: Bremsstrahlung <= 3.06 (n=127)
#     Zona: 429 colunas
#     Importance: 0.113883
#   Predicado: Bremsstrahlung > 3.06 (n=87)
#     Zona: 429 colunas
#     Importance: 0.112524
#   Predicado: Bremsstrahlung <= 3.46 (n=169)
#     Zona: 429 colunas
#     Importance: 0.112575
#   Predicado: Ag compton > -2.89 (n=169)
#     Zona: 62 colunas
#     Importance: 0.043414
#   Predicado: Ag compton <= -2.03 (n=88)
#     Zona: 62 colunas
#     Importance: 0.058395
#   Predicado: Ag compton > -2.03 (n=126)
#     Zona: 62 colunas
#     Importance: 0.045364
#   Predicado: Ag compton <= 2.58 (n=130)
#     Zona: 62 colunas
#     Importance: 0.048190
#   Predicado: Ag compton > 2.58 (n=84)
#     Zona: 62 colunas
#     Importance: 0.054642
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.046115
#   Predicado: Ag ka > -7.93 (n=169)
#     Zona: 45 colunas
#     Importance: 0.107161
#   Predicado: Ag ka <= -3.39 (n=89)
#     Zona: 45 colunas
#     Importance: 0.145327
#   Predicado: Ag ka > -3.39 (n=125)
#     Zona: 45 colunas
#     Importance: 0.115214
#   Predicado: Ag ka <= 5.20 (n=132)
#     Zona: 45 colunas
#     Importance: 0.122566
#   Predicado: Ag ka > 5.20 (n=82)
#     Zona: 45 colunas
#     Importance: 0.136063
#   Predicado: Ag ka <= 10.15 (n=170)
#     Zona: 45 colunas
#     Importance: 0.121236
#
# [Bag_4] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.130655
#   Predicado: Ag La <= 2.83 (n=85)
#     Zona: 18 colunas
#     Importance: 0.219014
#   Predicado: Ag La > 2.83 (n=129)
#     Zona: 18 colunas
#     Importance: 0.133201
#   Predicado: Ag La <= 4.26 (n=130)
#     Zona: 18 colunas
#     Importance: 0.179486
#   Predicado: Ag La > 4.26 (n=84)
#     Zona: 18 colunas
#     Importance: 0.148403
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.168334
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.076635
#   Predicado: Ag Lb <= 2.77 (n=87)
#     Zona: 15 colunas
#     Importance: 0.128336
#   Predicado: Ag Lb > 2.77 (n=127)
#     Zona: 15 colunas
#     Importance: 0.079716
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.108539
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.086513
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.102260
#   Predicado: Ca > -1.96 (n=168)
#     Zona: 19 colunas
#     Importance: 0.011913
#   Predicado: Ca <= -1.26 (n=86)
#     Zona: 19 colunas
#     Importance: 0.013403
#   Predicado: Ca > -1.26 (n=128)
#     Zona: 19 colunas
#     Importance: 0.012024
#   Predicado: Ca <= 1.99 (n=130)
#     Zona: 19 colunas
#     Importance: 0.012000
#   Predicado: Ca > 1.99 (n=84)
#     Zona: 19 colunas
#     Importance: 0.013472
#   Predicado: Ca <= 2.47 (n=173)
#     Zona: 19 colunas
#     Importance: 0.011549
#   Predicado: background > -1.72 (n=174)
#     Zona: 87 colunas
#     Importance: 0.013382
#   Predicado: background <= 2.11 (n=82)
#     Zona: 87 colunas
#     Importance: 0.013606
#   Predicado: background > 2.11 (n=132)
#     Zona: 87 colunas
#     Importance: 0.012882
#   Predicado: background <= 2.38 (n=126)
#     Zona: 87 colunas
#     Importance: 0.013197
#   Predicado: background > 2.38 (n=88)
#     Zona: 87 colunas
#     Importance: 0.013107
#   Predicado: background <= 2.73 (n=167)
#     Zona: 87 colunas
#     Importance: 0.012692
#   Predicado: Fe > -1.71 (n=179)
#     Zona: 23 colunas
#     Importance: 0.019410
#   Predicado: Fe <= -1.30 (n=78)
#     Zona: 23 colunas
#     Importance: 0.018582
#   Predicado: Fe > -1.30 (n=136)
#     Zona: 23 colunas
#     Importance: 0.020343
#   Predicado: Fe <= 1.63 (n=119)
#     Zona: 23 colunas
#     Importance: 0.016768
#   Predicado: Fe > 1.63 (n=95)
#     Zona: 23 colunas
#     Importance: 0.023375
#   Predicado: Fe <= 2.10 (n=169)
#     Zona: 23 colunas
#     Importance: 0.017828
#   Predicado: Cu > -2.02 (n=175)
#     Zona: 66 colunas
#     Importance: 0.012109
#   Predicado: Cu <= 2.01 (n=80)
#     Zona: 66 colunas
#     Importance: 0.011485
#   Predicado: Cu > 2.01 (n=134)
#     Zona: 66 colunas
#     Importance: 0.012567
#   Predicado: Cu <= 2.35 (n=125)
#     Zona: 66 colunas
#     Importance: 0.012247
#   Predicado: Cu > 2.35 (n=89)
#     Zona: 66 colunas
#     Importance: 0.012044
#   Predicado: Cu <= 2.71 (n=167)
#     Zona: 66 colunas
#     Importance: 0.012157
#   Predicado: Zn > -1.89 (n=177)
#     Zona: 29 colunas
#     Importance: 0.024281
#   Predicado: Zn <= -1.35 (n=84)
#     Zona: 29 colunas
#     Importance: 0.026268
#   Predicado: Zn > -1.35 (n=130)
#     Zona: 29 colunas
#     Importance: 0.024655
#   Predicado: Zn <= 1.85 (n=128)
#     Zona: 29 colunas
#     Importance: 0.022501
#   Predicado: Zn > 1.85 (n=86)
#     Zona: 29 colunas
#     Importance: 0.029437
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.022733
#   Predicado: Bremsstrahlung > -3.10 (n=174)
#     Zona: 429 colunas
#     Importance: 0.102330
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.107520
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.105142
#   Predicado: Bremsstrahlung <= 3.06 (n=129)
#     Zona: 429 colunas
#     Importance: 0.102795
#   Predicado: Bremsstrahlung > 3.06 (n=85)
#     Zona: 429 colunas
#     Importance: 0.111082
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.103461
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.042236
#   Predicado: Ag compton <= -2.03 (n=85)
#     Zona: 62 colunas
#     Importance: 0.055409
#   Predicado: Ag compton > -2.03 (n=129)
#     Zona: 62 colunas
#     Importance: 0.044383
#   Predicado: Ag compton <= 2.58 (n=131)
#     Zona: 62 colunas
#     Importance: 0.045287
#   Predicado: Ag compton > 2.58 (n=83)
#     Zona: 62 colunas
#     Importance: 0.054249
#   Predicado: Ag compton <= 3.09 (n=172)
#     Zona: 62 colunas
#     Importance: 0.044544
#   Predicado: Ag ka > -7.93 (n=167)
#     Zona: 45 colunas
#     Importance: 0.101725
#   Predicado: Ag ka <= -3.39 (n=87)
#     Zona: 45 colunas
#     Importance: 0.146040
#   Predicado: Ag ka > -3.39 (n=127)
#     Zona: 45 colunas
#     Importance: 0.108213
#   Predicado: Ag ka <= 5.20 (n=133)
#     Zona: 45 colunas
#     Importance: 0.123358
#   Predicado: Ag ka > 5.20 (n=81)
#     Zona: 45 colunas
#     Importance: 0.123973
#   Predicado: Ag ka <= 10.15 (n=175)
#     Zona: 45 colunas
#     Importance: 0.120500
#
# [Bag_5] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=169)
#     Zona: 18 colunas
#     Importance: 0.126992
#   Predicado: Ag La <= 2.83 (n=86)
#     Zona: 18 colunas
#     Importance: 0.219963
#   Predicado: Ag La > 2.83 (n=128)
#     Zona: 18 colunas
#     Importance: 0.130386
#   Predicado: Ag La <= 4.26 (n=127)
#     Zona: 18 colunas
#     Importance: 0.181044
#   Predicado: Ag La > 4.26 (n=87)
#     Zona: 18 colunas
#     Importance: 0.144985
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.168101
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.075309
#   Predicado: Ag Lb <= 2.77 (n=88)
#     Zona: 15 colunas
#     Importance: 0.128570
#   Predicado: Ag Lb > 2.77 (n=126)
#     Zona: 15 colunas
#     Importance: 0.077307
#   Predicado: Ag Lb <= 3.70 (n=133)
#     Zona: 15 colunas
#     Importance: 0.106264
#   Predicado: Ag Lb > 3.70 (n=81)
#     Zona: 15 colunas
#     Importance: 0.085453
#   Predicado: Ag Lb <= 4.33 (n=176)
#     Zona: 15 colunas
#     Importance: 0.100625
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.011913
#   Predicado: Ca <= -1.26 (n=84)
#     Zona: 19 colunas
#     Importance: 0.012522
#   Predicado: Ca > -1.26 (n=130)
#     Zona: 19 colunas
#     Importance: 0.012217
#   Predicado: Ca <= 1.99 (n=130)
#     Zona: 19 colunas
#     Importance: 0.011337
#   Predicado: Ca > 1.99 (n=84)
#     Zona: 19 colunas
#     Importance: 0.013883
#   Predicado: Ca <= 2.47 (n=172)
#     Zona: 19 colunas
#     Importance: 0.011437
#   Predicado: background > -1.72 (n=170)
#     Zona: 87 colunas
#     Importance: 0.013522
#   Predicado: background <= 2.11 (n=85)
#     Zona: 87 colunas
#     Importance: 0.013810
#   Predicado: background > 2.11 (n=129)
#     Zona: 87 colunas
#     Importance: 0.013271
#   Predicado: background <= 2.38 (n=125)
#     Zona: 87 colunas
#     Importance: 0.013337
#   Predicado: background > 2.38 (n=89)
#     Zona: 87 colunas
#     Importance: 0.013693
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.013074
#   Predicado: Fe > -1.71 (n=172)
#     Zona: 23 colunas
#     Importance: 0.019122
#   Predicado: Fe <= -1.30 (n=80)
#     Zona: 23 colunas
#     Importance: 0.019791
#   Predicado: Fe > -1.30 (n=134)
#     Zona: 23 colunas
#     Importance: 0.019545
#   Predicado: Fe <= 1.63 (n=120)
#     Zona: 23 colunas
#     Importance: 0.017771
#   Predicado: Fe > 1.63 (n=94)
#     Zona: 23 colunas
#     Importance: 0.022019
#   Predicado: Fe <= 2.10 (n=168)
#     Zona: 23 colunas
#     Importance: 0.018127
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.012101
#   Predicado: Cu <= 2.01 (n=83)
#     Zona: 66 colunas
#     Importance: 0.010498
#   Predicado: Cu > 2.01 (n=131)
#     Zona: 66 colunas
#     Importance: 0.012720
#   Predicado: Cu <= 2.35 (n=126)
#     Zona: 66 colunas
#     Importance: 0.011718
#   Predicado: Cu > 2.35 (n=88)
#     Zona: 66 colunas
#     Importance: 0.012059
#   Predicado: Cu <= 2.71 (n=169)
#     Zona: 66 colunas
#     Importance: 0.011532
#   Predicado: Zn > -1.89 (n=171)
#     Zona: 29 colunas
#     Importance: 0.025017
#   Predicado: Zn <= -1.35 (n=88)
#     Zona: 29 colunas
#     Importance: 0.025685
#   Predicado: Zn > -1.35 (n=126)
#     Zona: 29 colunas
#     Importance: 0.025774
#   Predicado: Zn <= 1.85 (n=134)
#     Zona: 29 colunas
#     Importance: 0.022139
#   Predicado: Zn > 1.85 (n=80)
#     Zona: 29 colunas
#     Importance: 0.031764
#   Predicado: Zn <= 2.28 (n=175)
#     Zona: 29 colunas
#     Importance: 0.023620
#   Predicado: Bremsstrahlung > -3.10 (n=171)
#     Zona: 429 colunas
#     Importance: 0.100325
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.114879
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.101371
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.105115
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.109245
#   Predicado: Bremsstrahlung <= 3.46 (n=174)
#     Zona: 429 colunas
#     Importance: 0.104623
#   Predicado: Ag compton > -2.89 (n=170)
#     Zona: 62 colunas
#     Importance: 0.041851
#   Predicado: Ag compton <= -2.03 (n=87)
#     Zona: 62 colunas
#     Importance: 0.056627
#   Predicado: Ag compton > -2.03 (n=127)
#     Zona: 62 colunas
#     Importance: 0.043660
#   Predicado: Ag compton <= 2.58 (n=133)
#     Zona: 62 colunas
#     Importance: 0.045926
#   Predicado: Ag compton > 2.58 (n=81)
#     Zona: 62 colunas
#     Importance: 0.053867
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.044764
#   Predicado: Ag ka > -7.93 (n=168)
#     Zona: 45 colunas
#     Importance: 0.109354
#   Predicado: Ag ka <= -3.39 (n=81)
#     Zona: 45 colunas
#     Importance: 0.152528
#   Predicado: Ag ka > -3.39 (n=133)
#     Zona: 45 colunas
#     Importance: 0.116581
#   Predicado: Ag ka <= 5.20 (n=126)
#     Zona: 45 colunas
#     Importance: 0.126719
#   Predicado: Ag ka > 5.20 (n=88)
#     Zona: 45 colunas
#     Importance: 0.135153
#   Predicado: Ag ka <= 10.15 (n=170)
#     Zona: 45 colunas
#     Importance: 0.124483
#
# [Bag_6] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=170)
#     Zona: 18 colunas
#     Importance: 0.128557
#   Predicado: Ag La <= 2.83 (n=83)
#     Zona: 18 colunas
#     Importance: 0.218767
#   Predicado: Ag La > 2.83 (n=131)
#     Zona: 18 colunas
#     Importance: 0.134101
#   Predicado: Ag La <= 4.26 (n=125)
#     Zona: 18 colunas
#     Importance: 0.180370
#   Predicado: Ag La > 4.26 (n=89)
#     Zona: 18 colunas
#     Importance: 0.148075
#   Predicado: Ag La <= 5.23 (n=170)
#     Zona: 18 colunas
#     Importance: 0.166739
#   Predicado: Ag Lb > -6.25 (n=169)
#     Zona: 15 colunas
#     Importance: 0.073598
#   Predicado: Ag Lb <= 2.77 (n=85)
#     Zona: 15 colunas
#     Importance: 0.126868
#   Predicado: Ag Lb > 2.77 (n=129)
#     Zona: 15 colunas
#     Importance: 0.078256
#   Predicado: Ag Lb <= 3.70 (n=126)
#     Zona: 15 colunas
#     Importance: 0.106113
#   Predicado: Ag Lb > 3.70 (n=88)
#     Zona: 15 colunas
#     Importance: 0.085325
#   Predicado: Ag Lb <= 4.33 (n=171)
#     Zona: 15 colunas
#     Importance: 0.100173
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.011636
#   Predicado: Ca <= -1.26 (n=83)
#     Zona: 19 colunas
#     Importance: 0.012140
#   Predicado: Ca > -1.26 (n=131)
#     Zona: 19 colunas
#     Importance: 0.011701
#   Predicado: Ca <= 1.99 (n=129)
#     Zona: 19 colunas
#     Importance: 0.011266
#   Predicado: Ca > 1.99 (n=85)
#     Zona: 19 colunas
#     Importance: 0.012789
#   Predicado: Ca <= 2.47 (n=170)
#     Zona: 19 colunas
#     Importance: 0.010953
#   Predicado: background > -1.72 (n=165)
#     Zona: 87 colunas
#     Importance: 0.013511
#   Predicado: background <= 2.11 (n=94)
#     Zona: 87 colunas
#     Importance: 0.013906
#   Predicado: background > 2.11 (n=120)
#     Zona: 87 colunas
#     Importance: 0.013263
#   Predicado: background <= 2.38 (n=133)
#     Zona: 87 colunas
#     Importance: 0.013509
#   Predicado: background > 2.38 (n=81)
#     Zona: 87 colunas
#     Importance: 0.013604
#   Predicado: background <= 2.73 (n=175)
#     Zona: 87 colunas
#     Importance: 0.013199
#   Predicado: Fe > -1.71 (n=173)
#     Zona: 23 colunas
#     Importance: 0.019437
#   Predicado: Fe <= -1.30 (n=89)
#     Zona: 23 colunas
#     Importance: 0.019740
#   Predicado: Fe > -1.30 (n=125)
#     Zona: 23 colunas
#     Importance: 0.020479
#   Predicado: Fe <= 1.63 (n=132)
#     Zona: 23 colunas
#     Importance: 0.017751
#   Predicado: Fe > 1.63 (n=82)
#     Zona: 23 colunas
#     Importance: 0.024069
#   Predicado: Fe <= 2.10 (n=173)
#     Zona: 23 colunas
#     Importance: 0.019017
#   Predicado: Cu > -2.02 (n=166)
#     Zona: 66 colunas
#     Importance: 0.012472
#   Predicado: Cu <= 2.01 (n=87)
#     Zona: 66 colunas
#     Importance: 0.010973
#   Predicado: Cu > 2.01 (n=127)
#     Zona: 66 colunas
#     Importance: 0.013238
#   Predicado: Cu <= 2.35 (n=131)
#     Zona: 66 colunas
#     Importance: 0.011989
#   Predicado: Cu > 2.35 (n=83)
#     Zona: 66 colunas
#     Importance: 0.012835
#   Predicado: Cu <= 2.71 (n=172)
#     Zona: 66 colunas
#     Importance: 0.011917
#   Predicado: Zn > -1.89 (n=167)
#     Zona: 29 colunas
#     Importance: 0.025364
#   Predicado: Zn <= -1.35 (n=88)
#     Zona: 29 colunas
#     Importance: 0.025820
#   Predicado: Zn > -1.35 (n=126)
#     Zona: 29 colunas
#     Importance: 0.026067
#   Predicado: Zn <= 1.85 (n=127)
#     Zona: 29 colunas
#     Importance: 0.022045
#   Predicado: Zn > 1.85 (n=87)
#     Zona: 29 colunas
#     Importance: 0.031687
#   Predicado: Zn <= 2.28 (n=168)
#     Zona: 29 colunas
#     Importance: 0.022765
#   Predicado: Bremsstrahlung > -3.10 (n=169)
#     Zona: 429 colunas
#     Importance: 0.098050
#   Predicado: Bremsstrahlung <= -2.45 (n=93)
#     Zona: 429 colunas
#     Importance: 0.113012
#   Predicado: Bremsstrahlung > -2.45 (n=121)
#     Zona: 429 colunas
#     Importance: 0.100089
#   Predicado: Bremsstrahlung <= 3.06 (n=135)
#     Zona: 429 colunas
#     Importance: 0.102849
#   Predicado: Bremsstrahlung > 3.06 (n=79)
#     Zona: 429 colunas
#     Importance: 0.110586
#   Predicado: Bremsstrahlung <= 3.46 (n=176)
#     Zona: 429 colunas
#     Importance: 0.103603
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.038675
#   Predicado: Ag compton <= -2.03 (n=89)
#     Zona: 62 colunas
#     Importance: 0.054344
#   Predicado: Ag compton > -2.03 (n=125)
#     Zona: 62 colunas
#     Importance: 0.040189
#   Predicado: Ag compton <= 2.58 (n=132)
#     Zona: 62 colunas
#     Importance: 0.044438
#   Predicado: Ag compton > 2.58 (n=82)
#     Zona: 62 colunas
#     Importance: 0.048711
#   Predicado: Ag compton <= 3.09 (n=176)
#     Zona: 62 colunas
#     Importance: 0.043124
#   Predicado: Ag ka > -7.93 (n=170)
#     Zona: 45 colunas
#     Importance: 0.110054
#   Predicado: Ag ka <= -3.39 (n=81)
#     Zona: 45 colunas
#     Importance: 0.148748
#   Predicado: Ag ka > -3.39 (n=133)
#     Zona: 45 colunas
#     Importance: 0.115263
#   Predicado: Ag ka <= 5.20 (n=129)
#     Zona: 45 colunas
#     Importance: 0.124183
#   Predicado: Ag ka > 5.20 (n=85)
#     Zona: 45 colunas
#     Importance: 0.133635
#   Predicado: Ag ka <= 10.15 (n=174)
#     Zona: 45 colunas
#     Importance: 0.120371
#
# [Bag_7] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.129262
#   Predicado: Ag La <= 2.83 (n=86)
#     Zona: 18 colunas
#     Importance: 0.217453
#   Predicado: Ag La > 2.83 (n=128)
#     Zona: 18 colunas
#     Importance: 0.131359
#   Predicado: Ag La <= 4.26 (n=127)
#     Zona: 18 colunas
#     Importance: 0.180607
#   Predicado: Ag La > 4.26 (n=87)
#     Zona: 18 colunas
#     Importance: 0.144572
#   Predicado: Ag La <= 5.23 (n=174)
#     Zona: 18 colunas
#     Importance: 0.167424
#   Predicado: Ag Lb > -6.25 (n=173)
#     Zona: 15 colunas
#     Importance: 0.076669
#   Predicado: Ag Lb <= 2.77 (n=88)
#     Zona: 15 colunas
#     Importance: 0.126688
#   Predicado: Ag Lb > 2.77 (n=126)
#     Zona: 15 colunas
#     Importance: 0.078131
#   Predicado: Ag Lb <= 3.70 (n=131)
#     Zona: 15 colunas
#     Importance: 0.105503
#   Predicado: Ag Lb > 3.70 (n=83)
#     Zona: 15 colunas
#     Importance: 0.086411
#   Predicado: Ag Lb <= 4.33 (n=172)
#     Zona: 15 colunas
#     Importance: 0.100518
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.011978
#   Predicado: Ca <= -1.26 (n=83)
#     Zona: 19 colunas
#     Importance: 0.013018
#   Predicado: Ca > -1.26 (n=131)
#     Zona: 19 colunas
#     Importance: 0.012140
#   Predicado: Ca <= 1.99 (n=125)
#     Zona: 19 colunas
#     Importance: 0.011889
#   Predicado: Ca > 1.99 (n=89)
#     Zona: 19 colunas
#     Importance: 0.013311
#   Predicado: Ca <= 2.47 (n=170)
#     Zona: 19 colunas
#     Importance: 0.011516
#   Predicado: background > -1.72 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012879
#   Predicado: background <= 2.11 (n=85)
#     Zona: 87 colunas
#     Importance: 0.012602
#   Predicado: background > 2.11 (n=129)
#     Zona: 87 colunas
#     Importance: 0.013124
#   Predicado: background <= 2.38 (n=129)
#     Zona: 87 colunas
#     Importance: 0.012513
#   Predicado: background > 2.38 (n=85)
#     Zona: 87 colunas
#     Importance: 0.013530
#   Predicado: background <= 2.73 (n=172)
#     Zona: 87 colunas
#     Importance: 0.012369
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.018924
#   Predicado: Fe <= -1.30 (n=83)
#     Zona: 23 colunas
#     Importance: 0.019333
#   Predicado: Fe > -1.30 (n=131)
#     Zona: 23 colunas
#     Importance: 0.019785
#   Predicado: Fe <= 1.63 (n=123)
#     Zona: 23 colunas
#     Importance: 0.017524
#   Predicado: Fe > 1.63 (n=91)
#     Zona: 23 colunas
#     Importance: 0.022430
#   Predicado: Fe <= 2.10 (n=172)
#     Zona: 23 colunas
#     Importance: 0.018084
#   Predicado: Cu > -2.02 (n=173)
#     Zona: 66 colunas
#     Importance: 0.012299
#   Predicado: Cu <= 2.01 (n=86)
#     Zona: 66 colunas
#     Importance: 0.011161
#   Predicado: Cu > 2.01 (n=128)
#     Zona: 66 colunas
#     Importance: 0.013002
#   Predicado: Cu <= 2.35 (n=130)
#     Zona: 66 colunas
#     Importance: 0.012230
#   Predicado: Cu > 2.35 (n=84)
#     Zona: 66 colunas
#     Importance: 0.012312
#   Predicado: Cu <= 2.71 (n=174)
#     Zona: 66 colunas
#     Importance: 0.012024
#   Predicado: Zn > -1.89 (n=169)
#     Zona: 29 colunas
#     Importance: 0.025670
#   Predicado: Zn <= -1.35 (n=86)
#     Zona: 29 colunas
#     Importance: 0.025123
#   Predicado: Zn > -1.35 (n=128)
#     Zona: 29 colunas
#     Importance: 0.026155
#   Predicado: Zn <= 1.85 (n=130)
#     Zona: 29 colunas
#     Importance: 0.021731
#   Predicado: Zn > 1.85 (n=84)
#     Zona: 29 colunas
#     Importance: 0.031945
#   Predicado: Zn <= 2.28 (n=170)
#     Zona: 29 colunas
#     Importance: 0.022677
#   Predicado: Bremsstrahlung > -3.10 (n=175)
#     Zona: 429 colunas
#     Importance: 0.098169
#   Predicado: Bremsstrahlung <= -2.45 (n=82)
#     Zona: 429 colunas
#     Importance: 0.111353
#   Predicado: Bremsstrahlung > -2.45 (n=132)
#     Zona: 429 colunas
#     Importance: 0.099639
#   Predicado: Bremsstrahlung <= 3.06 (n=128)
#     Zona: 429 colunas
#     Importance: 0.103411
#   Predicado: Bremsstrahlung > 3.06 (n=86)
#     Zona: 429 colunas
#     Importance: 0.105193
#   Predicado: Bremsstrahlung <= 3.46 (n=168)
#     Zona: 429 colunas
#     Importance: 0.101309
#   Predicado: Ag compton > -2.89 (n=175)
#     Zona: 62 colunas
#     Importance: 0.042862
#   Predicado: Ag compton <= -2.03 (n=79)
#     Zona: 62 colunas
#     Importance: 0.060045
#   Predicado: Ag compton > -2.03 (n=135)
#     Zona: 62 colunas
#     Importance: 0.044196
#   Predicado: Ag compton <= 2.58 (n=124)
#     Zona: 62 colunas
#     Importance: 0.046618
#   Predicado: Ag compton > 2.58 (n=90)
#     Zona: 62 colunas
#     Importance: 0.054772
#   Predicado: Ag compton <= 3.09 (n=168)
#     Zona: 62 colunas
#     Importance: 0.045281
#   Predicado: Ag ka > -7.93 (n=171)
#     Zona: 45 colunas
#     Importance: 0.107955
#   Predicado: Ag ka <= -3.39 (n=83)
#     Zona: 45 colunas
#     Importance: 0.141632
#   Predicado: Ag ka > -3.39 (n=131)
#     Zona: 45 colunas
#     Importance: 0.116001
#   Predicado: Ag ka <= 5.20 (n=130)
#     Zona: 45 colunas
#     Importance: 0.119403
#   Predicado: Ag ka > 5.20 (n=84)
#     Zona: 45 colunas
#     Importance: 0.136063
#   Predicado: Ag ka <= 10.15 (n=172)
#     Zona: 45 colunas
#     Importance: 0.119997
#
# [Bag_8] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=168)
#     Zona: 18 colunas
#     Importance: 0.133119
#   Predicado: Ag La <= 2.83 (n=82)
#     Zona: 18 colunas
#     Importance: 0.235937
#   Predicado: Ag La > 2.83 (n=132)
#     Zona: 18 colunas
#     Importance: 0.132467
#   Predicado: Ag La <= 4.26 (n=124)
#     Zona: 18 colunas
#     Importance: 0.191214
#   Predicado: Ag La > 4.26 (n=90)
#     Zona: 18 colunas
#     Importance: 0.145800
#   Predicado: Ag La <= 5.23 (n=172)
#     Zona: 18 colunas
#     Importance: 0.174244
#   Predicado: Ag Lb > -6.25 (n=168)
#     Zona: 15 colunas
#     Importance: 0.078563
#   Predicado: Ag Lb <= 2.77 (n=83)
#     Zona: 15 colunas
#     Importance: 0.138988
#   Predicado: Ag Lb > 2.77 (n=131)
#     Zona: 15 colunas
#     Importance: 0.078515
#   Predicado: Ag Lb <= 3.70 (n=127)
#     Zona: 15 colunas
#     Importance: 0.113227
#   Predicado: Ag Lb > 3.70 (n=87)
#     Zona: 15 colunas
#     Importance: 0.085536
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.105947
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.011988
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.013014
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.012260
#   Predicado: Ca <= 1.99 (n=131)
#     Zona: 19 colunas
#     Importance: 0.011632
#   Predicado: Ca > 1.99 (n=83)
#     Zona: 19 colunas
#     Importance: 0.014023
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.011435
#   Predicado: background > -1.72 (n=172)
#     Zona: 87 colunas
#     Importance: 0.013583
#   Predicado: background <= 2.11 (n=87)
#     Zona: 87 colunas
#     Importance: 0.014163
#   Predicado: background > 2.11 (n=127)
#     Zona: 87 colunas
#     Importance: 0.013586
#   Predicado: background <= 2.38 (n=132)
#     Zona: 87 colunas
#     Importance: 0.013505
#   Predicado: background > 2.38 (n=82)
#     Zona: 87 colunas
#     Importance: 0.014329
#   Predicado: background <= 2.73 (n=169)
#     Zona: 87 colunas
#     Importance: 0.013441
#   Predicado: Fe > -1.71 (n=168)
#     Zona: 23 colunas
#     Importance: 0.019266
#   Predicado: Fe <= -1.30 (n=88)
#     Zona: 23 colunas
#     Importance: 0.019727
#   Predicado: Fe > -1.30 (n=126)
#     Zona: 23 colunas
#     Importance: 0.019943
#   Predicado: Fe <= 1.63 (n=134)
#     Zona: 23 colunas
#     Importance: 0.017929
#   Predicado: Fe > 1.63 (n=80)
#     Zona: 23 colunas
#     Importance: 0.023079
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.018644
#   Predicado: Cu > -2.02 (n=172)
#     Zona: 66 colunas
#     Importance: 0.012451
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.010913
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.013267
#   Predicado: Cu <= 2.35 (n=127)
#     Zona: 66 colunas
#     Importance: 0.011998
#   Predicado: Cu > 2.35 (n=87)
#     Zona: 66 colunas
#     Importance: 0.012847
#   Predicado: Cu <= 2.71 (n=172)
#     Zona: 66 colunas
#     Importance: 0.011865
#   Predicado: Zn > -1.89 (n=171)
#     Zona: 29 colunas
#     Importance: 0.026065
#   Predicado: Zn <= -1.35 (n=85)
#     Zona: 29 colunas
#     Importance: 0.025609
#   Predicado: Zn > -1.35 (n=129)
#     Zona: 29 colunas
#     Importance: 0.027016
#   Predicado: Zn <= 1.85 (n=126)
#     Zona: 29 colunas
#     Importance: 0.022152
#   Predicado: Zn > 1.85 (n=88)
#     Zona: 29 colunas
#     Importance: 0.032621
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.023510
#   Predicado: Bremsstrahlung > -3.10 (n=172)
#     Zona: 429 colunas
#     Importance: 0.108713
#   Predicado: Bremsstrahlung <= -2.45 (n=86)
#     Zona: 429 colunas
#     Importance: 0.121751
#   Predicado: Bremsstrahlung > -2.45 (n=128)
#     Zona: 429 colunas
#     Importance: 0.110077
#   Predicado: Bremsstrahlung <= 3.06 (n=130)
#     Zona: 429 colunas
#     Importance: 0.110775
#   Predicado: Bremsstrahlung > 3.06 (n=84)
#     Zona: 429 colunas
#     Importance: 0.120950
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.110103
#   Predicado: Ag compton > -2.89 (n=171)
#     Zona: 62 colunas
#     Importance: 0.042556
#   Predicado: Ag compton <= -2.03 (n=86)
#     Zona: 62 colunas
#     Importance: 0.055872
#   Predicado: Ag compton > -2.03 (n=128)
#     Zona: 62 colunas
#     Importance: 0.044335
#   Predicado: Ag compton <= 2.58 (n=131)
#     Zona: 62 colunas
#     Importance: 0.045557
#   Predicado: Ag compton > 2.58 (n=83)
#     Zona: 62 colunas
#     Importance: 0.054359
#   Predicado: Ag compton <= 3.09 (n=170)
#     Zona: 62 colunas
#     Importance: 0.044349
#   Predicado: Ag ka > -7.93 (n=173)
#     Zona: 45 colunas
#     Importance: 0.106593
#   Predicado: Ag ka <= -3.39 (n=79)
#     Zona: 45 colunas
#     Importance: 0.141754
#   Predicado: Ag ka > -3.39 (n=135)
#     Zona: 45 colunas
#     Importance: 0.114081
#   Predicado: Ag ka <= 5.20 (n=126)
#     Zona: 45 colunas
#     Importance: 0.118952
#   Predicado: Ag ka > 5.20 (n=88)
#     Zona: 45 colunas
#     Importance: 0.131950
#   Predicado: Ag ka <= 10.15 (n=168)
#     Zona: 45 colunas
#     Importance: 0.117622
#
# [Bag_9] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=172)
#     Zona: 18 colunas
#     Importance: 0.129953
#   Predicado: Ag La <= 2.83 (n=88)
#     Zona: 18 colunas
#     Importance: 0.212534
#   Predicado: Ag La > 2.83 (n=126)
#     Zona: 18 colunas
#     Importance: 0.135007
#   Predicado: Ag La <= 4.26 (n=130)
#     Zona: 18 colunas
#     Importance: 0.177207
#   Predicado: Ag La > 4.26 (n=84)
#     Zona: 18 colunas
#     Importance: 0.150916
#   Predicado: Ag La <= 5.23 (n=169)
#     Zona: 18 colunas
#     Importance: 0.166942
#   Predicado: Ag Lb > -6.25 (n=170)
#     Zona: 15 colunas
#     Importance: 0.075914
#   Predicado: Ag Lb <= 2.77 (n=85)
#     Zona: 15 colunas
#     Importance: 0.130714
#   Predicado: Ag Lb > 2.77 (n=129)
#     Zona: 15 colunas
#     Importance: 0.077788
#   Predicado: Ag Lb <= 3.70 (n=125)
#     Zona: 15 colunas
#     Importance: 0.107914
#   Predicado: Ag Lb > 3.70 (n=89)
#     Zona: 15 colunas
#     Importance: 0.086024
#   Predicado: Ag Lb <= 4.33 (n=169)
#     Zona: 15 colunas
#     Importance: 0.101247
#   Predicado: Ca > -1.96 (n=170)
#     Zona: 19 colunas
#     Importance: 0.011582
#   Predicado: Ca <= -1.26 (n=85)
#     Zona: 19 colunas
#     Importance: 0.012022
#   Predicado: Ca > -1.26 (n=129)
#     Zona: 19 colunas
#     Importance: 0.011668
#   Predicado: Ca <= 1.99 (n=128)
#     Zona: 19 colunas
#     Importance: 0.010756
#   Predicado: Ca > 1.99 (n=86)
#     Zona: 19 colunas
#     Importance: 0.013375
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.010537
#   Predicado: background > -1.72 (n=171)
#     Zona: 87 colunas
#     Importance: 0.013073
#   Predicado: background <= 2.11 (n=83)
#     Zona: 87 colunas
#     Importance: 0.012634
#   Predicado: background > 2.11 (n=131)
#     Zona: 87 colunas
#     Importance: 0.013216
#   Predicado: background <= 2.38 (n=128)
#     Zona: 87 colunas
#     Importance: 0.012520
#   Predicado: background > 2.38 (n=86)
#     Zona: 87 colunas
#     Importance: 0.013689
#   Predicado: background <= 2.73 (n=168)
#     Zona: 87 colunas
#     Importance: 0.012410
#   Predicado: Fe > -1.71 (n=172)
#     Zona: 23 colunas
#     Importance: 0.017879
#   Predicado: Fe <= -1.30 (n=83)
#     Zona: 23 colunas
#     Importance: 0.018469
#   Predicado: Fe > -1.30 (n=131)
#     Zona: 23 colunas
#     Importance: 0.018078
#   Predicado: Fe <= 1.63 (n=131)
#     Zona: 23 colunas
#     Importance: 0.016865
#   Predicado: Fe > 1.63 (n=83)
#     Zona: 23 colunas
#     Importance: 0.020383
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.016785
#   Predicado: Cu > -2.02 (n=170)
#     Zona: 66 colunas
#     Importance: 0.011611
#   Predicado: Cu <= 2.01 (n=84)
#     Zona: 66 colunas
#     Importance: 0.010918
#   Predicado: Cu > 2.01 (n=130)
#     Zona: 66 colunas
#     Importance: 0.012159
#   Predicado: Cu <= 2.35 (n=129)
#     Zona: 66 colunas
#     Importance: 0.011956
#   Predicado: Cu > 2.35 (n=85)
#     Zona: 66 colunas
#     Importance: 0.011241
#   Predicado: Cu <= 2.71 (n=171)
#     Zona: 66 colunas
#     Importance: 0.011793
#   Predicado: Zn > -1.89 (n=177)
#     Zona: 29 colunas
#     Importance: 0.025057
#   Predicado: Zn <= -1.35 (n=79)
#     Zona: 29 colunas
#     Importance: 0.024906
#   Predicado: Zn > -1.35 (n=135)
#     Zona: 29 colunas
#     Importance: 0.025725
#   Predicado: Zn <= 1.85 (n=127)
#     Zona: 29 colunas
#     Importance: 0.021247
#   Predicado: Zn > 1.85 (n=87)
#     Zona: 29 colunas
#     Importance: 0.031519
#   Predicado: Zn <= 2.28 (n=173)
#     Zona: 29 colunas
#     Importance: 0.022524
#   Predicado: Bremsstrahlung > -3.10 (n=172)
#     Zona: 429 colunas
#     Importance: 0.106851
#   Predicado: Bremsstrahlung <= -2.45 (n=85)
#     Zona: 429 colunas
#     Importance: 0.123052
#   Predicado: Bremsstrahlung > -2.45 (n=129)
#     Zona: 429 colunas
#     Importance: 0.109360
#   Predicado: Bremsstrahlung <= 3.06 (n=129)
#     Zona: 429 colunas
#     Importance: 0.114224
#   Predicado: Bremsstrahlung > 3.06 (n=85)
#     Zona: 429 colunas
#     Importance: 0.115670
#   Predicado: Bremsstrahlung <= 3.46 (n=171)
#     Zona: 429 colunas
#     Importance: 0.112174
#   Predicado: Ag compton > -2.89 (n=172)
#     Zona: 62 colunas
#     Importance: 0.042891
#   Predicado: Ag compton <= -2.03 (n=83)
#     Zona: 62 colunas
#     Importance: 0.059604
#   Predicado: Ag compton > -2.03 (n=131)
#     Zona: 62 colunas
#     Importance: 0.044846
#   Predicado: Ag compton <= 2.58 (n=130)
#     Zona: 62 colunas
#     Importance: 0.047292
#   Predicado: Ag compton > 2.58 (n=84)
#     Zona: 62 colunas
#     Importance: 0.055642
#   Predicado: Ag compton <= 3.09 (n=171)
#     Zona: 62 colunas
#     Importance: 0.046072
#   Predicado: Ag ka > -7.93 (n=172)
#     Zona: 45 colunas
#     Importance: 0.108084
#   Predicado: Ag ka <= -3.39 (n=83)
#     Zona: 45 colunas
#     Importance: 0.134834
#   Predicado: Ag ka > -3.39 (n=131)
#     Zona: 45 colunas
#     Importance: 0.115865
#   Predicado: Ag ka <= 5.20 (n=127)
#     Zona: 45 colunas
#     Importance: 0.117525
#   Predicado: Ag ka > 5.20 (n=87)
#     Zona: 45 colunas
#     Importance: 0.131539
#   Predicado: Ag ka <= 10.15 (n=169)
#     Zona: 45 colunas
#     Importance: 0.117587
#
# [Bag_10] Processando 60 predicados...
#   Predicado: Ag La > -8.20 (n=174)
#     Zona: 18 colunas
#     Importance: 0.132280
#   Predicado: Ag La <= 2.83 (n=79)
#     Zona: 18 colunas
#     Importance: 0.222177
#   Predicado: Ag La > 2.83 (n=135)
#     Zona: 18 colunas
#     Importance: 0.134466
#   Predicado: Ag La <= 4.26 (n=122)
#     Zona: 18 colunas
#     Importance: 0.181325
#   Predicado: Ag La > 4.26 (n=92)
#     Zona: 18 colunas
#     Importance: 0.147642
#   Predicado: Ag La <= 5.23 (n=171)
#     Zona: 18 colunas
#     Importance: 0.166970
#   Predicado: Ag Lb > -6.25 (n=174)
#     Zona: 15 colunas
#     Importance: 0.078136
#   Predicado: Ag Lb <= 2.77 (n=79)
#     Zona: 15 colunas
#     Importance: 0.132709
#   Predicado: Ag Lb > 2.77 (n=135)
#     Zona: 15 colunas
#     Importance: 0.078744
#   Predicado: Ag Lb <= 3.70 (n=123)
#     Zona: 15 colunas
#     Importance: 0.107778
#   Predicado: Ag Lb > 3.70 (n=91)
#     Zona: 15 colunas
#     Importance: 0.086349
#   Predicado: Ag Lb <= 4.33 (n=168)
#     Zona: 15 colunas
#     Importance: 0.101637
#   Predicado: Ca > -1.96 (n=171)
#     Zona: 19 colunas
#     Importance: 0.012034
#   Predicado: Ca <= -1.26 (n=90)
#     Zona: 19 colunas
#     Importance: 0.012607
#   Predicado: Ca > -1.26 (n=124)
#     Zona: 19 colunas
#     Importance: 0.012278
#   Predicado: Ca <= 1.99 (n=132)
#     Zona: 19 colunas
#     Importance: 0.011504
#   Predicado: Ca > 1.99 (n=82)
#     Zona: 19 colunas
#     Importance: 0.013886
#   Predicado: Ca <= 2.47 (n=171)
#     Zona: 19 colunas
#     Importance: 0.011350
#   Predicado: background > -1.72 (n=169)
#     Zona: 87 colunas
#     Importance: 0.013594
#   Predicado: background <= 2.11 (n=91)
#     Zona: 87 colunas
#     Importance: 0.012753
#   Predicado: background > 2.11 (n=123)
#     Zona: 87 colunas
#     Importance: 0.013780
#   Predicado: background <= 2.38 (n=136)
#     Zona: 87 colunas
#     Importance: 0.012515
#   Predicado: background > 2.38 (n=78)
#     Zona: 87 colunas
#     Importance: 0.014787
#   Predicado: background <= 2.73 (n=178)
#     Zona: 87 colunas
#     Importance: 0.012483
#   Predicado: Fe > -1.71 (n=171)
#     Zona: 23 colunas
#     Importance: 0.019392
#   Predicado: Fe <= -1.30 (n=84)
#     Zona: 23 colunas
#     Importance: 0.017769
#   Predicado: Fe > -1.30 (n=130)
#     Zona: 23 colunas
#     Importance: 0.020230
#   Predicado: Fe <= 1.63 (n=128)
#     Zona: 23 colunas
#     Importance: 0.016187
#   Predicado: Fe > 1.63 (n=86)
#     Zona: 23 colunas
#     Importance: 0.023843
#   Predicado: Fe <= 2.10 (n=174)
#     Zona: 23 colunas
#     Importance: 0.017109
#   Predicado: Cu > -2.02 (n=176)
# ...
#
# Removida aresta Cu > 2.01 -> background > 2.11 (peso 0.0128)
# Mantida aresta background > 2.11 -> Cu > 2.01 (peso 0.0263)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> background <= 2.38 (peso 0.0131)
# Mantida aresta background <= 2.38 -> background > 2.11 (peso 0.0398)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> background <= 2.38 (peso 0.0127)
# Mantida aresta background <= 2.38 -> Cu > 2.35 (peso 0.0128)
#
# ======================================================================
#
# Removida aresta background <= 2.38 -> background <= 2.73 (peso 0.0133)
# Mantida aresta background <= 2.73 -> background <= 2.38 (peso 0.0134)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> background <= 2.73 (peso 0.0132)
# Mantida aresta background <= 2.73 -> background > 2.11 (peso 0.0255)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> background <= 2.73 (peso 0.0123)
# Mantida aresta background <= 2.73 -> Cu <= 2.35 (peso 0.0124)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Cu > -2.02 (peso 0.0123)
# Mantida aresta Cu > -2.02 -> Ca > -1.26 (peso 0.0124)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Ca > -1.26 (peso 0.0234)
# Mantida aresta Ca > -1.26 -> Ca > -1.96 (peso 0.0368)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Cu <= 2.35 (peso 0.0120)
# Mantida aresta Cu <= 2.35 -> Ca > -1.26 (peso 0.0239)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ca > -1.96 (peso 0.0234)
# Mantida aresta Ca > -1.96 -> Ca <= 1.99 (peso 0.0361)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca > -1.96 (peso 0.0113)
# Mantida aresta Ca > -1.96 -> Ca <= 2.47 (peso 0.0231)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Cu <= 2.71 (peso 0.0121)
# Mantida aresta Cu <= 2.71 -> Ca > -1.96 (peso 0.0237)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca <= 1.99 (peso 0.0113)
# Mantida aresta Ca <= 1.99 -> Ca <= 2.47 (peso 0.0805)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Cu <= 2.01 (peso 0.0113)
# Mantida aresta Cu <= 2.01 -> Ca <= 1.99 (peso 0.0118)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ca <= 2.47 (peso 0.0114)
# Mantida aresta Ca <= 2.47 -> Cu <= 2.01 (peso 0.0558)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu <= 2.71 (peso 0.0365)
# Mantida aresta Cu <= 2.71 -> Cu <= 2.35 (peso 0.0597)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 251
# Total de arestas removidas por bidirecionalidade: 61
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Perturbation
#
#
# ======================================================================
# Processando Grafo - Semente: 3
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 53
# Removida aresta Ag ka <= -3.39 -> Ag La > 4.26 (peso 0.2978)
# Mantida aresta Ag La > 4.26 -> Ag ka <= -3.39 (peso 0.7394)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag ka <= -3.39 (peso 0.2656)
# Mantida aresta Ag ka <= -3.39 -> Ag La > 2.83 (peso 0.8477)
#
# ======================================================================
#
# Removida aresta Ag La > 2.83 -> Ag ka > 5.20 (peso 0.3995)
# Mantida aresta Ag ka > 5.20 -> Ag La > 2.83 (peso 0.4030)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag Lb <= 2.77 (peso 0.5130)
# Mantida aresta Ag Lb <= 2.77 -> Ag La > -8.20 (peso 0.6541)
#
# ======================================================================
#
# Removida aresta Ag ka <= 5.20 -> Ag Lb <= 2.77 (peso 0.1256)
# Mantida aresta Ag Lb <= 2.77 -> Ag ka <= 5.20 (peso 0.1274)
#
# ======================================================================
#
# Removida aresta Ag La > -8.20 -> Ag ka > 5.20 (peso 0.2599)
# Mantida aresta Ag ka > 5.20 -> Ag La > -8.20 (peso 0.2623)
#
# ======================================================================
#
# Removida aresta Ag ka > 5.20 -> Bremsstrahlung <= -2.45 (peso 0.1279)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag ka > 5.20 (peso 0.1279)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka <= 5.20 (peso 0.2325)
# Mantida aresta Ag ka <= 5.20 -> Ag ka <= 10.15 (peso 0.7359)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Ag ka <= 5.20 (peso 0.1214)
# Mantida aresta Ag ka <= 5.20 -> Bremsstrahlung <= -2.45 (peso 0.2298)
#
# ======================================================================
#
# Removida aresta Ag ka <= 10.15 -> Ag ka > -3.39 (peso 0.1231)
# Mantida aresta Ag ka > -3.39 -> Ag ka <= 10.15 (peso 0.3546)
#
# ======================================================================
#
# Removida aresta Ag ka > -3.39 -> Bremsstrahlung <= -2.45 (peso 0.1152)
# Mantida aresta Bremsstrahlung <= -2.45 -> Ag ka > -3.39 (peso 0.4730)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= -2.45 -> Bremsstrahlung > 3.06 (peso 0.1110)
# Mantida aresta Bremsstrahlung > 3.06 -> Bremsstrahlung <= -2.45 (peso 0.1185)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Ag ka > -3.39 (peso 0.2266)
# Mantida aresta Ag ka > -3.39 -> Bremsstrahlung > 3.06 (peso 0.2346)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Bremsstrahlung > 3.06 (peso 0.1056)
# Mantida aresta Bremsstrahlung > 3.06 -> Ag Lb <= 3.70 (peso 0.1128)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Bremsstrahlung > 3.06 (peso 0.1028)
# Mantida aresta Bremsstrahlung > 3.06 -> Bremsstrahlung <= 3.06 (peso 0.1137)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > 3.06 -> Bremsstrahlung <= 3.46 (peso 0.1021)
# Mantida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung > 3.06 (peso 0.2154)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Bremsstrahlung <= 3.46 (peso 0.1053)
# Mantida aresta Bremsstrahlung <= 3.46 -> Ag Lb <= 3.70 (peso 0.3176)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 3.70 -> Bremsstrahlung > -3.10 (peso 0.1035)
# Mantida aresta Bremsstrahlung > -3.10 -> Ag Lb <= 3.70 (peso 0.2092)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.06 -> Ag ka > -7.93 (peso 0.1090)
# Mantida aresta Ag ka > -7.93 -> Bremsstrahlung <= 3.06 (peso 0.4339)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Ag ka > -7.93 (peso 0.1099)
# Mantida aresta Ag ka > -7.93 -> Bremsstrahlung > -2.45 (peso 0.1109)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -2.45 -> Bremsstrahlung <= 3.06 (peso 0.1088)
# Mantida aresta Bremsstrahlung <= 3.06 -> Bremsstrahlung > -2.45 (peso 0.2126)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung > -2.45 (peso 0.1078)
# Mantida aresta Bremsstrahlung > -2.45 -> Bremsstrahlung <= 3.46 (peso 0.2094)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Bremsstrahlung > -2.45 (peso 0.0955)
# Mantida aresta Bremsstrahlung > -2.45 -> Bremsstrahlung > -3.10 (peso 0.5127)
#
# ======================================================================
#
# Removida aresta Bremsstrahlung > -3.10 -> Bremsstrahlung <= 3.46 (peso 0.1070)
# Mantida aresta Bremsstrahlung <= 3.46 -> Bremsstrahlung > -3.10 (peso 0.2089)
#
# ======================================================================
#
# Removida aresta Ag Lb <= 4.33 -> Bremsstrahlung > -3.10 (peso 0.1022)
# Mantida aresta Bremsstrahlung > -3.10 -> Ag Lb <= 4.33 (peso 0.1035)
#
# ======================================================================
#
# Removida aresta Zn > -1.35 -> Zn <= -1.35 (peso 0.0263)
# Mantida aresta Zn <= -1.35 -> Zn > -1.35 (peso 0.1315)
#
# ======================================================================
#
# Removida aresta Zn <= -1.35 -> Zn > -1.89 (peso 0.0521)
# Mantida aresta Zn > -1.89 -> Zn <= -1.35 (peso 0.0771)
#
# ======================================================================
#
# Removida aresta Zn > -1.89 -> Zn > -1.35 (peso 0.0245)
# Mantida aresta Zn > -1.35 -> Zn > -1.89 (peso 0.2064)
#
# ======================================================================
#
# Removida aresta Zn <= 2.28 -> Fe > 1.63 (peso 0.0231)
# Mantida aresta Fe > 1.63 -> Zn <= 2.28 (peso 0.1406)
#
# ======================================================================
#
# Removida aresta Fe > 1.63 -> Zn <= 1.85 (peso 0.0218)
# Mantida aresta Zn <= 1.85 -> Fe > 1.63 (peso 0.0675)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Fe > -1.30 (peso 0.0388)
# Mantida aresta Fe > -1.30 -> Fe <= -1.30 (peso 0.0592)
#
# ======================================================================
#
# Removida aresta Fe <= -1.30 -> Fe > -1.71 (peso 0.0565)
# Mantida aresta Fe > -1.71 -> Fe <= -1.30 (peso 0.0948)
#
# ======================================================================
#
# Removida aresta Ca > 1.99 -> background > 2.38 (peso 0.0555)
# Mantida aresta background > 2.38 -> Ca > 1.99 (peso 0.0558)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Ca > 1.99 (peso 0.0127)
# Mantida aresta Ca > 1.99 -> background > 2.11 (peso 0.0406)
#
# ======================================================================
#
# Removida aresta background > -1.72 -> background > 2.11 (peso 0.0394)
# Mantida aresta background > 2.11 -> background > -1.72 (peso 0.0537)
#
# ======================================================================
#
# Removida aresta Cu > 2.01 -> background > -1.72 (peso 0.0265)
# Mantida aresta background > -1.72 -> Cu > 2.01 (peso 0.0526)
#
# ======================================================================
#
# Removida aresta background > 2.11 -> Ca <= -1.26 (peso 0.0133)
# Mantida aresta Ca <= -1.26 -> background > 2.11 (peso 0.0391)
#
# ======================================================================
#
# Removida aresta Cu > 2.01 -> Ca <= -1.26 (peso 0.0260)
# Mantida aresta Ca <= -1.26 -> Cu > 2.01 (peso 0.0388)
#
# ======================================================================
#
# Removida aresta Ca <= -1.26 -> background <= 2.73 (peso 0.0128)
# Mantida aresta background <= 2.73 -> Ca <= -1.26 (peso 0.0253)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background <= 2.11 (peso 0.0126)
# Mantida aresta background <= 2.11 -> background <= 2.73 (peso 0.0127)
#
# ======================================================================
#
# Removida aresta background <= 2.73 -> background <= 2.38 (peso 0.0123)
# Mantida aresta background <= 2.38 -> background <= 2.73 (peso 0.0888)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> background <= 2.38 (peso 0.0124)
# Mantida aresta background <= 2.38 -> Cu <= 2.35 (peso 0.0124)
#
# ======================================================================
#
# Removida aresta Cu > 2.35 -> background <= 2.73 (peso 0.0124)
# Mantida aresta background <= 2.73 -> Cu > 2.35 (peso 0.0127)
#
# ======================================================================
#
# Removida aresta Cu <= 2.71 -> Cu > 2.35 (peso 0.0118)
# Mantida aresta Cu > 2.35 -> Cu <= 2.71 (peso 0.0244)
#
# ======================================================================
#
# Removida aresta Cu > -2.02 -> Cu > 2.35 (peso 0.0249)
# Mantida aresta Cu > 2.35 -> Cu > -2.02 (peso 0.0377)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Cu > 2.35 (peso 0.0115)
# Mantida aresta Cu > 2.35 -> Ca > -1.26 (peso 0.0122)
#
# ======================================================================
#
# Removida aresta Ca > -1.26 -> Cu > -2.02 (peso 0.0242)
# Mantida aresta Cu > -2.02 -> Ca > -1.26 (peso 0.0245)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Ca > -1.26 (peso 0.0116)
# Mantida aresta Ca > -1.26 -> Ca <= 1.99 (peso 0.0116)
#
# ======================================================================
#
# Removida aresta Cu <= 2.35 -> Cu > -2.02 (peso 0.0246)
# Mantida aresta Cu > -2.02 -> Cu <= 2.35 (peso 0.0363)
#
# ======================================================================
#
# Removida aresta Ca > -1.96 -> Cu <= 2.35 (peso 0.0119)
# Mantida aresta Cu <= 2.35 -> Ca > -1.96 (peso 0.0236)
#
# ======================================================================
#
# Removida aresta Ca <= 2.47 -> Ca <= 1.99 (peso 0.0114)
# Mantida aresta Ca <= 1.99 -> Ca <= 2.47 (peso 0.0686)
#
# ======================================================================
#
# Removida aresta Ca <= 1.99 -> Cu <= 2.01 (peso 0.0114)
# Mantida aresta Cu <= 2.01 -> Ca <= 1.99 (peso 0.0115)
#
# ======================================================================
#
# Removida aresta Cu <= 2.01 -> Ca <= 2.47 (peso 0.0228)
# Mantida aresta Ca <= 2.47 -> Cu <= 2.01 (peso 0.0452)
#
# ======================================================================
#
#
# ======================================================================
# RESUMO DO GRAFO CONSTRUÍDO
# ======================================================================
# Total de arestas iniciais: 230
# Total de arestas removidas por bidirecionalidade: 53
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 60
# Total de nós terminais: 2
# Métrica utilizada para pesos: Perturbation
#
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#
# Processando LRC do grafo...
#    Predicate_pert_Seed_0 Predicate_pert_Seed_1 Predicate_pert_Seed_2  \
# 0          Ag La <= 2.83         Ag La <= 2.83         Ag La <= 2.83
# 1          Ag La <= 4.26         Ag La <= 4.26         Ag La <= 4.26
# 2          Ag La <= 5.23         Ag La <= 5.23         Ag La <= 5.23
# 3           Ag La > 4.26          Ag La > 4.26          Ag La > 4.26
# 4          Ag ka <= 5.20          Ag ka > 5.20        Ag ka <= -3.39
# ..                   ...                   ...                   ...
# 57            Cu > -2.02            Ca <= 1.99     background > 2.11
# 58            Ca <= 2.47            Ca <= 2.47            Cu > -2.02
# 59            Cu <= 2.01            Cu <= 2.01           Ca <= -1.26
# 60               Class_A               Class_A               Class_A
# 61               Class_B               Class_B               Class_B
#
#    Predicate_pert_Seed_3
# 0          Ag La <= 2.83
# 1          Ag La <= 4.26
# 2          Ag La <= 5.23
# 3           Ag La > 4.26
# 4          Ag ka <= 5.20
# ..                   ...
# 57             Cu > 2.35
# 58            Cu <= 2.71
# 59    background <= 2.73
# 60               Class_A
# 61               Class_B
#
# [62 rows x 4 columns]

# %%
all_results_pert[0]['pert_results_dict']['Bag_5']
# Out:
#                   Predicate  Perturbation
# 0             Ag La <= 2.83      0.219963
# 1             Ag La <= 4.26      0.181044
# 2             Ag La <= 5.23      0.168101
# 3            Ag ka <= -3.39      0.152528
# 4              Ag La > 4.26      0.144985
# 5              Ag ka > 5.20      0.135153
# 6              Ag La > 2.83      0.130386
# 7             Ag Lb <= 2.77      0.128570
# 8             Ag La > -8.20      0.126992
# 9             Ag ka <= 5.20      0.126719
# 10           Ag ka <= 10.15      0.124483
# 11            Ag ka > -3.39      0.116581
# 12  Bremsstrahlung <= -2.45      0.114879
# 13            Ag ka > -7.93      0.109354
# 14    Bremsstrahlung > 3.06      0.109245
# 15            Ag Lb <= 3.70      0.106264
# 16   Bremsstrahlung <= 3.06      0.105115
# 17   Bremsstrahlung <= 3.46      0.104623
# 18   Bremsstrahlung > -2.45      0.101371
# 19            Ag Lb <= 4.33      0.100625
# 20   Bremsstrahlung > -3.10      0.100325
# 21             Ag Lb > 3.70      0.085453
# 22             Ag Lb > 2.77      0.077307
# 23            Ag Lb > -6.25      0.075309
# 24      Ag compton <= -2.03      0.056627
# 25        Ag compton > 2.58      0.053867
# 26       Ag compton <= 2.58      0.045926
# 27       Ag compton <= 3.09      0.044764
# 28       Ag compton > -2.03      0.043660
# 29       Ag compton > -2.89      0.041851
# 30                Zn > 1.85      0.031764
# 31               Zn > -1.35      0.025774
# 32              Zn <= -1.35      0.025685
# 33               Zn > -1.89      0.025017
# 34               Zn <= 2.28      0.023620
# 35               Zn <= 1.85      0.022139
# 36                Fe > 1.63      0.022019
# 37              Fe <= -1.30      0.019791
# 38               Fe > -1.30      0.019545
# 39               Fe > -1.71      0.019122
# 40               Fe <= 2.10      0.018127
# 41               Fe <= 1.63      0.017771
# 42                Ca > 1.99      0.013883
# 43       background <= 2.11      0.013810
# 44        background > 2.38      0.013693
# 45       background > -1.72      0.013522
# 46       background <= 2.38      0.013337
# 47        background > 2.11      0.013271
# 48       background <= 2.73      0.013074
# 49                Cu > 2.01      0.012720
# 50              Ca <= -1.26      0.012522
# 51               Ca > -1.26      0.012217
# 52               Cu > -2.02      0.012101
# 53                Cu > 2.35      0.012059
# 54               Ca > -1.96      0.011913
# 55               Cu <= 2.35      0.011718
# 56               Cu <= 2.71      0.011532
# 57               Ca <= 2.47      0.011437
# 58               Ca <= 1.99      0.011337
# 59               Cu <= 2.01      0.010498

# %%
# Somar LRCs de predicados equivalentes entre diferentes seeds
lrc_combined_list = []

for seed in random_seeds:
    lrc_df = lrc_pert_by_seed[seed].copy()
    lrc_combined_list.append(lrc_df) # o append adiciona o dataframe ao final da lista

# Concatenar todos os dataframes
lrc_all_seeds = pd.concat(lrc_combined_list, ignore_index=True) 

# Agrupar por predicado (Node) e somar as LRCs, mantendo Zone, Threshold e Operator
lrc_summed_df = lrc_all_seeds.groupby('Node').agg({ # o .agg pode ser usado para aplicar múltiplas funções de agregação
    'Local_Reaching_Centrality': 'mean', # sum = somando as LRCs, poderia ser média ou outro agregado
    'Zone': 'first',
    'Threshold': 'first',
    'Operator': 'first'
}).reset_index()

# Ordenar pelo valor de LRC somado (maior para menor)
lrc_summed_df = lrc_summed_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
# vamoss pegar so os valore sunicos de lrc_summed_df baseado na zona espectral
lrc_summed_unique_df_pert = lrc_summed_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
lrc_summed_unique_df_pert = lrc_summed_unique_df_pert.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
lrc_summed_unique_df_pert
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.83                   4.415740           Ag La
# 1           Ag ka <= -3.39                   2.125566           Ag ka
# 2            Ag Lb <= 2.77                   2.112727           Ag Lb
# 3   Bremsstrahlung > -3.10                   1.833634  Bremsstrahlung
# 4      Ag compton <= -2.03                   0.991817      Ag compton
# 5                Zn > 1.85                   0.353998              Zn
# 6                Fe > 1.63                   0.208031              Fe
# 7       background <= 2.38                   0.060124      background
# 8               Ca <= 1.99                   0.053569              Ca
# 9                Cu > 2.35                   0.051271              Cu
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator
# 0       2.83       <=
# 1      -3.39       <=
# 2       2.77       <=
# 3      -3.10        >
# 4      -2.03       <=
# 5       1.85        >
# 6       1.63        >
# 7       2.38       <=
# 8       1.99       <=
# 9       2.35        >
# 10      None     None

# %%
lrc_summed_df
# Out:
#               Node  Local_Reaching_Centrality   Zone Threshold Operator
# 0    Ag La <= 2.83                   4.415740  Ag La      2.83       <=
# 1    Ag La <= 4.26                   3.665127  Ag La      4.26       <=
# 2    Ag La <= 5.23                   3.006098  Ag La      5.23       <=
# 3     Ag La > 4.26                   2.439751  Ag La      4.26        >
# 4   Ag ka <= -3.39                   2.125566  Ag ka     -3.39       <=
# ..             ...                        ...    ...       ...      ...
# 57      Cu > -2.02                   0.044722     Cu     -2.02        >
# 58      Cu <= 2.01                   0.032486     Cu      2.01       <=
# 59      Ca <= 2.47                   0.029383     Ca      2.47       <=
# 60         Class_B                   0.000000   None      None     None
# 61         Class_A                   0.000000   None      None     None
#
# [62 rows x 5 columns]

# %%
# Criar zone_sums_df para dados NÃO pré-processados (Xcalclass)
spectral_zones_original = exp.extract_spectral_zones(Xcalclass, spectral_cuts)
zone_sums_df_original = exp.aggregate_spectral_zones(spectral_zones_original, aggregator='extreme')

# Aplicar o mapeamento
lrc_summed_unique_df_pert_with_natural = exp.map_thresholds_to_natural(
    lrc_df=lrc_summed_unique_df_pert,
    zone_sums_preprocessed=zone_sums_df,
    zone_sums_natural=zone_sums_df_original
)

lrc_summed_unique_df_pert_with_natural
# Out:
#                       Node  Local_Reaching_Centrality            Zone  \
# 0            Ag La <= 2.83                   4.415740           Ag La
# 1           Ag ka <= -3.39                   2.125566           Ag ka
# 2            Ag Lb <= 2.77                   2.112727           Ag Lb
# 3   Bremsstrahlung > -3.10                   1.833634  Bremsstrahlung
# 4      Ag compton <= -2.03                   0.991817      Ag compton
# 5                Zn > 1.85                   0.353998              Zn
# 6                Fe > 1.63                   0.208031              Fe
# 7       background <= 2.38                   0.060124      background
# 8               Ca <= 1.99                   0.053569              Ca
# 9                Cu > 2.35                   0.051271              Cu
# 10                 Class_B                   0.000000            None
#
#    Threshold Operator  Threshold_Natural  Reference_Sample_Index  \
# 0       2.83       <=           255.0000                    58.0
# 1      -3.39       <=          3452.0000                    29.0
# 2       2.77       <=           179.0000                    95.0
# 3      -3.10        >           634.0000                   245.0
# 4      -2.03       <=           641.4210                   251.0
# 5       1.85        >            44.2632                     6.0
# 6       1.63        >            19.4737                   250.0
# 7       2.38       <=            15.0000                    73.0
# 8       1.99       <=            36.3684                   117.0
# 9       2.35        >            38.7895                   220.0
# 10      None     None                NaN                     NaN
#
#     Approximation_Error                 Node_Natural
# 0              0.002861          Ag La <= 255.000000
# 1              0.008152         Ag ka <= 3452.000000
# 2              0.003992          Ag Lb <= 179.000000
# 3              0.000855  Bremsstrahlung > 634.000000
# 4              0.001921     Ag compton <= 641.421000
# 5              0.000309               Zn > 44.263200
# 6              0.002499               Fe > 19.473700
# 7              0.004027      background <= 15.000000
# 8              0.003036              Ca <= 36.368400
# 9              0.000164               Cu > 38.789500
# 10                  NaN                         None

# %%
import numpy as np

max_len = max(
    len(vip_scores_unique_df['Zone']),
    len(reg_vet_unique_df['Zone']),
    len(shap_unique_df['Zone']),
    len(lrc_summed_unique_df_pert_with_natural['Zone']),
    len(lrc_summed_unique_df_cov_with_natural['Zone'])
)

def pad_list(lst, length):
    return list(lst) + [None] * (length - len(lst))

features_importance = pd.DataFrame({
    'Vip': pad_list(vip_scores_unique_df['Zone'], max_len),
    'Reg_coef': pad_list(reg_vet_unique_df['Zone'], max_len),
    'Shap': pad_list(shap_unique_df['Zone'], max_len),
    'LRC_perturbation' : pad_list(lrc_summed_unique_df_pert_with_natural['Zone'], max_len),
    'LRC_covariance' : pad_list(lrc_summed_unique_df_cov_with_natural['Zone'], max_len),
})

features_importance.to_csv('feature_importance.csv', index=False, sep=';')
features_importance
# Out:
#                Vip        Reg_coef            Shap LRC_perturbation  \
# 0            Ag La           Ag ka           Ag La            Ag La
# 1            Ag Lb              Zn           Ag ka            Ag ka
# 2            Ag ka           Ag La           Ag Lb            Ag Lb
# 3               Zn              Fe              Zn   Bremsstrahlung
# 4       Ag compton           Ag Lb      Ag compton       Ag compton
# 5               Fe  Bremsstrahlung              Fe               Zn
# 6   Bremsstrahlung      Ag compton  Bremsstrahlung               Fe
# 7               Ca              Ca      background       background
# 8       background      background              Ca               Ca
# 9               Cu              Cu              Cu               Cu
# 10            None            None            None             None
#
#     LRC_covariance
# 0            Ag La
# 1            Ag Lb
# 2            Ag ka
# 3               Zn
# 4       Ag compton
# 5               Fe
# 6               Ca
# 7   Bremsstrahlung
# 8               Cu
# 9       background
# 10            None

# %%
# RBO (Rank-Biased Overlap) para comparar rankings
import rbo
rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if x is not None]
methods = ['Reg_coef', 'Shap', 'LRC_covariance', 'LRC_perturbation']
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if x is not None]
    # Truncate both lists to the same length (minimum of both)
    min_len = min(len(reference_list), len(compare_list))
    ref_trunc = reference_list[:min_len]
    cmp_trunc = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trunc, cmp_trunc).rbo(p=0.7, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method','RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_results.to_csv('rbo_rank.csv', index=False, sep=';')
rbo_results
# Out:
#   Reference            Method  RBO_Score
# 2       Vip    LRC_covariance   0.964789
# 1       Vip              Shap   0.863664
# 3       Vip  LRC_perturbation   0.815130
# 0       Vip          Reg_coef   0.364218
