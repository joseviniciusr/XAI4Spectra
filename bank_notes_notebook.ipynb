# %% [markdown]
# # **Model**

# %% [markdown]
# # **XRF bank notes database**

# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks

# loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv('XRF_databases/bank_notes/plsda/bank_notes.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '1':'26.07']
#data.insert(0, 'exCa', data_complete['exCa'])  # inserting the target variable (e.g., exCa (exchangeable calcium))

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_complete['Class'] = np.where(data_complete['Type'] == 'Authentic', 'A', 'B') # Class A: Authentic bank notes, Class B: Counterfeit bank notes
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1':'26.07'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1':'26.07'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)

from modeling import pls_optimized

# performing PLS-DA with optimized latent variables
plsda_results = pls_optimized(Xcalclass_prep, 
                              ycalclass,
                              LVmax=4,
                              Xpred=Xpredclass_prep,
                              ypred=ypredclass,
                              aim='classification',
                              cv=10)
plsda_results[0]
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-03 16:30:31,244 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-03 16:30:31,361 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-03 16:30:31,417 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2026-01-03 16:30:31,467 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#    LVs  Accuracy Cal  Sensitivity Cal  Specificity Cal                CM Cal  \
# 0    1      0.792254         0.458716              1.0  [[175, 0], [59, 50]]
# 1    2      0.926056         0.807339              1.0  [[175, 0], [21, 88]]
# 2    3      0.992958         0.981651              1.0  [[175, 0], [2, 107]]
# 3    4      0.992958         0.981651              1.0  [[175, 0], [2, 107]]
#
#    Accuracy CV  Sensitivity CV  Specificity CV                 CM CV  \
# 0     0.750000        0.348624             1.0  [[175, 0], [71, 38]]
# 1     0.926056        0.807339             1.0  [[175, 0], [21, 88]]
# 2     0.989437        0.972477             1.0  [[175, 0], [3, 106]]
# 3     0.992958        0.981651             1.0  [[175, 0], [2, 107]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred              CM Pred  \
# 0       0.723577          0.276596               1.0  [[76, 0], [34, 13]]
# 1       0.878049          0.680851               1.0  [[76, 0], [15, 32]]
# 2       0.991870          0.978723               1.0   [[76, 0], [1, 46]]
# 3       1.000000          1.000000               1.0   [[76, 0], [0, 47]]
#
#    X Cum Exp Var  Y Cum Exp Var  X Ind Exp Var  Y Ind Exp Var
# 0      64.931212      24.779135      64.931212      24.779135
# 1      81.754926      48.359819      16.823715      23.580684
# 2      86.031657      51.820942       4.276731       3.461123
# 3      90.236841      52.878856       4.205184       1.057914

# %% [markdown]
# # **VIP and SHAP**

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('background1', 1.0, 2.74),
('Ar ka + Ag L', 2.76, 3.47),
('Ca ka', 3.5, 3.91),
('Ca kb', 3.93, 4.24),
('Ti ka', 4.26, 4.72),
('Ti kb', 4.75, 5.13),
('background2', 5.16, 6.12),
('Fe ka', 6.15, 6.76),
('Fe kb', 6.79, 7.32),
('background3', 7.35, 7.78),
('Cu', 7.81, 8.29),
('background4', 8.32, 21.46),
('Ag ka scattering', 21.49, 22.71),
('background5', 22.74, 24.52),
('Ti ka', 24.55, 26.07),
]

# %%
import numpy as np
import pandas as pd

# vip
vip_scores_df = pd.DataFrame({
    'energy' : plsda_results[4].T.index,
    'VIP_Score' : plsda_results[4].T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# vamos gerar uma nova coluna em vip_scores_df com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_vip = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
	for i in vip_scores_df['energy']: # iterando sobre cada valor de energia no vip_scores_df
		i_float = float(i)
		if start <= i_float <= end:
			energy_to_zone_vip[i] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_vip

# vamos filtrar vip_scores_df para manter apenas as zonas espectrais únicas com maior VIP score
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# reg vet
reg_vet = pd.DataFrame(plsda_results[3].coef_, columns=plsda_results[3].feature_names_in_) # creating a DataFrame with regression coefficients
reg_vet = reg_vet.T
reg_vet.insert(0, 'energy', reg_vet.index) # adding energy column
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy', 'Reg_coef'] # renaming
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs() # adding absolute value column
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True) # sorting by absolute value

# gerando uma nova coluna em reg_vet com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_reg = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
    for i in reg_vet['energy']: # iterando sobre cada valor de energia no reg_vet
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_reg[i] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_reg
reg_vet

# vamos filtrar reg_vet para manter apenas as zonas espectrais únicas com maior valor absoluto do coeficiente de regressão
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# %%
# vamos agora extrair as variaveis mais importantes atraves do método SHAP
import shap

# Para PLSRegression, usamos KernelExplainer porque não há explainer dedicado muito rápido
explainer_pls = shap.KernelExplainer(plsda_results[3].predict, Xcalclass_prep)
shap_values_pls = explainer_pls(Xcalclass_prep)

shap_global_importance = pd.DataFrame({
    'energy': Xpredclass_prep.columns,
    'Mean_Abs_SHAP': np.abs(shap_values_pls.values).mean(axis=0)}) # tomando a importancia global como a media dos valores absolutos dos valores SHAP para cada feature
shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False, inplace=True)

# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)

# 15 MIN

# %%
vip_scores_unique_df.to_csv('XRF_databases/bank_notes/plsda/vip_scores_bank_notes.csv', index=False, sep=';')
reg_vet_unique_df.to_csv('XRF_databases/bank_notes/plsda/reg_vet_bank_notes.csv', index=False, sep=';')
shap_unique_df.to_csv('XRF_databases/bank_notes/plsda/shap_bank_notes.csv', index=False, sep=';')

# %%
shap_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df
vip_scores_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/vip_scores_bank_notes.csv', sep=';') # loading previously saved vip_scores_unique_df#
reg_vet_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/reg_vet_bank_notes.csv', sep=';') # loading previously saved reg_vet_unique_df

# %% [markdown]
# # **SMeX**

# %%
from explaining import extract_spectral_zones
from explaining import aggregate_spectral_zones
from explaining import predicates_by_quantiles
from explaining import create_predicate_info_dict
from explaining import bagging_predicates, calculate_predicate_metrics
from explaining import build_predicate_graph
import numpy as np
import pandas as pd

spectral_zones_class = extract_spectral_zones(Xcalclass, spectral_cuts) # extracting the spectral zones
zone_sums_df = aggregate_spectral_zones(spectral_zones_class, aggregator='max')
predicates_quantiles = predicates_by_quantiles(zone_sums_df, [0.25, 0.5, 0.75]) # getting predicates for quartiles
co_occurrence_matrix_df=predicates_quantiles[2]

# Criar dicionário de informações
predicate_info_dict = create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=plsda_results[5].iloc[:, -1]
)

# LISTA DE SEMENTES A TESTAR

random_seeds = [0, 1, 42]

all_results = {}

training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    
    # Bagging
    bags_result_seed = bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=60,
        #n_predicates_per_bag=int(training_samples*0.6), # 60 % da base para predicados (convertido para int)
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.20), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    mi_results_dict_seed = calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='covariance',
        threshold=0.001, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results[seed] = {
        'bags_result': bags_result_seed,
        'mi_results_dict': mi_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)

# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente
    DG = build_predicate_graph(
        bags_result=all_results[seed]['bags_result'],
        mi_results_dict=all_results[seed]['mi_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )
    
    # Armazenar grafo
    graphs_by_seed[seed] = DG  

# vamos calcular a LRC de acordo com as diferentes sementes
import networkx as nx

lrc_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    local_reaching_centrality = {
        node: nx.local_reaching_centrality(DG, node, weight='weight') 
        for node in DG.nodes()
    }

    # Ordenar por LRC
    sorted_lrc = sorted(local_reaching_centrality.items(), key=lambda x: x[1], reverse=True)
    
    # Criar DataFrame com LRC
    lrc_df_seed = pd.DataFrame(sorted_lrc, columns=['Node', 'Local_Reaching_Centrality'])
    
    # Extrair informações dos predicados (zona, threshold, operador)
    zones = []
    thresholds = []
    operators = []
    
    for node in lrc_df_seed['Node']:
        if node.startswith('Class_'):
            zones.append(None)
            thresholds.append(None)
            operators.append(None)
        else:
            pred_row = predicates_quantiles[0][predicates_quantiles[0]['rule'] == node].iloc[0]
            zones.append(pred_row['zone'])
            thresholds.append(pred_row['thresholds'])
            operators.append(pred_row['operator'])
    
    lrc_df_seed['Zone'] = zones
    lrc_df_seed['Threshold'] = thresholds
    lrc_df_seed['Operator'] = operators
    lrc_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    
    # Armazenar LRC
    lrc_by_seed[seed] = lrc_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe

lrc_all_seeds_df = pd.DataFrame() # 
for seed in random_seeds:
    lrc_df_seed = lrc_by_seed[seed]
    lrc_df_seed = lrc_df_seed.rename(columns={
        'Node': f'Predicate_Seed_{seed}'
    })
    lrc_all_seeds_df = pd.concat([lrc_all_seeds_df, lrc_df_seed[[f'Predicate_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_unique_by_seed = {}
for seed, lrc_df in lrc_by_seed.items():
    lrc_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_unique_df = lrc_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_unique_by_seed[seed] = lrc_unique_df

lrc_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 68 | Descartados: 16
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
#
# ======================================================================
# Calculando Covariance para Predicados
# ======================================================================
# Métrica: covariance
# Threshold: 0.001
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
#
# ======================================================================
# Calculando Covariance para Predicados
# ======================================================================
# Métrica: covariance
# Threshold: 0.001
#
# ======================================================================
# Processando semente: 42
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
#
# ======================================================================
# Calculando Covariance para Predicados
# ======================================================================
# Métrica: covariance
# Threshold: 0.001
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 533
# Removida aresta Ca ka > 25.00 -> Fe ka > 20.75 (peso 1148.0)
# Mantida aresta Fe ka > 20.75 -> Ca ka > 25.00 (peso 8528.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 103.50 -> Fe ka > 20.75 (peso 119.0)
# Mantida aresta Fe ka > 20.75 -> Ca ka > 103.50 (peso 833.0)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> Fe kb > 12.00 (peso 300.0)
# Mantida aresta Fe kb > 12.00 -> Cu > 19.00 (peso 3900.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 14.00 -> Fe kb > 12.00 (peso 154.0)
# Mantida aresta Fe kb > 12.00 -> Ca kb > 14.00 (peso 3696.0)
#
# ======================================================================
#
# Removida aresta Cu > 32.00 -> Fe kb > 12.00 (peso 54.0)
# Mantida aresta Fe kb > 12.00 -> Cu > 32.00 (peso 432.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 14.00 -> Cu > 19.00 (peso 3021.0)
# Mantida aresta Cu > 19.00 -> Ca kb > 14.00 (peso 3657.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 23.00 -> Cu > 19.00 (peso 416.0)
# Mantida aresta Cu > 19.00 -> Ca kb > 23.00 (peso 1560.0)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> Cu > 32.00 (peso 414.0)
# Mantida aresta Cu > 32.00 -> Cu > 19.00 (peso 483.0)
#
# ======================================================================
#
# Removida aresta Cu > 23.00 -> Cu > 19.00 (peso 133.0)
# Mantida aresta Cu > 19.00 -> Cu > 23.00 (peso 1862.0)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 32.00 -> Ca kb > 14.00 (peso 408.0)
# Mantida aresta Ca kb > 14.00 -> Cu > 32.00 (peso 408.0)
#
# ======================================================================
#
# Removida aresta Cu > 23.00 -> Ca kb > 14.00 (peso 805.0)
# Mantida aresta Ca kb > 14.00 -> Cu > 23.00 (peso 1840.0)
#
# ======================================================================
#
# Removida aresta Cu > 23.00 -> Cu > 32.00 (peso 276.0)
# Mantida aresta Cu > 32.00 -> Cu > 23.00 (peso 483.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > 23.00 -> Cu > 32.00 (peso 210.0)
# Mantida aresta Cu > 32.00 -> Ca kb > 23.00 (peso 210.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 23.00 -> Cu > 23.00 (peso 1470.0)
# Mantida aresta Cu > 23.00 -> Ca kb > 23.00 (peso 1540.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 13.00 -> Ti kb <= 48.00 (peso 1104.0)
# Mantida aresta Ti kb <= 48.00 -> Ti kb > 13.00 (peso 6624.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 268.00 -> Ti kb <= 48.00 (peso 288.0)
# Mantida aresta Ti kb <= 48.00 -> Ca ka <= 268.00 (peso 1152.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 268.00 -> Ti kb > 13.00 (peso 1152.0)
# Mantida aresta Ti kb > 13.00 -> Ca ka <= 268.00 (peso 6336.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 38.00 -> Ca ka <= 268.00 (peso 375.0)
# Mantida aresta Ca ka <= 268.00 -> Ti kb <= 38.00 (peso 2700.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3509.25 -> Ca ka <= 268.00 (peso 122.0)
# Mantida aresta Ca ka <= 268.00 -> Ag ka scattering <= 3509.25 (peso 244.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 268.00 -> Ag ka scattering > 3590.25 (peso 147.0)
# Mantida aresta Ag ka scattering > 3590.25 -> Ca ka <= 268.00 (peso 196.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 787.00 -> Ca ka <= 268.00 (peso 63.0)
# Mantida aresta Ca ka <= 268.00 -> Ti ka <= 787.00 (peso 63.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 38.00 -> Ca ka <= 268.00 (peso 138.0)
# Mantida aresta Ca ka <= 268.00 -> Ti kb > 38.00 (peso 414.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 103.50 -> Ca ka <= 268.00 (peso 142.0)
# Mantida aresta Ca ka <= 268.00 -> Ca ka <= 103.50 (peso 426.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3590.25 -> Ti kb <= 38.00 (peso 114.0)
# Mantida aresta Ti kb <= 38.00 -> Ag ka scattering > 3590.25 (peso 760.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3509.25 -> Ti kb <= 38.00 (peso 245.0)
# Mantida aresta Ti kb <= 38.00 -> Ag ka scattering <= 3509.25 (peso 280.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 38.00 -> Ag ka scattering > 3590.25 (peso 99.0)
# Mantida aresta Ag ka scattering > 3590.25 -> Ti kb > 38.00 (peso 297.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 103.50 -> Ag ka scattering > 3590.25 (peso 80.0)
# Mantida aresta Ag ka scattering > 3590.25 -> Ca ka <= 103.50 (peso 320.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3509.25 -> Ag ka scattering > 3590.25 (peso 0.0)
# Mantida aresta Ag ka scattering > 3590.25 -> Ag ka scattering <= 3509.25 (peso 0.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 3590.25 -> Ti ka > 787.00 (peso 59.0)
# Mantida aresta Ti ka > 787.00 -> Ag ka scattering > 3590.25 (peso 59.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3551.00 -> Ag ka scattering > 3590.25 (peso 0.0)
# Mantida aresta Ag ka scattering > 3590.25 -> Ag ka scattering <= 3551.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 787.00 -> Ti kb > 38.00 (peso 396.0)
# Mantida aresta Ti kb > 38.00 -> Ti ka > 787.00 (peso 792.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 38.00 -> Ca ka <= 103.50 (peso 1520.0)
# Mantida aresta Ca ka <= 103.50 -> Ti kb > 38.00 (peso 1995.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3509.25 -> Ti kb > 38.00 (peso 144.0)
# Mantida aresta Ti kb > 38.00 -> Ag ka scattering <= 3509.25 (peso 252.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3551.00 -> Ti kb > 38.00 (peso 272.0)
# Mantida aresta Ti kb > 38.00 -> Ag ka scattering > 3551.00 (peso 680.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Ti kb > 38.00 (peso 70.0)
# Mantida aresta Ti kb > 38.00 -> Ag ka scattering <= 3551.00 (peso 140.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 38.00 -> Ag ka scattering <= 3590.25 (peso 105.0)
# Mantida aresta Ag ka scattering <= 3590.25 -> Ti kb > 38.00 (peso 210.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > 787.00 -> Ag ka scattering > 3551.00 (peso 812.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ti ka > 787.00 (peso 812.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 801.00 -> Ti ka > 787.00 (peso 1540.0)
# Mantida aresta Ti ka > 787.00 -> Ti ka > 801.00 (peso 2940.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 787.00 -> Ti kb > 48.00 (peso 92.0)
# Mantida aresta Ti kb > 48.00 -> Ti ka > 787.00 (peso 230.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 787.00 -> Ti ka > 787.00 (peso 0.0)
# Mantida aresta Ti ka > 787.00 -> Ti ka <= 787.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ti ka > 787.00 (peso 170.0)
# Mantida aresta Ti ka > 787.00 -> Ag ka scattering > 3509.25 (peso 340.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 787.00 -> Ag ka scattering <= 3590.25 (peso 300.0)
# Mantida aresta Ag ka scattering <= 3590.25 -> Ti ka > 787.00 (peso 600.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 787.00 -> Ca ka <= 103.50 (peso 200.0)
# Mantida aresta Ca ka <= 103.50 -> Ti ka > 787.00 (peso 600.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 801.00 -> Ti ka > 787.00 (peso 69.0)
# Mantida aresta Ti ka > 787.00 -> Ti ka <= 801.00 (peso 138.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Ti ka > 787.00 (peso 93.0)
# Mantida aresta Ti ka > 787.00 -> Ag ka scattering <= 3551.00 (peso 279.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 787.00 -> Ag ka scattering <= 3509.25 (peso 39.0)
# Mantida aresta Ag ka scattering <= 3509.25 -> Ti ka > 787.00 (peso 312.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 48.00 -> Ag ka scattering > 3551.00 (peso 66.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ti kb > 48.00 (peso 165.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 268.00 -> Ag ka scattering > 3551.00 (peso 40.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ca ka > 268.00 (peso 80.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3590.25 -> Ag ka scattering > 3551.00 (peso 70.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ag ka scattering <= 3590.25 (peso 490.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3509.25 -> Ag ka scattering > 3551.00 (peso 0.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ag ka scattering <= 3509.25 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3551.00 -> Ca ka <= 103.50 (peso 304.0)
# Mantida aresta Ca ka <= 103.50 -> Ag ka scattering > 3551.00 (peso 380.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ag ka scattering > 3551.00 (peso 141.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ag ka scattering > 3509.25 (peso 423.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 3551.00 -> background4 <= 238.00 (peso 32.0)
# Mantida aresta background4 <= 238.00 -> Ag ka scattering > 3551.00 (peso 32.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3551.00 -> Ti ka <= 787.00 (peso 100.0)
# Mantida aresta Ti ka <= 787.00 -> Ag ka scattering > 3551.00 (peso 125.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 353.25 -> Ag ka scattering > 3551.00 (peso 123.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ar ka + Ag L > 353.25 (peso 164.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > 818.00 -> Ag ka scattering > 3551.00 (peso 46.0)
# Mantida aresta Ag ka scattering > 3551.00 -> Ti ka > 818.00 (peso 46.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3551.00 -> Ti ka > 801.00 (peso 83.0)
# Mantida aresta Ti ka > 801.00 -> Ag ka scattering > 3551.00 (peso 581.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 103.50 -> Ti kb > 48.00 (peso 177.0)
# Mantida aresta Ti kb > 48.00 -> Ca ka <= 103.50 (peso 236.0)
#
# ======================================================================
#
# Removida aresta Ti kb > 48.00 -> Ag ka scattering <= 3509.25 (peso 17.0)
# Mantida aresta Ag ka scattering <= 3509.25 -> Ti kb > 48.00 (peso 34.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 801.00 -> Ti kb > 48.00 (peso 29.0)
# Mantida aresta Ti kb > 48.00 -> Ti ka > 801.00 (peso 116.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 103.50 -> Ti ka <= 787.00 (peso 126.0)
# Mantida aresta Ti ka <= 787.00 -> Ca ka <= 103.50 (peso 126.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 49.25 -> Ti ka <= 787.00 (peso 310.0)
# Mantida aresta Ti ka <= 787.00 -> Ca kb <= 49.25 (peso 372.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ti ka <= 787.00 (peso 86.0)
# Mantida aresta Ti ka <= 787.00 -> Ag ka scattering > 3509.25 (peso 172.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > 801.00 -> Ti ka <= 787.00 (peso 0.0)
# Mantida aresta Ti ka <= 787.00 -> Ti ka > 801.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 268.00 -> Ti ka <= 787.00 (peso 12.0)
# Mantida aresta Ti ka <= 787.00 -> Ca ka > 268.00 (peso 36.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 818.00 -> Ti ka <= 787.00 (peso 75.0)
# Mantida aresta Ti ka <= 787.00 -> Ti ka <= 818.00 (peso 75.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 787.00 -> Ar ka + Ag L > 353.25 (peso 15.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> Ti ka <= 787.00 (peso 15.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka <= 787.00 -> Ag ka scattering <= 3509.25 (peso 32.0)
# Mantida aresta Ag ka scattering <= 3509.25 -> Ti ka <= 787.00 (peso 32.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 787.00 -> Cu <= 32.00 (peso 60.0)
# Mantida aresta Cu <= 32.00 -> Ti ka <= 787.00 (peso 120.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 801.00 -> Ti ka <= 787.00 (peso 75.0)
# Mantida aresta Ti ka <= 787.00 -> Ti ka <= 801.00 (peso 225.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 787.00 -> Ag ka scattering <= 3551.00 (peso 50.0)
# Mantida aresta Ag ka scattering <= 3551.00 -> Ti ka <= 787.00 (peso 100.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 103.50 -> Ag ka scattering <= 3509.25 (peso 174.0)
# Mantida aresta Ag ka scattering <= 3509.25 -> Ca ka <= 103.50 (peso 290.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3590.25 -> Ca ka <= 103.50 (peso 102.0)
# Mantida aresta Ca ka <= 103.50 -> Ag ka scattering <= 3590.25 (peso 408.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 353.25 -> Ti ka > 801.00 (peso 36.0)
# Mantida aresta Ti ka > 801.00 -> Ar ka + Ag L > 353.25 (peso 108.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3509.25 -> Ti ka > 801.00 (peso 20.0)
# Mantida aresta Ti ka > 801.00 -> Ag ka scattering <= 3509.25 (peso 60.0)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > 801.00 -> Ag ka scattering <= 3551.00 (peso 228.0)
# Mantida aresta Ag ka scattering <= 3551.00 -> Ti ka > 801.00 (peso 228.0)
#
# ======================================================================
#
# Removida aresta Ti ka > 818.00 -> Ti ka > 801.00 (peso 134.0)
# Mantida aresta Ti ka > 801.00 -> Ti ka > 818.00 (peso 201.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 268.00 -> Ti ka > 801.00 (peso 74.0)
# Mantida aresta Ti ka > 801.00 -> Ca ka > 268.00 (peso 148.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 49.25 -> Ti ka > 801.00 (peso 210.0)
# Mantida aresta Ti ka > 801.00 -> Ca kb <= 49.25 (peso 525.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ti ka > 801.00 (peso 720.0)
# Mantida aresta Ti ka > 801.00 -> Ag ka scattering > 3509.25 (peso 840.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > 341.00 -> Ti ka > 801.00 (peso 72.0)
# Mantida aresta Ti ka > 801.00 -> Ar ka + Ag L > 341.00 (peso 72.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3590.25 -> Ti ka > 801.00 (peso 99.0)
# Mantida aresta Ti ka > 801.00 -> Ag ka scattering <= 3590.25 (peso 99.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 353.25 -> Ca kb <= 49.25 (peso 378.0)
# Mantida aresta Ca kb <= 49.25 -> Ar ka + Ag L > 353.25 (peso 432.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Ar ka + Ag L > 353.25 (peso 90.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> Ag ka scattering <= 3551.00 (peso 150.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 353.25 -> Cu <= 32.00 (peso 55.0)
# Mantida aresta Cu <= 32.00 -> Ar ka + Ag L > 353.25 (peso 165.0)
#
# ======================================================================
#
# Removida aresta background4 <= 243.00 -> Ar ka + Ag L > 353.25 (peso 42.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> background4 <= 243.00 (peso 84.0)
#
# ======================================================================
#
# Removida aresta background4 <= 247.00 -> Ar ka + Ag L > 353.25 (peso 59.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> background4 <= 247.00 (peso 118.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 268.00 -> Ar ka + Ag L > 353.25 (peso 34.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> Ca ka > 268.00 (peso 51.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 329.00 -> Ar ka + Ag L > 353.25 (peso 0.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> Ar ka + Ag L <= 329.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 801.00 -> Ar ka + Ag L > 353.25 (peso 70.0)
# Mantida aresta Ar ka + Ag L > 353.25 -> Ti ka <= 801.00 (peso 105.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 353.25 -> Ag ka scattering > 3509.25 (peso 53.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Ar ka + Ag L > 353.25 (peso 424.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 49.25 -> Ca ka > 268.00 (peso 6.0)
# Mantida aresta Ca ka > 268.00 -> Ca kb <= 49.25 (peso 15.0)
#
# ======================================================================
#
# Removida aresta Cu <= 32.00 -> Ca kb <= 49.25 (peso 294.0)
# Mantida aresta Ca kb <= 49.25 -> Cu <= 32.00 (peso 735.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ca kb <= 49.25 (peso 302.0)
# Mantida aresta Ca kb <= 49.25 -> Ag ka scattering > 3509.25 (peso 755.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 49.25 -> Ar ka + Ag L <= 329.00 (peso 162.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Ca kb <= 49.25 (peso 378.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > 329.00 -> Ca kb <= 49.25 (peso 159.0)
# Mantida aresta Ca kb <= 49.25 -> Ar ka + Ag L > 329.00 (peso 159.0)
#
# ======================================================================
#
# Removida aresta background4 > 238.00 -> Ca kb <= 49.25 (peso 300.0)
# Mantida aresta Ca kb <= 49.25 -> background4 > 238.00 (peso 450.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 49.25 -> Ag ka scattering <= 3590.25 (peso 328.0)
# Mantida aresta Ag ka scattering <= 3590.25 -> Ca kb <= 49.25 (peso 820.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3509.25 -> Ca kb <= 49.25 (peso 124.0)
# Mantida aresta Ca kb <= 49.25 -> Ag ka scattering <= 3509.25 (peso 124.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 49.25 -> Ag ka scattering <= 3551.00 (peso 113.0)
# Mantida aresta Ag ka scattering <= 3551.00 -> Ca kb <= 49.25 (peso 339.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 268.00 -> background4 <= 247.00 (peso 116.0)
# Mantida aresta background4 <= 247.00 -> Ca ka > 268.00 (peso 116.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Ca ka > 268.00 (peso 31.0)
# Mantida aresta Ca ka > 268.00 -> Ag ka scattering <= 3551.00 (peso 124.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 268.00 -> Ti ka <= 801.00 (peso 68.0)
# Mantida aresta Ti ka <= 801.00 -> Ca ka > 268.00 (peso 102.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > 341.00 -> Ca ka > 268.00 (peso 33.0)
# Mantida aresta Ca ka > 268.00 -> Ar ka + Ag L > 341.00 (peso 33.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 268.00 -> Ca kb <= 23.00 (peso 0.0)
# Mantida aresta Ca kb <= 23.00 -> Ca ka > 268.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 329.00 -> Ca ka > 268.00 (peso 22.0)
# Mantida aresta Ca ka > 268.00 -> Ar ka + Ag L <= 329.00 (peso 44.0)
#
# ======================================================================
#
# Removida aresta Ca ka > 268.00 -> Ag ka scattering > 3509.25 (peso 61.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Ca ka > 268.00 (peso 122.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 243.00 -> Ca ka > 268.00 (peso 31.0)
# Mantida aresta Ca ka > 268.00 -> background4 > 243.00 (peso 31.0)
#
# ======================================================================
#
# Removida aresta background4 <= 247.00 -> Ar ka + Ag L <= 329.00 (peso 174.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> background4 <= 247.00 (peso 348.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 247.00 -> Ar ka + Ag L <= 341.00 (peso 114.0)
# Mantida aresta Ar ka + Ag L <= 341.00 -> background4 <= 247.00 (peso 114.0)
#
# ======================================================================
#
# Removida aresta background4 <= 243.00 -> background4 <= 247.00 (peso 972.0)
# Mantida aresta background4 <= 247.00 -> background4 <= 243.00 (peso 1782.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3551.00 -> background4 <= 247.00 (peso 228.0)
# Mantida aresta background4 <= 247.00 -> Ag ka scattering <= 3551.00 (peso 228.0)
#
# ======================================================================
#
# Removida aresta background4 <= 247.00 -> Ti ka <= 801.00 (peso 118.0)
# Mantida aresta Ti ka <= 801.00 -> background4 <= 247.00 (peso 472.0)
#
# ======================================================================
#
# Removida aresta background4 > 243.00 -> background4 <= 247.00 (peso 67.0)
# Mantida aresta background4 <= 247.00 -> background4 > 243.00 (peso 201.0)
#
# ======================================================================
#
# Removida aresta background4 <= 247.00 -> background4 > 238.00 (peso 882.0)
# Mantida aresta background4 > 238.00 -> background4 <= 247.00 (peso 1176.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 23.00 -> background4 <= 247.00 (peso 345.0)
# Mantida aresta background4 <= 247.00 -> Ca kb <= 23.00 (peso 345.0)
#
# ======================================================================
#
# Removida aresta Cu <= 32.00 -> background4 <= 247.00 (peso 1211.0)
# Mantida aresta background4 <= 247.00 -> Cu <= 32.00 (peso 1903.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 247.00 -> Ag ka scattering <= 3590.25 (peso 172.0)
# Mantida aresta Ag ka scattering <= 3590.25 -> background4 <= 247.00 (peso 172.0)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 247.00 -> Fe ka <= 27.00 (peso 172.0)
# Mantida aresta Fe ka <= 27.00 -> background4 <= 247.00 (peso 172.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 329.00 -> Ag ka scattering > 3509.25 (peso 51.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Ar ka + Ag L <= 329.00 (peso 153.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> background2 <= 16.00 (peso 167.0)
# Mantida aresta background2 <= 16.00 -> Ag ka scattering > 3509.25 (peso 501.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ti ka <= 818.00 (peso 153.0)
# Mantida aresta Ti ka <= 818.00 -> Ag ka scattering > 3509.25 (peso 459.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3590.25 -> Ag ka scattering > 3509.25 (peso 142.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Ag ka scattering <= 3590.25 (peso 568.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 341.00 -> Ag ka scattering > 3509.25 (peso 112.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Ar ka + Ag L > 341.00 (peso 448.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Ag ka scattering > 3509.25 (peso 216.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Ag ka scattering <= 3551.00 (peso 288.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 27.00 -> Ag ka scattering > 3509.25 (peso 172.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Fe ka <= 27.00 (peso 344.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 12.00 -> Ag ka scattering > 3509.25 (peso 64.0)
# Mantida aresta Ag ka scattering > 3509.25 -> Fe kb <= 12.00 (peso 64.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 3509.25 -> Ar ka + Ag L > 329.00 (peso 162.0)
# Mantida aresta Ar ka + Ag L > 329.00 -> Ag ka scattering > 3509.25 (peso 162.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3509.25 -> Ti ka <= 801.00 (peso 186.0)
# Mantida aresta Ti ka <= 801.00 -> Ag ka scattering > 3509.25 (peso 372.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 > 121.00 -> Ag ka scattering > 3509.25 (peso 326.0)
# Mantida aresta Ag ka scattering > 3509.25 -> background5 > 121.00 (peso 326.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 3509.25 -> background2 <= 14.00 (peso 130.0)
# Mantida aresta background2 <= 14.00 -> Ag ka scattering > 3509.25 (peso 130.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 329.00 -> Ag ka scattering <= 3551.00 (peso 41.0)
# Mantida aresta Ag ka scattering <= 3551.00 -> Ar ka + Ag L <= 329.00 (peso 123.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3590.25 -> Ar ka + Ag L <= 329.00 (peso 112.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Ag ka scattering <= 3590.25 (peso 112.0)
#
# ======================================================================
#
# Removida aresta Cu <= 32.00 -> Ar ka + Ag L <= 329.00 (peso 108.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Cu <= 32.00 (peso 270.0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 24.00 -> Ar ka + Ag L <= 329.00 (peso 42.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Fe ka <= 24.00 (peso 84.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 13.00 -> Ar ka + Ag L <= 329.00 (peso 49.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> background2 > 13.00 (peso 49.0)
#
# ======================================================================
#
# Removida aresta background4 > 238.00 -> Ar ka + Ag L <= 329.00 (peso 104.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> background4 > 238.00 (peso 156.0)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L > 329.00 -> Ar ka + Ag L <= 329.00 (peso 0.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Ar ka + Ag L > 329.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 23.00 -> Ar ka + Ag L <= 329.00 (peso 74.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Ca kb <= 23.00 (peso 111.0)
#
# ======================================================================
#
# Removida aresta Ti ka <= 801.00 -> Ar ka + Ag L <= 329.00 (peso 40.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Ti ka <= 801.00 (peso 120.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 25.00 -> Ar ka + Ag L <= 329.00 (peso 11.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> Ca ka <= 25.00 (peso 11.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Ar ka + Ag L <= 329.00 (peso 51.0)
# Mantida aresta Ar ka + Ag L <= 329.00 -> background2 <= 16.00 (peso 51.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Ti ka <= 801.00 (peso 86.0)
# Mantida aresta Ti ka <= 801.00 -> Ag ka scattering <= 3551.00 (peso 258.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3551.00 -> Ca kb <= 23.00 (peso 73.0)
# Mantida aresta Ca kb <= 23.00 -> Ag ka scattering <= 3551.00 (peso 73.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3551.00 -> Ti ka <= 818.00 (peso 244.0)
# Mantida aresta Ti ka <= 818.00 -> Ag ka scattering <= 3551.00 (peso 244.0)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Ag ka scattering <= 3551.00 (peso 101.0)
# Mantida aresta Ag ka scattering <= 3551.00 -> background2 <= 16.00 (peso 101.0)
#
# ======================================================================
#
# Removida aresta Ag ka scattering <= 3551.00 -> Cu <= 32.00 (peso 111.0)
# Mantida aresta Cu <= 32.00 -> Ag ka scattering <= 3551.00 (peso 222.0)
#
# ======================================================================
#
# Removida aresta background5 > 121.00 -> Ag ka scattering <= 3551.00 (peso 105.0)
# Mantida aresta Ag ka scattering <= 3551.00 -> background5 > 121.00 (peso 210.0)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering <= 3551.00 -> Ar ka + Ag L > 341.00 (peso 62.0)
# Mantida aresta Ar ka + Ag L > 341.00 -> Ag ka scattering <= 3551.00 (peso 62.0)
#
# ...
# Mantida aresta background1 <= 56.00 -> background1 <= 54.00 (peso 1141.0)
#
# ======================================================================
#
# Removida aresta Cu <= 23.00 -> background1 <= 56.00 (peso 248.0)
# Mantida aresta background1 <= 56.00 -> Cu <= 23.00 (peso 372.0)
#
# ======================================================================
#
# Removida aresta background1 <= 52.00 -> background1 <= 56.00 (peso 202.0)
# Mantida aresta background1 <= 56.00 -> background1 <= 52.00 (peso 505.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> background1 <= 56.00 (peso 394.0)
# Mantida aresta background1 <= 56.00 -> background3 <= 14.00 (peso 591.0)
#
# ======================================================================
#
# Removida aresta background1 <= 56.00 -> Fe kb <= 12.00 (peso 61.0)
# Mantida aresta Fe kb <= 12.00 -> background1 <= 56.00 (peso 366.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 12.00 -> background1 <= 56.00 (peso 432.0)
# Mantida aresta background1 <= 56.00 -> background3 <= 12.00 (peso 432.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 13.00 -> background1 <= 56.00 (peso 60.0)
# Mantida aresta background1 <= 56.00 -> Ti kb <= 13.00 (peso 300.0)
#
# ======================================================================
#
# Removida aresta background1 <= 56.00 -> Fe kb <= 14.00 (peso 276.0)
# Mantida aresta Fe kb <= 14.00 -> background1 <= 56.00 (peso 552.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 49.25 -> background1 <= 56.00 (peso 55.0)
# Mantida aresta background1 <= 56.00 -> Ca kb > 49.25 (peso 165.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 15.00 -> background1 <= 56.00 (peso 338.0)
# Mantida aresta background1 <= 56.00 -> Fe kb <= 15.00 (peso 338.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 11.00 -> background1 <= 56.00 (peso 51.0)
# Mantida aresta background1 <= 56.00 -> background3 <= 11.00 (peso 51.0)
#
# ======================================================================
#
# Removida aresta background1 <= 56.00 -> Ca ka <= 25.00 (peso 60.0)
# Mantida aresta Ca ka <= 25.00 -> background1 <= 56.00 (peso 120.0)
#
# ======================================================================
#
# Removida aresta background1 <= 54.00 -> background3 <= 12.00 (peso 222.0)
# Mantida aresta background3 <= 12.00 -> background1 <= 54.00 (peso 296.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 13.00 -> background1 <= 54.00 (peso 88.0)
# Mantida aresta background1 <= 54.00 -> Ti kb <= 13.00 (peso 132.0)
#
# ======================================================================
#
# Removida aresta background1 <= 54.00 -> Fe kb <= 15.00 (peso 242.0)
# Mantida aresta Fe kb <= 15.00 -> background1 <= 54.00 (peso 363.0)
#
# ======================================================================
#
# Removida aresta background1 <= 54.00 -> background3 > 12.00 (peso 178.0)
# Mantida aresta background3 > 12.00 -> background1 <= 54.00 (peso 267.0)
#
# ======================================================================
#
# Removida aresta background1 <= 54.00 -> Cu <= 23.00 (peso 89.0)
# Mantida aresta Cu <= 23.00 -> background1 <= 54.00 (peso 356.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 12.00 -> background1 <= 54.00 (peso 94.0)
# Mantida aresta background1 <= 54.00 -> Fe kb <= 12.00 (peso 235.0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 25.00 -> background1 <= 54.00 (peso 40.0)
# Mantida aresta background1 <= 54.00 -> Ca ka <= 25.00 (peso 80.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> background1 <= 54.00 (peso 441.0)
# Mantida aresta background1 <= 54.00 -> background3 <= 14.00 (peso 588.0)
#
# ======================================================================
#
# Removida aresta background1 <= 54.00 -> background3 <= 11.00 (peso 32.0)
# Mantida aresta background3 <= 11.00 -> background1 <= 54.00 (peso 224.0)
#
# ======================================================================
#
# Removida aresta background1 <= 52.00 -> background1 <= 54.00 (peso 202.0)
# Mantida aresta background1 <= 54.00 -> background1 <= 52.00 (peso 606.0)
#
# ======================================================================
#
# Removida aresta background1 <= 54.00 -> Ca kb > 49.25 (peso 78.0)
# Mantida aresta Ca kb > 49.25 -> background1 <= 54.00 (peso 156.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 14.00 -> background1 <= 54.00 (peso 198.0)
# Mantida aresta background1 <= 54.00 -> Fe kb <= 14.00 (peso 297.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 12.00 -> background3 > 12.00 (peso 0.0)
# Mantida aresta background3 > 12.00 -> background3 <= 12.00 (peso 0.0)
#
# ======================================================================
#
# Removida aresta Cu <= 23.00 -> background3 <= 12.00 (peso 166.0)
# Mantida aresta background3 <= 12.00 -> Cu <= 23.00 (peso 581.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 15.00 -> background3 <= 12.00 (peso 212.0)
# Mantida aresta background3 <= 12.00 -> Fe kb <= 15.00 (peso 212.0)
#
# ======================================================================
#
# Removida aresta background3 <= 12.00 -> background3 <= 14.00 (peso 286.0)
# Mantida aresta background3 <= 14.00 -> background3 <= 12.00 (peso 715.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 12.00 -> background3 <= 12.00 (peso 47.0)
# Mantida aresta background3 <= 12.00 -> Fe kb <= 12.00 (peso 141.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 14.00 -> background3 <= 12.00 (peso 352.0)
# Mantida aresta background3 <= 12.00 -> Fe kb <= 14.00 (peso 528.0)
#
# ======================================================================
#
# Removida aresta background3 <= 11.00 -> background3 <= 12.00 (peso 73.0)
# Mantida aresta background3 <= 12.00 -> background3 <= 11.00 (peso 292.0)
#
# ======================================================================
#
# Removida aresta background1 <= 52.00 -> background3 > 12.00 (peso 196.0)
# Mantida aresta background3 > 12.00 -> background1 <= 52.00 (peso 343.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 12.00 -> Cu <= 23.00 (peso 136.0)
# Mantida aresta Cu <= 23.00 -> background3 > 12.00 (peso 136.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 12.00 -> Ca kb > 49.25 (peso 108.0)
# Mantida aresta Ca kb > 49.25 -> background3 > 12.00 (peso 108.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 12.00 -> Ti kb <= 13.00 (peso 33.0)
# Mantida aresta Ti kb <= 13.00 -> background3 > 12.00 (peso 33.0)
#
# ======================================================================
#
# Removida aresta background3 > 12.00 -> Fe kb <= 12.00 (peso 64.0)
# Mantida aresta Fe kb <= 12.00 -> background3 > 12.00 (peso 128.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 14.00 -> background3 > 12.00 (peso 89.0)
# Mantida aresta background3 > 12.00 -> Fe kb <= 14.00 (peso 89.0)
#
# ======================================================================
#
# Removida aresta Cu <= 23.00 -> background1 <= 52.00 (peso 216.0)
# Mantida aresta background1 <= 52.00 -> Cu <= 23.00 (peso 270.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 15.00 -> background1 <= 52.00 (peso 225.0)
# Mantida aresta background1 <= 52.00 -> Fe kb <= 15.00 (peso 300.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 13.00 -> background1 <= 52.00 (peso 130.0)
# Mantida aresta background1 <= 52.00 -> Ti kb <= 13.00 (peso 156.0)
#
# ======================================================================
#
# Removida aresta background1 <= 52.00 -> Fe kb <= 12.00 (peso 90.0)
# Mantida aresta Fe kb <= 12.00 -> background1 <= 52.00 (peso 210.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> background1 <= 52.00 (peso 188.0)
# Mantida aresta background1 <= 52.00 -> background3 <= 14.00 (peso 282.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> Cu <= 23.00 (peso 133.0)
# Mantida aresta Cu <= 23.00 -> background3 <= 14.00 (peso 665.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 14.00 -> Cu <= 23.00 (peso 276.0)
# Mantida aresta Cu <= 23.00 -> Fe kb <= 14.00 (peso 368.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 15.00 -> Cu <= 23.00 (peso 220.0)
# Mantida aresta Cu <= 23.00 -> Fe kb <= 15.00 (peso 550.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 25.00 -> Cu <= 23.00 (peso 61.0)
# Mantida aresta Cu <= 23.00 -> Ca ka <= 25.00 (peso 61.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 49.25 -> Cu <= 23.00 (peso 162.0)
# Mantida aresta Cu <= 23.00 -> Ca kb > 49.25 (peso 216.0)
#
# ======================================================================
#
# Removida aresta Cu <= 23.00 -> background3 <= 11.00 (peso 80.0)
# Mantida aresta background3 <= 11.00 -> Cu <= 23.00 (peso 120.0)
#
# ======================================================================
#
# Removida aresta Cu <= 23.00 -> Fe kb <= 12.00 (peso 47.0)
# Mantida aresta Fe kb <= 12.00 -> Cu <= 23.00 (peso 188.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> Fe kb <= 14.00 (peso 474.0)
# Mantida aresta Fe kb <= 14.00 -> background3 <= 14.00 (peso 790.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> Ti kb <= 13.00 (peso 201.0)
# Mantida aresta Ti kb <= 13.00 -> background3 <= 14.00 (peso 469.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 15.00 -> background3 <= 14.00 (peso 760.0)
# Mantida aresta background3 <= 14.00 -> Fe kb <= 15.00 (peso 1710.0)
#
# ======================================================================
#
# Removida aresta background3 <= 11.00 -> background3 <= 14.00 (peso 219.0)
# Mantida aresta background3 <= 14.00 -> background3 <= 11.00 (peso 511.0)
#
# ======================================================================
#
# Removida aresta background3 <= 14.00 -> Fe kb <= 12.00 (peso 71.0)
# Mantida aresta Fe kb <= 12.00 -> background3 <= 14.00 (peso 213.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 49.25 -> Fe kb <= 14.00 (peso 36.0)
# Mantida aresta Fe kb <= 14.00 -> Ca kb > 49.25 (peso 72.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 14.00 -> background3 <= 11.00 (peso 102.0)
# Mantida aresta background3 <= 11.00 -> Fe kb <= 14.00 (peso 408.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 14.00 -> Fe kb <= 12.00 (peso 316.0)
# Mantida aresta Fe kb <= 12.00 -> Fe kb <= 14.00 (peso 553.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 15.00 -> Fe kb <= 14.00 (peso 531.0)
# Mantida aresta Fe kb <= 14.00 -> Fe kb <= 15.00 (peso 1062.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 13.00 -> Fe kb <= 14.00 (peso 126.0)
# Mantida aresta Fe kb <= 14.00 -> Ti kb <= 13.00 (peso 294.0)
#
# ======================================================================
#
# Removida aresta Ca kb > 49.25 -> background3 <= 11.00 (peso 13.0)
# Mantida aresta background3 <= 11.00 -> Ca kb > 49.25 (peso 26.0)
#
# ======================================================================
#
# Empate! Removida aresta Fe kb <= 12.00 -> Fe kb <= 15.00 (peso 316.0)
# Mantida aresta Fe kb <= 15.00 -> Fe kb <= 12.00 (peso 316.0)
#
# ======================================================================
#
# Empate! Removida aresta background3 <= 11.00 -> Fe kb <= 12.00 (peso 56.0)
# Mantida aresta Fe kb <= 12.00 -> background3 <= 11.00 (peso 56.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 12.00 -> Ti kb <= 13.00 (peso 42.0)
# Mantida aresta Ti kb <= 13.00 -> Fe kb <= 12.00 (peso 105.0)
#
# ======================================================================
#
# Removida aresta Ti kb <= 13.00 -> Fe kb <= 15.00 (peso 49.0)
# Mantida aresta Fe kb <= 15.00 -> Ti kb <= 13.00 (peso 392.0)
#
# ======================================================================
#
# Removida aresta Fe kb <= 15.00 -> background3 <= 11.00 (peso 252.0)
# Mantida aresta background3 <= 11.00 -> Fe kb <= 15.00 (peso 315.0)
#
# ======================================================================
#
# Removida aresta background3 <= 11.00 -> Ti kb <= 13.00 (peso 51.0)
# Mantida aresta Ti kb <= 13.00 -> background3 <= 11.00 (peso 119.0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L > 353.25 -> Ti ka > 818.00 (peso 17.0)
# Mantida aresta Ti ka > 818.00 -> Ar ka + Ag L > 353.25 (peso 34.0)
#
# ======================================================================
#
# Empate! Removida aresta background5 <= 121.00 -> background2 > 16.00 (peso 15.0)
# Mantida aresta background2 > 16.00 -> background5 <= 121.00 (peso 15.0)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 25.00 -> background5 <= 121.00 (peso 21.0)
# Mantida aresta background5 <= 121.00 -> Ca ka <= 25.00 (peso 21.0)
#
# ======================================================================
#
#
# Total de arestas iniciais: 1600
# Total de arestas removidas por bidirecionalidade: 546
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 81
# Total de nós terminais: 2
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
#         Predicate_Seed_0       Predicate_Seed_1    Predicate_Seed_42
# 0          Fe ka > 24.00          Fe ka > 24.00        Fe ka > 24.00
# 1          Fe ka > 20.75          Fe ka > 20.75        Fe ka > 20.75
# 2          Fe ka > 27.00          Fe ka > 27.00        Fe ka > 27.00
# 3          Ca ka > 25.00          Ca ka > 25.00        Ca ka > 25.00
# 4          Fe kb > 14.00          Fe kb > 14.00       Ca ka > 103.50
# ..                   ...                    ...                  ...
# 78   background2 > 14.00  background4 <= 238.00        Ca kb > 49.25
# 79  background5 > 130.00          Ca kb > 49.25       Fe ka <= 20.75
# 80   background2 > 16.00         Fe ka <= 20.75  background2 > 16.00
# 81               Class_A                Class_A              Class_A
# 82               Class_B                Class_B              Class_B
#
# [83 rows x 3 columns]

# %%
features_importance = pd.DataFrame({
    'Vip' : vip_scores_unique_df['Zone'].values,
    'Reg_coef' : reg_vet_unique_df['Zone'].values,
    'Shap' : shap_unique_df['Zone'].values
    })

for seed, lrc_unique_df in lrc_unique_by_seed.items():
    zones = lrc_unique_df['Zone'].values
    # condição para padronizar o tamanho das listas (usando o tamanho do features_importance)
    if len(zones) < len(features_importance):
        zones = np.concatenate([zones, [None]*(len(features_importance)-len(zones))]) # adicionando None para completar o tamanho
    features_importance[f'LRC_Seed_{seed}'] = zones[:len(features_importance)]
features_importance
# Out:
#                  Vip          Reg_coef        LRC_Seed_0        LRC_Seed_1  \
# 0              Fe ka             Ti ka             Fe ka             Fe ka
# 1              Ca ka             Ti kb             Ca ka             Ca ka
# 2              Ti ka  Ag ka scattering             Fe kb             Fe kb
# 3                 Cu             Ca ka             Ca kb             Ca kb
# 4              Fe kb                Cu             Ti kb                Cu
# 5              Ca kb             Ca kb                Cu             Ti kb
# 6              Ti kb       background4             Ti ka             Ti ka
# 7   Ag ka scattering       background2  Ag ka scattering  Ag ka scattering
# 8        background4      Ar ka + Ag L       background4       background3
# 9        background2       background5       background2       background4
# 10      Ar ka + Ag L             Fe ka      Ar ka + Ag L       background5
# 11       background5       background1       background1       background2
# 12       background1       background3       background3       background1
# 13       background3             Fe kb       background5      Ar ka + Ag L
#
#          LRC_Seed_42
# 0              Fe ka
# 1              Ca ka
# 2              Fe kb
# 3              Ca kb
# 4                 Cu
# 5              Ti kb
# 6              Ti ka
# 7        background4
# 8   Ag ka scattering
# 9        background3
# 10       background2
# 11      Ar ka + Ag L
# 12       background1
# 13       background5

# %% [markdown]
# ## **RBO**

# %%
# utilizando o Rank-Biased Overlap (RBO) para comparar as listas de importância de características tendo o vip como referencia
# com p = 1 é rbo equivalente ao overlap simples (interseção sobre união) sem peso para posições iniciais
# quanto menor o p, mais peso é dado para as posições iniciais da lista (mais relevante para nosso caso)
import rbo

rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if pd.notnull(x)]
methods = ['Reg_coef', 'Shap'] + [f'LRC_Seed_{seed}' for seed in random_seeds]
rbo_results = {}
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if pd.notnull(x)]
    # Ensure both lists are the same length for RBO calculation
    min_len = min(len(reference_list), len(compare_list))
    ref_trimmed = reference_list[:min_len]
    comp_trimmed = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trimmed, comp_trimmed).rbo(p=0.4, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method', 'RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_results
# Out:
#   Reference       Method  RBO_Score
# 2       Vip   LRC_Seed_1   0.944540
# 3       Vip  LRC_Seed_42   0.944461
# 1       Vip   LRC_Seed_0   0.941527
# 0       Vip     Reg_coef   0.067436

# %%
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from both lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Ensure both lists are the same length for RBO calculation
        min_len = min(len(list_1), len(list_2))
        list_1_trimmed = list_1[:min_len]
        list_2_trimmed = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trimmed, list_2_trimmed).rbo(p=0.8, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4828\646247094.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
#      Method_1     Method_2  RBO_Score
# 7  LRC_Seed_0   LRC_Seed_1   0.779999
# 8  LRC_Seed_0  LRC_Seed_42   0.665242
# 9  LRC_Seed_1  LRC_Seed_42   0.603655
# 1         Vip   LRC_Seed_0   0.395146
# 4    Reg_coef   LRC_Seed_0   0.394111
# 3         Vip  LRC_Seed_42   0.382414
# 2         Vip   LRC_Seed_1   0.378685
# 6    Reg_coef  LRC_Seed_42   0.375699
# 0         Vip     Reg_coef   0.303188
# 5    Reg_coef   LRC_Seed_1   0.290456
