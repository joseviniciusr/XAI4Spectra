# %% [markdown]
# # **Model**

# %% [markdown]
# # **XRF bank notes database**

# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import kennard_stone as ks

# loading a soil spectral dataset based on X-ray fluorescence (XRF)
data_complete = pd.read_csv('XRF_databases/bank_notes/plsda/bank_notes.csv', sep=';') # local copy of Toledo 2022 dataset
data = data_complete.loc[:, '1':'26.07']
#data.insert(0, 'exCa', data_complete['exCa'])  # inserting the target variable (e.g., exCa (exchangeable calcium))

# Creating a new column 'Class' based on the condition of the samples in the 'Type' column being 'Authentic'
data_complete['Class'] = np.where(data_complete['Type'] == 'Authentic', 'A', 'B') # Class A: Authentic bank notes, Class B: Counterfeit bank notes
data_A = data_complete[data_complete['Class'] == 'A'].reset_index(drop=True)
data_B = data_complete[data_complete['Class'] == 'B'].reset_index(drop=True)

# splitting the data into calibration and prediction sets by kennard-stone algorithm
XA_cal, XA_pred = ks.train_test_split(data_A.loc[:, '1':'26.07'], test_size=0.30) # class A
XA_cal = XA_cal.reset_index(drop=True)
XA_pred = XA_pred.reset_index(drop=True)

XB_cal, XB_pred = ks.train_test_split(data_B.loc[:, '1':'26.07'], test_size=0.30) # class B
XB_cal = XB_cal.reset_index(drop=True)
XB_pred = XB_pred.reset_index(drop=True)

Xcalclass = pd.concat([XA_cal, XB_cal], axis=0).reset_index(drop=True) # concatenating both classes
Xpredclass = pd.concat([XA_pred, XB_pred], axis=0).reset_index(drop=True)
ycalclass = pd.Series(['A']*XA_cal.shape[0] + ['B']*XB_cal.shape[0]) # creating the target variable for calibration set
ypredclass = pd.Series(['A']*XA_pred.shape[0] + ['B']*XB_pred.shape[0]) # creating the target variable for prediction set

# preprocessings
import preprocessings as prepr # preprocessing methods for XRF data

Xcalclass_prep, mean_calclass, mean_calclass_poisson  = prepr.poisson(Xcalclass, mc=True)
Xpredclass_prep = ((Xpredclass/np.sqrt(mean_calclass)) - mean_calclass_poisson)

from modeling import pls_optimized

# performing PLS-DA with optimized latent variables
plsda_results = pls_optimized(Xcalclass_prep, 
                              ycalclass,
                              LVmax=4,
                              Xpred=Xpredclass_prep,
                              ypred=ypredclass,
                              aim='classification',
                              cv=10)
plsda_results[0]
# Out:
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-12-11 12:22:09,894 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-12-11 12:22:09,931 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-12-11 12:22:09,995 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-12-11 12:22:10,008 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#    LVs  Accuracy Cal  Sensitivity Cal  Specificity Cal               CM Cal  \
# 0    1      0.857143         0.714286              1.0  [[35, 0], [10, 25]]
# 1    2      1.000000         1.000000              1.0   [[35, 0], [0, 35]]
# 2    3      1.000000         1.000000              1.0   [[35, 0], [0, 35]]
# 3    4      1.000000         1.000000              1.0   [[35, 0], [0, 35]]
#
#    Accuracy CV  Sensitivity CV  Specificity CV                CM CV  \
# 0     0.657143        0.314286        1.000000  [[35, 0], [24, 11]]
# 1     0.985714        0.971429        1.000000   [[35, 0], [1, 34]]
# 2     0.971429        1.000000        0.942857   [[33, 2], [0, 35]]
# 3     1.000000        1.000000        1.000000   [[35, 0], [0, 35]]
#
#    Accuracy Pred  Sensitivity Pred  Specificity Pred             CM Pred  \
# 0        0.75000               0.5            1.0000   [[16, 0], [8, 8]]
# 1        1.00000               1.0            1.0000  [[16, 0], [0, 16]]
# 2        0.96875               1.0            0.9375  [[15, 1], [0, 16]]
# 3        1.00000               1.0            1.0000  [[16, 0], [0, 16]]
#
#    X Cum Exp Var  Y Cum Exp Var  X Ind Exp Var  Y Ind Exp Var
# 0      67.666513      13.906535      67.666513      13.906535
# 1      80.515995      41.765993      12.849483      27.859459
# 2      87.313002      43.868807       6.797007       2.102813
# 3      91.586650      44.904629       4.273648       1.035822

# %% [markdown]
# # **VIP and SHAP**

# %%
# establishing spectral cuts based on expert knowledge of XRF spectra
spectral_cuts = [
('background1', 1.0, 2.74),
('Ar ka + Ag L', 2.76, 3.47),
('Ca ka', 3.5, 3.91),
('Ca kb', 3.93, 4.24),
('Ti ka', 4.26, 4.72),
('Ti kb', 4.75, 5.13),
('background2', 5.16, 6.12),
('Fe ka', 6.15, 6.76),
('Fe kb', 6.79, 7.32),
('background3', 7.35, 7.78),
('Cu', 7.81, 8.29),
('background4', 8.32, 21.46),
('Ag ka scattering', 21.49, 22.71),
('background5', 22.74, 24.52),
('Ti ka', 24.55, 26.07),
]

# %%
import numpy as np
import pandas as pd

# vip
vip_scores_df = pd.DataFrame({
    'energy' : plsda_results[4].T.index,
    'VIP_Score' : plsda_results[4].T.iloc[:,0].values
})
vip_scores_df = vip_scores_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# vamos gerar uma nova coluna em vip_scores_df com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_vip = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
	for i in vip_scores_df['energy']: # iterando sobre cada valor de energia no vip_scores_df
		i_float = float(i)
		if start <= i_float <= end:
			energy_to_zone_vip[i] = zone_name
vip_scores_df['Zone'] = vip_scores_df['energy'].map(energy_to_zone_vip) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_vip

# vamos filtrar vip_scores_df para manter apenas as zonas espectrais únicas com maior VIP score
vip_scores_unique_df = vip_scores_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
vip_scores_unique_df = vip_scores_unique_df.sort_values(by='VIP_Score', ascending=False).reset_index(drop=True)

# reg vet
reg_vet = pd.DataFrame(plsda_results[3].coef_, columns=plsda_results[3].feature_names_in_) # creating a DataFrame with regression coefficients
reg_vet = reg_vet.T
reg_vet.insert(0, 'energy', reg_vet.index) # adding energy column
reg_vet = reg_vet.reset_index(drop=True)
reg_vet.columns = ['energy', 'Reg_coef'] # renaming
reg_vet['Abs_Reg_coef'] = reg_vet['Reg_coef'].abs() # adding absolute value column
reg_vet = reg_vet.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True) # sorting by absolute value

# gerando uma nova coluna em reg_vet com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_reg = {} # dicionário para mapear energia para zona espectral
for zone_name, start, end in spectral_cuts: # iterando sobre cada zona espectral (que tem nome, início e fim)
    for i in reg_vet['energy']: # iterando sobre cada valor de energia no reg_vet
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_reg[i] = zone_name
reg_vet['Zone'] = reg_vet['energy'].map(energy_to_zone_reg) # a funcao map funciona como um buscador que substitui os valores de 'energy' pelos valores correspondentes no dicionário energy_to_zone_reg
reg_vet

# vamos filtrar reg_vet para manter apenas as zonas espectrais únicas com maior valor absoluto do coeficiente de regressão
reg_vet_unique_df = reg_vet.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
reg_vet_unique_df = reg_vet_unique_df.sort_values(by='Abs_Reg_coef', ascending=False).reset_index(drop=True)

# vamos agora extrair as variaveis mais importantes atraves do método SHAP
import shap

# Para PLSRegression, usamos KernelExplainer porque não há explainer dedicado muito rápido
explainer_pls = shap.KernelExplainer(plsda_results[3].predict, Xcalclass_prep)
shap_values_pls = explainer_pls(Xcalclass_prep)

shap_global_importance = pd.DataFrame({
    'energy': Xpredclass_prep.columns,
    'Mean_Abs_SHAP': np.abs(shap_values_pls.values).mean(axis=0)}) # tomando a importancia global como a media dos valores absolutos dos valores SHAP para cada feature
shap_global_importance.sort_values(by='Mean_Abs_SHAP', ascending=False, inplace=True)

# vamos gerar uma nova coluna em shap_global_importance com o nome da zona espectral correspondente de acordo com a lista spectral_cuts
energy_to_zone_shap = {}
for zone_name, start, end in spectral_cuts:
    for i in shap_global_importance['energy']:
        i_float = float(i)
        if start <= i_float <= end:
            energy_to_zone_shap[i] = zone_name
shap_global_importance['Zone'] = shap_global_importance['energy'].map(energy_to_zone_shap)

# agora vamos filtrar shap_global_importance para manter apenas as zonas espectrais únicas com maior SHAP score
shap_unique_df = shap_global_importance.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
shap_unique_df = shap_unique_df.sort_values(by='Mean_Abs_SHAP', ascending=False).reset_index(drop=True)

# 15 MIN
# Out:
# 100%|██████████| 70/70 [07:10<00:00,  6.15s/it]

# %%
vip_scores_unique_df.to_csv('XRF_databases/bank_notes/plsda/vip_scores_bank_notes.csv', index=False, sep=';')
reg_vet_unique_df.to_csv('XRF_databases/bank_notes/plsda/reg_vet_bank_notes.csv', index=False, sep=';')
shap_unique_df.to_csv('XRF_databases/bank_notes/plsda/shap_bank_notes.csv', index=False, sep=';')

# %%
shap_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/shap_bank_notes.csv', sep=';') # loading previously saved shap_unique_df
vip_scores_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/vip_scores_bank_notes.csv', sep=';') # loading previously saved vip_scores_unique_df#
reg_vet_unique_df = pd.read_csv('XRF_databases/bank_notes/plsda/reg_vet_bank_notes.csv', sep=';') # loading previously saved reg_vet_unique_df

# %% [markdown]
# # **SMeX**

# %%
from explaining import extract_spectral_zones
from explaining import aggregate_spectral_zones
from explaining import predicates_by_quantiles
from explaining import create_predicate_info_dict
from explaining import bagging_predicates, calculate_predicate_metrics
from explaining import build_predicate_graph
import numpy as np
import pandas as pd

spectral_zones_class = extract_spectral_zones(Xcalclass, spectral_cuts) # extracting the spectral zones
zone_sums_df = aggregate_spectral_zones(spectral_zones_class, aggregator='max')
predicates_quantiles = predicates_by_quantiles(zone_sums_df, [0.25, 0.5, 0.75]) # getting predicates for quartiles
co_occurrence_matrix_df=predicates_quantiles[2]

# Criar dicionário de informações
predicate_info_dict = create_predicate_info_dict(
    predicates_df=predicates_quantiles[0],
    predicate_indicator_df=predicates_quantiles[1],
    zone_aggregated_df=zone_sums_df,
    y_predicted_numeric=plsda_results[5].iloc[:, -1]
)

# LISTA DE SEMENTES A TESTAR

random_seeds = [0, 1, 42]

all_results = {}

training_samples = len(Xcalclass)

# LOOP: PROCESSAR CADA SEMENTE

y_predicted_numeric = plsda_results[5].iloc[:, -1] # predições numéricas do modelo

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando semente: {seed}")
    print(f"{'='*70}\n")
    
    # Bagging
    bags_result_seed = bagging_predicates(
        zone_sums_df=zone_sums_df,
        y_predicted_numeric=y_predicted_numeric,
        predicates_df=predicates_quantiles[0],
        n_bags=60,
        #n_predicates_per_bag=int(training_samples*0.6), # 60 % da base para predicados (convertido para int)
        n_samples_per_bag=int(training_samples*0.8), # 80 % da base para amostrar (convertido para int)
        min_samples_per_predicate=int(training_samples*0.20), # 20 % da base para limitar (convertido para int)
        replace=False,
        sample_bagging=True,
        predicate_bagging=False,
        random_seed=seed
    )
    
    # Inserir classe prevista
    for bag_name, pred_dict in bags_result_seed.items(): # iterando sobre cada bag
        for pred_rule, df_info in pred_dict.items():
            df_info['Class_Predicted'] = np.where(df_info['Predicted_Y'] >= 0.5, 'A', 'B') # binarizando com threshold 0.5, A = eut, B = dist
    
    # Calcular MI
    mi_results_dict_seed = calculate_predicate_metrics(
        bags_result=bags_result_seed,
        metric='mutual_info',
        threshold=0.1, # threshold para cortar predicados irrelevantes
        n_neighbors=5
    )
    
    # Salvar no dicionário principal
    all_results[seed] = {
        'bags_result': bags_result_seed,
        'mi_results_dict': mi_results_dict_seed
    }

# CONSTRUÇÃO DE GRAFOS PARA MÚLTIPLAS SEMENTES (LOOP EXTERNO)

# Dicionário para armazenar grafos
graphs_by_seed = {}

for seed in random_seeds:
    print(f"\n{'='*70}")
    print(f"Processando Grafo - Semente: {seed}")
    print(f"{'='*70}\n")
    
    # Construir grafo para esta semente
    DG = build_predicate_graph(
        bags_result=all_results[seed]['bags_result'],
        mi_results_dict=all_results[seed]['mi_results_dict'],
        co_occurrence_matrix_df=co_occurrence_matrix_df,
        predicates_df=predicates_quantiles[0],
        random_state=seed,
        show_details=True
    )
    
    # Armazenar grafo
    graphs_by_seed[seed] = DG  

# vamos calcular a LRC de acordo com as diferentes sementes
import networkx as nx

lrc_by_seed = {}
for seed in random_seeds:
    DG = graphs_by_seed[seed]
    local_reaching_centrality = {
        node: nx.local_reaching_centrality(DG, node, weight='weight') 
        for node in DG.nodes()
    }

    # Ordenar por LRC
    sorted_lrc = sorted(local_reaching_centrality.items(), key=lambda x: x[1], reverse=True)
    
    # Criar DataFrame com LRC
    lrc_df_seed = pd.DataFrame(sorted_lrc, columns=['Node', 'Local_Reaching_Centrality'])
    
    # Extrair informações dos predicados (zona, threshold, operador)
    zones = []
    thresholds = []
    operators = []
    
    for node in lrc_df_seed['Node']:
        if node.startswith('Class_'):
            zones.append(None)
            thresholds.append(None)
            operators.append(None)
        else:
            pred_row = predicates_quantiles[0][predicates_quantiles[0]['rule'] == node].iloc[0]
            zones.append(pred_row['zone'])
            thresholds.append(pred_row['thresholds'])
            operators.append(pred_row['operator'])
    
    lrc_df_seed['Zone'] = zones
    lrc_df_seed['Threshold'] = thresholds
    lrc_df_seed['Operator'] = operators
    lrc_df_seed['Seed'] = seed  # Adicionar coluna com a semente
    
    # Armazenar LRC
    lrc_by_seed[seed] = lrc_df_seed

# junando todas as colunas 'Node' de lrc_by_seed em um único dataframe

lrc_all_seeds_df = pd.DataFrame() # 
for seed in random_seeds:
    lrc_df_seed = lrc_by_seed[seed]
    lrc_df_seed = lrc_df_seed.rename(columns={
        'Node': f'Predicate_Seed_{seed}'
    })
    lrc_all_seeds_df = pd.concat([lrc_all_seeds_df, lrc_df_seed[[f'Predicate_Seed_{seed}']]], axis=1)

# vamos filtrar lrc_by_seed em cada semente para manter apenas as zonas espectrais únicas com maior LRC em um mesmo dataframe
lrc_unique_by_seed = {}
for seed, lrc_df in lrc_by_seed.items():
    lrc_unique_df = lrc_df.drop_duplicates(subset=['Zone'], keep='first').reset_index(drop=True)
    lrc_unique_df = lrc_unique_df.sort_values(by='Local_Reaching_Centrality', ascending=False).reset_index(drop=True)
    lrc_unique_by_seed[seed] = lrc_unique_df

lrc_all_seeds_df # exibindo o dataframe consolidado com predicados de todas as sementes
# Out:
# ======================================================================
# Processando semente: 0
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
#
# ======================================================================
# Calculando Mutual_Info para Predicados
# ======================================================================
# Métrica: mutual_info
# Threshold: 0.1
#
# ======================================================================
# Processando semente: 1
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 79 | Descartados: 5
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
#
# ======================================================================
# Calculando Mutual_Info para Predicados
# ======================================================================
# Métrica: mutual_info
# Threshold: 0.1
#
# ======================================================================
# Processando semente: 42
# ======================================================================
#
# Bag_1 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_2 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_3 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 78 | Descartados: 6
# Bag_4 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_5 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_6 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_7 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_8 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_9 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_10 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 69 | Descartados: 15
# Bag_11 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_12 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_13 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_14 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_15 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_16 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_17 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_18 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_19 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_20 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_21 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_22 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_23 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 79 | Descartados: 5
# Bag_24 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_25 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_26 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_27 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_28 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_29 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_30 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_31 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_32 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_33 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_34 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_35 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 71 | Descartados: 13
# Bag_36 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_37 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 77 | Descartados: 7
# Bag_38 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_39 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_40 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_41 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_42 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_43 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_44 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_45 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_46 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_47 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 70 | Descartados: 14
# Bag_48 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_49 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 75 | Descartados: 9
# Bag_50 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_51 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_52 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_53 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_54 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 72 | Descartados: 12
# Bag_55 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_56 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_57 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 74 | Descartados: 10
# Bag_58 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
# Bag_59 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 73 | Descartados: 11
# Bag_60 | Amostras: Sim | Predicados: Não (Todos) | Válidos: 76 | Descartados: 8
#
# ======================================================================
# Calculando Mutual_Info para Predicados
# ======================================================================
# Métrica: mutual_info
# Threshold: 0.1
#
# ======================================================================
# Processando Grafo - Semente: 0
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 130
# Removida aresta Ca ka > 37.50 -> Ca kb > 16.00 (peso 527)
# Mantida aresta Ca kb > 16.00 -> Ca ka > 37.50 (peso 1023)
#
# ======================================================================
#
# Removida aresta Ti kb > 31.00 -> Ca ka > 37.50 (peso 273)
# Mantida aresta Ca ka > 37.50 -> Ti kb > 31.00 (peso 504)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 31.00 -> Ca kb > 16.00 (peso 266)
# Mantida aresta Ca kb > 16.00 -> Ti kb > 31.00 (peso 266)
#
# ======================================================================
#
# Removida aresta Ca ka <= 145.75 -> Ca kb > 16.00 (peso 16)
# Mantida aresta Ca kb > 16.00 -> Ca ka <= 145.75 (peso 48)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= 31.00 -> Ca kb > 16.00 (peso 15)
# Mantida aresta Ca kb > 16.00 -> Ti kb <= 31.00 (peso 15)
#
# ======================================================================
#
# Removida aresta Ca kb > 12.25 -> Ti kb > 31.00 (peso 30)
# Mantida aresta Ti kb > 31.00 -> Ca kb > 12.25 (peso 420)
#
# ======================================================================
#
# Removida aresta Ca ka > 22.00 -> Ti kb > 31.00 (peso 31)
# Mantida aresta Ti kb > 31.00 -> Ca ka > 22.00 (peso 186)
#
# ======================================================================
#
# Removida aresta Ca kb > 12.25 -> Ti kb <= 31.00 (peso 132)
# Mantida aresta Ti kb <= 31.00 -> Ca kb > 12.25 (peso 154)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Ca ka <= 145.75 (peso 189)
# Mantida aresta Ca ka <= 145.75 -> Ti kb <= 31.00 (peso 231)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 245.00 -> Ti kb <= 31.00 (peso 32)
# Mantida aresta Ti kb <= 31.00 -> background4 <= 245.00 (peso 32)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 30.00 -> Ti kb <= 31.00 (peso 110)
# Mantida aresta Ti kb <= 31.00 -> Ca kb <= 30.00 (peso 110)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Ar ka + Ag L <= 341.00 (peso 16)
# Mantida aresta Ar ka + Ag L <= 341.00 -> Ti kb <= 31.00 (peso 32)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= 31.00 -> background3 > 13.00 (peso 14)
# Mantida aresta background3 > 13.00 -> Ti kb <= 31.00 (peso 14)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 22.00 -> Ti kb <= 31.00 (peso 76)
# Mantida aresta Ti kb <= 31.00 -> Ca ka > 22.00 (peso 76)
#
# ======================================================================
#
# Removida aresta Cu > 31.75 -> Ti kb <= 31.00 (peso 3)
# Mantida aresta Ti kb <= 31.00 -> Cu > 31.75 (peso 9)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Cu > 19.00 (peso 63)
# Mantida aresta Cu > 19.00 -> Ti kb <= 31.00 (peso 105)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Cu > 22.50 (peso 11)
# Mantida aresta Cu > 22.50 -> Ti kb <= 31.00 (peso 22)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= 31.00 -> background2 <= 16.00 (peso 32)
# Mantida aresta background2 <= 16.00 -> Ti kb <= 31.00 (peso 32)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Ti kb <= 31.00 (peso 24)
# Mantida aresta Ti kb <= 31.00 -> Cu <= 22.50 (peso 24)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 145.75 -> Ti kb <= 31.00 (peso 28)
# Mantida aresta Ti kb <= 31.00 -> Ca ka > 145.75 (peso 28)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= 31.00 -> background5 > 128.75 (peso 6)
# Mantida aresta background5 > 128.75 -> Ti kb <= 31.00 (peso 6)
#
# ======================================================================
#
# Removida aresta Ca ka > 22.00 -> Ca kb > 12.25 (peso 656)
# Mantida aresta Ca kb > 12.25 -> Ca ka > 22.00 (peso 1066)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ca kb > 12.25 (peso 70)
# Mantida aresta Ca kb > 12.25 -> Ca kb <= 30.00 (peso 455)
#
# ======================================================================
#
# Removida aresta Ca kb > 12.25 -> Ca ka <= 145.75 (peso 272)
# Mantida aresta Ca ka <= 145.75 -> Ca kb > 12.25 (peso 306)
#
# ======================================================================
#
# Removida aresta Ca kb > 30.00 -> Ca ka > 22.00 (peso 17)
# Mantida aresta Ca ka > 22.00 -> Ca kb > 30.00 (peso 68)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ca ka > 22.00 (peso 132)
# Mantida aresta Ca ka > 22.00 -> Ca kb <= 30.00 (peso 198)
#
# ======================================================================
#
# Removida aresta Ca ka <= 145.75 -> Ca ka > 22.00 (peso 224)
# Mantida aresta Ca ka > 22.00 -> Ca ka <= 145.75 (peso 512)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> Ca ka > 22.00 (peso 39)
# Mantida aresta Ca ka > 22.00 -> Cu > 19.00 (peso 117)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> Ca ka > 22.00 (peso 32)
# Mantida aresta Ca ka > 22.00 -> Cu <= 31.75 (peso 32)
#
# ======================================================================
#
# Removida aresta Ca ka <= 145.75 -> Ca kb > 30.00 (peso 1)
# Mantida aresta Ca kb > 30.00 -> Ca ka <= 145.75 (peso 3)
#
# ======================================================================
#
# Removida aresta Cu <= 31.75 -> Ca kb > 30.00 (peso 11)
# Mantida aresta Ca kb > 30.00 -> Cu <= 31.75 (peso 44)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Ca kb > 30.00 (peso 11)
# Mantida aresta Ca kb > 30.00 -> background4 > 237.00 (peso 22)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 12.00 -> Ca kb > 30.00 (peso 8)
# Mantida aresta Ca kb > 30.00 -> background3 > 12.00 (peso 8)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 16.00 -> Ca kb > 30.00 (peso 0)
# Mantida aresta Ca kb > 30.00 -> Ca kb <= 16.00 (peso 0)
#
# ======================================================================
#
# Removida aresta Ca kb > 30.00 -> Cu > 19.00 (peso 15)
# Mantida aresta Cu > 19.00 -> Ca kb > 30.00 (peso 30)
#
# ======================================================================
#
# Removida aresta Ca kb > 30.00 -> Cu > 22.50 (peso 9)
# Mantida aresta Cu > 22.50 -> Ca kb > 30.00 (peso 18)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 341.00 -> Ca ka <= 145.75 (peso 26)
# Mantida aresta Ca ka <= 145.75 -> Ar ka + Ag L <= 341.00 (peso 78)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ca ka <= 145.75 (peso 612)
# Mantida aresta Ca ka <= 145.75 -> Ca kb <= 30.00 (peso 1020)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> Ar ka + Ag L <= 341.00 (peso 58)
# Mantida aresta Ar ka + Ag L <= 341.00 -> background4 > 237.00 (peso 58)
#
# ======================================================================
#
# Removida aresta Fe ka <= 23.00 -> Ar ka + Ag L <= 341.00 (peso 22)
# Mantida aresta Ar ka + Ag L <= 341.00 -> Fe ka <= 23.00 (peso 44)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 341.00 -> background5 > 128.75 (peso 16)
# Mantida aresta background5 > 128.75 -> Ar ka + Ag L <= 341.00 (peso 16)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 341.00 -> Cu > 22.50 (peso 38)
# Mantida aresta Cu > 22.50 -> Ar ka + Ag L <= 341.00 (peso 57)
#
# ======================================================================
#
# Removida aresta Ca kb <= 12.25 -> Ar ka + Ag L <= 341.00 (peso 6)
# Mantida aresta Ar ka + Ag L <= 341.00 -> Ca kb <= 12.25 (peso 12)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 341.00 -> Cu > 19.00 (peso 54)
# Mantida aresta Cu > 19.00 -> Ar ka + Ag L <= 341.00 (peso 162)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ar ka + Ag L <= 341.00 (peso 52)
# Mantida aresta Ar ka + Ag L <= 341.00 -> Ca kb <= 30.00 (peso 78)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 341.00 -> background2 <= 14.00 (peso 19)
# Mantida aresta background2 <= 14.00 -> Ar ka + Ag L <= 341.00 (peso 38)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 341.00 -> background2 <= 16.00 (peso 29)
# Mantida aresta background2 <= 16.00 -> Ar ka + Ag L <= 341.00 (peso 29)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 341.00 -> Cu > 31.75 (peso 10)
# Mantida aresta Cu > 31.75 -> Ar ka + Ag L <= 341.00 (peso 20)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> Ca kb <= 30.00 (peso 76)
# Mantida aresta Ca kb <= 30.00 -> background4 > 237.00 (peso 76)
#
# ======================================================================
#
# Removida aresta Cu > 31.75 -> background4 > 237.00 (peso 39)
# Mantida aresta background4 > 237.00 -> Cu > 31.75 (peso 52)
#
# ======================================================================
#
# Empate! Removida aresta background5 > 128.75 -> background4 > 237.00 (peso 13)
# Mantida aresta background4 > 237.00 -> background5 > 128.75 (peso 13)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 13.00 -> background4 > 237.00 (peso 14)
# Mantida aresta background4 > 237.00 -> background3 > 13.00 (peso 14)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> background4 > 237.00 (peso 76)
# Mantida aresta background4 > 237.00 -> background2 <= 16.00 (peso 76)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> background4 > 237.00 (peso 27)
# Mantida aresta background4 > 237.00 -> background2 <= 14.00 (peso 108)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> background4 > 237.00 (peso 34)
# Mantida aresta background4 > 237.00 -> Cu > 19.00 (peso 68)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 145.75 -> background4 > 237.00 (peso 12)
# Mantida aresta background4 > 237.00 -> Ca ka > 145.75 (peso 12)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Ca kb <= 16.00 (peso 48)
# Mantida aresta Ca kb <= 16.00 -> background4 > 237.00 (peso 96)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 245.00 -> background4 > 237.00 (peso 35)
# Mantida aresta background4 > 237.00 -> background4 <= 245.00 (peso 35)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> Ti kb > 44.00 (peso 15)
# Mantida aresta Ti kb > 44.00 -> background4 > 237.00 (peso 15)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> background4 > 237.00 (peso 25)
# Mantida aresta background4 > 237.00 -> Cu > 22.50 (peso 50)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= 23.00 -> background4 > 237.00 (peso 90)
# Mantida aresta background4 > 237.00 -> Fe ka <= 23.00 (peso 90)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Ca ka <= 37.50 (peso 23)
# Mantida aresta Ca ka <= 37.50 -> background4 > 237.00 (peso 69)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Cu <= 22.50 (peso 24)
# Mantida aresta Cu <= 22.50 -> background4 > 237.00 (peso 48)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 242.00 -> background3 > 13.00 (peso 11)
# Mantida aresta background3 > 13.00 -> background4 > 242.00 (peso 11)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 19.00 -> background4 > 242.00 (peso 25)
# Mantida aresta background4 > 242.00 -> Cu > 19.00 (peso 25)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 242.00 -> Cu <= 22.50 (peso 14)
# Mantida aresta Cu <= 22.50 -> background4 > 242.00 (peso 14)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 30.00 -> Cu <= 31.75 (peso 41)
# Mantida aresta Cu <= 31.75 -> Ca kb <= 30.00 (peso 41)
#
# ======================================================================
#
# Removida aresta Cu <= 31.75 -> Ca kb <= 16.00 (peso 35)
# Mantida aresta Ca kb <= 16.00 -> Cu <= 31.75 (peso 70)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 245.00 -> Cu <= 31.75 (peso 43)
# Mantida aresta Cu <= 31.75 -> background4 <= 245.00 (peso 43)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> Ca ka <= 37.50 (peso 34)
# Mantida aresta Ca ka <= 37.50 -> Cu <= 31.75 (peso 34)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> Ca kb <= 30.00 (peso 33)
# Mantida aresta Ca kb <= 30.00 -> Cu > 19.00 (peso 198)
#
# ======================================================================
#
# Removida aresta background3 > 13.00 -> Ca kb <= 30.00 (peso 10)
# Mantida aresta Ca kb <= 30.00 -> background3 > 13.00 (peso 40)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> Cu > 19.00 (peso 105)
# Mantida aresta Cu > 19.00 -> Cu > 22.50 (peso 210)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> background2 <= 14.00 (peso 23)
# Mantida aresta background2 <= 14.00 -> Cu > 19.00 (peso 69)
#
# ======================================================================
#
# Removida aresta Cu > 31.75 -> Cu > 19.00 (peso 36)
# Mantida aresta Cu > 19.00 -> Cu > 31.75 (peso 54)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> background3 > 13.00 (peso 13)
# Mantida aresta background3 > 13.00 -> Cu > 19.00 (peso 26)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> Ca kb <= 16.00 (peso 57)
# Mantida aresta Ca kb <= 16.00 -> Cu > 19.00 (peso 76)
#
# ======================================================================
#
# Removida aresta Cu <= 22.50 -> Cu > 19.00 (peso 13)
# Mantida aresta Cu > 19.00 -> Cu <= 22.50 (peso 26)
#
# ======================================================================
#
# Removida aresta background4 <= 245.00 -> Cu > 19.00 (peso 38)
# Mantida aresta Cu > 19.00 -> background4 <= 245.00 (peso 152)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 19.00 -> Ca ka > 145.75 (peso 15)
# Mantida aresta Ca ka > 145.75 -> Cu > 19.00 (peso 15)
#
# ======================================================================
#
# Removida aresta Ca kb <= 12.25 -> Cu > 19.00 (peso 20)
# Mantida aresta Cu > 19.00 -> Ca kb <= 12.25 (peso 30)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= 23.00 -> Cu > 19.00 (peso 25)
# Mantida aresta Cu > 19.00 -> Fe ka <= 23.00 (peso 25)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> Ca ka <= 37.50 (peso 17)
# Mantida aresta Ca ka <= 37.50 -> Cu > 19.00 (peso 34)
#
# ======================================================================
#
# Removida aresta Ag ka scattering > 3584.75 -> background2 <= 14.00 (peso 12)
# Mantida aresta background2 <= 14.00 -> Ag ka scattering > 3584.75 (peso 24)
#
# ======================================================================
#
# Removida aresta Ca ka <= 37.50 -> Ag ka scattering > 3584.75 (peso 11)
# Mantida aresta Ag ka scattering > 3584.75 -> Ca ka <= 37.50 (peso 22)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 145.75 -> Cu > 31.75 (peso 18)
# Mantida aresta Cu > 31.75 -> Ca ka > 145.75 (peso 18)
#
# ======================================================================
#
# Removida aresta Ca ka > 145.75 -> background2 <= 14.00 (peso 11)
# Mantida aresta background2 <= 14.00 -> Ca ka > 145.75 (peso 22)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> Ca ka > 145.75 (peso 18)
# Mantida aresta Ca ka > 145.75 -> Cu > 22.50 (peso 36)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Ca ka > 145.75 (peso 17)
# Mantida aresta Ca ka > 145.75 -> background2 <= 16.00 (peso 17)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 145.75 -> Fe ka <= 23.00 (peso 10)
# Mantida aresta Fe ka <= 23.00 -> Ca ka > 145.75 (peso 10)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 16.00 -> Ca ka > 145.75 (peso 0)
# Mantida aresta Ca ka > 145.75 -> Ca kb <= 16.00 (peso 0)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Ca ka > 145.75 (peso 9)
# Mantida aresta Ca ka > 145.75 -> Cu <= 22.50 (peso 9)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 44.00 -> Ca ka > 145.75 (peso 1)
# Mantida aresta Ca ka > 145.75 -> Ti kb > 44.00 (peso 1)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > 792.00 -> Ca ka > 145.75 (peso 10)
# Mantida aresta Ca ka > 145.75 -> Ti ka > 792.00 (peso 10)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 14.00 -> Ca ka > 145.75 (peso 7)
# Mantida aresta Ca ka > 145.75 -> background2 > 14.00 (peso 7)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 44.00 -> background3 > 11.00 (peso 10)
# Mantida aresta background3 > 11.00 -> Ti kb > 44.00 (peso 10)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 44.00 -> Ca kb <= 16.00 (peso 11)
# Mantida aresta Ca kb <= 16.00 -> Ti kb > 44.00 (peso 11)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 14.00 -> background3 > 13.00 (peso 9)
# Mantida aresta background3 > 13.00 -> background2 <= 14.00 (peso 9)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Cu > 22.50 (peso 0)
# Mantida aresta Cu > 22.50 -> Cu <= 22.50 (peso 0)
#
# ======================================================================
#
# Removida aresta Fe ka <= 23.00 -> Cu <= 22.50 (peso 17)
# Mantida aresta Cu <= 22.50 -> Fe ka <= 23.00 (peso 34)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 330.00 -> Cu <= 22.50 (peso 9)
# Mantida aresta Cu <= 22.50 -> Ar ka + Ag L <= 330.00 (peso 9)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 31.75 -> Cu <= 22.50 (peso 0)
# Mantida aresta Cu <= 22.50 -> Cu > 31.75 (peso 0)
#
# ======================================================================
#
# Removida aresta Ca kb <= 12.25 -> Cu <= 22.50 (peso 12)
# Mantida aresta Cu <= 22.50 -> Ca kb <= 12.25 (peso 24)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Ar ka + Ag L <= 354.75 (peso 24)
# Mantida aresta Ar ka + Ag L <= 354.75 -> Cu <= 22.50 (peso 24)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 22.50 -> background4 <= 245.00 (peso 78)
# Mantida aresta background4 <= 245.00 -> Cu > 22.50 (peso 78)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 22.50 -> Ca kb <= 16.00 (peso 36)
# Mantida aresta Ca kb <= 16.00 -> Cu > 22.50 (peso 36)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> Cu > 22.50 (peso 17)
# Mantida aresta Cu > 22.50 -> background2 <= 14.00 (peso 34)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 354.75 -> Cu > 22.50 (peso 56)
# Mantida aresta Cu > 22.50 -> Ar ka + Ag L <= 354.75 (peso 84)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> background5 > 128.75 (peso 12)
# Mantida aresta background5 > 128.75 -> Cu > 22.50 (peso 36)
#
# ======================================================================
#
# Removida aresta Cu > 31.75 -> Cu > 22.50 (peso 36)
# Mantida aresta Cu > 22.50 -> Cu > 31.75 (peso 54)
#
# ======================================================================
#
# Removida aresta Ca ka <= 37.50 -> Cu > 22.50 (peso 24)
# Mantida aresta Cu > 22.50 -> Ca ka <= 37.50 (peso 36)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> Ti ka > 792.00 (peso 20)
# Mantida aresta Ti ka > 792.00 -> Cu > 22.50 (peso 40)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 22.50 -> background2 <= 16.00 (peso 28)
# Mantida aresta background2 <= 16.00 -> Cu > 22.50 (peso 28)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> background2 <= 16.00 (peso 38)
# Mantida aresta background2 <= 16.00 -> background2 <= 14.00 (peso 76)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 354.75 -> background2 <= 14.00 (peso 27)
# Mantida aresta background2 <= 14.00 -> Ar ka + Ag L <= 354.75 (peso 27)
#
# ======================================================================
#
# Removida aresta background2 <= 16.00 -> Ca kb <= 16.00 (peso 27)
# Mantida aresta Ca kb <= 16.00 -> background2 <= 16.00 (peso 54)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Cu > 31.75 (peso 17)
# Mantida aresta Cu > 31.75 -> background2 <= 16.00 (peso 17)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 11.00 -> background2 <= 16.00 (peso 37)
# Mantida aresta background2 <= 16.00 -> background3 > 11.00 (peso 37)
#
# ======================================================================
#
# Removida aresta Ca ka <= 37.50 -> background2 <= 16.00 (peso 26)
# Mantida aresta background2 <= 16.00 -> Ca ka <= 37.50 (peso 52)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Ca kb <= 12.25 (peso 15)
# Mantida aresta Ca kb <= 12.25 -> background2 <= 16.00 (peso 15)
#
# ======================================================================
#
# Removida aresta background2 <= 16.00 -> background4 <= 245.00 (peso 44)
# Mantida aresta background4 <= 245.00 -> background2 <= 16.00 (peso 88)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 16.00 -> Cu > 31.75 (peso 1)
# Mantida aresta Cu > 31.75 -> Ca kb <= 16.00 (peso 1)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 16.00 -> Ca ka <= 37.50 (peso 32)
# Mantida aresta Ca ka <= 37.50 -> Ca kb <= 16.00 (peso 32)
#
# ======================================================================
#
# Removida aresta background5 > 128.75 -> Ca kb <= 16.00 (peso 10)
# Mantida aresta Ca kb <= 16.00 -> background5 > 128.75 (peso 20)
#
# ======================================================================
#
# Removida aresta Ca kb <= 16.00 -> Fe ka <= 23.00 (peso 14)
# Mantida aresta Fe ka <= 23.00 -> Ca kb <= 16.00 (peso 28)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 12.00 -> Ca kb <= 16.00 (peso 12)
# Mantida aresta Ca kb <= 16.00 -> background3 > 12.00 (peso 12)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 11.00 -> background2 > 14.00 (peso 25)
# Mantida aresta background2 > 14.00 -> background3 > 11.00 (peso 25)
#
# ======================================================================
#
# Removida aresta Fe ka <= 23.00 -> Cu > 31.75 (peso 12)
# Mantida aresta Cu > 31.75 -> Fe ka <= 23.00 (peso 36)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 31.75 -> Fe ka <= 26.00 (peso 15)
# Mantida aresta Fe ka <= 26.00 -> Cu > 31.75 (peso 15)
#
# ======================================================================
#
# Empate! Removida aresta background4 <= 245.00 -> Ca ka <= 37.50 (peso 29)
# Mantida aresta Ca ka <= 37.50 -> background4 <= 245.00 (peso 29)
#
# ======================================================================
#
#
# Total de arestas iniciais: 575
# Total de arestas removidas por bidirecionalidade: 130
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 61
# Total de nós terminais: 2
#
#
# ======================================================================
# Processando Grafo - Semente: 1
# ======================================================================
#
#
# Total de pares bidirecionais encontrados: 134
# Removida aresta Ti kb <= 44.00 -> Ti kb > 13.00 (peso 34)
# Mantida aresta Ti kb > 13.00 -> Ti kb <= 44.00 (peso 2006)
#
# ======================================================================
#
# Removida aresta Ca ka > 37.50 -> Ca kb > 16.00 (peso 806)
# Mantida aresta Ca kb > 16.00 -> Ca ka > 37.50 (peso 899)
#
# ======================================================================
#
# Removida aresta Ti kb > 31.00 -> Ca kb > 16.00 (peso 95)
# Mantida aresta Ca kb > 16.00 -> Ti kb > 31.00 (peso 304)
#
# ======================================================================
#
# Removida aresta Ti kb > 31.00 -> Ca ka > 37.50 (peso 336)
# Mantida aresta Ca ka > 37.50 -> Ti kb > 31.00 (peso 525)
#
# ======================================================================
#
# Removida aresta Ca kb > 12.25 -> Ti kb > 31.00 (peso 30)
# Mantida aresta Ti kb > 31.00 -> Ca kb > 12.25 (peso 630)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 31.00 -> Ti kb <= 31.00 (peso 0)
# Mantida aresta Ti kb <= 31.00 -> Ti kb > 31.00 (peso 0)
#
# ======================================================================
#
# Removida aresta Ca ka <= 145.75 -> Ca kb > 12.25 (peso 476)
# Mantida aresta Ca kb > 12.25 -> Ca ka <= 145.75 (peso 612)
#
# ======================================================================
#
# Removida aresta Ca ka <= 145.75 -> Ca ka > 22.00 (peso 448)
# Mantida aresta Ca ka > 22.00 -> Ca ka <= 145.75 (peso 608)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Ca ka <= 145.75 (peso 42)
# Mantida aresta Ca ka <= 145.75 -> Ti kb <= 31.00 (peso 189)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ca ka <= 145.75 (peso 357)
# Mantida aresta Ca ka <= 145.75 -> Ca kb <= 30.00 (peso 408)
#
# ======================================================================
#
# Removida aresta background3 > 13.00 -> Ca ka <= 145.75 (peso 9)
# Mantida aresta Ca ka <= 145.75 -> background3 > 13.00 (peso 27)
#
# ======================================================================
#
# Removida aresta Ca ka <= 145.75 -> background2 <= 14.00 (peso 27)
# Mantida aresta background2 <= 14.00 -> Ca ka <= 145.75 (peso 54)
#
# ======================================================================
#
# Removida aresta Ca ka > 22.00 -> Ca kb > 12.25 (peso 451)
# Mantida aresta Ca kb > 12.25 -> Ca ka > 22.00 (peso 779)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Ca kb > 12.25 (peso 22)
# Mantida aresta Ca kb > 12.25 -> Ti kb <= 31.00 (peso 176)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ca kb > 12.25 (peso 70)
# Mantida aresta Ca kb > 12.25 -> Ca kb <= 30.00 (peso 245)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 13.00 -> Ca kb > 12.25 (peso 14)
# Mantida aresta Ca kb > 12.25 -> background3 > 13.00 (peso 14)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Ca ka > 22.00 (peso 132)
# Mantida aresta Ca ka > 22.00 -> Ca kb <= 30.00 (peso 495)
#
# ======================================================================
#
# Removida aresta Ti kb <= 31.00 -> Ca ka > 22.00 (peso 114)
# Mantida aresta Ca ka > 22.00 -> Ti kb <= 31.00 (peso 133)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 22.00 -> background3 > 13.00 (peso 13)
# Mantida aresta background3 > 13.00 -> Ca ka > 22.00 (peso 13)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka > 22.00 -> Cu > 22.50 (peso 30)
# Mantida aresta Cu > 22.50 -> Ca ka > 22.00 (peso 30)
#
# ======================================================================
#
# Removida aresta Ca kb <= 30.00 -> Cu <= 22.50 (peso 27)
# Mantida aresta Cu <= 22.50 -> Ca kb <= 30.00 (peso 54)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Ar ka + Ag L <= 341.00 (peso 17)
# Mantida aresta Ar ka + Ag L <= 341.00 -> Cu <= 22.50 (peso 17)
#
# ======================================================================
#
# Removida aresta Cu <= 31.75 -> Cu <= 22.50 (peso 70)
# Mantida aresta Cu <= 22.50 -> Cu <= 31.75 (peso 105)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Ca kb <= 16.00 (peso 24)
# Mantida aresta Ca kb <= 16.00 -> Cu <= 22.50 (peso 24)
#
# ======================================================================
#
# Removida aresta Cu <= 22.50 -> Ca ka > 145.75 (peso 9)
# Mantida aresta Ca ka > 145.75 -> Cu <= 22.50 (peso 18)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Cu > 22.50 (peso 0)
# Mantida aresta Cu > 22.50 -> Cu <= 22.50 (peso 0)
#
# ======================================================================
#
# Removida aresta Cu <= 22.50 -> background3 > 13.00 (peso 9)
# Mantida aresta background3 > 13.00 -> Cu <= 22.50 (peso 27)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Fe ka <= 26.00 (peso 29)
# Mantida aresta Fe ka <= 26.00 -> Cu <= 22.50 (peso 29)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> background3 <= 13.00 (peso 26)
# Mantida aresta background3 <= 13.00 -> Cu <= 22.50 (peso 26)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb > 30.00 -> Cu <= 22.50 (peso 8)
# Mantida aresta Cu <= 22.50 -> Ca kb > 30.00 (peso 8)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> Ca kb > 30.00 (peso 30)
# Mantida aresta Ca kb > 30.00 -> background2 <= 14.00 (peso 40)
#
# ======================================================================
#
# ...
#
# Removida aresta Cu > 19.00 -> Ca ka <= 37.50 (peso 17)
# Mantida aresta Ca ka <= 37.50 -> Cu > 19.00 (peso 68)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> Ca ka <= 37.50 (peso 102)
# Mantida aresta Ca ka <= 37.50 -> Cu <= 31.75 (peso 102)
#
# ======================================================================
#
# Empate! Removida aresta Ca ka <= 37.50 -> background5 > 128.75 (peso 8)
# Mantida aresta background5 > 128.75 -> Ca ka <= 37.50 (peso 8)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 31.75 -> Ca ka <= 37.50 (peso 1)
# Mantida aresta Ca ka <= 37.50 -> Cu > 31.75 (peso 1)
#
# ======================================================================
#
# Removida aresta background1 <= 53.50 -> Cu > 22.50 (peso 17)
# Mantida aresta Cu > 22.50 -> background1 <= 53.50 (peso 34)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Cu > 22.50 (peso 100)
# Mantida aresta Cu > 22.50 -> background4 > 237.00 (peso 150)
#
# ======================================================================
#
# Removida aresta Cu > 31.75 -> Cu > 22.50 (peso 36)
# Mantida aresta Cu > 22.50 -> Cu > 31.75 (peso 90)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 22.50 -> Cu > 22.50 (peso 0)
# Mantida aresta Cu > 22.50 -> Cu <= 22.50 (peso 0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 330.00 -> Cu > 22.50 (peso 9)
# Mantida aresta Cu > 22.50 -> Ar ka + Ag L <= 330.00 (peso 18)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> Cu > 19.00 (peso 105)
# Mantida aresta Cu > 19.00 -> Cu > 22.50 (peso 210)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 22.50 -> background4 > 242.00 (peso 19)
# Mantida aresta background4 > 242.00 -> Cu > 22.50 (peso 19)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Cu > 22.50 (peso 28)
# Mantida aresta Cu > 22.50 -> background2 <= 16.00 (peso 28)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 22.50 -> Fe ka <= 23.00 (peso 19)
# Mantida aresta Fe ka <= 23.00 -> Cu > 22.50 (peso 19)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 22.50 -> background3 > 13.00 (peso 7)
# Mantida aresta background3 > 13.00 -> Cu > 22.50 (peso 7)
#
# ======================================================================
#
# Removida aresta background4 <= 245.00 -> Cu > 22.50 (peso 26)
# Mantida aresta Cu > 22.50 -> background4 <= 245.00 (peso 78)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 14.00 -> Cu > 22.50 (peso 36)
# Mantida aresta Cu > 22.50 -> background2 > 14.00 (peso 36)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 11.00 -> Cu > 22.50 (peso 23)
# Mantida aresta Cu > 22.50 -> background3 > 11.00 (peso 23)
#
# ======================================================================
#
# Removida aresta Cu > 22.50 -> Cu <= 31.75 (peso 17)
# Mantida aresta Cu <= 31.75 -> Cu > 22.50 (peso 34)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> background1 <= 53.50 (peso 50)
# Mantida aresta background1 <= 53.50 -> Cu <= 31.75 (peso 50)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 53.50 -> Cu > 31.75 (peso 10)
# Mantida aresta Cu > 31.75 -> background1 <= 53.50 (peso 10)
#
# ======================================================================
#
# Empate! Removida aresta background1 <= 53.50 -> Ar ka + Ag L > 330.00 (peso 25)
# Mantida aresta Ar ka + Ag L > 330.00 -> background1 <= 53.50 (peso 25)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 12.25 -> background1 <= 53.50 (peso 9)
# Mantida aresta background1 <= 53.50 -> Ca kb <= 12.25 (peso 9)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Cu > 19.00 (peso 68)
# Mantida aresta Cu > 19.00 -> background4 > 237.00 (peso 102)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> background2 > 14.00 (peso 22)
# Mantida aresta background2 > 14.00 -> background4 > 237.00 (peso 22)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> background4 > 237.00 (peso 27)
# Mantida aresta background4 > 237.00 -> background2 <= 14.00 (peso 81)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Ar ka + Ag L <= 341.00 (peso 29)
# Mantida aresta Ar ka + Ag L <= 341.00 -> background4 > 237.00 (peso 58)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 354.75 -> background4 > 237.00 (peso 38)
# Mantida aresta background4 > 237.00 -> Ar ka + Ag L <= 354.75 (peso 76)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> Cu <= 22.50 (peso 72)
# Mantida aresta Cu <= 22.50 -> background4 > 237.00 (peso 72)
#
# ======================================================================
#
# Removida aresta background4 > 237.00 -> Cu > 31.75 (peso 13)
# Mantida aresta Cu > 31.75 -> background4 > 237.00 (peso 26)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> background3 > 13.00 (peso 14)
# Mantida aresta background3 > 13.00 -> background4 > 237.00 (peso 14)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> Cu <= 31.75 (peso 36)
# Mantida aresta Cu <= 31.75 -> background4 > 237.00 (peso 36)
#
# ======================================================================
#
# Empate! Removida aresta Ag ka scattering > 3584.75 -> background4 > 237.00 (peso 14)
# Mantida aresta background4 > 237.00 -> Ag ka scattering > 3584.75 (peso 14)
#
# ======================================================================
#
# Empate! Removida aresta background4 > 237.00 -> Ca kb <= 12.25 (peso 11)
# Mantida aresta Ca kb <= 12.25 -> background4 > 237.00 (peso 11)
#
# ======================================================================
#
# Removida aresta Cu > 31.75 -> Cu > 19.00 (peso 54)
# Mantida aresta Cu > 19.00 -> Cu > 31.75 (peso 72)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb > 44.00 -> Cu > 19.00 (peso 26)
# Mantida aresta Cu > 19.00 -> Ti kb > 44.00 (peso 26)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 19.00 -> background3 > 12.00 (peso 21)
# Mantida aresta background3 > 12.00 -> Cu > 19.00 (peso 21)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 12.25 -> Cu > 19.00 (peso 10)
# Mantida aresta Cu > 19.00 -> Ca kb <= 12.25 (peso 10)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> Cu > 19.00 (peso 69)
# Mantida aresta Cu > 19.00 -> background2 <= 14.00 (peso 138)
#
# ======================================================================
#
# Removida aresta Cu > 19.00 -> background5 > 128.75 (peso 14)
# Mantida aresta background5 > 128.75 -> Cu > 19.00 (peso 28)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> Cu > 31.75 (peso 9)
# Mantida aresta Cu > 31.75 -> background2 <= 14.00 (peso 18)
#
# ======================================================================
#
# Removida aresta background2 <= 16.00 -> Cu > 31.75 (peso 34)
# Mantida aresta Cu > 31.75 -> background2 <= 16.00 (peso 85)
#
# ======================================================================
#
# Empate! Removida aresta background3 > 12.00 -> Cu > 31.75 (peso 9)
# Mantida aresta Cu > 31.75 -> background3 > 12.00 (peso 9)
#
# ======================================================================
#
# Removida aresta Ca kb <= 12.25 -> Cu > 31.75 (peso 1)
# Mantida aresta Cu > 31.75 -> Ca kb <= 12.25 (peso 2)
#
# ======================================================================
#
# Empate! Removida aresta Cu > 31.75 -> Cu <= 22.50 (peso 0)
# Mantida aresta Cu <= 22.50 -> Cu > 31.75 (peso 0)
#
# ======================================================================
#
# Empate! Removida aresta Fe ka <= 26.00 -> Cu > 31.75 (peso 15)
# Mantida aresta Cu > 31.75 -> Fe ka <= 26.00 (peso 15)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 12.25 -> Cu > 31.75 (peso 16)
# Mantida aresta Cu > 31.75 -> background2 > 12.25 (peso 16)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> background5 <= 128.75 (peso 26)
# Mantida aresta background5 <= 128.75 -> background2 <= 14.00 (peso 52)
#
# ======================================================================
#
# Removida aresta Cu <= 22.50 -> background2 <= 14.00 (peso 21)
# Mantida aresta background2 <= 14.00 -> Cu <= 22.50 (peso 42)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> background2 <= 14.00 (peso 38)
# Mantida aresta background2 <= 14.00 -> background2 <= 16.00 (peso 38)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 14.00 -> background2 <= 14.00 (peso 0)
# Mantida aresta background2 <= 14.00 -> background2 > 14.00 (peso 0)
#
# ======================================================================
#
# Removida aresta Ar ka + Ag L <= 341.00 -> background2 <= 14.00 (peso 19)
# Mantida aresta background2 <= 14.00 -> Ar ka + Ag L <= 341.00 (peso 57)
#
# ======================================================================
#
# Empate! Removida aresta Ti kb <= 13.00 -> background2 <= 14.00 (peso 15)
# Mantida aresta background2 <= 14.00 -> Ti kb <= 13.00 (peso 15)
#
# ======================================================================
#
# Removida aresta background2 <= 14.00 -> Cu <= 31.75 (peso 29)
# Mantida aresta Cu <= 31.75 -> background2 <= 14.00 (peso 58)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Ca kb <= 12.25 (peso 15)
# Mantida aresta Ca kb <= 12.25 -> background2 <= 16.00 (peso 15)
#
# ======================================================================
#
# Empate! Removida aresta Ca kb <= 12.25 -> background4 <= 245.00 (peso 16)
# Mantida aresta background4 <= 245.00 -> Ca kb <= 12.25 (peso 16)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 14.00 -> background5 > 128.75 (peso 6)
# Mantida aresta background5 > 128.75 -> background2 > 14.00 (peso 6)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 14.00 -> Cu <= 31.75 (peso 23)
# Mantida aresta Cu <= 31.75 -> background2 > 14.00 (peso 23)
#
# ======================================================================
#
# Removida aresta background5 > 128.75 -> background2 <= 16.00 (peso 16)
# Mantida aresta background2 <= 16.00 -> background5 > 128.75 (peso 32)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> Fe ka <= 23.00 (peso 28)
# Mantida aresta Fe ka <= 23.00 -> background2 <= 16.00 (peso 28)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> background4 > 242.00 (peso 25)
# Mantida aresta background4 > 242.00 -> background2 <= 16.00 (peso 25)
#
# ======================================================================
#
# Empate! Removida aresta background2 <= 16.00 -> background2 > 12.25 (peso 37)
# Mantida aresta background2 > 12.25 -> background2 <= 16.00 (peso 37)
#
# ======================================================================
#
# Empate! Removida aresta Ti ka > 792.00 -> background2 <= 16.00 (peso 27)
# Mantida aresta background2 <= 16.00 -> Ti ka > 792.00 (peso 27)
#
# ======================================================================
#
# Removida aresta Cu <= 22.50 -> Cu <= 31.75 (peso 35)
# Mantida aresta Cu <= 31.75 -> Cu <= 22.50 (peso 70)
#
# ======================================================================
#
# Removida aresta Cu <= 22.50 -> Fe ka <= 23.00 (peso 17)
# Mantida aresta Fe ka <= 23.00 -> Cu <= 22.50 (peso 51)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> background5 > 128.75 (peso 22)
# Mantida aresta background5 > 128.75 -> Cu <= 31.75 (peso 22)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> Ar ka + Ag L <= 341.00 (peso 26)
# Mantida aresta Ar ka + Ag L <= 341.00 -> Cu <= 31.75 (peso 26)
#
# ======================================================================
#
# Empate! Removida aresta background2 > 12.25 -> Cu <= 31.75 (peso 36)
# Mantida aresta Cu <= 31.75 -> background2 > 12.25 (peso 36)
#
# ======================================================================
#
# Removida aresta Cu <= 31.75 -> Fe ka <= 23.00 (peso 24)
# Mantida aresta Fe ka <= 23.00 -> Cu <= 31.75 (peso 48)
#
# ======================================================================
#
# Empate! Removida aresta Cu <= 31.75 -> Ar ka + Ag L > 330.00 (peso 39)
# Mantida aresta Ar ka + Ag L > 330.00 -> Cu <= 31.75 (peso 39)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 354.75 -> background5 <= 128.75 (peso 39)
# Mantida aresta background5 <= 128.75 -> Ar ka + Ag L <= 354.75 (peso 39)
#
# ======================================================================
#
# Empate! Removida aresta Ar ka + Ag L <= 341.00 -> background2 > 12.25 (peso 27)
# Mantida aresta background2 > 12.25 -> Ar ka + Ag L <= 341.00 (peso 27)
#
# ======================================================================
#
#
# Total de arestas iniciais: 591
# Total de arestas removidas por bidirecionalidade: 138
# Arestas bidirecionais restantes: 0
# Total de nós predicados: 58
# Total de nós terminais: 2
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
# C:\Users\Usuario\AppData\Roaming\Python\Python313\site-packages\networkx\algorithms\centrality\reaching.py:193: RuntimeWarning: divide by zero encountered in scalar divide
#   return total_weight / d.get(weight, 1)
#               Predicate_Seed_0     Predicate_Seed_1 Predicate_Seed_42
# 0                Ti kb > 13.00        Ti kb > 13.00     Ti kb > 13.00
# 1                Ca kb > 16.00        Ca ka > 37.50    Ti kb <= 44.00
# 2               Ti kb <= 44.00       Ti kb <= 44.00     Ca ka > 37.50
# 3                Ca ka > 22.00        Ti kb > 31.00     Ti kb > 31.00
# 4                Ti kb > 31.00        Ca kb > 16.00     Ca kb > 12.25
# ..                         ...                  ...               ...
# 58              Ti kb <= 13.00  background2 > 16.00           Class_A
# 59  Ag ka scattering > 3584.75       Fe ka <= 20.25           Class_B
# 60              Ca ka <= 22.00              Class_A               NaN
# 61                     Class_A              Class_B               NaN
# 62                     Class_B                  NaN               NaN
#
# [63 rows x 3 columns]

# %%
features_importance = pd.DataFrame({
    'Vip' : vip_scores_unique_df['Zone'].values,
    'Reg_coef' : reg_vet_unique_df['Zone'].values,
    'Shap' : shap_unique_df['Zone'].values
    })

for seed, lrc_unique_df in lrc_unique_by_seed.items():
    zones = lrc_unique_df['Zone'].values
    # condição para padronizar o tamanho das listas (usando o tamanho do features_importance)
    if len(zones) < len(features_importance):
        zones = np.concatenate([zones, [None]*(len(features_importance)-len(zones))]) # adicionando None para completar o tamanho
    features_importance[f'LRC_Seed_{seed}'] = zones[:len(features_importance)]
features_importance
# Out:
#                  Vip          Reg_coef              Shap        LRC_Seed_0  \
# 0              Fe ka             Ti ka             Ti ka             Ti kb
# 1              Ti ka             Ti kb             Ti kb             Ca kb
# 2              Ca ka  Ag ka scattering             Ca ka             Ca ka
# 3                 Cu                Cu                Cu                Cu
# 4              Fe kb       background4             Fe ka       background2
# 5              Ti kb             Ca kb  Ag ka scattering       background4
# 6   Ag ka scattering       background2       background4      Ar ka + Ag L
# 7              Ca kb             Ca ka       background1       background3
# 8        background4       background1       background5       background1
# 9        background2       background5       background2             Fe ka
# 10       background5      Ar ka + Ag L             Ca kb  Ag ka scattering
# 11       background1             Fe ka             Fe kb             Ti ka
# 12      Ar ka + Ag L       background3       background3       background5
# 13       background3             Fe kb      Ar ka + Ag L              None
#
#           LRC_Seed_1       LRC_Seed_42
# 0              Ti kb             Ti kb
# 1              Ca ka             Ca ka
# 2              Ca kb             Ca kb
# 3       Ar ka + Ag L      Ar ka + Ag L
# 4                 Cu                Cu
# 5              Fe kb       background3
# 6        background2       background2
# 7        background4       background4
# 8        background3       background5
# 9              Ti ka             Fe ka
# 10       background1             Ti ka
# 11             Fe ka  Ag ka scattering
# 12       background5             Fe kb
# 13  Ag ka scattering       background1

# %% [markdown]
# ## **RBO**

# %%
# utilizando o Rank-Biased Overlap (RBO) para comparar as listas de importância de características tendo o vip como referencia
# com p = 1 é rbo equivalente ao overlap simples (interseção sobre união) sem peso para posições iniciais
# quanto menor o p, mais peso é dado para as posições iniciais da lista (mais relevante para nosso caso)
import rbo

rbo_results = {}
reference_list = [x for x in features_importance['Vip'].tolist() if pd.notnull(x)]
methods = ['Reg_coef', 'Shap'] + [f'LRC_Seed_{seed}' for seed in random_seeds]
rbo_results = {}
for method in methods:
    compare_list = [x for x in features_importance[method].tolist() if pd.notnull(x)]
    # Ensure both lists are the same length for RBO calculation
    min_len = min(len(reference_list), len(compare_list))
    ref_trimmed = reference_list[:min_len]
    comp_trimmed = compare_list[:min_len]
    score = rbo.RankingSimilarity(ref_trimmed, comp_trimmed).rbo(p=0.4, k=10)
    rbo_results[method] = score
rbo_results = pd.DataFrame(list(rbo_results.items()), columns=['Method', 'RBO_Score'])
rbo_results.insert(0, 'Reference', 'Vip')
rbo_results.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_results
# Out:
#   Reference       Method  RBO_Score
# 1       Vip         Shap   0.233483
# 0       Vip     Reg_coef   0.182989
# 2       Vip   LRC_Seed_0   0.062289
# 3       Vip   LRC_Seed_1   0.054247
# 4       Vip  LRC_Seed_42   0.052689

# %%
rbo_comparison = pd.DataFrame(columns=['Method_1', 'Method_2', 'RBO_Score'])
methods = features_importance.columns.tolist()
for i in range(len(methods)):
    for j in range(i + 1, len(methods)):
        method_1 = methods[i]
        method_2 = methods[j]
        # Remove None values from both lists
        list_1 = [x for x in features_importance[method_1].tolist() if x is not None]
        list_2 = [x for x in features_importance[method_2].tolist() if x is not None]
        # Ensure both lists are the same length for RBO calculation
        min_len = min(len(list_1), len(list_2))
        list_1_trimmed = list_1[:min_len]
        list_2_trimmed = list_2[:min_len]
        rbo_score = rbo.RankingSimilarity(list_1_trimmed, list_2_trimmed).rbo(p=0.8, k=10)
        rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
            'Method_1': [method_1],
            'Method_2': [method_2],
            'RBO_Score': [rbo_score]
        })], ignore_index=True)
rbo_comparison.sort_values(by='RBO_Score', ascending=False, inplace=True)
rbo_comparison
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4828\646247094.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rbo_comparison = pd.concat([rbo_comparison, pd.DataFrame({
#      Method_1     Method_2  RBO_Score
# 7  LRC_Seed_0   LRC_Seed_1   0.779999
# 8  LRC_Seed_0  LRC_Seed_42   0.665242
# 9  LRC_Seed_1  LRC_Seed_42   0.603655
# 1         Vip   LRC_Seed_0   0.395146
# 4    Reg_coef   LRC_Seed_0   0.394111
# 3         Vip  LRC_Seed_42   0.382414
# 2         Vip   LRC_Seed_1   0.378685
# 6    Reg_coef  LRC_Seed_42   0.375699
# 0         Vip     Reg_coef   0.303188
# 5    Reg_coef   LRC_Seed_1   0.290456
